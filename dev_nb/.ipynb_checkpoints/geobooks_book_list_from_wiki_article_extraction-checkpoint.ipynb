# %%
from langchain_community.llms import Ollama

# %%
import wikipediaapi

# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

# %%
import json
import time

# %%
import os

# %% [markdown]
# ### Try Historical Novels Page
#
# https://en.wikipedia.org/wiki/List_of_historical_novels
#
#
# TODONE:
#
# * created semantic filter class!
# * pipelined the whole thing all the way out to generating books
#
#
# TODO:
#
# * need pipeline verification cuz there are some real authors in there...; try jay's idea of just the first 10 words or so? Frank Yerby and Joseph Henry Shorthouse two examples
# * also we still haven't incorporated check results into a pipeline...might want a pipeline class that shows you each aspect of the pipeline. the part we need to include is to add the check quality class and create a csv, then write that csv. the csv will be what our front end ingests for geodisplay. might want some other tertiary stuff like getting lat lons for the city country pairs?  anyways, include it so you don't lose that part of the pipeline!

# %%
os.path.exists('filtered_pages.json')
# Out:
# True

# %%
os.path.exists('data/whn_pages/' + 'filtered_pages_final.json')  # means self.filter_pages() ran
# Out:
# True

# %%
class FetchWikiHNPages:
    """
    Going to get a nice clean set of book pages from this website: https://en.wikipedia.org/wiki/List_of_historical_novels
    """

    def __init__(self, root_page="List_of_historical_novels", data_dir='data/whn_pages/'):
        self.llm = Ollama(model="llama3")
        self.wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')
        self.root_page = self.wiki.page(root_page)
        self.data_dir = data_dir

    def triple_filter_short_pipeline(self):
        """
        temp pipeline to get triple filtering running
        TODO: merge with run_full_pipeline
        note: inefficient because we're better off just running the pages we already single filtered
        """

        self.load_filtered_and_unfiltered_pages()
        self.triple_filter_pages()

    def run_full_pipeline(self, mode='continue'):
        """

        runs full pipeline
        TODO: write this so that we can tell where we are and if we failed jobs. Wherever state of completion we are when
        we have the list, we start from there and keep going. there could also be a setting for delete current records and start from
        scratch. So if we already have a filtered_pages_final.json just use that. that would look like:


        mode: takes on vals 'continue' to continue from last known point or 'overwrite' if we want to start from the beginning
        """

        if mode == 'continue':
            # use existence of files written during process to determine where we left off
            if os.path.exists(self.data_dir + 'filtered_pages_final.json'):  # means self.filter_pages() ran
                print('final page list already exists--loading...')
                with open(self.data_dir + 'filtered_pages_final.json', "r") as f:
                    self.filtered_pages = json.load(f)

            # elif os.path.exists(
                #    self.data_dir + 'filtered_pages_cache.json'):  # means self.filter_pages ran but did not complete...
                # hard case...because there are some edge cases, but let's right a solution that updates with cached results and continues
                # not really adequate because for instance filtered_pages_cache might update but unfiltered_pages_cache might not, in same loop
                # meaning they would be mismatched
                # actually...let's just leave this case for another day, I want to move on to generating actual data rather than writing endless cases

            # replace / reformat this elif and below with load_filtered_and_unfiltered_pages
            # note the get_unfiltered_pages() in the else is included in load_filtered_and_unfiltered_pages()
            elif os.path.exists(self.data_dir + 'filtered_pages.json'):  # means self.reduce_pages() ran
                with open(self.data_dir + "unfiltered_pages.json", "r") as f:
                    self.unfiltered_pages = json.load(f)
                with open(self.data_dir + "filtered_pages.json", "r") as f:
                    self.filtered_pages = json.load(f)
                self.filter_pages()
            else:

                self.get_unfiltered_pages()
                self.reduce_pages()
                self.filter_pages()

        elif mode == 'overwrite':

            self.get_unfiltered_pages()
            self.reduce_pages()
            self.filter_pages()

    def load_filtered_and_unfiltered_pages(self):

        if os.path.exists(self.data_dir + 'filtered_pages.json'):  # means self.reduce_pages() ran
            with open(self.data_dir + "unfiltered_pages.json", "r") as f:
                self.unfiltered_pages = json.load(f)
            with open(self.data_dir + "filtered_pages.json", "r") as f:
                self.filtered_pages = json.load(f)  

        else:
            self.get_unfiltered_pages()
            self.reduce_pages()

    def get_unfiltered_pages(self):
        """
        Queries pages from hns site and does a validity check
        """
        print('started querying unfiltered pages at ' + time.ctime())

        root_links = self.root_page.links  # gets a dictionary whose keys are all the linked pages, potentially including red links though
        self.unfiltered_pages = list(root_links.keys())

        self.unfiltered_pages = [pg for pg in self.unfiltered_pages if self.wiki.page(pg).exists()]
        self.filtered_pages = []
        print('ended querying unfiltered pages at ' + time.ctime())

    def reduce_pages(self):
        """
        We want to limit the number of API calls we'll make, so let's move any pages with novel in the title over to our filtered list.
        This isn't robust to all possible edge cases but looks good for the actual list we're dealing with here (based on direct inspection).
        """

        # manually parsed suffixes that identify whether a wiki page in our list is a novel or a non-novel
        novel_title_suffix_list = ['novel', 'historical novel', 'book', 'Uris novel', 'Seton novel', '1962 novel',
                                   'Prus novel', 'novel series', 'Foote novel', 'Gann novel', 'Mario Puzo novel',
                                   'Spanish novel', 'Sutcliff novel', 'Scott novel', 'Penman novel']
        not_novel_title_suffix_list = ['journalist', 'author', 'novelist', 'writer', 'abolitionist', 'World War II',
                                       'consul 218 BC', 'fictional character', '535-554', '1919–1922', '410',
                                       'Third Punic War', 'Polish history']
        novels_by_wiki_title = [pg for pg in self.unfiltered_pages if
                                pg.rstrip(')').split('(')[-1] in novel_title_suffix_list]
        not_novels_by_wiki_title = [pg for pg in self.unfiltered_pages if
                                    pg.rstrip(')').split('(')[-1] in not_novel_title_suffix_list]

        self.unfiltered_pages = list(
            set(self.unfiltered_pages) - set(novels_by_wiki_title) - set(not_novels_by_wiki_title))
        self.filtered_pages.extend(novels_by_wiki_title)

        # write results of this stage of pipeline
        with open(self.data_dir + "unfiltered_pages.json", "w") as f:
            json.dump(self.unfiltered_pages, f)
        with open(self.data_dir + "filtered_pages.json", "w") as f:
            json.dump(self.filtered_pages, f)

    def filter_pages(self):
        """
        Checks that a page exists and that it's the page for an actual author
        """
        print('started filtering pages at ' + time.ctime())

        self.unfiltered_pages_class_dict = {}  # just as a backup, record the llm-generated class in a dict
        self.unfiltered_remaining = self.unfiltered_pages.copy()
        for pg in self.unfiltered_pages:
            self.wc = WikiClassify(w_page=pg)
            print('filtering page:  ' + str(pg) + ' at ' + time.ctime())

            self.wc.classify_page_by_summary()
            self.unfiltered_pages_class_dict[pg] = self.wc.parsed_json['class']
            if self.wc.parsed_json['class'] == 'book':
                self.filtered_pages.append(pg)
                with open(self.data_dir + "filtered_pages_cache.json", "w") as f:
                    json.dump(self.filtered_pages, f)

                self.unfiltered_remaining.remove(pg)
                with open(self.data_dir + "unfiltered_pages_cache.json", "w") as f:
                    json.dump(self.unfiltered_remaining, f)

        with open(self.data_dir + "filtered_pages_final.json", "w") as f:
            json.dump(self.filtered_pages, f)


    def triple_filter_pages(self):
        """
        Checks that a page exists and that it's the page for an actual author
        Uses three filters: classifying the summary page, classifying the text up to the first period, and up to the first comma.
        We use a triple filter because we saw that just classifying based on the summary text yielded too much misclassification
        Instead, just pass through pages that are classified as books by all three 
        """
        print('started filtering pages at ' + time.ctime())
        ## TODO: need to manage self.filtered_pages and self.unfiltered_pages and connect it to pipeline
        self.triple_filter_results = {}
        for pg in self.unfiltered_pages:
            self.wc = WikiClassify(w_page=pg)
            print('filtering page:  ' + str(pg) + ' at ' + time.ctime())

            self.wc.classify_page_by_summary()
            first_pass = self.wc.parsed_json['class']

            self.wc.classify_page_to_first_period()
            second_pass = self.wc.parsed_json['class']

            self.wc.classify_page_to_first_comma()
            third_pass = self.wc.parsed_json['class']

            self.triple_filter_results[pg] = {'first_pass': first_pass, 'second_pass':second_pass, 'third_pass':third_pass}

            if (first_pass=='book') & (second_pass=='book') & (third_pass=='book'):
                self.filtered_pages.append(pg)


        with open(self.data_dir + "triple_filtered_pages.json", "w") as f:
            json.dump(self.filtered_pages, f)

        with open(self.data_dir + "triple_filtered_pages_verbose.json", "w") as f:
            json.dump(self.triple_filter_results, f)

# %%
hnp = FetchWikiHNPages()
hnp.triple_filter_short_pipeline()
# Out:
# started filtering pages at Tue Jul  2 17:32:53 2024
# filtering page:  The Stronghold at Tue Jul  2 17:32:54 2024

# %%
tdict = {}

x = 'hi'
y = 'bye'

tdict[x] = y

# %%
tdict
# Out:
# {'hi': 'bye'}

# %%
with open("dummy.json", "w") as f:
    json.dump(tdict, f)

# %%
hnp = FetchWikiHNPages()
hnp.run_full_pipeline()
# Out:
# started filtering pages at Tue Jul  2 15:57:19 2024
# filtering page:  The Stronghold at Tue Jul  2 15:57:19 2024
# filtering page:  American Civil War at Tue Jul  2 15:57:33 2024
# filtering page:  Operation Wrath of God at Tue Jul  2 15:57:45 2024
# filtering page:  Reconquista at Tue Jul  2 15:57:51 2024
# filtering page:  Charles Frazier at Tue Jul  2 15:58:01 2024
# filtering page:  Victor Hugo at Tue Jul  2 15:58:06 2024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[412], line 2
#       1 hnp = FetchWikiHNPages()
# ----> 2 hnp.run_full_pipeline()
#
# Cell In[411], line 43, in FetchWikiHNPages.run_full_pipeline(self, mode)
#      41     with open(self.data_dir + "filtered_pages.json", "r") as f:
#      42         self.filtered_pages = json.load(f)
# ---> 43     self.filter_pages()
#      44 else:
#      46     self.get_unfiltered_pages()
#
# Cell In[411], line 109, in FetchWikiHNPages.filter_pages(self)
#     106 self.wc = WikiClassify(w_page=pg)
#     107 print('filtering page:  ' + str(pg) + ' at ' + time.ctime())
# --> 109 self.wc.classify_page_by_summary()
#     110 self.unfiltered_pages_class_dict[pg] = self.wc.parsed_json['class']
#     111 if self.wc.parsed_json['class'] == 'book':
#
# Cell In[394], line 25, in WikiClassify.classify_page_by_summary(self)
#      24 def classify_page_by_summary(self):
# ---> 25     self.classify_page_by_w_text(w_text = self.w_summary)
#
# Cell In[394], line 65, in WikiClassify.classify_page_by_w_text(self, w_text)
#      36 prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
#      37 Do not output anything other than the JSON.\
#      38 First, determine if the wikipedia page is a page for an author, a book, or something else.\
#    (...)
#      46 \
#      47 Here is the text from the wikipedia article for this book: "
#      51 end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
#      52 Do not output anything other than the JSON.\
#      53 First, determine if the wikipedia page is a page for an author, a book, or something else.\
#    (...)
#      61 Finally, surround your JSON output with <result></result> tags.\
#      62 The three allowable outputs are: "
# ---> 65 self.llm_response = self.llm(prompt + w_text + end_prompt + output1 + "or " + output2 + "or " + output3)
#      66 self.parse_response()
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/language_models/llms.py:1086, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1079 if not isinstance(prompt, str):
#    1080     raise ValueError(
#    1081         "Argument `prompt` is expected to be a string. Instead found "
#    1082         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#    1083         "`generate` instead."
#    1084     )
#    1085 return (
# -> 1086     self.generate(
#    1087         [prompt],
#    1088         stop=stop,
#    1089         callbacks=callbacks,
#    1090         tags=tags,
#    1091         metadata=metadata,
#    1092         **kwargs,
#    1093     )
#    1094     .generations[0][0]
#    1095     .text
#    1096 )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/language_models/llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/language_models/llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/language_models/llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_community/llms/ollama.py:417, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     415 generations = []
#     416 for prompt in prompts:
# --> 417     final_chunk = super()._stream_with_aggregation(
#     418         prompt,
#     419         stop=stop,
#     420         images=images,
#     421         run_manager=run_manager,
#     422         verbose=self.verbose,
#     423         **kwargs,
#     424     )
#     425     generations.append([final_chunk])
#     426 return LLMResult(generations=generations)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_community/llms/ollama.py:326, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     317 def _stream_with_aggregation(
#     318     self,
#     319     prompt: str,
#    (...)
#     323     **kwargs: Any,
#     324 ) -> GenerationChunk:
#     325     final_chunk: Optional[GenerationChunk] = None
# --> 326     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     327         if stream_resp:
#     328             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_community/llms/ollama.py:172, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     164 def _create_generate_stream(
#     165     self,
#     166     prompt: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> Iterator[str]:
#     171     payload = {"prompt": prompt, "images": images}
# --> 172     yield from self._create_stream(
#     173         payload=payload,
#     174         stop=stop,
#     175         api_url=f"{self.base_url}/api/generate",
#     176         **kwargs,
#     177     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_community/llms/ollama.py:231, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     224 else:
#     225     request_payload = {
#     226         "prompt": payload.get("prompt"),
#     227         "images": payload.get("images", []),
#     228         **params,
#     229     }
# --> 231 response = requests.post(
#     232     url=api_url,
#     233     headers={
#     234         "Content-Type": "application/json",
#     235         **(self.headers if isinstance(self.headers, dict) else {}),
#     236     },
#     237     json=request_payload,
#     238     stream=True,
#     239     timeout=self.timeout,
#     240 )
#     241 response.encoding = "utf-8"
#     242 if response.status_code != 200:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1345, in HTTPConnection.getresponse(self)
#    1343 try:
#    1344     try:
# -> 1345         response.begin()
#    1346     except ConnectionError:
#    1347         self.close()
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
hnp = FetchWikiHNPages()
hnp.run_full_pipeline()
# Out:
# started filtering pages at Tue Jun 25 21:52:16 2024
# filtering page:  The Stronghold at Tue Jun 25 21:52:16 2024
# filtering page:  American Civil War at Tue Jun 25 21:52:22 2024
# filtering page:  Operation Wrath of God at Tue Jun 25 21:52:35 2024
# filtering page:  Reconquista at Tue Jun 25 21:52:40 2024
# filtering page:  Charles Frazier at Tue Jun 25 21:52:50 2024
# filtering page:  Victor Hugo at Tue Jun 25 21:52:55 2024
# filtering page:  The Siege of Krishnapur at Tue Jun 25 21:53:02 2024
# filtering page:  The Glory at Tue Jun 25 21:53:08 2024
# filtering page:  Nellie Campobello at Tue Jun 25 21:53:11 2024
# filtering page:  Socrates at Tue Jun 25 21:53:17 2024
# filtering page:  Valerio Massimo Manfredi at Tue Jun 25 21:53:25 2024
# filtering page:  Edward P. Jones at Tue Jun 25 21:53:29 2024
# filtering page:  Sacred Hunger at Tue Jun 25 21:53:33 2024
# filtering page:  The Heart of Jade at Tue Jun 25 21:53:38 2024
# filtering page:  Tai-Pan at Tue Jun 25 21:53:43 2024
# filtering page:  Oldest Living Confederate Widow Tells All at Tue Jun 25 21:53:47 2024
# filtering page:  James Clavell at Tue Jun 25 21:53:52 2024
# filtering page:  La Celestina at Tue Jun 25 21:53:57 2024
# filtering page:  Miguel de Cervantes Saavedra at Tue Jun 25 21:54:04 2024
# filtering page:  Mutiny of Aranjuez at Tue Jun 25 21:54:11 2024
# filtering page:  A fekete város at Tue Jun 25 21:54:16 2024
# filtering page:  Toussaint Louverture at Tue Jun 25 21:54:21 2024
# filtering page:  The Miniaturist at Tue Jun 25 21:54:31 2024
# filtering page:  Nero at Tue Jun 25 21:54:36 2024
# filtering page:  Inside, Outside at Tue Jun 25 21:54:46 2024
# filtering page:  Polish–Lithuanian Commonwealth at Tue Jun 25 21:54:51 2024
# filtering page:  World War I at Tue Jun 25 21:55:00 2024
# filtering page:  On Heroes and Tombs at Tue Jun 25 21:55:11 2024
# filtering page:  Robert Lewis Taylor at Tue Jun 25 21:55:15 2024
# filtering page:  Andersonville National Historic Site at Tue Jun 25 21:55:19 2024
# filtering page:  Anandamath at Tue Jun 25 21:55:25 2024
# filtering page:  Viswanatha Satyanarayana at Tue Jun 25 21:55:29 2024
# filtering page:  Johnny Tremain at Tue Jun 25 21:55:36 2024
# filtering page:  Morgan Llywelyn at Tue Jun 25 21:55:41 2024
# filtering page:  Lope de Aguirre at Tue Jun 25 21:55:46 2024
# filtering page:  Charles I of England at Tue Jun 25 21:55:52 2024
# filtering page:  Allan Gurganus at Tue Jun 25 21:56:01 2024
# filtering page:  World Without End (Follett novel) at Tue Jun 25 21:56:05 2024
# filtering page:  Walter Scott at Tue Jun 25 21:56:11 2024
# filtering page:  King Solomon's Mines at Tue Jun 25 21:56:18 2024
# filtering page:  Razia Butt at Tue Jun 25 21:56:23 2024
# filtering page:  The Eagle of the Ninth at Tue Jun 25 21:56:27 2024
# filtering page:  Gisbert Haefs at Tue Jun 25 21:56:31 2024
# filtering page:  The Jade Peony at Tue Jun 25 21:56:36 2024
# filtering page:  An Angel in Australia at Tue Jun 25 21:56:42 2024
# filtering page:  Jean Plaidy at Tue Jun 25 21:56:45 2024
# filtering page:  Ramón J. Sender at Tue Jun 25 21:56:51 2024
# filtering page:  Walter Macken at Tue Jun 25 21:56:56 2024
# filtering page:  Carlisle Indian Industrial School at Tue Jun 25 21:57:00 2024
# filtering page:  Pramoedya Ananta Toer at Tue Jun 25 21:57:05 2024
# filtering page:  A Dying Light in Corduba at Tue Jun 25 21:57:12 2024
# filtering page:  Ibis trilogy at Tue Jun 25 21:57:17 2024
# filtering page:  Rosemary Sutcliff at Tue Jun 25 21:57:22 2024
# filtering page:  The End of a Brave Man at Tue Jun 25 21:57:27 2024
# filtering page:  The War of the End of the World at Tue Jun 25 21:57:32 2024
# filtering page:  James Patterson at Tue Jun 25 21:57:36 2024
# filtering page:  Napoleon at Tue Jun 25 21:57:42 2024
# filtering page:  Peter Tremayne at Tue Jun 25 21:57:55 2024
# filtering page:  The Faithful River at Tue Jun 25 21:57:59 2024
# filtering page:  Gautama Buddha at Tue Jun 25 21:58:04 2024
# filtering page:  Chesapeake Bay at Tue Jun 25 21:58:12 2024
# filtering page:  The Silent People at Tue Jun 25 21:58:22 2024
# filtering page:  Sharon Kay Penman at Tue Jun 25 21:58:26 2024
# filtering page:  The Count of Monte Cristo at Tue Jun 25 21:58:32 2024
# filtering page:  The Known World at Tue Jun 25 21:58:39 2024
# filtering page:  Mazo de la Roche at Tue Jun 25 21:58:44 2024
# filtering page:  Iracema at Tue Jun 25 21:58:48 2024
# filtering page:  Corinth at Tue Jun 25 21:58:52 2024
# filtering page:  Glorious Revolution at Tue Jun 25 21:58:57 2024
# filtering page:  Antebellum era at Tue Jun 25 21:59:05 2024
# filtering page:  Bernardo de Gálvez at Tue Jun 25 21:59:11 2024
# filtering page:  Ferdinand I of León at Tue Jun 25 21:59:18 2024
# filtering page:  Robert E. Lee at Tue Jun 25 21:59:24 2024
# filtering page:  Jorge Manrique at Tue Jun 25 21:59:34 2024
# filtering page:  Edgar Watson at Tue Jun 25 21:59:40 2024
# filtering page:  Durgeshnandini at Tue Jun 25 21:59:45 2024
# filtering page:  Ceara at Tue Jun 25 21:59:51 2024
# filtering page:  Frank Yerby at Tue Jun 25 21:59:58 2024
# filtering page:  Graham Greene at Tue Jun 25 22:00:02 2024
# filtering page:  Cantabri at Tue Jun 25 22:00:08 2024
# filtering page:  Micah Clarke at Tue Jun 25 22:00:12 2024
# filtering page:  Caratacus at Tue Jun 25 22:00:19 2024
# filtering page:  Seven Years' War at Tue Jun 25 22:00:25 2024
# filtering page:  American Revolution at Tue Jun 25 22:00:32 2024
# filtering page:  Alias Grace at Tue Jun 25 22:00:43 2024
# filtering page:  Alex Rutherford at Tue Jun 25 22:00:50 2024
# filtering page:  Trajan at Tue Jun 25 22:00:56 2024
# filtering page:  Russian Civil War at Tue Jun 25 22:01:04 2024
# filtering page:  The Black Coat at Tue Jun 25 22:01:15 2024
# filtering page:  Margaret Mitchell at Tue Jun 25 22:01:21 2024
# filtering page:  D'Artagnan romances at Tue Jun 25 22:01:26 2024
# filtering page:  Kublai Khan at Tue Jun 25 22:01:31 2024
# filtering page:  Lion of Ireland at Tue Jun 25 22:01:38 2024
# filtering page:  Roddy Doyle at Tue Jun 25 22:01:42 2024
# filtering page:  Sivagamiyin Sabadham at Tue Jun 25 22:01:47 2024
# filtering page:  The Luck of Barry Lyndon at Tue Jun 25 22:01:53 2024
# filtering page:  Historical novel at Tue Jun 25 22:01:58 2024
# filtering page:  Michael Ondaatje at Tue Jun 25 22:02:05 2024
# filtering page:  Dutch colonialism in Southeast Asia at Tue Jun 25 22:02:10 2024
# filtering page:  Thomas Keneally at Tue Jun 25 22:02:19 2024
# filtering page:  Max Havelaar at Tue Jun 25 22:02:23 2024
# filtering page:  Parthiban Kanavu at Tue Jun 25 22:02:29 2024
# filtering page:  Vasily Grossman at Tue Jun 25 22:02:33 2024
# filtering page:  Spanish Armada at Tue Jun 25 22:02:41 2024
# filtering page:  Proselytism at Tue Jun 25 22:02:48 2024
# filtering page:  Duchy of Savoy at Tue Jun 25 22:02:53 2024
# filtering page:  Amsterdam at Tue Jun 25 22:02:59 2024
# filtering page:  Multatuli at Tue Jun 25 22:03:09 2024
# filtering page:  Edward Rutherfurd at Tue Jun 25 22:03:14 2024
# filtering page:  Ferdinand Magellan at Tue Jun 25 22:03:18 2024
# filtering page:  Qin Shi Huang at Tue Jun 25 22:03:27 2024
# filtering page:  Andrei Bely at Tue Jun 25 22:03:35 2024
# filtering page:  Alejandro Núñez Alonso at Tue Jun 25 22:03:42 2024
# filtering page:  Twentieth Dynasty at Tue Jun 25 22:03:46 2024
# filtering page:  Madison Smartt Bell at Tue Jun 25 22:03:51 2024
# filtering page:  Margaret Forster at Tue Jun 25 22:03:55 2024
# filtering page:  Eva Perón at Tue Jun 25 22:04:00 2024
# filtering page:  Guelphs and Ghibellines at Tue Jun 25 22:04:09 2024
# filtering page:  The Mask of Apollo at Tue Jun 25 22:04:14 2024
# filtering page:  Robert Graves at Tue Jun 25 22:04:19 2024
# filtering page:  Akilan at Tue Jun 25 22:04:25 2024
# filtering page:  Jeffrey Eugenides at Tue Jun 25 22:04:30 2024
# filtering page:  The Name of the Rose at Tue Jun 25 22:04:35 2024
# filtering page:  War and Peace at Tue Jun 25 22:04:40 2024
# filtering page:  Os Sertões at Tue Jun 25 22:04:47 2024
# filtering page:  Juan Prim, 1st Marquis of los Castillejos at Tue Jun 25 22:04:52 2024
# filtering page:  Siege of Saragossa (1808) at Tue Jun 25 22:04:57 2024
# filtering page:  Amita Kanekar at Tue Jun 25 22:05:01 2024
# filtering page:  German Peasants' War at Tue Jun 25 22:05:06 2024
# filtering page:  Nicholas Hawksmoor at Tue Jun 25 22:05:14 2024
# filtering page:  Alfred the Great at Tue Jun 25 22:05:19 2024
# filtering page:  Angus Donald at Tue Jun 25 22:05:26 2024
# filtering page:  The Journeyer at Tue Jun 25 22:05:30 2024
# filtering page:  Amitav Ghosh at Tue Jun 25 22:05:34 2024
# filtering page:  Aleksander Kamiński at Tue Jun 25 22:05:40 2024
# filtering page:  Blood Red, Snow White at Tue Jun 25 22:05:46 2024
# filtering page:  Philip IV of Spain at Tue Jun 25 22:05:50 2024
# filtering page:  Julie Myerson at Tue Jun 25 22:05:56 2024
# filtering page:  José Saramago at Tue Jun 25 22:06:00 2024
# filtering page:  Salman Rushdie at Tue Jun 25 22:06:07 2024
# filtering page:  A Journal of the Plague Year at Tue Jun 25 22:06:15 2024
# filtering page:  Eduardo Mendoza Garriga at Tue Jun 25 22:06:22 2024
# filtering page:  Jovita González at Tue Jun 25 22:06:26 2024
# filtering page:  J. G. Farrell at Tue Jun 25 22:06:30 2024
# filtering page:  Lanny Budd at Tue Jun 25 22:06:35 2024
# filtering page:  Yoshida Kenkō at Tue Jun 25 22:06:44 2024
# filtering page:  Cynthia Harnett at Tue Jun 25 22:06:48 2024
# filtering page:  Euclides da Cunha at Tue Jun 25 22:06:53 2024
# filtering page:  Tales of Count Lucanor at Tue Jun 25 22:06:59 2024
# filtering page:  F. Sionil José at Tue Jun 25 22:07:04 2024
# filtering page:  Wallace Breem at Tue Jun 25 22:07:09 2024
# filtering page:  Bring Larks and Heroes at Tue Jun 25 22:07:13 2024
# filtering page:  Pallava dynasty at Tue Jun 25 22:07:17 2024
# filtering page:  Marcus Sedgwick at Tue Jun 25 22:07:24 2024
# filtering page:  El filibusterismo at Tue Jun 25 22:07:29 2024
# filtering page:  Richard Carvel at Tue Jun 25 22:07:37 2024
# filtering page:  The Red Badge of Courage at Tue Jun 25 22:07:42 2024
# filtering page:  Great Plague of London at Tue Jun 25 22:07:50 2024
# filtering page:  Persecution of early Christians by the Romans at Tue Jun 25 22:07:55 2024
# filtering page:  Daniel Kehlmann at Tue Jun 25 22:08:03 2024
# filtering page:  Australian gold rushes at Tue Jun 25 22:08:11 2024
# filtering page:  The House of Niccolò at Tue Jun 25 22:08:16 2024
# filtering page:  Johannes Vermeer at Tue Jun 25 22:08:22 2024
# filtering page:  Salvatierra Castle at Tue Jun 25 22:08:29 2024
# filtering page:  Alfonso VIII of Castile at Tue Jun 25 22:08:33 2024
# filtering page:  Gordon riots at Tue Jun 25 22:08:39 2024
# filtering page:  Risorgimento at Tue Jun 25 22:08:46 2024
# filtering page:  Theodosius I at Tue Jun 25 22:08:54 2024
# filtering page:  Don Quixote at Tue Jun 25 22:09:05 2024
# filtering page:  The Forest House at Tue Jun 25 22:09:12 2024
# filtering page:  Outlander (book series) at Tue Jun 25 22:09:17 2024
# filtering page:  Upton Sinclair at Tue Jun 25 22:09:22 2024
# filtering page:  Cloudsplitter at Tue Jun 25 22:09:31 2024
# filtering page:  Robert Musil at Tue Jun 25 22:09:37 2024
# filtering page:  Iberia at Tue Jun 25 22:09:41 2024
# filtering page:  Rajendra Chola I at Tue Jun 25 22:09:47 2024
# filtering page:  Eleanor of Austria at Tue Jun 25 22:09:58 2024
# filtering page:  Gonzalo Guerrero at Tue Jun 25 22:10:03 2024
# filtering page:  Khmelnytsky Uprising at Tue Jun 25 22:10:08 2024
# filtering page:  This Earth of Mankind at Tue Jun 25 22:10:16 2024
# filtering page:  Atlantic slave trade at Tue Jun 25 22:10:23 2024
# filtering page:  Vespasian at Tue Jun 25 22:10:34 2024
# filtering page:  Brian Cleeve at Tue Jun 25 22:10:42 2024
# filtering page:  Mario Puzo at Tue Jun 25 22:10:47 2024
# filtering page:  Lawrence Hill at Tue Jun 25 22:10:52 2024
# filtering page:  Mary Renault at Tue Jun 25 22:10:58 2024
# filtering page:  A Spoke in the Wheel at Tue Jun 25 22:11:04 2024
# filtering page:  Horatio Hornblower at Tue Jun 25 22:11:08 2024
# filtering page:  James Conroyd Martin at Tue Jun 25 22:11:14 2024
# filtering page:  Midnight's Children at Tue Jun 25 22:11:18 2024
# filtering page:  Hunger's Brides at Tue Jun 25 22:11:23 2024
# filtering page:  Monmouth Rebellion at Tue Jun 25 22:11:28 2024
# filtering page:  Colonial Brazil at Tue Jun 25 22:11:35 2024
# filtering page:  Lymond Chronicles at Tue Jun 25 22:11:43 2024
# filtering page:  Themistocles at Tue Jun 25 22:11:48 2024
# filtering page:  Naseem Hijazi at Tue Jun 25 22:11:58 2024
# filtering page:  Anak Semua Bangsa at Tue Jun 25 22:12:02 2024
# filtering page:  Ninety-Three at Tue Jun 25 22:12:10 2024
# filtering page:  La Malinche at Tue Jun 25 22:12:15 2024
# filtering page:  Valladolid at Tue Jun 25 22:12:21 2024
# filtering page:  Fortunata y Jacinta at Tue Jun 25 22:12:29 2024
# filtering page:  The Emigrants (novels) at Tue Jun 25 22:12:34 2024
# filtering page:  Willa Cather at Tue Jun 25 22:12:39 2024
# filtering page:  John of Austria at Tue Jun 25 22:12:46 2024
# filtering page:  Wu Zetian at Tue Jun 25 22:12:51 2024
# filtering page:  Punic Wars at Tue Jun 25 22:13:05 2024
# filtering page:  Nandshankar Mehta at Tue Jun 25 22:13:14 2024
# filtering page:  Thaddeus of Warsaw at Tue Jun 25 22:13:18 2024
# filtering page:  Ben-Hur: A Tale of the Christ at Tue Jun 25 22:13:22 2024
# filtering page:  Leo Tolstoy at Tue Jun 25 22:13:29 2024
# filtering page:  The Man Without Qualities at Tue Jun 25 22:13:38 2024
# filtering page:  Isabel San Sebastián at Tue Jun 25 22:13:43 2024
# filtering page:  Sheikh Mujibur Rahman at Tue Jun 25 22:13:47 2024
# filtering page:  Bertrand du Guesclin at Tue Jun 25 22:13:59 2024
# filtering page:  Chanakya's Chant at Tue Jun 25 22:14:04 2024
# filtering page:  The Last Kabbalist of Lisbon at Tue Jun 25 22:14:09 2024
# filtering page:  List of historical novels in Indian languages at Tue Jun 25 22:14:13 2024
# filtering page:  Empress Dowager Cixi at Tue Jun 25 22:14:17 2024
# filtering page:  Spanish conquest of the Inca Empire at Tue Jun 25 22:14:27 2024
# filtering page:  John Cowper Powys at Tue Jun 25 22:14:41 2024
# filtering page:  Érico Veríssimo at Tue Jun 25 22:14:48 2024
# filtering page:  Salem witch trials at Tue Jun 25 22:14:52 2024
# filtering page:  Alta California at Tue Jun 25 22:15:00 2024
# filtering page:  Island Beneath the Sea at Tue Jun 25 22:15:07 2024
# filtering page:  Abd-ar-Rahman III at Tue Jun 25 22:15:12 2024
# filtering page:  Angelo F. Coniglio at Tue Jun 25 22:15:18 2024
# filtering page:  Henry VII of England at Tue Jun 25 22:15:29 2024
# filtering page:  Rumah Kaca at Tue Jun 25 22:15:37 2024
# filtering page:  Salisbury at Tue Jun 25 22:15:42 2024
# filtering page:  The Last of the Mohicans at Tue Jun 25 22:15:48 2024
# filtering page:  Sigrid Undset at Tue Jun 25 22:15:55 2024
# filtering page:  Fernando Fernán-Gómez at Tue Jun 25 22:16:01 2024
# filtering page:  Gonzalo Fernández de Córdoba at Tue Jun 25 22:16:09 2024
# filtering page:  Marion Zimmer Bradley at Tue Jun 25 22:16:15 2024
# filtering page:  The Roman Mysteries at Tue Jun 25 22:16:22 2024
# filtering page:  Morgan's Run at Tue Jun 25 22:16:27 2024
# filtering page:  Loaísa expedition at Tue Jun 25 22:16:31 2024
# filtering page:  Numantia at Tue Jun 25 22:16:36 2024
# filtering page:  Perkin Warbeck at Tue Jun 25 22:16:41 2024
# filtering page:  Eiji Yoshikawa at Tue Jun 25 22:16:48 2024
# filtering page:  Ponniyin Selvan at Tue Jun 25 22:16:53 2024
# filtering page:  Scouting at Tue Jun 25 22:17:00 2024
# filtering page:  Vilhelm Moberg at Tue Jun 25 22:17:07 2024
# filtering page:  Alejo Carpentier at Tue Jun 25 22:17:14 2024
# filtering page:  Juan Sebastián Elcano at Tue Jun 25 22:17:24 2024
# filtering page:  Vancouver at Tue Jun 25 22:17:30 2024
# filtering page:  Lady of the Glen at Tue Jun 25 22:17:40 2024
# filtering page:  Hades' Daughter at Tue Jun 25 22:17:45 2024
# filtering page:  Joseph Henry Shorthouse at Tue Jun 25 22:17:49 2024
# filtering page:  Fall of Constantinople at Tue Jun 25 22:17:54 2024
# filtering page:  Markus Zusak at Tue Jun 25 22:18:01 2024
# filtering page:  The Warsaw Anagrams at Tue Jun 25 22:18:05 2024
# filtering page:  Julia Alvarez at Tue Jun 25 22:18:11 2024
# filtering page:  The Master of Hestviken at Tue Jun 25 22:18:18 2024
# filtering page:  Leopoldo Alas at Tue Jun 25 22:18:25 2024
# filtering page:  Ay (pharaoh) at Tue Jun 25 22:18:29 2024
# filtering page:  Prehistoric Britain at Tue Jun 25 22:18:34 2024
# filtering page:  Texas Revolution at Tue Jun 25 22:18:45 2024
# filtering page:  Tutankhamun at Tue Jun 25 22:18:56 2024
# filtering page:  Grail Prince at Tue Jun 25 22:19:06 2024
# filtering page:  Death Comes for the Archbishop at Tue Jun 25 22:19:10 2024
# filtering page:  Les Rois maudits at Tue Jun 25 22:19:14 2024
# filtering page:  Teutonic Knights at Tue Jun 25 22:19:19 2024
# filtering page:  Kate Grenville at Tue Jun 25 22:19:25 2024
# filtering page:  David Liss at Tue Jun 25 22:19:30 2024
# filtering page:  Captain Alatriste at Tue Jun 25 22:19:36 2024
# filtering page:  Baltasar and Blimunda at Tue Jun 25 22:19:41 2024
# filtering page:  Kamienie na szaniec at Tue Jun 25 22:19:46 2024
# filtering page:  Hernando de Soto at Tue Jun 25 22:19:51 2024
# filtering page:  Mérida, Spain at Tue Jun 25 22:19:57 2024
# filtering page:  Jonathan Coe at Tue Jun 25 22:20:04 2024
# filtering page:  Christopher Columbus at Tue Jun 25 22:20:09 2024
# filtering page:  The Last Crossing at Tue Jun 25 22:20:20 2024
# filtering page:  Ignacio del Valle at Tue Jun 25 22:20:24 2024
# filtering page:  Colleen McCullough at Tue Jun 25 22:20:28 2024
# filtering page:  James Douglas, Lord of Douglas at Tue Jun 25 22:20:33 2024
# filtering page:  Theban hegemony at Tue Jun 25 22:20:37 2024
# filtering page:  José de Espronceda at Tue Jun 25 22:20:48 2024
# filtering page:  Sarah Waters at Tue Jun 25 22:20:52 2024
# filtering page:  Anne of Geierstein at Tue Jun 25 22:20:56 2024
# filtering page:  Simon Scarrow at Tue Jun 25 22:21:01 2024
# filtering page:  Israeli Declaration of Independence at Tue Jun 25 22:21:07 2024
# filtering page:  Karen Maitland at Tue Jun 25 22:21:12 2024
# filtering page:  Vengeance (Jonas book) at Tue Jun 25 22:21:18 2024
# filtering page:  Dudley Pope at Tue Jun 25 22:21:23 2024
# filtering page:  Volga Se Ganga at Tue Jun 25 22:21:27 2024
# filtering page:  Maurice Druon at Tue Jun 25 22:21:32 2024
# filtering page:  Colorado at Tue Jun 25 22:21:36 2024
# filtering page:  Michael Shaara at Tue Jun 25 22:21:45 2024
# filtering page:  William Caxton at Tue Jun 25 22:21:52 2024
# filtering page:  Kenmu Restoration at Tue Jun 25 22:21:59 2024
# filtering page:  Gabriel García Márquez at Tue Jun 25 22:22:05 2024
# filtering page:  Wilbur Smith at Tue Jun 25 22:22:13 2024
# filtering page:  Battle of Cartagena de Indias at Tue Jun 25 22:22:18 2024
# filtering page:  Night Thoughts of a Classical Physicist at Tue Jun 25 22:22:25 2024
# filtering page:  Peloponnesian War at Tue Jun 25 22:22:31 2024
# filtering page:  Jack Maggs at Tue Jun 25 22:22:41 2024
# filtering page:  Louis XI at Tue Jun 25 22:22:45 2024
# filtering page:  Battle of Teba at Tue Jun 25 22:22:53 2024
# filtering page:  And Quiet Flows the Don at Tue Jun 25 22:22:57 2024
# filtering page:  Teodor Jeske-Choiński at Tue Jun 25 22:23:02 2024
# filtering page:  George Washington at Tue Jun 25 22:23:07 2024
# filtering page:  Kelly Gang at Tue Jun 25 22:23:16 2024
# filtering page:  Novel at Tue Jun 25 22:23:26 2024
# filtering page:  Irish revolutionary period at Tue Jun 25 22:23:35 2024
# filtering page:  Pope Gregory VII at Tue Jun 25 22:23:41 2024
# filtering page:  Barry Unsworth at Tue Jun 25 22:23:49 2024
# filtering page:  Child of All Nations at Tue Jun 25 22:23:53 2024
# filtering page:  Valle de los Caídos at Tue Jun 25 22:24:00 2024
# filtering page:  James A. Michener at Tue Jun 25 22:24:10 2024
# filtering page:  Ramiro II of León at Tue Jun 25 22:24:16 2024
# filtering page:  Silence (Endō novel) at Tue Jun 25 22:24:21 2024
# filtering page:  Lois Lowry at Tue Jun 25 22:24:28 2024
# filtering page:  Pedro Santamaría at Tue Jun 25 22:24:33 2024
# filtering page:  Kalki Krishnamurthy at Tue Jun 25 22:24:37 2024
# filtering page:  Matilde Asensi at Tue Jun 25 22:24:42 2024
# filtering page:  George MacDonald Fraser at Tue Jun 25 22:24:46 2024
# filtering page:  Mika Waltari at Tue Jun 25 22:24:51 2024
# filtering page:  Mahapandit Rahul Sankrityayan at Tue Jun 25 22:24:55 2024
# filtering page:  Assassination of Julius Caesar at Tue Jun 25 22:25:01 2024
# filtering page:  Rafael Leónidas Trujillo at Tue Jun 25 22:25:07 2024
# filtering page:  World's Columbian Exposition at Tue Jun 25 22:25:17 2024
# filtering page:  Maurice Shadbolt at Tue Jun 25 22:25:26 2024
# filtering page:  The Woman Who had Two Navels at Tue Jun 25 22:25:30 2024
# filtering page:  Wayson Choy at Tue Jun 25 22:25:35 2024
# filtering page:  Battle of Thermopylae at Tue Jun 25 22:25:39 2024
# filtering page:  Quentin Durward at Tue Jun 25 22:25:50 2024
# filtering page:  Alonso Pérez de Guzmán at Tue Jun 25 22:25:54 2024
# filtering page:  Gilded Age at Tue Jun 25 22:25:59 2024
# filtering page:  Alfarrábios at Tue Jun 25 22:26:09 2024
# filtering page:  Margaret George at Tue Jun 25 22:26:16 2024
# filtering page:  Elizabeth Barrett Browning at Tue Jun 25 22:26:22 2024
# filtering page:  Cézanne’s Quarry at Tue Jun 25 22:26:31 2024
# filtering page:  Umberto Eco at Tue Jun 25 22:26:35 2024
# filtering page:  The Grail Quest at Tue Jun 25 22:26:41 2024
# filtering page:  Julian the Apostate at Tue Jun 25 22:26:45 2024
# filtering page:  Porto at Tue Jun 25 22:26:54 2024
# filtering page:  River God at Tue Jun 25 22:27:02 2024
# filtering page:  Season of the Jew at Tue Jun 25 22:27:07 2024
# filtering page:  The Fifth Queen at Tue Jun 25 22:27:11 2024
# filtering page:  Angelique (French series) at Tue Jun 25 22:27:15 2024
# filtering page:  Veyipadagalu at Tue Jun 25 22:27:20 2024
# filtering page:  László Passuth at Tue Jun 25 22:27:25 2024
# filtering page:  The Coffee Trader at Tue Jun 25 22:27:31 2024
# filtering page:  George Jonas at Tue Jun 25 22:27:37 2024
# filtering page:  Sofi Oksanen at Tue Jun 25 22:27:41 2024
# filtering page:  Alonso de Ojeda at Tue Jun 25 22:27:46 2024
# filtering page:  The Hunchback of Notre Dame at Tue Jun 25 22:27:51 2024
# filtering page:  New Kingdom of Egypt at Tue Jun 25 22:27:58 2024
# filtering page:  Hugo Claus at Tue Jun 25 22:28:05 2024
# filtering page:  Hernán Cortés at Tue Jun 25 22:28:10 2024
# filtering page:  Toni Morrison at Tue Jun 25 22:28:19 2024
# filtering page:  Byzantine at Tue Jun 25 22:28:26 2024
# filtering page:  Lisbon Massacre at Tue Jun 25 22:28:36 2024
# filtering page:  C. J. Sansom at Tue Jun 25 22:28:40 2024
# filtering page:  Siege of Cádiz at Tue Jun 25 22:28:45 2024
# filtering page:  Robert Hugh Benson at Tue Jun 25 22:28:52 2024
# filtering page:  Charles III of Spain at Tue Jun 25 22:28:57 2024
# filtering page:  Ford Madox Ford at Tue Jun 25 22:29:07 2024
# filtering page:  Pazzi conspiracy at Tue Jun 25 22:29:13 2024
# filtering page:  Ken Follett at Tue Jun 25 22:29:18 2024
# filtering page:  Ivo Andrić at Tue Jun 25 22:29:23 2024
# filtering page:  Aleksandr Solzhenitsyn at Tue Jun 25 22:29:33 2024
# filtering page:  Chia Black Dragon at Tue Jun 25 22:29:42 2024
# filtering page:  Miguel López de Legazpi at Tue Jun 25 22:29:46 2024
# filtering page:  James A Michener at Tue Jun 25 22:29:52 2024
# filtering page:  The Saxon Stories at Tue Jun 25 22:29:59 2024
# filtering page:  Thirty Years' War at Tue Jun 25 22:30:04 2024
# filtering page:  An Instance of the Fingerpost at Tue Jun 25 22:30:13 2024
# filtering page:  Gray Ranks at Tue Jun 25 22:30:17 2024
# filtering page:  A Tale of Old Mortality at Tue Jun 25 22:30:23 2024
# filtering page:  Quintus Sertorius at Tue Jun 25 22:30:28 2024
# filtering page:  Thornton Wilder at Tue Jun 25 22:30:34 2024
# filtering page:  Boris Pasternak at Tue Jun 25 22:30:39 2024
# filtering page:  Cleopatra VII at Tue Jun 25 22:30:46 2024
# filtering page:  Hasekura Tsunenaga at Tue Jun 25 22:30:58 2024
# filtering page:  Porius: A Romance of the Dark Ages at Tue Jun 25 22:31:05 2024
# filtering page:  The Load of Unicorn at Tue Jun 25 22:31:11 2024
# filtering page:  Mikhail Bulgakov at Tue Jun 25 22:31:16 2024
# filtering page:  The Athenian Murders at Tue Jun 25 22:31:23 2024
# filtering page:  J. G. Ballard at Tue Jun 25 22:31:27 2024
# filtering page:  Lauren Willig at Tue Jun 25 22:31:34 2024
# filtering page:  The Road to Wellville at Tue Jun 25 22:31:39 2024
# filtering page:  Mary Shelley at Tue Jun 25 22:31:45 2024
# filtering page:  Prince of Foxes at Tue Jun 25 22:31:55 2024
# filtering page:  Lee and Grant at Appomattox at Tue Jun 25 22:31:59 2024
# filtering page:  1745 Jacobite rising at Tue Jun 25 22:32:03 2024
# filtering page:  The Far Pavilions at Tue Jun 25 22:32:10 2024
# filtering page:  Sergeant Lamb novels at Tue Jun 25 22:32:16 2024
# filtering page:  Guy Endore at Tue Jun 25 22:32:20 2024
# filtering page:  The Trilogy at Tue Jun 25 22:32:26 2024
# filtering page:  Arevaci at Tue Jun 25 22:32:32 2024
# filtering page:  Twenty Years After at Tue Jun 25 22:32:36 2024
# filtering page:  Dennis Bock at Tue Jun 25 22:32:42 2024
# filtering page:  Moghul Empire at Tue Jun 25 22:32:50 2024
# filtering page:  John Harvey Kellogg at Tue Jun 25 22:32:59 2024
# filtering page:  Revolt of the Comuneros at Tue Jun 25 22:33:08 2024
# filtering page:  The General in his Labyrinth at Tue Jun 25 22:33:18 2024
# filtering page:  Lion of Macedon at Tue Jun 25 22:33:26 2024
# filtering page:  Third Crusade at Tue Jun 25 22:33:31 2024
# filtering page:  Leslie Barringer at Tue Jun 25 22:33:40 2024
# filtering page:  The Home and the World at Tue Jun 25 22:33:44 2024
# filtering page:  Alaska at Tue Jun 25 22:33:50 2024
# filtering page:  Cao Xueqin at Tue Jun 25 22:34:00 2024
# filtering page:  Francisco de Quevedo at Tue Jun 25 22:34:05 2024
# filtering page:  Blas de Lezo at Tue Jun 25 22:34:10 2024
# filtering page:  Bring up the Bodies at Tue Jun 25 22:34:16 2024
# filtering page:  Lord Dunmore's War at Tue Jun 25 22:34:20 2024
# filtering page:  Estebanillo González at Tue Jun 25 22:34:28 2024
# filtering page:  Number the Stars at Tue Jun 25 22:34:35 2024
# filtering page:  Nicolás de Ovando at Tue Jun 25 22:34:41 2024
# filtering page:  Anwar Sadat at Tue Jun 25 22:34:46 2024
# filtering page:  Kálmán Mikszáth at Tue Jun 25 22:34:54 2024
# filtering page:  Stephen Crane at Tue Jun 25 22:34:58 2024
# filtering page:  As Minas de Prata at Tue Jun 25 22:35:07 2024
# filtering page:  Dos de Mayo Uprising at Tue Jun 25 22:35:11 2024
# filtering page:  The Fair Maid of Perth at Tue Jun 25 22:35:16 2024
# filtering page:  Charles De Coster at Tue Jun 25 22:35:20 2024
# filtering page:  Alfonso VII of León and Castile at Tue Jun 25 22:35:24 2024
# filtering page:  Fernando de Rojas at Tue Jun 25 22:35:30 2024
# filtering page:  The White Guard at Tue Jun 25 22:35:36 2024
# filtering page:  Aag Ka Darya at Tue Jun 25 22:35:40 2024
# filtering page:  A Council of Dolls at Tue Jun 25 22:35:45 2024
# filtering page:  The Afghan Campaign at Tue Jun 25 22:35:50 2024
# filtering page:  Sara Douglass at Tue Jun 25 22:35:56 2024
# filtering page:  The Colony of Unrequited Dreams at Tue Jun 25 22:36:00 2024
# filtering page:  Jerónimo Tristante at Tue Jun 25 22:36:05 2024
# filtering page:  Akhenaten at Tue Jun 25 22:36:09 2024
# filtering page:  James Lincoln Collier at Tue Jun 25 22:36:19 2024
# filtering page:  María de Molina at Tue Jun 25 22:36:24 2024
# filtering page:  Galahad at Tue Jun 25 22:36:28 2024
# filtering page:  Visigothic Kingdom at Tue Jun 25 22:36:34 2024
# filtering page:  Artemisia I of Caria at Tue Jun 25 22:36:46 2024
# filtering page:  Stefan Żeromski at Tue Jun 25 22:36:52 2024
# filtering page:  1715 Jacobite rising at Tue Jun 25 22:36:57 2024
# filtering page:  A Star Called Henry at Tue Jun 25 22:37:02 2024
# filtering page:  Cecelia Holland at Tue Jun 25 22:37:07 2024
# filtering page:  Moshe Shamir at Tue Jun 25 22:37:10 2024
# filtering page:  Anne & Serge Golon at Tue Jun 25 22:37:15 2024
# filtering page:  Paleolithic at Tue Jun 25 22:37:19 2024
# filtering page:  Aaron Burr at Tue Jun 25 22:37:28 2024
# filtering page:  The Blood of Lorraine at Tue Jun 25 22:37:37 2024
# filtering page:  Hilary Mantel at Tue Jun 25 22:37:41 2024
# filtering page:  Shelby Foote at Tue Jun 25 22:37:46 2024
# filtering page:  The Bridge on the Drina at Tue Jun 25 22:37:52 2024
# filtering page:  Partitions of Poland at Tue Jun 25 22:38:00 2024
# filtering page:  Year of Wonders at Tue Jun 25 22:38:08 2024
# filtering page:  Philip II of Spain at Tue Jun 25 22:38:12 2024
# filtering page:  Patrick O'Brian at Tue Jun 25 22:38:21 2024
# filtering page:  A Body in the Bath House at Tue Jun 25 22:38:27 2024
# filtering page:  Oscar and Lucinda at Tue Jun 25 22:38:32 2024
# filtering page:  The Cloister and the Hearth at Tue Jun 25 22:38:37 2024
# filtering page:  Arthur Phillips at Tue Jun 25 22:38:44 2024
# filtering page:  Katharine Howard at Tue Jun 25 22:38:48 2024
# filtering page:  Suebi at Tue Jun 25 22:38:54 2024
# filtering page:  Domingo F. Sarmiento at Tue Jun 25 22:39:07 2024
# filtering page:  Three Day Road at Tue Jun 25 22:39:17 2024
# filtering page:  Bankim Chandra Chattopadhyay at Tue Jun 25 22:39:22 2024
# filtering page:  French invasion of Russia at Tue Jun 25 22:39:29 2024
# filtering page:  The Other Boleyn Girl at Tue Jun 25 22:39:44 2024
# filtering page:  Duke of Alba at Tue Jun 25 22:39:52 2024
# filtering page:  Oliver Cromwell at Tue Jun 25 22:39:58 2024
# filtering page:  The Red Wheel at Tue Jun 25 22:40:09 2024
# filtering page:  Charles Dickens at Tue Jun 25 22:40:14 2024
# filtering page:  Leo Africanus at Tue Jun 25 22:40:26 2024
# filtering page:  William Makepeace Thackeray at Tue Jun 25 22:40:32 2024
# filtering page:  Trojan War at Tue Jun 25 22:40:42 2024
# filtering page:  Anita Heiss at Tue Jun 25 22:40:50 2024
# filtering page:  Unburnable at Tue Jun 25 22:40:54 2024
# filtering page:  Jean-Christophe Rufin at Tue Jun 25 22:40:59 2024
# filtering page:  Miguel Delibes at Tue Jun 25 22:41:03 2024
# filtering page:  Alfonso X of Castile at Tue Jun 25 22:41:10 2024
# filtering page:  Benito Pérez Galdós at Tue Jun 25 22:41:17 2024
# filtering page:  Hereward the Wake at Tue Jun 25 22:41:24 2024
# filtering page:  Carlist Wars at Tue Jun 25 22:41:30 2024
# filtering page:  Jennifer Roberson at Tue Jun 25 22:41:40 2024
# filtering page:  Second Sino-Japanese War at Tue Jun 25 22:41:44 2024
# filtering page:  Amenhotep III at Tue Jun 25 22:41:56 2024
# filtering page:  Aurangzeb at Tue Jun 25 22:42:02 2024
# filtering page:  First Anglo-Afghan War at Tue Jun 25 22:42:12 2024
# filtering page:  Brian Boru at Tue Jun 25 22:42:20 2024
# filtering page:  Blanche II of Navarre at Tue Jun 25 22:42:30 2024
# filtering page:  Smenkhkare at Tue Jun 25 22:42:34 2024
# filtering page:  The Jupiter Myth at Tue Jun 25 22:42:39 2024
# filtering page:  Irene Hunt at Tue Jun 25 22:42:45 2024
# filtering page:  Bernard Cornwell at Tue Jun 25 22:42:49 2024
# filtering page:  Province of Maryland at Tue Jun 25 22:42:55 2024
# filtering page:  Know Ye Not Agincourt? at Tue Jun 25 22:43:03 2024
# filtering page:  Push Not the River at Tue Jun 25 22:43:07 2024
# filtering page:  The Heretic: A Novel of the Inquisition at Tue Jun 25 22:43:11 2024
# filtering page:  Beatrice of Portugal at Tue Jun 25 22:43:15 2024
# filtering page:  Gore Vidal at Tue Jun 25 22:43:23 2024
# filtering page:  Charles II of England at Tue Jun 25 22:43:31 2024
# filtering page:  James Michener at Tue Jun 25 22:43:41 2024
# filtering page:  Brazil Red at Tue Jun 25 22:43:47 2024
# filtering page:  Kathleen Winsor at Tue Jun 25 22:43:52 2024
# filtering page:  Caballero: A Historical Novel at Tue Jun 25 22:43:56 2024
# filtering page:  Horemheb at Tue Jun 25 22:44:02 2024
# filtering page:  The Legend of Thyl Ulenspiegel and Lamme Goedzak at Tue Jun 25 22:44:09 2024
# filtering page:  1960 United States presidential election at Tue Jun 25 22:44:14 2024
# filtering page:  The Greenlanders at Tue Jun 25 22:44:26 2024
# filtering page:  Tiberius at Tue Jun 25 22:44:30 2024
# filtering page:  Nootka Island at Tue Jun 25 22:44:40 2024
# filtering page:  Spanish conquest of the Aztec Empire at Tue Jun 25 22:44:46 2024
# filtering page:  Henry of Castile the Senator at Tue Jun 25 22:44:53 2024
# filtering page:  Jose Carlos Somoza at Tue Jun 25 22:44:57 2024
# filtering page:  Sword at Sunset at Tue Jun 25 22:45:02 2024
# filtering page:  Napoleonic Wars at Tue Jun 25 22:45:07 2024
# filtering page:  Ferdinand II of León at Tue Jun 25 22:45:19 2024
# filtering page:  Peter Matthiessen at Tue Jun 25 22:45:23 2024
# filtering page:  Mollie Hunter at Tue Jun 25 22:45:29 2024
# filtering page:  Munich massacre at Tue Jun 25 22:45:34 2024
# filtering page:  William Brown (admiral) at Tue Jun 25 22:45:41 2024
# filtering page:  The Saxon Shore at Tue Jun 25 22:45:46 2024
# filtering page:  Fernando Fernán Gómez at Tue Jun 25 22:45:51 2024
# filtering page:  Khaak aur Khoon at Tue Jun 25 22:45:59 2024
# filtering page:  David Gemmell at Tue Jun 25 22:46:03 2024
# filtering page:  The Killer Angels at Tue Jun 25 22:46:09 2024
# filtering page:  Joanna of Castile at Tue Jun 25 22:46:14 2024
# filtering page:  The Lambing Flat at Tue Jun 25 22:46:21 2024
# filtering page:  A Tale of Two Cities at Tue Jun 25 22:46:25 2024
# filtering page:  Maxim Gorky at Tue Jun 25 22:46:30 2024
# filtering page:  Geoffrey Trease at Tue Jun 25 22:46:40 2024
# filtering page:  Roots: The Saga of an American Family at Tue Jun 25 22:46:45 2024
# filtering page:  Warsaw Ghetto at Tue Jun 25 22:46:52 2024
# filtering page:  Jin Yong at Tue Jun 25 22:46:58 2024
# filtering page:  Alonso Fernández de Avellaneda at Tue Jun 25 22:47:05 2024
# filtering page:  The Orenda at Tue Jun 25 22:47:14 2024
# filtering page:  An Officer and a Spy at Tue Jun 25 22:47:18 2024
# filtering page:  Spanish Road at Tue Jun 25 22:47:22 2024
# filtering page:  Caligula at Tue Jun 25 22:47:30 2024
# filtering page:  Romance of the Three Kingdoms at Tue Jun 25 22:47:40 2024
# filtering page:  Caroline Lawrence at Tue Jun 25 22:47:47 2024
# filtering page:  Bolitho Novels at Tue Jun 25 22:47:51 2024
# filtering page:  Richard Adams at Tue Jun 25 22:47:56 2024
# filtering page:  English Renaissance theatre at Tue Jun 25 22:48:01 2024
# filtering page:  Theodosia Burr Alston at Tue Jun 25 22:48:05 2024
# filtering page:  The Travels of Jaimie McPheeters at Tue Jun 25 22:48:10 2024
# filtering page:  Marie-Elena John at Tue Jun 25 22:48:14 2024
# filtering page:  Tomás Eloy Martínez at Tue Jun 25 22:48:18 2024
# filtering page:  Isabella I of Castile at Tue Jun 25 22:48:23 2024
# filtering page:  Six-Day War at Tue Jun 25 22:48:32 2024
# filtering page:  Russell Banks at Tue Jun 25 22:48:47 2024
# filtering page:  C. S. Forester at Tue Jun 25 22:48:52 2024
# filtering page:  Jane Smiley at Tue Jun 25 22:48:59 2024
# filtering page:  Edo period at Tue Jun 25 22:49:04 2024
# filtering page:  Penobscot Expedition at Tue Jun 25 22:49:10 2024
# filtering page:  The Long Ships at Tue Jun 25 22:49:18 2024
# filtering page:  My Theodosia at Tue Jun 25 22:49:24 2024
# filtering page:  E. L. Doctorow at Tue Jun 25 22:49:29 2024
# filtering page:  Witiko of Prčice at Tue Jun 25 22:49:37 2024
# filtering page:  Manuel de Godoy, Prince of the Peace at Tue Jun 25 22:49:42 2024
# filtering page:  Toyotomi Hideyoshi at Tue Jun 25 22:49:48 2024
# filtering page:  Norfolk, England at Tue Jun 25 22:49:57 2024
# filtering page:  Karan Ghelo at Tue Jun 25 22:50:07 2024
# filtering page:  True History of the Kelly Gang at Tue Jun 25 22:50:14 2024
# filtering page:  Out of This Furnace at Tue Jun 25 22:50:19 2024
# filtering page:  Empire of the Moghul at Tue Jun 25 22:50:24 2024
# filtering page:  Fiction set in ancient Rome at Tue Jun 25 22:50:29 2024
# filtering page:  Lazarillo de Tormes at Tue Jun 25 22:50:34 2024
# filtering page:  M. M. Kaye at Tue Jun 25 22:50:40 2024
# filtering page:  Jack Whyte at Tue Jun 25 22:50:45 2024
# filtering page:  Mikhail Sholokhov at Tue Jun 25 22:50:50 2024
# filtering page:  Visigoths at Tue Jun 25 22:50:56 2024
# filtering page:  Wikipedia:Notability at Tue Jun 25 22:51:09 2024
# filtering page:  The History of Henry Esmond at Tue Jun 25 22:51:29 2024
# filtering page:  Memoirs of Hadrian at Tue Jun 25 22:51:36 2024
# filtering page:  Lindsey Davis at Tue Jun 25 22:51:43 2024
# filtering page:  Numantine War at Tue Jun 25 22:51:48 2024
# filtering page:  The Sorrow of War at Tue Jun 25 22:52:00 2024
# filtering page:  Eagle in the Snow at Tue Jun 25 22:52:05 2024
# filtering page:  Aztec Autumn at Tue Jun 25 22:52:11 2024
# filtering page:  Dublin: Foundation at Tue Jun 25 22:52:16 2024
# filtering page:  Tales of the Alhambra at Tue Jun 25 22:52:22 2024
# filtering page:  Belle Époque at Tue Jun 25 22:52:27 2024
# filtering page:  Protestant reformation at Tue Jun 25 22:52:35 2024
# filtering page:  Lope de Vega at Tue Jun 25 22:52:45 2024
# filtering page:  Sancho III of Castile at Tue Jun 25 22:52:53 2024
# filtering page:  Shahab Nama at Tue Jun 25 22:52:59 2024
# filtering page:  Facundo at Tue Jun 25 22:53:06 2024
# filtering page:  Cue for Treason at Tue Jun 25 22:53:18 2024
# filtering page:  The Tale of Genji at Tue Jun 25 22:53:23 2024
# filtering page:  Charles Kingsley at Tue Jun 25 22:53:32 2024
# filtering page:  Aubrey–Maturin series at Tue Jun 25 22:53:38 2024
# filtering page:  Juan de Tassis, 2nd Count of Villamediana at Tue Jun 25 22:53:45 2024
# filtering page:  The Thorn Birds at Tue Jun 25 22:53:50 2024
# filtering page:  I, Claudius at Tue Jun 25 22:53:57 2024
# filtering page:  Pearl Buck at Tue Jun 25 22:54:06 2024
# filtering page:  Here Be Dragons at Tue Jun 25 22:54:15 2024
# filtering page:  El Buscón at Tue Jun 25 22:54:20 2024
# filtering page:  The Deer and the Cauldron at Tue Jun 25 22:54:26 2024
# filtering page:  Leon Uris at Tue Jun 25 22:54:31 2024
# filtering page:  Bila Yarrudhanggalangdhuray at Tue Jun 25 22:54:36 2024
# filtering page:  Thomas Pynchon at Tue Jun 25 22:54:42 2024
# filtering page:  George Eliot at Tue Jun 25 22:54:50 2024
# filtering page:  The Book Thief at Tue Jun 25 22:54:58 2024
# filtering page:  Alexandre Dumas, père at Tue Jun 25 22:55:04 2024
# filtering page:  The Palaeologian Dynasty. The Rise and Fall of Byzantium at Tue Jun 25 22:55:14 2024
# filtering page:  The Feast of the Goat at Tue Jun 25 22:55:20 2024
# filtering page:  Bumi Manusia at Tue Jun 25 22:55:32 2024
# filtering page:  Girolamo Savonarola at Tue Jun 25 22:55:41 2024
# filtering page:  Neal Stephenson at Tue Jun 25 22:55:53 2024
# filtering page:  H. Rider Haggard at Tue Jun 25 22:56:00 2024
# filtering page:  The Devil's Brood at Tue Jun 25 22:56:05 2024
# filtering page:  Romola at Tue Jun 25 22:56:11 2024
# filtering page:  Battle of Berlin at Tue Jun 25 22:56:18 2024
# filtering page:  Charles Reade at Tue Jun 25 22:56:27 2024
# filtering page:  Washington Irving at Tue Jun 25 22:56:32 2024
# filtering page:  Convent of Mafra at Tue Jun 25 22:56:41 2024
# filtering page:  Salvador de Madariaga at Tue Jun 25 22:56:48 2024
# filtering page:  List of fiction set in ancient Greece at Tue Jun 25 22:56:53 2024
# filtering page:  The Reckoning (1991 novel) at Tue Jun 25 22:56:59 2024
# filtering page:  First Opium War at Tue Jun 25 22:57:04 2024
# filtering page:  The Black Tulip at Tue Jun 25 22:57:18 2024
# filtering page:  Boarding school at Tue Jun 25 22:57:22 2024
# filtering page:  Martin Dressler: The Tale of an American Dreamer at Tue Jun 25 22:57:32 2024
# filtering page:  French and Indian War at Tue Jun 25 22:57:38 2024
# filtering page:  Gates of Fire at Tue Jun 25 22:57:52 2024
# filtering page:  James Fenimore Cooper at Tue Jun 25 22:57:58 2024
# filtering page:  Shadow Country at Tue Jun 25 22:58:06 2024
# filtering page:  Pauline Gedge at Tue Jun 25 22:58:13 2024
# filtering page:  Gonzalo Torrente Ballester at Tue Jun 25 22:58:19 2024
# filtering page:  Delmarva Peninsula at Tue Jun 25 22:58:24 2024
# filtering page:  Babouk at Tue Jun 25 22:58:31 2024
# filtering page:  Catherine of Lancaster at Tue Jun 25 22:58:37 2024
# filtering page:  Empress Orchid at Tue Jun 25 22:58:43 2024
# filtering page:  Joseph Boyden at Tue Jun 25 22:58:49 2024
# filtering page:  Teresa of Ávila at Tue Jun 25 22:58:55 2024
# filtering page:  Manuel Chaves Nogales at Tue Jun 25 22:59:04 2024
# filtering page:  Battle of Lepanto at Tue Jun 25 22:59:09 2024
# filtering page:  Khadija Mastoor at Tue Jun 25 22:59:22 2024
# filtering page:  January Uprising at Tue Jun 25 22:59:27 2024
# filtering page:  Jamrach's Menagerie at Tue Jun 25 22:59:37 2024
# filtering page:  Sherman's March to the Sea at Tue Jun 25 22:59:42 2024
# filtering page:  First Jewish–Roman War at Tue Jun 25 22:59:50 2024
# filtering page:  Khufu at Tue Jun 25 23:00:03 2024
# filtering page:  Douglas Reeman at Tue Jun 25 23:00:11 2024
# filtering page:  Carol Birch at Tue Jun 25 23:00:17 2024
# filtering page:  Emirate of Granada at Tue Jun 25 23:00:21 2024
# filtering page:  Joseph Conrad at Tue Jun 25 23:00:31 2024
# filtering page:  Quebec at Tue Jun 25 23:00:41 2024
# filtering page:  Royal Escape at Tue Jun 25 23:00:52 2024
# filtering page:  List of fiction set in ancient Rome at Tue Jun 25 23:00:57 2024
# filtering page:  Battle of Las Navas de Tolosa at Tue Jun 25 23:01:02 2024
# filtering page:  Laura Esquivel at Tue Jun 25 23:01:09 2024
# filtering page:  The Kingdom of This World at Tue Jun 25 23:01:14 2024
# filtering page:  Shan Sa at Tue Jun 25 23:01:23 2024
# filtering page:  Christopher Wren at Tue Jun 25 23:01:29 2024
# filtering page:  War of the Spanish Succession at Tue Jun 25 23:01:36 2024
# filtering page:  Murasaki Shikibu at Tue Jun 25 23:01:46 2024
# filtering page:  Rachel Dyer: a North American Story at Tue Jun 25 23:01:56 2024
# filtering page:  Nicola Griffith at Tue Jun 25 23:02:05 2024
# filtering page:  Standing Rock Indian Reservation at Tue Jun 25 23:02:10 2024
# filtering page:  Cartucho at Tue Jun 25 23:02:18 2024
# filtering page:  Seville at Tue Jun 25 23:02:24 2024
# filtering page:  French Revolution at Tue Jun 25 23:02:35 2024
# filtering page:  Henry IV, Holy Roman Emperor at Tue Jun 25 23:02:44 2024
# filtering page:  Peter of Castile at Tue Jun 25 23:03:01 2024
# filtering page:  The Silver Pigs at Tue Jun 25 23:03:06 2024
# filtering page:  Jejak Langkah at Tue Jun 25 23:03:12 2024
# filtering page:  Lady of the Forest at Tue Jun 25 23:03:18 2024
# filtering page:  Episodios Nacionales at Tue Jun 25 23:03:26 2024
# filtering page:  Philippa Gregory at Tue Jun 25 23:03:32 2024
# filtering page:  Western Australia at Tue Jun 25 23:03:37 2024
# filtering page:  Nick Joaquin at Tue Jun 25 23:03:46 2024
# filtering page:  Bao Ninh at Tue Jun 25 23:03:53 2024
# filtering page:  Alberto Vázquez-Figueroa at Tue Jun 25 23:03:57 2024
# filtering page:  The Confessions of Nat Turner at Tue Jun 25 23:04:02 2024
# filtering page:  Alexander Farnese, Duke of Parma at Tue Jun 25 23:04:07 2024
# filtering page:  Anya Seton at Tue Jun 25 23:04:14 2024
# filtering page:  T. C. Boyle at Tue Jun 25 23:04:19 2024
# filtering page:  The Missing Italian Girl at Tue Jun 25 23:04:24 2024
# filtering page:  The Persian Boy at Tue Jun 25 23:04:29 2024
# filtering page:  A Struggle for Rome at Tue Jun 25 23:04:36 2024
# filtering page:  Alans at Tue Jun 25 23:04:41 2024
# filtering page:  Chola dynasty at Tue Jun 25 23:04:51 2024
# filtering page:  Jasper Jones at Tue Jun 25 23:04:59 2024
# filtering page:  Esther Forbes at Tue Jun 25 23:05:03 2024
# filtering page:  The Life of Klim Samgin at Tue Jun 25 23:05:07 2024
# filtering page:  The Memoirs of Cleopatra at Tue Jun 25 23:05:15 2024
# filtering page:  Henry III of Castile at Tue Jun 25 23:05:21 2024
# filtering page:  Robert the Bruce at Tue Jun 25 23:05:26 2024
# filtering page:  Jessie Burton at Tue Jun 25 23:05:39 2024
# filtering page:  The Guarani at Tue Jun 25 23:05:46 2024
# filtering page:  Guy Vanderhaeghe at Tue Jun 25 23:05:54 2024
# filtering page:  Fatelessness at Tue Jun 25 23:06:00 2024
# filtering page:  In the Time of the Butterflies at Tue Jun 25 23:06:08 2024
# filtering page:  Eleanor Catton at Tue Jun 25 23:06:13 2024
# filtering page:  Restoration (England) at Tue Jun 25 23:06:20 2024
# filtering page:  Miyamoto Musashi at Tue Jun 25 23:06:25 2024
# filtering page:  Antonio Gómez Rufo at Tue Jun 25 23:06:34 2024
# filtering page:  Alcibiades at Tue Jun 25 23:06:40 2024
# filtering page:  William the Conqueror at Tue Jun 25 23:06:50 2024
# filtering page:  Frans G. Bengtsson at Tue Jun 25 23:07:04 2024
# filtering page:  Iranian Revolution at Tue Jun 25 23:07:09 2024
# filtering page:  Isabel Allende at Tue Jun 25 23:07:22 2024
# filtering page:  Marguerite Yourcenar at Tue Jun 25 23:07:30 2024
# filtering page:  Alberto Laiseca at Tue Jun 25 23:07:36 2024
# filtering page:  Giuseppe Tomasi di Lampedusa at Tue Jun 25 23:07:41 2024
# filtering page:  Santa Evita at Tue Jun 25 23:07:48 2024
# filtering page:  The Renaissance at Tue Jun 25 23:07:53 2024
# filtering page:  Shadow Patriots at Tue Jun 25 23:08:04 2024
# filtering page:  Terenci Moix at Tue Jun 25 23:08:11 2024
# filtering page:  Tides of War at Tue Jun 25 23:08:17 2024
# filtering page:  Marcos Aguinis at Tue Jun 25 23:08:22 2024
# filtering page:  C V Raman Pillai at Tue Jun 25 23:08:27 2024
# filtering page:  Qing dynasty at Tue Jun 25 23:08:33 2024
# filtering page:  Company of Liars at Tue Jun 25 23:08:49 2024
# filtering page:  Magellan's circumnavigation at Tue Jun 25 23:08:54 2024
# filtering page:  Pelagius of Asturias at Tue Jun 25 23:09:05 2024
# filtering page:  Ivanhoe at Tue Jun 25 23:09:10 2024
# filtering page:  Sister Fidelma at Tue Jun 25 23:09:17 2024
# filtering page:  Sarah Dunant at Tue Jun 25 23:09:24 2024
# filtering page:  Rabindranath Tagore at Tue Jun 25 23:09:28 2024
# filtering page:  Pedro Lemebel at Tue Jun 25 23:09:37 2024
# filtering page:  Peveril of the Peak at Tue Jun 25 23:09:42 2024
# filtering page:  Andrés de Urdaneta at Tue Jun 25 23:09:46 2024
# filtering page:  My Tender Matador at Tue Jun 25 23:09:52 2024
# filtering page:  Winter in Madrid at Tue Jun 25 23:09:57 2024
# filtering page:  Mary Boleyn at Tue Jun 25 23:10:02 2024
# filtering page:  The Fortunes of Perkin Warbeck at Tue Jun 25 23:10:07 2024
# filtering page:  Arturo Pérez-Reverte at Tue Jun 25 23:10:13 2024
# filtering page:  Blue Division at Tue Jun 25 23:10:18 2024
# filtering page:  Anne of Cleves at Tue Jun 25 23:10:24 2024
# filtering page:  The Last of the Wine at Tue Jun 25 23:10:31 2024
# filtering page:  Ashwin Sanghi at Tue Jun 25 23:10:35 2024
# filtering page:  Luther Blissett at Tue Jun 25 23:10:40 2024
# filtering page:  Juan Manuel, Prince of Villena at Tue Jun 25 23:10:45 2024
# filtering page:  Jews in Iran at Tue Jun 25 23:10:52 2024
# filtering page:  MacKinlay Kantor at Tue Jun 25 23:11:00 2024
# filtering page:  The Lady of the Wheel at Tue Jun 25 23:11:04 2024
# filtering page:  The Leopard at Tue Jun 25 23:11:09 2024
# filtering page:  O Tempo e o Vento at Tue Jun 25 23:11:16 2024
# filtering page:  The Power and the Glory at Tue Jun 25 23:11:20 2024
# filtering page:  Ride the Wind at Tue Jun 25 23:11:26 2024
# filtering page:  Hanna Mina at Tue Jun 25 23:11:32 2024
# filtering page:  Luis Coloma at Tue Jun 25 23:11:37 2024
# filtering page:  The Fencing Master at Tue Jun 25 23:11:42 2024
# filtering page:  Minas Gerais at Tue Jun 25 23:11:47 2024
# filtering page:  The Wishing Game at Tue Jun 25 23:11:57 2024
# filtering page:  Linda Sue Park at Tue Jun 25 23:12:02 2024
# filtering page:  Timothy Mo at Tue Jun 25 23:12:07 2024
# filtering page:  Ashoka at Tue Jun 25 23:12:12 2024
# filtering page:  Second Persian invasion of Greece at Tue Jun 25 23:12:19 2024
# filtering page:  Paul Kingsnorth at Tue Jun 25 23:12:29 2024
# filtering page:  Qurratulain Hyder at Tue Jun 25 23:12:34 2024
# filtering page:  List of historical video games at Tue Jun 25 23:12:40 2024
# filtering page:  Janice Woods Windle at Tue Jun 25 23:12:45 2024
# filtering page:  Margaret Atwood at Tue Jun 25 23:12:49 2024
# filtering page:  Partition of India at Tue Jun 25 23:12:55 2024
# filtering page:  Ernesto Sabato at Tue Jun 25 23:13:05 2024
# filtering page:  Amy Robsart at Tue Jun 25 23:13:12 2024
# filtering page:  Alessandro Manzoni at Tue Jun 25 23:13:21 2024
# filtering page:  Neamat Imam at Tue Jun 25 23:13:26 2024
# filtering page:  José de Alencar at Tue Jun 25 23:13:31 2024
# filtering page:  Adalbert Stifter at Tue Jun 25 23:13:36 2024
# filtering page:  Mona Susan Power at Tue Jun 25 23:13:40 2024
# filtering page:  Battle of Simancas at Tue Jun 25 23:13:44 2024
# filtering page:  Andrew Vachss at Tue Jun 25 23:13:51 2024
# filtering page:  Fire from Heaven at Tue Jun 25 23:13:55 2024
# filtering page:  Blanche of Bourbon at Tue Jun 25 23:14:00 2024
# filtering page:  The Gods of War at Tue Jun 25 23:14:04 2024
# filtering page:  Patrick Redmond at Tue Jun 25 23:14:09 2024
# filtering page:  Way of St. James at Tue Jun 25 23:14:14 2024
# filtering page:  Nerida Newton at Tue Jun 25 23:14:21 2024
# filtering page:  Álvaro de Mendaña de Neira at Tue Jun 25 23:14:26 2024
# filtering page:  Kristin Lavransdatter at Tue Jun 25 23:14:31 2024
# filtering page:  Jane Porter at Tue Jun 25 23:14:37 2024
# filtering page:  Baudolino at Tue Jun 25 23:14:41 2024
# filtering page:  Julian Stockwin at Tue Jun 25 23:14:46 2024
# filtering page:  Amin Maalouf at Tue Jun 25 23:14:50 2024
# filtering page:  Santiago Posteguillo at Tue Jun 25 23:14:56 2024
# filtering page:  War of Canudos at Tue Jun 25 23:15:00 2024
# filtering page:  The Heart of Mid-Lothian at Tue Jun 25 23:15:07 2024
# filtering page:  Mavis Cheek at Tue Jun 25 23:15:13 2024
# filtering page:  Ana de Mendoza, Princess of Eboli at Tue Jun 25 23:15:17 2024
# filtering page:  Russian Revolution at Tue Jun 25 23:15:22 2024
# filtering page:  Shūsaku Endō at Tue Jun 25 23:15:34 2024
# filtering page:  Babur at Tue Jun 25 23:15:39 2024
# filtering page:  Anchee Min at Tue Jun 25 23:15:50 2024
# filtering page:  The Egyptian at Tue Jun 25 23:15:55 2024
# filtering page:  The Playmaker at Tue Jun 25 23:16:01 2024
# filtering page:  The Sunne in Splendour at Tue Jun 25 23:16:05 2024
# filtering page:  Under the Eagle at Tue Jun 25 23:16:09 2024
# filtering page:  Genpei War at Tue Jun 25 23:16:14 2024
# filtering page:  Antonio de Nebrija at Tue Jun 25 23:16:21 2024
# filtering page:  The Thousand Autumns of Jacob de Zoet at Tue Jun 25 23:16:26 2024
# filtering page:  Isabella II of Spain at Tue Jun 25 23:16:30 2024
# filtering page:  Daniel Defoe at Tue Jun 25 23:16:37 2024
# filtering page:  Vicente Blasco Ibáñez at Tue Jun 25 23:16:43 2024
# filtering page:  Gina B. Nahai at Tue Jun 25 23:16:47 2024
# filtering page:  SS Exodus at Tue Jun 25 23:16:52 2024
# filtering page:  Conquest of Mexico at Tue Jun 25 23:16:57 2024
# filtering page:  Logan, a Family History at Tue Jun 25 23:17:03 2024
# filtering page:  Pittsburgh at Tue Jun 25 23:17:11 2024
# filtering page:  Goat Song at Tue Jun 25 23:17:21 2024
# filtering page:  Barbara Corrado Pope at Tue Jun 25 23:17:25 2024
# filtering page:  The Pillars of the Earth at Tue Jun 25 23:17:29 2024
# filtering page:  The Sorrow of Belgium at Tue Jun 25 23:17:35 2024
# filtering page:  The Story of the Stone at Tue Jun 25 23:17:41 2024
# filtering page:  Philip V of Spain at Tue Jun 25 23:17:48 2024
# filtering page:  Peninsular War at Tue Jun 25 23:17:57 2024
# filtering page:  Celtiberians at Tue Jun 25 23:18:07 2024
# filtering page:  Across Five Aprils at Tue Jun 25 23:18:14 2024
# filtering page:  Giuseppe Garibaldi at Tue Jun 25 23:18:19 2024
# filtering page:  The Secret River at Tue Jun 25 23:18:30 2024
# filtering page:  Cryptonomicon at Tue Jun 25 23:18:34 2024
# filtering page:  I Am a Barbarian at Tue Jun 25 23:18:40 2024
# filtering page:  King Jesus at Tue Jun 25 23:18:45 2024
# filtering page:  Ferdinand Columbus at Tue Jun 25 23:18:50 2024
# filtering page:  True Women at Tue Jun 25 23:18:54 2024
# filtering page:  Steven Millhauser at Tue Jun 25 23:18:59 2024
# filtering page:  Liuvigild at Tue Jun 25 23:19:03 2024
# filtering page:  Paloma Sánchez-Garnica at Tue Jun 25 23:19:08 2024
# filtering page:  Louis XIV at Tue Jun 25 23:19:12 2024
# filtering page:  Bolesław Prus at Tue Jun 25 23:19:22 2024
# filtering page:  Lew Wallace at Tue Jun 25 23:19:29 2024
# filtering page:  Barnaby Rudge: A Tale of the Riots of 'Eighty at Tue Jun 25 23:19:36 2024
# filtering page:  Il Gattopardo at Tue Jun 25 23:19:42 2024
# filtering page:  Come Rack! Come Rope! at Tue Jun 25 23:19:48 2024
# filtering page:  In the Skin of a Lion at Tue Jun 25 23:19:53 2024
# filtering page:  Category:Historical novels at Tue Jun 25 23:20:02 2024
# filtering page:  Samuel Shellabarger at Tue Jun 25 23:20:05 2024
# filtering page:  Kay the Left-Handed at Tue Jun 25 23:20:12 2024
# filtering page:  Sor Juana at Tue Jun 25 23:20:17 2024
# filtering page:  Wolf Hall at Tue Jun 25 23:20:22 2024
# filtering page:  Richard Zimler at Tue Jun 25 23:20:28 2024
# filtering page:  Eva Díaz Pérez at Tue Jun 25 23:20:32 2024
# filtering page:  History of Athens at Tue Jun 25 23:20:36 2024
# filtering page:  Parmenion at Tue Jun 25 23:20:42 2024
# filtering page:  Alessandro Baricco at Tue Jun 25 23:20:46 2024
# filtering page:  Magnus Maximus at Tue Jun 25 23:20:50 2024
# filtering page:  Masters of Rome at Tue Jun 25 23:20:56 2024
# filtering page:  Salvatore Giuliano at Tue Jun 25 23:21:00 2024
# filtering page:  Mason & Dixon at Tue Jun 25 23:21:07 2024
# filtering page:  Texas at Tue Jun 25 23:21:13 2024
# filtering page:  Order of Calatrava at Tue Jun 25 23:21:23 2024
# filtering page:  Jacobitism at Tue Jun 25 23:21:28 2024
# filtering page:  The Knights of the Cross at Tue Jun 25 23:21:36 2024
# filtering page:  Category:Use dmy dates from November 2015 at Tue Jun 25 23:21:42 2024
# filtering page:  Mexican Revolution at Tue Jun 25 23:21:47 2024
# filtering page:  Juan Eslava Galán at Tue Jun 25 23:22:00 2024
# filtering page:  Kangxi Emperor at Tue Jun 25 23:22:04 2024
# filtering page:  Rafael Sabatini at Tue Jun 25 23:22:12 2024
# filtering page:  Shusaku Endo at Tue Jun 25 23:22:17 2024
# filtering page:  Diana Gabaldon at Tue Jun 25 23:22:22 2024
# filtering page:  George Leonardos at Tue Jun 25 23:22:26 2024
# filtering page:  The Prague Cemetery at Tue Jun 25 23:22:30 2024
# filtering page:  Victoria of the United Kingdom at Tue Jun 25 23:22:35 2024
# filtering page:  Vandals at Tue Jun 25 23:22:42 2024
# filtering page:  Bangladesh famine of 1974 at Tue Jun 25 23:22:51 2024
# filtering page:  Les Misérables at Tue Jun 25 23:22:56 2024
# filtering page:  Louis de Wohl at Tue Jun 25 23:23:02 2024
# filtering page:  William Styron at Tue Jun 25 23:23:06 2024
# filtering page:  Francisco Pizarro at Tue Jun 25 23:23:11 2024
# filtering page:  Imperial Woman at Tue Jun 25 23:23:18 2024
# filtering page:  Alex Haley at Tue Jun 25 23:23:22 2024
# filtering page:  Alexander the Great at Tue Jun 25 23:23:28 2024
# filtering page:  War Comes to Willy Freeman at Tue Jun 25 23:23:41 2024
# filtering page:  Culper Ring at Tue Jun 25 23:23:45 2024
# filtering page:  Tatjana Soli at Tue Jun 25 23:23:53 2024
# filtering page:  Hawaii at Tue Jun 25 23:23:58 2024
# filtering page:  Lucia St. Clair Robson at Tue Jun 25 23:24:12 2024
# filtering page:  Battle of St. Quentin (1557) at Tue Jun 25 23:24:17 2024
# filtering page:  Ernest K. Gann at Tue Jun 25 23:24:21 2024
# filtering page:  Dreyfus affair at Tue Jun 25 23:24:26 2024
# filtering page:  Almohad Caliphate at Tue Jun 25 23:24:36 2024
# filtering page:  Roman Egypt at Tue Jun 25 23:24:45 2024
# filtering page:  A Place of Greater Safety at Tue Jun 25 23:24:57 2024
# filtering page:  Life and Fate at Tue Jun 25 23:25:02 2024
# filtering page:  Mariano José de Larra at Tue Jun 25 23:25:10 2024
# filtering page:  Tracy Chevalier at Tue Jun 25 23:25:15 2024
# filtering page:  Edith Pargeter at Tue Jun 25 23:25:20 2024
# filtering page:  Álvar Fáñez at Tue Jun 25 23:25:24 2024
# filtering page:  Military history of Australia during World War II at Tue Jun 25 23:25:29 2024
# filtering page:  Felix Dahn at Tue Jun 25 23:25:37 2024
# filtering page:  Henryk Sienkiewicz at Tue Jun 25 23:25:41 2024
# filtering page:  List of historical fiction by time period at Tue Jun 25 23:25:49 2024
# filtering page:  La regenta at Tue Jun 25 23:25:53 2024
# filtering page:  Alfonso XI of Castile at Tue Jun 25 23:25:58 2024
# filtering page:  The Luminaries at Tue Jun 25 23:26:03 2024
# filtering page:  José Rizal at Tue Jun 25 23:26:09 2024
# filtering page:  Arturo Barea at Tue Jun 25 23:26:16 2024
# filtering page:  Arthur Conan Doyle at Tue Jun 25 23:26:20 2024
# filtering page:  Classical antiquity at Tue Jun 25 23:26:26 2024
# filtering page:  Abd ar-Rahman II at Tue Jun 25 23:26:33 2024
# filtering page:  Edgar Rice Burroughs at Tue Jun 25 23:26:42 2024
# filtering page:  Georgette Heyer at Tue Jun 25 23:26:48 2024
# filtering page:  Historical fiction at Tue Jun 25 23:26:57 2024
# filtering page:  Dorothy Dunnett at Tue Jun 25 23:27:05 2024
# filtering page:  Massacre of Glencoe at Tue Jun 25 23:27:10 2024
# filtering page:  Gonzalo Pizarro at Tue Jun 25 23:27:17 2024
# filtering page:  Viriathus at Tue Jun 25 23:27:22 2024
# filtering page:  John Inglesant at Tue Jun 25 23:27:28 2024
# filtering page:  The Tale of the Heike at Tue Jun 25 23:27:36 2024
# filtering page:  Redgauntlet at Tue Jun 25 23:27:42 2024
# filtering page:  Measuring the World at Tue Jun 25 23:27:47 2024
# filtering page:  Laura Blundy at Tue Jun 25 23:27:53 2024
# filtering page:  Susana March at Tue Jun 25 23:27:57 2024
# filtering page:  The Baroque Cycle at Tue Jun 25 23:28:02 2024
# filtering page:  Ramón López Soler at Tue Jun 25 23:28:07 2024
# filtering page:  Hatshepsut at Tue Jun 25 23:28:12 2024
# filtering page:  The Betrothed (Manzoni novel) at Tue Jun 25 23:28:20 2024
# filtering page:  Count Belisarius at Tue Jun 25 23:28:26 2024
# filtering page:  New Mexico Territory at Tue Jun 25 23:28:33 2024
# filtering page:  Napoleonic era at Tue Jun 25 23:28:38 2024
# filtering page:  Mario Vargas Llosa at Tue Jun 25 23:28:48 2024
# filtering page:  Greek theatre at Tue Jun 25 23:28:58 2024
# filtering page:  Holy Warrior at Tue Jun 25 23:29:04 2024
# filtering page:  The Sicilian at Tue Jun 25 23:29:08 2024
# filtering page:  The Three Musketeers at Tue Jun 25 23:29:14 2024
# filtering page:  Nancy McKenzie at Tue Jun 25 23:29:22 2024
# filtering page:  Belisarius at Tue Jun 25 23:29:26 2024
# filtering page:  Haitian Revolution at Tue Jun 25 23:29:33 2024
# filtering page:  Protestant Reformation at Tue Jun 25 23:29:41 2024
# filtering page:  The Flashman Papers at Tue Jun 25 23:29:49 2024
# filtering page:  Diary of an Ordinary Woman at Tue Jun 25 23:29:58 2024
# filtering page:  The Vicomte de Bragelonne at Tue Jun 25 23:30:03 2024
# filtering page:  Hadrian at Tue Jun 25 23:30:10 2024
# filtering page:  King's Man at Tue Jun 25 23:30:21 2024
# filtering page:  Ireland: Awakening at Tue Jun 25 23:30:25 2024
# filtering page:  Arthur Wellesley, 1st Duke of Wellington at Tue Jun 25 23:30:29 2024
# filtering page:  Qudratullah Shahab at Tue Jun 25 23:30:39 2024
# filtering page:  Craig Silvey at Tue Jun 25 23:30:44 2024
# filtering page:  Thomas Cromwell at Tue Jun 25 23:30:49 2024
# filtering page:  Indian Rebellion of 1857 at Tue Jun 25 23:30:56 2024
# filtering page:  José Javier Esparza at Tue Jun 25 23:31:09 2024
# filtering page:  Tartessos at Tue Jun 25 23:31:16 2024
# filtering page:  El húsar at Tue Jun 25 23:31:24 2024
# filtering page:  Herman Wouk at Tue Jun 25 23:31:30 2024
# filtering page:  The Islands of Unwisdom at Tue Jun 25 23:31:36 2024
# filtering page:  Steven Pressfield at Tue Jun 25 23:31:41 2024
# filtering page:  Anne Boleyn at Tue Jun 25 23:31:45 2024

# %%
hnp.filtered_pages
# Out:
# ['Aangan (novel)',
#  'Alaska (novel)',
#  'All That Matters (novel)',
#  'Andersonville (novel)',
#  'Avalon (novel)',
#  'Aztec (book)',
#  'Aztec (novel)',
#  'Bano (novel)',
#  'Beloved (novel)',
#  'Brother Jonathan (novel)',
#  'Burr (novel)',
#  'Captain Blood (novel)',
#  'Captain from Castile (novel)',
#  'Caravans (novel)',
#  'Caribbean (novel)',
#  'Centennial (novel)',
#  'Chesapeake (novel)',
#  'Cold Mountain (novel)',
#  'Cry of the Peacock (novel)',
#  'Destiny in Sydney (novel)',
#  'Dharmaraja (novel)',
#  'Doctor Zhivago (novel)',
#  'Dragon Seed (novel)',
#  'Empire of the Sun (novel)',
#  'Empress (novel)',
#  'Exodus (Uris novel)',
#  'Fingersmith (novel)',
#  'Flashman (novel)',
#  'Footsteps (novel)',
#  'Forever Amber (novel)',
#  'Funeral Games (novel)',
#  'Gai-Jin (novel)',
#  'Girl with a Pearl Earring (novel)',
#  'Gone with the Wind (novel)',
#  'Hawaii (novel)',
#  'Hawksmoor (novel)',
#  'Hereward the Wake (novel)',
#  'Hild (novel)',
#  'Hypatia (novel)',
#  'Ides of March (novel)',
#  'Jalna (novel series)',
#  'Journey (novel)',
#  'Judith (novel)',
#  'Julian (historical novel)',
#  'Katherine (Seton novel)',
#  'Kenilworth (novel)',
#  'King Rat (1962 novel)',
#  'Kydd (novel)',
#  'La Reine Margot (novel)',
#  'Lincoln (novel)',
#  'Lydia Bailey (novel)',
#  'Marthandavarma (novel)',
#  'Mexico (novel)',
#  'Middlesex (novel)',
#  'Musashi (novel)',
#  'New York (novel)',
#  'Noble House (book)',
#  'Noli Me Tángere (novel)',
#  'Outlaw (novel)',
#  'Owen Glendower (novel)',
#  'Peony (novel)',
#  'Pharaoh (Prus novel)',
#  'Po-on (novel)',
#  'Poland (novel)',
#  'Prague (novel)',
#  'Purge (novel)',
#  'Q (novel)',
#  'Quo Vadis (novel)',
#  'Ragtime (novel)',
#  'Ramage (novel)',
#  'Ramarajabahadur (novel)',
#  'Raptor (novel)',
#  'Redemption (Uris novel)',
#  'Rob Roy (novel)',
#  'Russka (novel)',
#  'Sarum (novel)',
#  'Scaramouche (novel)',
#  'Seventy-Six (novel)',
#  'Shaheen (novel)',
#  'Shiloh (Foote novel)',
#  'Shōgun (novel)',
#  'Silk (novel)',
#  'Texas (novel)',
#  'The Adventurer (novel)',
#  'The Antagonists (Gann novel)',
#  'The Birth of Venus (novel)',
#  'The Book of Negroes (novel)',
#  'The City Beautiful (novel)',
#  'The Conqueror (novel)',
#  'The Covenant (novel)',
#  'The Family (Mario Puzo novel)',
#  'The Fort (novel)',
#  'The Four Horsemen of the Apocalypse (Spanish novel)',
#  'The Haj (novel)',
#  'The Hope (novel)',
#  'The Jester (novel)',
#  'The Last Empress (novel)',
#  'The Lotus Eaters (novel)',
#  'The March (novel)',
#  "The Rotters' Club (novel)",
#  'The Rover (novel)',
#  'The Samurai (novel)',
#  'The Siege of Malta (novel)',
#  'The Silver Branch (Sutcliff novel)',
#  'The Source (novel)',
#  'The Talisman (Scott novel)',
#  'The Turquoise (novel)',
#  'The Wake (novel)',
#  'Time and Chance (Penman novel)',
#  'Traveller (novel)',
#  'Trinity (novel)',
#  'Troubles (novel)',
#  'Valperga (novel)',
#  'Waverley (novel)',
#  'Whirlwind (novel)',
#  'Witiko (novel)',
#  'Woodstock (novel)',
#  'The Stronghold',
#  'The Siege of Krishnapur',
#  'The Glory',
#  'Edward P. Jones',
#  'Sacred Hunger',
#  'The Heart of Jade',
#  'Oldest Living Confederate Widow Tells All',
#  'La Celestina',
#  'A fekete város',
#  'The Miniaturist',
#  'Inside, Outside',
#  'On Heroes and Tombs',
#  'Anandamath',
#  'Johnny Tremain',
#  'Allan Gurganus',
#  'World Without End (Follett novel)',
#  "King Solomon's Mines",
#  'The Eagle of the Ninth',
#  'The Jade Peony',
#  'An Angel in Australia',
#  'A Dying Light in Corduba',
#  'Ibis trilogy',
#  'The End of a Brave Man',
#  'The War of the End of the World',
#  'The Faithful River',
#  'The Silent People',
#  'The Count of Monte Cristo',
#  'The Known World',
#  'Iracema',
#  'Durgeshnandini',
#  'Frank Yerby',
#  'Micah Clarke',
#  'Alias Grace',
#  'Alex Rutherford',
#  'The Black Coat',
#  "D'Artagnan romances",
#  'Lion of Ireland',
#  'Sivagamiyin Sabadham',
#  'The Luck of Barry Lyndon',
#  'Max Havelaar',
#  'Parthiban Kanavu',
#  'Multatuli',
#  'The Mask of Apollo',
#  'The Name of the Rose',
#  'War and Peace',
#  'Os Sertões',
#  'The Journeyer',
#  'Blood Red, Snow White',
#  'A Journal of the Plague Year',
#  'J. G. Farrell',
#  'Euclides da Cunha',
#  'Tales of Count Lucanor',
#  'Bring Larks and Heroes',
#  'El filibusterismo',
#  'Richard Carvel',
#  'The Red Badge of Courage',
#  'Australian gold rushes',
#  'The House of Niccolò',
#  'Don Quixote',
#  'The Forest House',
#  'Outlander (book series)',
#  'Cloudsplitter',
#  'Robert Musil',
#  'This Earth of Mankind',
#  'A Spoke in the Wheel',
#  'Horatio Hornblower',
#  "Midnight's Children",
#  "Hunger's Brides",
#  'Lymond Chronicles',
#  'Anak Semua Bangsa',
#  'Ninety-Three',
#  'Fortunata y Jacinta',
#  'The Emigrants (novels)',
#  'Thaddeus of Warsaw',
#  'Ben-Hur: A Tale of the Christ',
#  'The Man Without Qualities',
#  "Chanakya's Chant",
#  'The Last Kabbalist of Lisbon',
#  'Island Beneath the Sea',
#  'Rumah Kaca',
#  'The Last of the Mohicans',
#  'The Roman Mysteries',
#  "Morgan's Run",
#  'Ponniyin Selvan',
#  'Lady of the Glen',
#  "Hades' Daughter",
#  'Joseph Henry Shorthouse',
#  'The Warsaw Anagrams',
#  'The Master of Hestviken',
#  'Grail Prince',
#  'Death Comes for the Archbishop',
#  'Les Rois maudits',
#  'Captain Alatriste',
#  'Baltasar and Blimunda',
#  'Kamienie na szaniec',
#  'The Last Crossing',
#  'Anne of Geierstein',
#  'Vengeance (Jonas book)',
#  'Volga Se Ganga',
#  'Night Thoughts of a Classical Physicist',
#  'Jack Maggs',
#  'And Quiet Flows the Don',
#  'Child of All Nations',
#  'Silence (Endō novel)',
#  'The Woman Who had Two Navels',
#  'Quentin Durward',
#  'Alfarrábios',
#  'Cézanne’s Quarry',
#  'The Grail Quest',
#  'River God',
#  'Season of the Jew',
#  'The Fifth Queen',
#  'Angelique (French series)',
#  'Veyipadagalu',
#  'The Coffee Trader',
#  'George Jonas',
#  'The Hunchback of Notre Dame',
#  'Robert Hugh Benson',
#  'Chia Black Dragon',
#  'The Saxon Stories',
#  'An Instance of the Fingerpost',
#  'A Tale of Old Mortality',
#  'Porius: A Romance of the Dark Ages',
#  'The Load of Unicorn',
#  'The Athenian Murders',
#  'The Road to Wellville',
#  'Prince of Foxes',
#  'Lee and Grant at Appomattox',
#  'The Far Pavilions',
#  'Sergeant Lamb novels',
#  'The Trilogy',
#  'Twenty Years After',
#  'The General in his Labyrinth',
#  'The Home and the World',
#  'Bring up the Bodies',
#  'Estebanillo González',
#  'Number the Stars',
#  'As Minas de Prata',
#  'The Fair Maid of Perth',
#  'The White Guard',
#  'Aag Ka Darya',
#  'A Council of Dolls',
#  'The Afghan Campaign',
#  'The Colony of Unrequited Dreams',
#  'A Star Called Henry',
#  'The Blood of Lorraine',
#  'Shelby Foote',
#  'The Bridge on the Drina',
#  'Year of Wonders',
#  'A Body in the Bath House',
#  'Oscar and Lucinda',
#  'The Cloister and the Hearth',
#  'Arthur Phillips',
#  'Three Day Road',
#  'The Other Boleyn Girl',
#  'The Red Wheel',
#  'Leo Africanus',
#  'Unburnable',
#  'The Jupiter Myth',
#  'Know Ye Not Agincourt?',
#  'Push Not the River',
#  'The Heretic: A Novel of the Inquisition',
#  'Brazil Red',
#  'Kathleen Winsor',
#  'Caballero: A Historical Novel',
#  'The Legend of Thyl Ulenspiegel and Lamme Goedzak',
#  'The Greenlanders',
#  'Sword at Sunset',
#  'The Saxon Shore',
#  'Khaak aur Khoon',
#  'The Killer Angels',
#  'The Lambing Flat',
#  'A Tale of Two Cities',
#  'Roots: The Saga of an American Family',
#  'The Orenda',
#  'An Officer and a Spy',
#  'Romance of the Three Kingdoms',
#  'Bolitho Novels',
#  'Richard Adams',
#  'The Travels of Jaimie McPheeters',
#  'Jane Smiley',
#  'The Long Ships',
#  'My Theodosia',
#  'Witiko of Prčice',
#  'Karan Ghelo',
#  'True History of the Kelly Gang',
#  'Out of This Furnace',
#  'Empire of the Moghul',
#  'Lazarillo de Tormes',
#  'M. M. Kaye',
#  'Mikhail Sholokhov',
#  'The History of Henry Esmond',
#  'Memoirs of Hadrian',
#  'Numantine War',
#  'The Sorrow of War',
#  'Eagle in the Snow',
#  'Dublin: Foundation',
#  'Tales of the Alhambra',
#  'Shahab Nama',
#  'Facundo',
#  'Cue for Treason',
#  'The Tale of Genji',
#  'Aubrey–Maturin series',
#  'The Thorn Birds',
#  'I, Claudius',
#  'Here Be Dragons',
#  'El Buscón',
#  'The Deer and the Cauldron',
#  'Bila Yarrudhanggalangdhuray',
#  'The Book Thief',
#  'The Palaeologian Dynasty. The Rise and Fall of Byzantium',
#  'The Feast of the Goat',
#  'Bumi Manusia',
#  "The Devil's Brood",
#  'Romola',
#  'Charles Reade',
#  'List of fiction set in ancient Greece',
#  'The Reckoning (1991 novel)',
#  'The Black Tulip',
#  'Martin Dressler: The Tale of an American Dreamer',
#  'Gates of Fire',
#  'Shadow Country',
#  'Babouk',
#  'Empress Orchid',
#  "Jamrach's Menagerie",
#  'Royal Escape',
#  'The Kingdom of This World',
#  'Rachel Dyer: a North American Story',
#  'Cartucho',
#  'The Silver Pigs',
#  'Jejak Langkah',
#  'Lady of the Forest',
#  'Episodios Nacionales',
#  'The Confessions of Nat Turner',
#  'The Missing Italian Girl',
#  'The Persian Boy',
#  'A Struggle for Rome',
#  'Jasper Jones',
#  'The Life of Klim Samgin',
#  'The Memoirs of Cleopatra',
#  'The Guarani',
#  'Fatelessness',
#  'In the Time of the Butterflies',
#  'Miyamoto Musashi',
#  'Giuseppe Tomasi di Lampedusa',
#  'Santa Evita',
#  'Shadow Patriots',
#  'Tides of War',
#  'C V Raman Pillai',
#  'Company of Liars',
#  'Ivanhoe',
#  'Sister Fidelma',
#  'Peveril of the Peak',
#  'My Tender Matador',
#  'Winter in Madrid',
#  'The Fortunes of Perkin Warbeck',
#  'The Last of the Wine',
#  'The Lady of the Wheel',
#  'The Leopard',
#  'O Tempo e o Vento',
#  'The Power and the Glory',
#  'Ride the Wind',
#  'The Fencing Master',
#  'The Wishing Game',
#  'Alessandro Manzoni',
#  'Neamat Imam',
#  'Mona Susan Power',
#  'Fire from Heaven',
#  'Kristin Lavransdatter',
#  'Jane Porter',
#  'Baudolino',
#  'War of Canudos',
#  'The Heart of Mid-Lothian',
#  'The Egyptian',
#  'The Playmaker',
#  'The Sunne in Splendour',
#  'Under the Eagle',
#  'The Thousand Autumns of Jacob de Zoet',
#  'Logan, a Family History',
#  'Goat Song',
#  'The Pillars of the Earth',
#  'The Sorrow of Belgium',
#  'The Story of the Stone',
#  'Across Five Aprils',
#  'The Secret River',
#  'Cryptonomicon',
#  'I Am a Barbarian',
#  'True Women',
#  "Barnaby Rudge: A Tale of the Riots of 'Eighty",
#  'Il Gattopardo',
#  'Come Rack! Come Rope!',
#  'In the Skin of a Lion',
#  'Kay the Left-Handed',
#  'Wolf Hall',
#  'Masters of Rome',
#  'Mason & Dixon',
#  'The Knights of the Cross',
#  'The Prague Cemetery',
#  'Les Misérables',
#  'Imperial Woman',
#  'Alex Haley',
#  'War Comes to Willy Freeman',
#  'Tatjana Soli',
#  'A Place of Greater Safety',
#  'Life and Fate',
#  'Álvar Fáñez',
#  'La regenta',
#  'The Luminaries',
#  'John Inglesant',
#  'The Tale of the Heike',
#  'Redgauntlet',
#  'Measuring the World',
#  'Laura Blundy',
#  'The Baroque Cycle',
#  'The Betrothed (Manzoni novel)',
#  'Count Belisarius',
#  'Holy Warrior',
#  'The Sicilian',
#  'The Three Musketeers',
#  'The Flashman Papers',
#  'Diary of an Ordinary Woman',
#  'The Vicomte de Bragelonne',
#  "King's Man",
#  'Ireland: Awakening',
#  'El húsar',
#  'The Islands of Unwisdom']

# %%
hnp.unfiltered_pages_class_dict['Frank Yerby']
# Out:
# 'book'

# %%
x = 'Musashi_(novel)'

# %%
wc = WikiClassify(x)
wc.classify_page_by_summary()
wc.parsed_json
# Out:
# {'class': 'book'}

# %%
wc.classify_page_by_first_sentence(x)
wc.parsed_json
# Out:
# {'class': 'book'}

# %%
wc.classify_page_by_first_comma(x)
wc.parsed_json
# Out:
# {'class': 'book'}

# %%
class WikiClassify:
    """
    Classify wikipedia articles
    """

    def __init__(self, w_page):
        self.llm = Ollama(model="llama3")
        self.wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')
        self.w_page = w_page
        self.query_summary()

    def query_summary(self):

        self.w_summary = self.wiki.page(self.w_page).summary
        self.w_summary_to_first_period = self.w_summary.split('.')[0]
        self.w_summary_to_first_comma = self.w_summary.split(',')[0]

    def classify_page_to_first_period(self):
        self.classify_page_by_w_text(w_text = self.w_summary_to_first_period)

    def classify_page_to_first_comma(self):
        self.classify_page_by_w_text(w_text = self.w_summary_to_first_comma)

    def classify_page_by_summary(self):
        self.classify_page_by_w_text(w_text = self.w_summary)
        
    def classify_page_by_w_text(self, w_text):
        """
        For a wikipedia page, classify it as belonging to a novel, an author, or neither ("other")
        """

        output1 = '<result>\n{\n"class": "author"\n}\n</result>'
        output2 = '<result>\n{\n"class": "book"\n}\n</result>'
        output3 = '<result>\n{\n"class": "other"\n}\n</result>'
        
        prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, determine if the wikipedia page is a page for an author, a book, or something else.\
        If it is a page for an author (not a book), add the value author to the JSON with the key class. \
        If it is a page for a book (not an author), add the value book to the JSON with the key class. \
        If it is neither for a book nor an author, add the value other to the JSON with the key class \
        Finally, surround your JSON output with <result></result> tags. \
        \
        Ensure the JSON output has one key, class, and one value, which can either be author, book, or other.\
        Do not return any other type of output.\
        \
        Here is the text from the wikipedia article for this book: "
        
        
        
        end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, determine if the wikipedia page is a page for an author, a book, or something else.\
        If it is a page for an author (not a book), add the value author to the JSON with the key class. \
        If it is a page for a book (not an author), add the value book to the JSON with the key class. \
        If it is neither for a book nor an author, add the value other to the JSON with the key class \
        \
        Ensure the JSON output has one key, class, and one value, which can either be author,book, or other.\
        Do not return any other type of output.\
        \
        Finally, surround your JSON output with <result></result> tags.\
        The three allowable outputs are: "
        
                
        self.llm_response = self.llm(prompt + w_text + end_prompt + output1 + "or " + output2 + "or " + output3)
        self.parse_response()

    def parse_response(self):

        json_string = self.llm_response.split('<result>')[1].split('</result>')[0]
        self.parsed_json = json.loads(json_string.strip())

# %%
wc = WikiClassify()
wc.classify_page()

# %%
class SaveWork:
    """
    This is great work so far. We are able to pass a book's wiki page title, query it on wikipedia, \
    parse the article, and extract key info: author, title, and city, and country.
    """
    def __init__(self):
        self.llm = Ollama(model="llama3")
        self.wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')
        return 

    def pull_book(self, wpage ="Musashi_(novel)" ):

        prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, find the book's title and add it to the JSON with the key 'title'.\
        Next, find the book's author and add it to the JSON with the key 'author'.\
        Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
        you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
        Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
        If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
        with the key 'country'. Finally, surround your JSON output with <result></result> tags. \
        Here is the text from the wikipedia article for this book: "
        
        
        
        end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, find the book's title and add it to the JSON with the key 'title'.\
        Next, find the book's author and add it to the JSON with the key 'author'.\
        Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
        you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
        Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
        If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
        with the key 'country'. Finally, surround your JSON output with <result></result> tags."
                
        self.llm_response = self.llm(prompt + self.wiki.page(wpage).text + end_prompt)

    def parse_response(self):

        json_string = self.llm_response.split('<result>')[1].split('</result>')[0]
        self.parsed_json = json.loads(json_string.strip())
        
sw = SaveWork()
sw.pull_book(wpage='Adalbert Stifter')
sw.parse_response()

# %%
wc.wiki.page()

# %%
wc.llm_response
# Out:
# '<result>\n{\n"class": "book"\n}\n</result>'

# %%
wc.parsed_json['class']
# Out:
# 'other'

# %%
wc.parse_response()

# %%
wc.classify_page('Adalbert_Stifter')
wc.parsed_json
# Out:
# {'class': 'author'}

# %%
wc.classify_page('International_Booker_Prize')
wc.parsed_json
# Out:
# {'class': 'other'}

# %%
wc.llm_response
# Out:
# '<result>\n{\n"class": "author"\n}\n</result>'

# %%
x = wc.llm_response.split('<result>')[1].split('</result>')[0]

# %%
x
# Out:
# '\n{\n"class": "author",\n}\n'

# %%
json.loads(x.strip())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[244], line 1
# ----> 1 json.loads(x.strip())
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 3 column 1 (char 21)

# %%
json.loads(wc.llm_response.split('<result>')[1].split('</result>')[0].strip())
# Out:
# {'class': 'book'}

# %%
wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')  
hns = wiki.page("List_of_historical_novels")

# %%
x = hns.sections

# %%
y = hns.links

# %%
list(y.keys())
# Out:
# ['1715 Jacobite rising',
#  '1745 Jacobite rising',
#  '1960 United States presidential election',
#  'A Body in the Bath House',
#  'A Council of Dolls',
#  'A Dying Light in Corduba',
#  'A Journal of the Plague Year',
#  'A Place of Greater Safety',
#  'A Spoke in the Wheel',
#  'A Star Called Henry',
#  'A Struggle for Rome',
#  'A Tale of Old Mortality',
#  'A Tale of Two Cities',
#  'A fekete város',
#  'Aag Ka Darya',
#  'Aangan (novel)',
#  'Aaron Burr',
#  'Abd-ar-Rahman III',
#  'Abd ar-Rahman II',
#  'Across Five Aprils',
#  'Adalbert Stifter',
#  'Aden Polydoros',
#  'Akhenaten',
#  'Akilan',
#  'Alans',
#  'Alaska',
#  'Alaska (novel)',
#  'Alberto Laiseca',
#  'Alberto Vázquez-Figueroa',
#  'Alcibiades',
#  'Alejandro Núñez Alonso',
#  'Alejo Carpentier',
#  'Aleksander Kamiński',
#  'Aleksandr Solzhenitsyn',
#  'Alessandro Baricco',
#  'Alessandro Manzoni',
#  'Alex Haley',
#  'Alex Rutherford',
#  'Alexander Farnese, Duke of Parma',
#  'Alexander the Great',
#  'Alexandre Dumas, père',
#  'Alfarrábios',
#  'Alfonso VIII of Castile',
#  'Alfonso VII of León and Castile',
#  'Alfonso XI of Castile',
#  'Alfonso X of Castile',
#  'Alfred the Great',
#  'Alias Grace',
#  'All That Matters (novel)',
#  'Allan Gurganus',
#  'Almohad Caliphate',
#  'Almudena de Arteaga',
#  'Alonso Fernández de Avellaneda',
#  'Alonso Pérez de Guzmán',
#  'Alonso de Ojeda',
#  'Alta California',
#  'Amenhotep III',
#  'American Civil War',
#  'American Revolution',
#  'Amin Maalouf',
#  'Amita Kanekar',
#  'Amitav Ghosh',
#  'Amsterdam',
#  'Amy Robsart',
#  'An Angel in Australia',
#  'An Instance of the Fingerpost',
#  'An Insular Possession',
#  'An Officer and a Spy',
#  'Ana de Mendoza, Princess of Eboli',
#  'Anak Semua Bangsa',
#  'Anandamath',
#  'Anchee Min',
#  'And Quiet Flows the Don',
#  'Andersonville (novel)',
#  'Andersonville National Historic Site',
#  'Andrei Bely',
#  'Andrew Vachss',
#  'Andrés de Urdaneta',
#  'Angelique (French series)',
#  'Angelo F. Coniglio',
#  'Angus Donald',
#  'Anita Heiss',
#  'Anne & Serge Golon',
#  'Anne Boleyn',
#  'Anne of Cleves',
#  'Anne of Geierstein',
#  'Antebellum era',
#  'Antonio Cavanillas de Blas',
#  'Antonio Gómez Rufo',
#  'Antonio Pérez Henares',
#  'Antonio de Nebrija',
#  'Anwar Sadat',
#  'Anya Seton',
#  'Arevaci',
#  'Artemisia I of Caria',
#  'Arthur Conan Doyle',
#  'Arthur Phillips',
#  'Arthur Wellesley, 1st Duke of Wellington',
#  'Arturo Barea',
#  'Arturo Pérez-Reverte',
#  'As Minas de Prata',
#  'Ashoka',
#  'Ashwin Sanghi',
#  'Assassination of Julius Caesar',
#  'Atlantic slave trade',
#  'Aubrey–Maturin series',
#  'Aurangzeb',
#  'Australian gold rushes',
#  'Avalon (novel)',
#  'Ay (pharaoh)',
#  'Aztec (book)',
#  'Aztec (novel)',
#  'Aztec Autumn',
#  'Babouk',
#  'Babur',
#  'Baltasar Magro',
#  'Baltasar and Blimunda',
#  'Bangladesh famine of 1974',
#  'Bankim Chandra Chattopadhyay',
#  'Bano (novel)',
#  'Bao Ninh',
#  'Barbara Corrado Pope',
#  "Barnaby Rudge: A Tale of the Riots of 'Eighty",
#  'Barry Unsworth',
#  'Battle of Berlin',
#  'Battle of Cartagena de Indias',
#  'Battle of Las Navas de Tolosa',
#  'Battle of Lepanto',
#  'Battle of Simancas',
#  'Battle of St. Quentin (1557)',
#  'Battle of Teba',
#  'Battle of Thermopylae',
#  'Baudolino',
#  'Beatrice of Portugal',
#  'Belisarius',
#  'Belle Époque',
#  'Beloved (novel)',
#  'Ben-Hur: A Tale of the Christ',
#  'Benito Pérez Galdós',
#  'Bernard Cornwell',
#  'Bernardo de Gálvez',
#  'Bertrand du Guesclin',
#  'Bila Yarrudhanggalangdhuray',
#  'Blanche II of Navarre',
#  'Blanche of Bourbon',
#  'Blas de Lezo',
#  'Blood Red, Snow White',
#  'Blue Division',
#  'Boarding school',
#  'Bolesław Prus',
#  'Bolitho Novels',
#  'Boris Pasternak',
#  'Brazil Red',
#  'Brian Boru',
#  'Brian Cleeve',
#  'Bring Larks and Heroes',
#  'Bring up the Bodies',
#  'Brother Jonathan (novel)',
#  'Bumi Manusia',
#  'Burr (novel)',
#  'Byzantine',
#  'C. J. Sansom',
#  'C. S. Forester',
#  'C V Raman Pillai',
#  'Caballero: A Historical Novel',
#  'Caligula',
#  'Cantabri',
#  'Cao Xueqin',
#  'Captain Alatriste',
#  'Captain Blood (novel)',
#  'Captain from Castile (novel)',
#  'Caratacus',
#  'Caravans (novel)',
#  'Caribbean (novel)',
#  'Carlisle Indian Industrial School',
#  'Carlist Wars',
#  'Carol Birch',
#  'Caroline Lawrence',
#  'Cartucho',
#  'Catherine of Lancaster',
#  'Ceara',
#  'Cecelia Holland',
#  'Celtiberians',
#  'Centennial (novel)',
#  "Chanakya's Chant",
#  'Charles De Coster',
#  'Charles Dickens',
#  'Charles Frazier',
#  'Charles III of Spain',
#  'Charles II of England',
#  'Charles I of England',
#  'Charles Kingsley',
#  'Charles Reade',
#  'Chesapeake (novel)',
#  'Chesapeake Bay',
#  'Chia Black Dragon',
#  'Child of All Nations',
#  'Chola dynasty',
#  'Christopher Columbus',
#  'Christopher Wren',
#  'Classical antiquity',
#  'Cleopatra VII',
#  'Cloudsplitter',
#  'Cold Mountain (novel)',
#  'Colleen McCullough',
#  'Colonial Brazil',
#  'Colorado',
#  'Come Rack! Come Rope!',
#  'Company of Liars',
#  'Conquest of Mexico',
#  'Convent of Mafra',
#  'Corinth',
#  'Count Belisarius',
#  'Craig Silvey',
#  'Cristina Rodríguez (journalist)',
#  'Cry of the Peacock (novel)',
#  'Cryptonomicon',
#  'Cue for Treason',
#  'Culper Ring',
#  'Cynthia Harnett',
#  'Cézanne’s Quarry',
#  "D'Artagnan romances",
#  'Daniel Defoe',
#  'Daniel Kehlmann',
#  'David Gemmell',
#  'David Liss',
#  'David Mitchell (author)',
#  'Death Comes for the Archbishop',
#  'Delmarva Peninsula',
#  'Dennis Bock',
#  'Destiny in Sydney (novel)',
#  'Dharmaraja (novel)',
#  'Diana Gabaldon',
#  'Diary of an Ordinary Woman',
#  'Doctor Zhivago (novel)',
#  'Domingo F. Sarmiento',
#  'Don Quixote',
#  'Dorothy Dunnett',
#  'Dos de Mayo Uprising',
#  'Douglas Reeman',
#  'Dragon Seed (novel)',
#  'Dreyfus affair',
#  'Dublin: Foundation',
#  'Duchy of Savoy',
#  'Dudley Pope',
#  'Duke of Alba',
#  'Durgeshnandini',
#  'Dutch colonialism in Southeast Asia',
#  'E. L. Doctorow',
#  'Eagle in the Snow',
#  'Eastern Front (World War II)',
#  'Edgar Rice Burroughs',
#  'Edgar Watson',
#  'Edith Pargeter',
#  'Edo period',
#  'Eduardo Mendoza Garriga',
#  'Edward P. Jones',
#  'Edward Rosset',
#  'Edward Rutherfurd',
#  'Eiji Yoshikawa',
#  'El Buscón',
#  'El combate perpetuo',
#  'El filibusterismo',
#  'El húsar',
#  'Eleanor Catton',
#  'Eleanor of Austria',
#  'Elizabeth Barrett Browning',
#  'Emirate of Granada',
#  'Empire of the Moghul',
#  'Empire of the Sun (novel)',
#  'Empress (novel)',
#  'Empress Dowager Cixi',
#  'Empress Orchid',
#  'English Renaissance theatre',
#  'Enrique Gil y Carrasco',
#  'Episodios Nacionales',
#  'Ernest K. Gann',
#  'Ernesto Sabato',
#  'Estebanillo González',
#  'Esther Forbes',
#  'Euclides da Cunha',
#  'Eva Díaz Pérez',
#  'Eva Perón',
#  'Exodus (Uris novel)',
#  'F. Sionil José',
#  'Facundo',
#  'Fall of Constantinople',
#  'Fatelessness',
#  'Felix Dahn',
#  'Ferdinand Columbus',
#  'Ferdinand II of León',
#  'Ferdinand I of León',
#  'Ferdinand Magellan',
#  'Fernando Fernán-Gómez',
#  'Fernando Fernán Gómez',
#  'Fernando Martínez Laínez',
#  'Fernando de Rojas',
#  'Fiction set in ancient Rome',
#  'Fingersmith (novel)',
#  'Fire from Heaven',
#  'First Anglo-Afghan War',
#  'First Jewish–Roman War',
#  'First Opium War',
#  'Flashman (novel)',
#  'Footsteps (novel)',
#  'Ford Madox Ford',
#  'Forever Amber (novel)',
#  'Fortunata y Jacinta',
#  'Francisco Navarro Villoslada',
#  'Francisco Pizarro',
#  'Francisco de Quevedo',
#  'Frank Yerby',
#  'Frans G. Bengtsson',
#  'French Revolution',
#  'French and Indian War',
#  'French invasion of Russia',
#  'Funeral Games (novel)',
#  'Gabriel García Márquez',
#  'Gai-Jin (novel)',
#  'Galahad',
#  'Gary Jennings (author)',
#  'Gates of Fire',
#  'Gautama Buddha',
#  'Genpei War',
#  'Geoffrey Trease',
#  'George Eliot',
#  'George Jonas',
#  'George Leonardos',
#  'George MacDonald Fraser',
#  'George Washington',
#  'Georgette Heyer',
#  'Geraldine Brooks (writer)',
#  "German Peasants' War",
#  'Gilded Age',
#  'Gina B. Nahai',
#  'Girl with a Pearl Earring (novel)',
#  'Girolamo Savonarola',
#  'Gisbert Haefs',
#  'Giuseppe Garibaldi',
#  'Giuseppe Tomasi di Lampedusa',
#  'Glorious Revolution',
#  'Goat Song',
#  'Gone with the Wind (novel)',
#  'Gonzalo Fernández de Córdoba',
#  'Gonzalo Guerrero',
#  'Gonzalo Pizarro',
#  'Gonzalo Torrente Ballester',
#  'Gordon riots',
#  'Gore Vidal',
#  'Gothic War (535-554)',
#  'Graham Greene',
#  'Grail Prince',
#  'Gray Ranks',
#  'Great Plague of London',
#  'Greco-Turkish War (1919–1922)',
#  'Greek theatre',
#  'Guelphs and Ghibellines',
#  'Guy Endore',
#  'Guy Vanderhaeghe',
#  'H. Rider Haggard',
#  "Hades' Daughter",
#  'Hadrian',
#  'Haitian Revolution',
#  'Hanna Mina',
#  'Hasekura Tsunenaga',
#  'Hatshepsut',
#  'Hawaii',
#  'Hawaii (novel)',
#  'Hawksmoor (novel)',
#  'Henry III of Castile',
#  'Henry IV, Holy Roman Emperor',
#  'Henry VII of England',
#  'Henry of Castile the Senator',
#  'Henryk Sienkiewicz',
#  'Here Be Dragons',
#  'Hereward the Wake',
#  'Hereward the Wake (novel)',
#  'Herman Wouk',
#  'Hernando de Soto',
#  'Hernán Cortés',
#  'Hilary Mantel',
#  'Hild (novel)',
#  'Historical fiction',
#  'Historical novel',
#  'History of Athens',
#  'Holy Warrior',
#  'Horatio Hornblower',
#  'Horemheb',
#  'Hugo Claus',
#  "Hunger's Brides",
#  'Hypatia (novel)',
#  'I, Claudius',
#  'I Am a Barbarian',
#  'Iberia',
#  'Ibis trilogy',
#  'Ides of March (novel)',
#  'Ignacio del Valle',
#  'Il Gattopardo',
#  'Imperial Woman',
#  'In the Skin of a Lion',
#  'In the Time of the Butterflies',
#  'Indian Rebellion of 1857',
#  'Inside, Outside',
#  'Iny Lorentz',
#  'Iracema',
#  'Iranian Revolution',
#  'Ireland: Awakening',
#  'Irene Hunt',
#  'Irish revolutionary period',
#  'Isabel Allende',
#  'Isabel San Sebastián',
#  'Isabella II of Spain',
#  'Isabella I of Castile',
#  'Island Beneath the Sea',
#  'Israeli Declaration of Independence',
#  'Ivanhoe',
#  'Ivo Andrić',
#  'J. G. Ballard',
#  'J. G. Farrell',
#  'Jack Maggs',
#  'Jack Whyte',
#  'Jacobitism',
#  'Jalna (novel series)',
#  'James A. Michener',
#  'James A Michener',
#  'James Clavell',
#  'James Conroyd Martin',
#  'James Douglas, Lord of Douglas',
#  'James Fenimore Cooper',
#  'James Lincoln Collier',
#  'James Michener',
#  'James Patterson',
#  "Jamrach's Menagerie",
#  'Jane Porter',
#  'Jane Smiley',
#  'Janice Woods Windle',
#  'January Uprising',
#  'Jasper Jones',
#  'Jean-Christophe Rufin',
#  'Jean Plaidy',
#  'Jeffrey Eugenides',
#  'Jejak Langkah',
#  'Jennifer Roberson',
#  'Jerónimo Tristante',
#  'Jessie Burton',
#  'Jesús Sánchez Adalid',
#  'Jews in Iran',
#  'Jin Yong',
#  'Joanna of Castile',
#  'Johannes Vermeer',
#  'John Brown (abolitionist)',
#  'John Cowper Powys',
#  'John Harvey Kellogg',
#  'John Inglesant',
#  'John Neal (writer)',
#  'John of Austria',
#  'Johnny Tremain',
#  'Jonathan Coe',
#  'Jorge Manrique',
#  'Jose Carlos Somoza',
#  'Joseph Boyden',
#  'Joseph Conrad',
#  'Joseph Henry Shorthouse',
#  'José Calvo Poyato',
#  'José Gómez de Arteche',
#  'José Javier Esparza',
#  'José María Pérez González',
#  'José Rizal',
#  'José Saramago',
#  'José de Alencar',
#  'José de Espronceda',
#  'Journey (novel)',
#  'Jovita González',
#  'João Aguiar (writer)',
#  'Juan Eslava Galán',
#  'Juan Manuel, Prince of Villena',
#  'Juan Pedro Cosano',
#  'Juan Prim, 1st Marquis of los Castillejos',
#  'Juan Sebastián Elcano',
#  'Juan de Tassis, 2nd Count of Villamediana',
#  'Juda Barber',
#  'Judith (novel)',
#  'Julia Alvarez',
#  'Julian (historical novel)',
#  'Julian Stockwin',
#  'Julian the Apostate',
#  'Julie Myerson',
#  'Kalki Krishnamurthy',
#  'Kamienie na szaniec',
#  'Kangxi Emperor',
#  'Karan Ghelo',
#  'Karen Maitland',
#  'Kate Grenville',
#  "Kate O'Brien (novelist)",
#  'Katharine Howard',
#  'Katherine (Seton novel)',
#  'Kathleen Winsor',
#  'Kay the Left-Handed',
#  'Kelly Gang',
#  'Ken Follett',
#  'Kenilworth (novel)',
#  'Kenmu Restoration',
#  'Kenneth Roberts (author)',
#  'Khaak aur Khoon',
#  'Khadija Mastoor',
#  'Khmelnytsky Uprising',
#  'Khufu',
#  "King's Man",
#  'King Jesus',
#  'King Rat (1962 novel)',
#  "King Solomon's Mines",
#  'Know Ye Not Agincourt?',
#  'Kristin Lavransdatter',
#  'Kublai Khan',
#  'Kydd (novel)',
#  'Kálmán Mikszáth',
#  'La Celestina',
#  'La Malinche',
#  'La Reine Margot (novel)',
#  'La regenta',
#  'Lady of the Forest',
#  'Lady of the Glen',
#  'Lanny Budd',
#  'Laura Blundy',
#  'Laura Esquivel',
#  'Lauren Willig',
#  'Lawrence Hill',
#  'Lazarillo de Tormes',
#  'Lee and Grant at Appomattox',
#  'Leo Africanus',
#  'Leo Tolstoy',
#  'Leon Uris',
#  'Leopoldo Alas',
#  'Les Misérables',
#  'Les Rois maudits',
#  'Leslie Barringer',
#  'Lew Wallace',
#  'León Arsenal',
#  'Life and Fate',
#  'Lincoln (novel)',
#  'Linda Sue Park',
#  'Lindsey Davis',
#  'Lion of Ireland',
#  'Lion of Macedon',
#  'Lisbon Massacre',
#  'List of fiction set in ancient Greece',
#  'List of fiction set in ancient Rome',
#  'List of historical fiction by time period',
#  'List of historical novels in Indian languages',
#  'List of historical video games',
#  'Liuvigild',
#  'Loaísa expedition',
#  'Logan, a Family History',
#  'Lois Lowry',
#  'Lope de Aguirre',
#  'Lope de Vega',
#  "Lord Dunmore's War",
#  'Louis XI',
#  'Louis XIV',
#  'Louis de Wohl',
#  'Lucia St. Clair Robson',
#  'Luis Coloma',
#  'Luis Delgado Bañón',
#  'Luis García Jambrina',
#  'Luther Blissett',
#  'Lydia Bailey (novel)',
#  'Lymond Chronicles',
#  'László Passuth',
#  'M. M. Kaye',
#  'MacKinlay Kantor',
#  'Madison Smartt Bell',
#  "Magellan's circumnavigation",
#  'Magnus Maximus',
#  'Mahapandit Rahul Sankrityayan',
#  'Manuel Chaves Nogales',
#  'Manuel de Godoy, Prince of the Peace',
#  'Marcos Aguinis',
#  'Marcus Sedgwick',
#  'Margaret Atwood',
#  'Margaret Forster',
#  'Margaret George',
#  'Margaret Irwin (novelist)',
#  'Margaret Mitchell',
#  'Margarita Torres',
#  'Marguerite Yourcenar',
#  'Mariano José de Larra',
#  'Marie-Elena John',
#  'Mario Puzo',
#  'Mario Vargas Llosa',
#  'Marion Zimmer Bradley',
#  'Markus Zusak',
#  'Marthandavarma (novel)',
#  'Marthese Fenech',
#  'Martin Dressler: The Tale of an American Dreamer',
#  'Mary Boleyn',
#  'Mary Renault',
#  'Mary Shelley',
#  'María de Molina',
#  'Mason & Dixon',
#  'Massacre of Glencoe',
#  'Masters of Rome',
#  'Matilde Asensi',
#  'Maurice Druon',
#  'Maurice Shadbolt',
#  'Mavis Cheek',
#  'Max Havelaar',
#  'Maxim Gorky',
#  'Mazo de la Roche',
#  'Measuring the World',
#  'Memoirs of Hadrian',
#  'Mexican Revolution',
#  'Mexico (novel)',
#  'Micah Clarke',
#  'Michael Ondaatje',
#  'Michael Shaara',
#  'Middlesex (novel)',
#  "Midnight's Children",
#  'Miguel Delibes',
#  'Miguel López de Legazpi',
#  'Miguel de Cervantes Saavedra',
#  'Mika Waltari',
#  'Mikhail Bulgakov',
#  'Mikhail Sholokhov',
#  'Military history of Australia during World War II',
#  'Minas Gerais',
#  'Miyamoto Musashi',
#  'Moghul Empire',
#  'Mollie Hunter',
#  'Mona Susan Power',
#  'Monmouth Rebellion',
#  "Morgan's Run",
#  'Morgan Llywelyn',
#  'Moshe Shamir',
#  'Multatuli',
#  'Munich massacre',
#  'Murasaki Shikibu',
#  'Musashi (novel)',
#  'Mutiny of Aranjuez',
#  'My Tender Matador',
#  'My Theodosia',
#  'Mérida, Spain',
#  'Nancy McKenzie',
#  'Nandshankar Mehta',
#  'Napoleon',
#  'Napoleonic Wars',
#  'Napoleonic era',
#  'Naseem Hijazi',
#  'Neal Stephenson',
#  'Neamat Imam',
#  'Nellie Campobello',
#  'Nerida Newton',
#  'Nero',
#  'New Kingdom of Egypt',
#  'New Mexico Territory',
#  'New York (novel)',
#  'Nicholas Hawksmoor',
#  'Nick Joaquin',
#  'Nicola Griffith',
#  'Nicolás de Ovando',
#  'Night Thoughts of a Classical Physicist',
#  'Ninety-Three',
#  'Noble House (book)',
#  'Noli Me Tángere (novel)',
#  'Nootka Island',
#  'Norfolk, England',
#  'Novel',
#  'Numantia',
#  'Numantine War',
#  'Number the Stars',
#  'O Tempo e o Vento',
#  'Octavio Sánchez-Machuca',
#  'Oldest Living Confederate Widow Tells All',
#  'Oliver Cromwell',
#  'On Heroes and Tombs',
#  'Operation Wrath of God',
#  'Order of Calatrava',
#  'Os Sertões',
#  'Oscar and Lucinda',
#  'Out of This Furnace',
#  'Outlander (book series)',
#  'Outlaw (novel)',
#  'Owen Glendower (novel)',
#  'Paleolithic',
#  'Pallava dynasty',
#  'Paloma Sánchez-Garnica',
#  'Parmenion',
#  'Parthiban Kanavu',
#  'Partition of India',
#  'Partitions of Poland',
#  "Patrick O'Brian",
#  'Patrick Redmond',
#  'Paul Kingsnorth',
#  'Paula Cifuentes',
#  'Pauline Gedge',
#  'Pazzi conspiracy',
#  'Pearl Buck',
#  'Pedro Lemebel',
#  'Pedro Santamaría',
#  'Pelagius of Asturias',
#  'Peloponnesian War',
#  'Peninsular War',
#  'Penobscot Expedition',
#  'Peony (novel)',
#  'Perkin Warbeck',
#  'Persecution of early Christians by the Romans',
#  'Peter Carey (novelist)',
#  'Peter Matthiessen',
#  'Peter Tremayne',
#  'Peter of Castile',
#  'Peveril of the Peak',
#  'Pharaoh (Prus novel)',
#  'Philip II of Spain',
#  'Philip IV of Spain',
#  'Philip V of Spain',
#  'Philippa Gregory',
#  'Pittsburgh',
#  'Po-on (novel)',
#  'Poland (novel)',
#  'Polish–Lithuanian Commonwealth',
#  'Ponniyin Selvan',
#  'Pope Gregory VII',
#  'Porius: A Romance of the Dark Ages',
#  'Porto',
#  'Prague (novel)',
#  'Pramoedya Ananta Toer',
#  'Prehistoric Britain',
#  'Prince of Foxes',
#  'Proselytism',
#  'Protestant Reformation',
#  'Protestant reformation',
#  'Province of Maryland',
#  'Publius Cornelius Scipio (consul 218 BC)',
#  'Punic Wars',
#  'Purge (novel)',
#  'Push Not the River',
#  'Q (novel)',
#  'Qin Shi Huang',
#  'Qing dynasty',
#  'Qudratullah Shahab',
#  'Quebec',
#  'Quentin Durward',
#  'Quintus Sertorius',
#  'Quo Vadis (novel)',
#  'Qurratulain Hyder',
#  'Rabindranath Tagore',
#  'Rachel Dyer: a North American Story',
#  'Rafael Leónidas Trujillo',
#  'Rafael Sabatini',
#  'Ragtime (novel)',
#  'Rajendra Chola I',
#  'Rajshingho',
#  'Ramage (novel)',
#  'Ramarajabahadur (novel)',
#  'Ramiro II of León',
#  'Ramón J. Sender',
#  'Ramón López Soler',
#  'Raptor (novel)',
#  'Razia Butt',
#  'Reconquista',
#  'Redemption (Uris novel)',
#  'Redgauntlet',
#  'Restoration (England)',
#  'Revolt of the Comuneros',
#  'Ricardo Fernández de la Reguera',
#  'Richard Adams',
#  'Richard Carvel',
#  'Richard Sharpe (fictional character)',
#  'Richard Zimler',
#  'Ride the Wind',
#  'Risorgimento',
#  'River God',
#  'Rob Roy (novel)',
#  'Robert E. Lee',
#  'Robert Graves',
#  'Robert Harris (novelist)',
#  'Robert Hugh Benson',
#  'Robert Lewis Taylor',
#  'Robert Musil',
#  'Robert the Bruce',
#  'Roddy Doyle',
#  'Roman Egypt',
#  'Romance of the Three Kingdoms',
#  'Romola',
#  'Roots: The Saga of an American Family',
#  'Rosemary Sutcliff',
#  'Royal Escape',
#  'Rumah Kaca',
#  'Russell Banks',
#  'Russian Civil War',
#  'Russian Revolution',
#  'Russka (novel)',
#  'SS Exodus',
#  'Sack of Rome (410)',
#  'Sacred Hunger',
#  'Salem witch trials',
#  'Salisbury',
#  'Salman Rushdie',
#  'Salvador de Madariaga',
#  'Salvatierra Castle',
#  'Salvatore Giuliano',
#  'Samuel Shellabarger',
#  'Sancho III of Castile',
#  'Santa Evita',
#  'Santiago Posteguillo',
#  'Sara Douglass',
#  'Sarah Dunant',
#  'Sarah Waters',
#  'Sarum (novel)',
#  'Scaramouche (novel)',
#  'Scouting',
#  'Season of the Jew',
#  'Second Persian invasion of Greece',
#  'Second Sino-Japanese War',
#  'Sergeant Lamb novels',
#  "Seven Years' War",
#  'Seventy-Six (novel)',
#  'Seville',
#  'Shadow Country',
#  'Shadow Patriots',
#  'Shahab Nama',
#  'Shaheen (novel)',
#  'Shan Sa',
#  'Sharon Kay Penman',
#  'Sheikh Mujibur Rahman',
#  'Shelby Foote',
#  "Sherman's March to the Sea",
#  'Shiloh (Foote novel)',
#  'Shusaku Endo',
#  'Shōgun (novel)',
#  'Shūsaku Endō',
#  'Siege of Carthage (Third Punic War)',
#  'Siege of Cádiz',
#  'Siege of Saragossa (1808)',
#  'Sigrid Undset',
#  'Silence (Endō novel)',
#  'Silk (novel)',
#  'Simon Scarrow',
#  'Sister Fidelma',
#  'Sivagamiyin Sabadham',
#  'Six-Day War',
#  'Smenkhkare',
#  'Socrates',
#  'Sofi Oksanen',
#  'Sor Juana',
#  'Spanish Armada',
#  'Spanish Road',
#  'Spanish conquest of the Aztec Empire',
#  'Spanish conquest of the Inca Empire',
#  'Standing Rock Indian Reservation',
#  'Stefan Żeromski',
#  'Stephen Crane',
#  'Stephen Marley (writer)',
#  'Steven Millhauser',
#  'Steven Pressfield',
#  'Suebi',
#  'Susana March',
#  'Sword at Sunset',
#  'T. C. Boyle',
#  'Tai-Pan',
#  'Tales of Count Lucanor',
#  'Tales of the Alhambra',
#  'Tartessos',
#  'Tatjana Soli',
#  'Teodor Jeske-Choiński',
#  'Terenci Moix',
#  'Teresa of Ávila',
#  'Teutonic Knights',
#  'Texas',
#  'Texas (novel)',
#  'Texas Revolution',
#  'Thaddeus of Warsaw',
#  'The Adventurer (novel)',
#  'The Afghan Campaign',
#  'The Antagonists (Gann novel)',
#  'The Athenian Murders',
#  'The Baroque Cycle',
#  'The Betrothed (Manzoni novel)',
#  'The Birth of Venus (novel)',
#  'The Black Coat',
#  'The Black Tulip',
#  'The Blood of Lorraine',
#  'The Book Thief',
#  'The Book of Negroes (novel)',
#  'The Bridge on the Drina',
#  'The City Beautiful (novel)',
#  'The Cloister and the Hearth',
#  'The Coffee Trader',
#  'The Colony of Unrequited Dreams',
#  'The Confessions of Nat Turner',
#  'The Conqueror (novel)',
#  'The Count of Monte Cristo',
#  'The Covenant (novel)',
#  'The Deer and the Cauldron',
#  'The Deluge (Polish history)',
#  "The Devil's Brood",
#  'The Eagle of the Ninth',
#  'The Egyptian',
#  'The Emigrants (novels)',
#  'The End of a Brave Man',
#  'The Fair Maid of Perth',
#  'The Faithful River',
#  'The Family (Mario Puzo novel)',
#  'The Far Pavilions',
#  'The Feast of the Goat',
#  'The Fencing Master',
#  'The Fifth Queen',
#  'The Flashman Papers',
#  'The Forest House',
#  'The Fort (novel)',
#  'The Fortunes of Perkin Warbeck',
#  'The Four Horsemen of the Apocalypse (Spanish novel)',
#  'The General in his Labyrinth',
#  'The Glory',
#  'The Gods of War',
#  'The Grail Quest',
#  'The Greenlanders',
#  'The Guarani',
#  'The Haj (novel)',
#  'The Heart of Jade',
#  'The Heart of Mid-Lothian',
#  'The Heretic: A Novel of the Inquisition',
#  'The History of Henry Esmond',
#  'The Home and the World',
#  'The Hope (novel)',
#  'The House of Niccolò',
#  'The Hunchback of Notre Dame',
#  'The Islands of Unwisdom',
#  'The Jade Peony',
#  'The Jester (novel)',
#  'The Journeyer',
#  'The Jupiter Myth',
#  'The Killer Angels',
#  'The Kingdom of This World',
#  'The Knights of the Cross',
#  'The Known World',
#  'The Lady of the Wheel',
#  'The Lambing Flat',
#  'The Last Crossing',
#  'The Last Empress (novel)',
#  'The Last Kabbalist of Lisbon',
#  'The Last of the Mohicans',
#  'The Last of the Wine',
#  'The Legend of Thyl Ulenspiegel and Lamme Goedzak',
#  'The Leopard',
#  'The Life of Klim Samgin',
#  'The Load of Unicorn',
#  'The Long Ships',
#  'The Lotus Eaters (novel)',
#  'The Luck of Barry Lyndon',
#  'The Luminaries',
#  'The Man Without Qualities',
#  'The March (novel)',
#  'The Mask of Apollo',
#  'The Master of Hestviken',
#  'The Memoirs of Cleopatra',
#  'The Miniaturist',
#  'The Missing Italian Girl',
#  'The Name of the Rose',
#  'The Orenda',
#  'The Other Boleyn Girl',
#  'The Palaeologian Dynasty. The Rise and Fall of Byzantium',
#  'The Persian Boy',
#  'The Pillars of the Earth',
#  'The Playmaker',
#  'The Power and the Glory',
#  'The Prague Cemetery',
#  'The Reckoning (1991 novel)',
#  'The Red Badge of Courage',
#  'The Red Wheel',
#  'The Renaissance',
#  'The Road to Wellville',
#  'The Roman Mysteries',
#  "The Rotters' Club (novel)",
#  'The Rover (novel)',
#  'The Samurai (novel)',
#  'The Saxon Shore',
#  'The Saxon Stories',
#  'The Secret River',
#  'The Sicilian',
#  'The Siege of Krishnapur',
#  'The Siege of Malta (novel)',
#  'The Silent People',
#  'The Silver Branch (Sutcliff novel)',
#  'The Silver Pigs',
#  'The Sorrow of Belgium',
#  'The Sorrow of War',
#  'The Source (novel)',
#  'The Story of the Stone',
#  'The Stronghold',
#  'The Sunne in Splendour',
#  'The Tale of Genji',
#  'The Tale of the Heike',
#  'The Talisman (Scott novel)',
#  'The Thorn Birds',
#  'The Thousand Autumns of Jacob de Zoet',
#  'The Three Musketeers',
#  'The Travels of Jaimie McPheeters',
#  'The Trilogy',
#  'The Turquoise (novel)',
#  'The Vicomte de Bragelonne',
#  ...]

# %%
x[2]
# Out:
# Section: Australia (1):
# The Playmaker and Bring Larks and Heroes by Thomas Keneally (18th century colonial Australia)
# Morgan's Run by Colleen McCullough (end of the 18th century)
# Destiny in Sydney by D. Manning Richards (1787–1902 Scots-Irish, Aboriginal, and Chinese family saga story)
# The Lambing Flat by Nerida Newton (mid-19th century Australian gold rushes)
# The Secret River by Kate Grenville (19th century colonial Australia)
# Jack Maggs by Peter Carey (19th century colonial Australia)
# The Thorn Birds by Colleen McCullough (end of the 19th century)
# True History of the Kelly Gang by Peter Carey (Kelly Gang, 1878–1880)
# An Angel in Australia by Thomas Keneally (World War II)
# Oscar and Lucinda by Peter Carey
# Jasper Jones by Craig Silvey (1960s Western Australia)
# Bila Yarrudhanggalangdhuray by Anita Heiss (19th century indigenous New South Wales)
# Subsections (0):

# %%
x
# Out:
# [Section: Afghanistan (1):
#  The Afghan Campaign by Steven Pressfield (Alexander the Great's invasion of the Afghan kingdoms in 330 BC)
#  Flashman by George MacDonald Fraser (1840s, First Anglo-Afghan War)
#  Caravans by James Michener (post-World War II)
#  Subsections (0):,
#  Section: Argentina (1):
#  On Heroes and Tombs by Ernesto Sabato (19th century, during the Civil War)
#  Facundo: Civilization and Barbarism by Domingo F. Sarmiento (19th century)
#  Santa Evita by Tomás Eloy Martínez (20th century, Eva Perón)
#  El combate perpetuo by Marcos Aguinis (19th century, Admiral William Brown)
#  La fragata Proserpina by Luis Delgado Bañón (19th century)
#  El queche Hiena by Luis Delgado Bañón (19th century)
#  Subsections (0):,
#  Section: Australia (1):
#  The Playmaker and Bring Larks and Heroes by Thomas Keneally (18th century colonial Australia)
#  Morgan's Run by Colleen McCullough (end of the 18th century)
#  Destiny in Sydney by D. Manning Richards (1787–1902 Scots-Irish, Aboriginal, and Chinese family saga story)
#  The Lambing Flat by Nerida Newton (mid-19th century Australian gold rushes)
#  The Secret River by Kate Grenville (19th century colonial Australia)
#  Jack Maggs by Peter Carey (19th century colonial Australia)
#  The Thorn Birds by Colleen McCullough (end of the 19th century)
#  True History of the Kelly Gang by Peter Carey (Kelly Gang, 1878–1880)
#  An Angel in Australia by Thomas Keneally (World War II)
#  Oscar and Lucinda by Peter Carey
#  Jasper Jones by Craig Silvey (1960s Western Australia)
#  Bila Yarrudhanggalangdhuray by Anita Heiss (19th century indigenous New South Wales)
#  Subsections (0):,
#  Section: Austria (1):
#  The Man Without Qualities by Robert Musil (World War I)
#  Subsections (0):,
#  Section: Bangladesh (1):
#  The Black Coat by Neamat Imam (Sheikh Mujibur Rahman's rule in Bangladesh, 1972–75, including famine of 1974)
#  Subsections (0):,
#  Section: Belgium (1):
#  The Legend of Thyl Ulenspiegel and Lamme Goedzak by Charles De Coster (Protestant Reformation in the Netherlands)
#  The Sorrow of Belgium (Het verdriet van België) by Hugo Claus (WW II and after)
#  Subsections (0):,
#  Section: Bosnia and Herzegovina (1):
#  The Bridge on the Drina by Ivo Andrić (1500s–1900s)
#  Subsections (0):,
#  Section: Brazil (1):
#  Alfarrábios by José de Alencar (Colonial Brazil)
#  Iracema by José de Alencar (legend from Ceara, 16th century)
#  The Guarani by José de Alencar (Brazil, 16th century)
#  Brazil Red by Jean-Christophe Rufin (recounts the unsuccessful attempt by the French to conquer Brazil, 16th century)
#  As Minas de Prata by José de Alencar (Minas Gerais, 18th century)
#  O Tempo e o Vento by Érico Veríssimo (from the late 18th century to 1945)
#  Os Sertões by Euclides da Cunha (Canudos Campaign, 19th century)
#  La guerra del fin del mundo by Mario Vargas Llosa (Canudos Campaign, 19th century)
#  Subsections (0):,
#  Section: Canada (1):
#  The Orenda by Joseph Boyden (17th-century Quebec)
#  The Last Crossing by Guy Vanderhaeghe (19th century western Canada)
#  All That Matters by Wayson Choy (1920s–1940s Vancouver)
#  Journey by James A. Michener
#  Alias Grace by Margaret Atwood
#  Three Day Road by Joseph Boyden
#  The Colony of Unrequited Dreams by Wayne Johnston
#  The Book of Negroes by Lawrence Hill
#  In the Skin of a Lion by Michael Ondaatje
#  Jalna by Mazo de la Roche
#  The Jade Peony by Wayson Choy (1930s–1940s Vancouver)
#  Subsections (0):,
#  Section: Caribbean (multiple countries) (1):
#  Unburnable by Marie-Elena John (the African origins of Caribbean culture and the original inhabitants of the Caribbean, the Kalinago (Carib Indians)).
#  Caribbean by James A. Michener
#  Subsections (0):,
#  Section: Chile (1):
#  My Tender Matador by Pedro Lemebel
#  Subsections (0):,
#  Section: China (1):
#  Empress by Shan Sa (Wu Zetian, 1st century)
#  Chia Black Dragon series by Stephen Marley (2nd century, 7th century)
#  Romance of the Three Kingdoms by Luo Guanzhong (3rd century)
#  The Journeyer by Gary Jennings (Kublai Khan, 13th century)
#  The Deer and the Cauldron by Jin Yong - Early Qing dynasty during the rule of the Kangxi Emperor. (1654–89)
#  The Story of the Stone by Cao Xueqin (18th century)
#  Tai-Pan by James Clavell (Hong Kong, 1841)
#  Peony by Pearl Buck (19th century, Jewish family in China)
#  Imperial Woman by Pearl Buck (about Empress Dowager Cixi)
#  Empress Orchid by Anchee Min (about Empress Dowager Cixi)
#  The Last Empress by Anchee Min (about Empress Dowager Cixi)
#  Empire of the Sun by J. G. Ballard (World War II)
#  Dragon Seed by Pearl Buck (Life of Chinese peasant family during Second Sino-Japanese War)
#  Noble House by James Clavell (Hong Kong, 1963)
#  La mujer en la muralla by Alberto Laiseca (Qin Shi Huang, 3rd century BC)
#  An Insular Possession by Timothy Mo (Canton, Macau, and Hong Kong) (1833-1841)
#  Subsections (0):,
#  Section: Colombia (1):
#  The General in his Labyrinth by Gabriel García Márquez
#  Subsections (0):,
#  Section: Pre-Columbian civilizations (1):
#
#  Subsections (3):
#  Section: Aztec Empire (2):
#  The Fair God; or The Last of the 'Tzins: A Tale of the Conquest of Mexico (1873) by Lew Wallace (16th century)
#  Aztec by Gary Jennings (before Spanish invasion)
#  Aztec Autumn by Gary Jennings (one generation after Spanish invasion)
#  Tlaloc Weeps For Mexico by László Passuth (Hernán Cortés, Conquest of Mexico)
#  El Corazón de Piedra Verde (The Green-Stone Heart) by Salvador de Madariaga (encounter between Aztecs and Spanish)
#  Subsections (0):
#
#  Section: Inca Empire (2):
#  El inca by Alberto Vázquez-Figueroa
#  Subsections (0):
#
#  Section: Mayan Empire (2):
#  Caminarás con el Sol by Alfonso Mateo-Sagasta (Gonzalo Guerrero)
#  Gonzalo Guerrero by Eugenio Aguirre
#  Subsections (0):,
#  Section: Czech Republic (1):
#  Witiko by Adalbert Stifter (Witiko of Prčice, 12th century Bohemia)
#  Subsections (0):,
#  Section: Denmark (1):
#  Number the Stars by Lois Lowry (20th century)
#  Subsections (0):,
#  Section: Dominican Republic (1):
#  In the Time of the Butterflies by Julia Alvarez (rebellion against Rafael Leónidas Trujillo, mid-20th century)
#  The Feast of the Goat by Mario Vargas Llosa (Assassination of Trujillo and its aftermath, early 1960s)
#  Subsections (0):,
#  Section: Egypt (1):
#  Cheops by Paul West (26th century BC)
#  Pharaoh by Bolesław Prus (fall of Egypt's Twentieth Dynasty and New Kingdom)
#  Hypatia by Charles Kingsley (late Roman Egypt)
#  The Egyptian by Mika Waltari (reign of Pharaoh Akhenaten)
#  The Memoirs of Cleopatra by Margaret George (reign of Cleopatra VII)
#  River God by Wilbur Smith
#  Leo Africanus by Amin Maalouf (15th and 16th century)
#  El arpista ciego by Terenci Moix
#  No digas que fue un sueño by Terenci Moix (reign of Cleopatra VII)
#  Child of the Morning  by Pauline Gedge (reign of Hatshepsut)
#  Scroll of Saqqara  by Pauline Gedge
#  La boca del Nilo  by León Arsenal
#  El secreto del Nilo by Antonio Cabanas (Amenhotep III, Akhenaten, Smenkhkare, Tutankhamun, Ay and Horemheb reigns)
#  La conjura del faraón by Antonio Cabanas
#  El Ladrón de Tumbas by Antonio Cabanas
#  El Camino de los dioses by Antonio Cabanas
#  Subsections (0):,
#  Section: Estonia (1):
#  Purge by Sofi Oksanen (20th century)
#  Subsections (0):,
#  Section: Finland (1):
#  The Adventurer by Mika Waltari (16th century)
#  Subsections (0):,
#  Section: France (1):
#  The Jester by James Patterson (11th century)
#  Les Rois maudits series (The Accursed Kings) by Maurice Druon (14th century)
#  Quentin Durward by Sir Walter Scott (Louis XI – 15th century)
#  The Hunchback of Notre Dame by Victor Hugo (15th century)
#  Queen Margot by Alexandre Dumas, père (16th century)
#  The Angélique series by Anne & Serge Golon (mid-17th century in the reign of Louis XIV)
#  The d'Artagnan romances (The Three Musketeers, Twenty Years After, and The Vicomte de Bragelonne) by Alexandre Dumas, père (17th century)
#  A Place of Greater Safety by Hilary Mantel (French Revolution)
#  A Tale of Two Cities by Charles Dickens (French Revolution)
#  Scaramouche by Rafael Sabatini (French Revolution)
#  Ninety-Three by Victor Hugo (1793, French Revolution)
#  The Rover by Joseph Conrad (Revolutionary and Napoleonic periods)
#  Les Misérables by Victor Hugo (19th century)
#  The Count of Monte Cristo by Alexandre Dumas, père (19th century)
#  Cézanne’s Quarry by Barbara Corrado Pope, (Belle Époque)
#  The Blood of Lorraine by Barbara Corrado Pope, (Belle Époque)
#  The Missing Italian Girl by Barbara Corrado Pope, (Belle Époque)
#  An Officer and a Spy by Robert Harris (the Dreyfus affair)
#  The Four Horsemen of the Apocalypse by Vicente Blasco Ibáñez (World War I)
#  Subsections (0):,
#  Section: Germany (1):
#  Q (1999) by Luther Blissett (15th-century Europe during the Protestant reformation and German Peasants' War)
#  Measuring the World by Daniel Kehlmann (19th century)
#  Night Thoughts of a Classical Physicist by Russell McCormmach (development of physics in the early 20th century)
#  The Seventh Gate by Richard Zimler (1930s Berlin)
#  The Book Thief by Markus Zusak (World War II)
#  Los demonios de Berlín by Ignacio del Valle (Battle of Berlin)
#  Subsections (0):,
#  Section: Greece (1):
#  Hades' Daughter by Sara Douglass (classical antiquity)
#  Tides of War: A Novel of Alcibiades and the Peloponnesian War by Steven Pressfield
#  The Palaeologian Dynasty. The Rise and Fall of Byzantium by George Leonardos
#  Gates of Fire by Steven Pressfield (the Battle of Thermopylae)
#  Middlesex by Jeffrey Eugenides (World War I and Greco-Turkish War)
#  The Last of the Wine by Mary Renault (Athens in the time of Socrates)
#  The Mask of Apollo by Mary Renault (Greek theatre, 4th century BC)
#  The Athenian Murders (La caverna de las ideas) by Jose Carlos Somoza (classical antiquity)
#  Lion of Macedon by David Gemmell (Alexander's general Parmenion)
#  Fire from Heaven and The Persian Boy by Mary Renault (Alexander the Great)
#  Funeral Games by Mary Renault (the successors of Alexander)
#  Goat Song by Frank Yerby (Peloponnesian War)
#  La joven de Esparta by Cristina Rodríguez
#  The Song Of Troy by Colleen McCullough (the Greek - Trojan war)
#  Salamina by Javier Negrete, (Second Persian invasion of Greece, Themistocles)
#  El espartano by Javier Negrete, (Second Persian invasion of Greece)
#  El agua y la tierra by Julio Murillo
#  Los milagros del vino by Jesús Sánchez Adalid (Corinth, 1st century AD)
#  Enemigos de Esparta by Sebastián Roa (Theban hegemony rising)
#  El ateniense by Pedro Santamaría (Alcibiades)
#  Némesis by Sebastián Roa (Artemisia I of Caria)
#  Subsections (0):,
#  Section: Greenland (1):
#  The Greenlanders by Jane Smiley
#  Subsections (0):,
#  Section: Haiti (1):
#  Lydia Bailey by Kenneth Roberts (1800s Haitian Revolution)
#  Haitian Revolution trilogy by Madison Smartt Bell (Toussaint Louverture and the Haitian Revolution)
#  The Kingdom of This World by Alejo Carpentier (Haitian Revolution)
#  Island Beneath the Sea by Isabel Allende (late 18th century)
#  Babouk by Guy Endore (Haitian Revolution)
#  Subsections (0):,
#  Section: Hungary (1):
#  A fekete város (The Black Town, 1910) by Kálmán Mikszáth (set in the 18th c.)
#  Sorstalanság (Fatelessness; Fateless (2001) by Imre Kertész (Nobel Prize winner, set in World War II)
#  Prague (2002) by Arthur Phillips (set in the 1990s)
#  Subsections (0):,
#  Section: India (1):
#
#  Subsections (8):
#  Section: Bengali (2):
#  Durgeshnôndini, Rajshingho, Anondomôţh by Bankim Chandra Chattopadhyay
#  Ghôre Baire by Rabindranath Tagore
#  Subsections (0):
#
#  Section: English (2):
#  A Spoke in the Wheel by Amita Kanekar (Gautama Buddha/Ashoka)
#  Chanakya's Chant by Ashwin Sanghi (4th century BC)
#  Empire of the Moghul series by Alex Rutherford (Moghul Empire, Babur to Aurangzeb)
#  Guardian of the Dawn by Richard Zimler (17th century Goa)
#  The Far Pavilions by M. M. Kaye (British India in the 19th century)
#  The Ibis trilogy by Amitav Ghosh (before and during the First Opium War)
#  The Siege of Krishnapur by J. G. Farrell (Indian Rebellion of 1857)
#  Midnight's Children by Salman Rushdie (Partition of India)
#  Subsections (0):
#
#  Section: Hindi (2):
#  Volga Se Ganga by Mahapandit Rahul Sankrityayan
#  Subsections (0):
#
#  Section: Malayalam (2):
#  Marthandavarma (1891), Dharmaraja (1913), Ramarajabahadur (1918–1919) by C V Raman Pillai
#  Subsections (0):
#
#  Section: Tamil (2):
#  Parthiban Kanavu and Sivagamiyin Sabadham by Kalki Krishnamurthy (Pallava dynasty)
#  Ponniyin Selvan by Kalki Krishnamurthy (Chola dynasty)
#  Vengaiyin Mayinthan by Akilan (Rajendra Chola I, 11th century)
#  Subsections (0):
#
#  Section: Telugu (2):
#  Veyipadagalu (1934) by Viswanatha Satyanarayana
#  Subsections (0):
#
#  Section: Urdu (2):
#  Aag Ka Darya (River of Fire) by Qurratulain Hyder
#  Aangan (Courtyard)  by Khadija Mastoor
#  Bano by Razia Butt
#  Subsections (0):
#
#  Section: Gujarati (2):
#  Karan Ghelo by Nandshankar Mehta
#  Subsections (0):,
#  Section: Indonesia (1):
#  Bumi Manusia (This Earth of Mankind), Anak Semua Bangsa (Child of All Nations), Jejak Langkah (Footsteps) and Rumah Kaca (House of Glass) by Pramoedya Ananta Toer (Dutch colonialism, late 19th early 20th century)
#  Max Havelaar by Multatuli (Dutch colonialism, 19th century)
#  Subsections (0):,
#  Section: Iran (1):
#  Cry of the Peacock by Gina B. Nahai (Jews in Iran, 18th–20th centuries)
#  Whirlwind by James Clavell (Iranian Revolution, 1979)
#  Subsections (0):,
#  Section: Ireland (1):
#  Trinity and Redemption by Leon Uris
#  The Princes of Ireland: The Dublin Saga and The Rebels of Ireland: The Dublin Saga by Edward Rutherfurd
#  Troubles by J. G. Farrell (Irish War of Independence)
#  A Star Called Henry by Roddy Doyle (Irish Revolution)
#  Sister Fidelma series by Peter Tremayne (7th century)
#  Lion of Ireland by Morgan Llywelyn (High King Brian Boru, 10th century)
#  The Silent People by Walter Macken (The Great Famine, 19th century)
#  Subsections (0):,
#  Section: Israel (1):
#  The Source by James A. Michener
#  The King of Flesh and Blood by Moshe Shamir (2nd century BCE)
#  The Antagonists: A Novel of Masada by Ernest K. Gann (1st century)
#  The Gospel According to Lazarus by Richard Zimler (1st century)
#  Holy Warrior by Angus Donald, second novel in the Outlaw Chronicles (12th century)
#  Jerusalem by Cecelia Holland (12th century)
#  Exodus by Leon Uris (SS Exodus and the founding of Israel)
#  The Haj by Leon Uris (1920s–1950s)
#  The Hope by Herman Wouk (Creation of Israel to the Six-Day War, 1948–1967)
#  The Glory by Herman Wouk (Six-Day War to Peace with Egypt, 1967–1978)
#  Inside, Outside by Herman Wouk (Four generations of a Russian Jewish family in the 20th century)
#  Vengeance by George Jonas (Following Operation Wrath of God - the Israeli hunt for the 1972 Munich Olympics massacre planners).
#  Subsections (0):,
#  Section: Italy (1):
#  Raptor by Gary Jennings (5th–6th centuries)
#  A Struggle for Rome (Ein Kampf um Rom) by Felix Dahn (Gothic War)
#  Tiara i korona by Teodor Jeske-Choiński  (Pope Gregory VII and Henry IV, Holy Roman Emperor, 11th century)
#  Baudolino by Umberto Eco (12th century)
#  Valperga by Mary Shelley (14th century; Guelphs and Ghibellines)
#  The Name of the Rose by Umberto Eco (14th century)
#  La Cruz y el Lirio Dorado by Fernando Fernán-Gómez (Pazzi conspiracy, 15th century)
#  The Birth of Venus by Sarah Dunant (Florence, Savonarola period)
#  Prince of Foxes by Samuel Shellabarger (Renaissance)
#  Romola by George Eliot (Renaissance)
#  The Family by Mario Puzo (Renaissance)
#  The Betrothed by Alessandro Manzoni (17th century)
#  Silk by Alessandro Baricco (1860s)
#  The Prague Cemetery by Umberto Eco (19th century)
#  La confesión del embajador by Juan Martín Salamanca (17th century, Spanish ambassador in Duchy of Savoy)
#  Subsections (0):,
#  Section: Japan (1):
#  Musashi by Eiji Yoshikawa (Miyamoto Musashi, 17th century)
#  Shōgun, Gai-Jin & King Rat by James Clavell
#  Silence by Shusaku Endo (Jesuit missionary in the 17th century)
#  The Samurai by Shusaku Endo (The journey of four samurai to Spain in the 17th century)
#  The Tale of Genji by Murasaki Shikibu, 11th century
#  The Thousand Autumns of Jacob de Zoet by David Mitchell (Dutch trading concession with Japan in the late 18th century)
#  Heike Monogatari by Yoshida Kenkō, (Genpei War)
#  Taiko by Eiji Yoshikawa (Toyotomi Hideyoshi, 16th century)
#  The Samurai by Shūsaku Endō (Keichō Embassy to Spain, Hasekura Tsunenaga)
#  Las piedras de Chihaya trilogy by Sergio Vega (Kenmu Restoration)
#  El hilo del karma
#  La nube rasgada
#  El Dragón y el Crisantemo
#  El guerrero a la sombra del cerezo by David B. Gil (Edo period)
#  Ocho millones de dioses by David B. Gil
#  Forjada en la tormenta by David B. Gil
#  Subsections (0):,
#  Section: Korea (1):
#  A Single Shard by Linda Sue Park
#  Subsections (0):,
#  Section: Malta (1):
#  The Siege of Malta by Walter Scott
#  Eight Pointed Cross by Marthese Fenech
#  Falcon's Shadow by Marthese Fenech
#  Subsections (0):,
#  Section: Mexico (1):
#  The Fair God; or The Last of the 'Tzins: A Tale of the Conquest of Mexico (1873) by Lew Wallace (16th century)
#  Mexico by James A. Michener
#  Captain from Castile by Samuel Shellabarger (16th century)
#  Hunger's Brides by Paul Anderson (17th century, Sor Juana)
#  Caballero by Jovita González and Eve Raleigh (1840s)
#  Cartucho by Nellie Campobello (Mexican Revolution)
#  The Power and the Glory by Graham Greene (1930s)
#  Aztec and Aztec Autumn by Gary Jennings (16th century)
#  El navío Asia by Luis Delgado Bañón (19th century)
#  Subsections (0):,
#  Section: Netherlands (1):
#  Girl with a Pearl Earring by Tracy Chevalier (Johannes Vermeer, 17th century)
#  The Black Tulip by Alexandre Dumas, père (17th century)
#  The Cloister and the Hearth by Charles Reade (15th century)
#  The Coffee Trader by David Liss (17th century)
#  The Miniaturist by Jessie Burton (17th century Amsterdam)
#  Subsections (0):,
#  Section: New Zealand (1):
#  The Luminaries by Eleanor Catton (1860s New Zealand gold rush)
#  Season of the Jew by Maurice Shadbolt (mid-nineteenth century New Zealand)
#  Subsections (0):,
#  Section: Norway (1):
#  Kristin Lavransdatter by Sigrid Undset (14th century)
#  The Master of Hestviken by Sigrid Undset (14th century)
#  Subsections (0):,
#  Section: Pakistan (1):
#  Khaak aur Khoon by Naseem Hijazi
#  Shaheen by Naseem Hijazi
#  Shahab Nama by Qudratullah Shahab
#  Subsections (0):,
#  Section: Palestine (1):
#  The Talisman by Sir Walter Scott (12th century, Third Crusade)
#  El asombroso viaje de Pomponio Flato by Eduardo Mendoza
#  Subsections (0):,
#  Section: Philippines (1):
#  Noli Me Tángere by José Rizal (early 1880s Philippines, under Spanish colonial rule)
#  El filibusterismo by José Rizal (set 13 years after the events of Noli Me Tángere)
#  The Woman Who had Two Navels by Nick Joaquin
#  Po-on by F. Sionil José (Set in the late 19th century.)
#  Subsections (0):,
#  Section: Poland (1):
#  Poland by James A. Michener (13th century onward)
#  Krzyzacy (The Teutonic Knights) by Henryk Sienkiewicz (Teutonic Knights, 14th century)
#  The Trilogy by Henryk Sienkiewicz (17th century, including the Khmelnytsky Uprising and The Deluge)
#  Thaddeus of Warsaw by Jane Porter (Polish–Lithuanian Commonwealth)
#  Push Not the River by James Conroyd Martin (1792 Partition of Poland)
#  The Faithful River (Wierna rzeka) by Stefan Żeromski (January Uprising, 1863–1865)
#  The Warsaw Anagrams by Richard Zimler (Warsaw Ghetto, 1940–1943)
#  Kamienie na szaniec (Stones for the Rampart) by Aleksander Kamiński (Polish Scouting or Gray Ranks during World War II)
#  Subsections (0):,
#  Section: Portugal (1):
#  The Last Kabbalist of Lisbon by Richard Zimler (early 16th-century Lisbon, Lisbon Massacre of 1506)
#  Baltasar and Blimunda by José Saramago (18th-century construction of the Convent of Mafra)
#  Hunting Midnight by Richard Zimler (19th century Porto)
#  Subsections (0):,
#  Section: Ancient Rome (1):
#  Scipio trilogy by Santiago Posteguillo (the Punic Wars general Publius Cornelius Scipio)
#  The Masters of Rome series by Colleen McCullough (1st century BC)
#  The Gods of War (Life of Julius Caesar)
#  The Ides of March by Thornton Wilder (Last days of Julius Caesar)
#  La leyenda del falso traidor by Antonio Gómez Rufo (Assassination of Julius Caesar)
#  El lazo de púrpura by Alejandro Núñez Alonso (Tiberius period)
#  King Jesus by Robert Graves
#  Ben-Hur: A Tale of the Christ by Lew Wallace
#  I Am a Barbarian by Edgar Rice Burroughs (The life of Caligula as seen through the eyes of his slave)
#  I, Claudius and Claudius, the God by Robert Graves (Roman emperors, 1st century)
#  Quo Vadis by Henryk Sienkiewicz (Christians under Nero)
#  The Roman Mysteries, a series of children's books by Caroline Lawrence (late 1st century)
#  Trajan trilogy by Santiago Posteguillo (Trajan life)
#  Memoirs of Hadrian by Marguerite Yourcenar (life and death of Roman Emperor Hadrian)
#  Julian by Gore Vidal (Julian the Apostate, 4th century)
#  Eagle in the Snow by Wallace Breem (Magnus Maximus, 4th century)
#  The Last Romans by Teodor Jeske-Choiński (Theodosius I, 4th century Roman Emperor)
#  Count Belisarius by Robert Graves (the Byzantine general Belisarius, 6th century)
#  Pax romana by Yeyo Balbás
#  Memorias de Escipión Emiliano by José Enrique López Jiménez
#  Al servicio del imperio by Pedro Santamaría (Cantabri in First Jewish–Roman War)
#  El saqueo de Roma by Pedro Santamaría (Sack of Rome (410))
#  El primer senador de Roma: Carthago delenda est by Juan Torres Zalba (Numantine War, Siege of Carthage (Third Punic War))
#  Subsections (0):,
#  Section: Russia (1):
#  War and Peace by Leo Tolstoy (Napoleonic era)
#  La sombra del águila by Arturo Pérez-Reverte (Napoléon's invasion)
#  The Life of Klim Samgin by Maxim Gorky (World War I and Russian 1917 Revolution)
#  Moscow by Andrei Bely (World War I and Russian 1917 Revolution)
#  Blood Red, Snow White by Marcus Sedgwick (Russian 1917 Revolution)
#  Doctor Zhivago by Boris Pasternak (Russian 1917 Revolution and Russian Civil War)
#  And Quiet Flows the Don by Mikhail Sholokhov (Russian 1917 Revolution and Russian Civil War)
#  The White Guard by Mikhail Bulgakov (Russian Civil War)
#  Life and Fate by Vasily Grossman (Eastern Front)
#  The Red Wheel by Aleksandr Solzhenitsyn (World War I and Russian 1917 Revolution)
#  Russka by Edward Rutherfurd (1800 years of Russian history from pre-Russia to the beginning of the Russian Revolution)
#  El tiempo de los emperadores extraños by Ignacio del Valle (Blue Division on the Eastern Front)
#  Subsections (0):,
#  Section: Sicily (1):
#  The Lady of the Wheel by Angelo F. Coniglio (19th century foundlings and sulfur mine workers)
#  The Leopard or Il Gattopardo by Giuseppe Tomasi di Lampedusa (19th century Risorgimento, Giuseppe Garibaldi)
#  The Sicilian by Mario Puzo (Fictionalized biography of Sicilian popular hero Salvatore Giuliano.)
#  Subsections (0):,
#  Section: South Africa (1):
#  The Covenant by James A. Michener (from prehistory onwards)
#  King Solomon's Mines by H. Rider Haggard (19th century)
#  Subsections (0):,
#  Section: Spain (1):
#
#  Subsections (9):
#  Section: Multiple time frames (2):
#  Un soldado español de veinte siglos by José Gómez de Arteche
#  Subsections (0):
#
#  Section: Early history (2):
#  Viriato by João Aguiar (1st century BC, Viriathus)
#  Rey Lobo by Juan Eslava Galán
#  Nublares series by Antonio Pérez Henares (Paleolithic)
#  El Último Soldurio by Javier Lorenzo (1st century BC)
#  Numancia by José Luis Corral (1st century BC, Numantia)
#  El hombre de la plata by León Arsenal (Tartessos)
#  Celtiberia series by Ángel L. Gallero (Celtiberians)
#  En los reinos de Lug
#  Arde Iberia
#  El arévaco
#  Subsections (0):
#
#  Section: Roman Spain (2):
#  A Dying Light in Corduba by Lindsey Davis
#  Sertorio by João Aguiar (Quintus Sertorius)
#  Hay luz en casa de Publio Fama by Juan Miñana
#  Los arcos del agua by Montse Barderi
#  Interregno by José Vicente Pascual
#  Subsections (0):
#
#  Section: Visigothic Kingdom (2):
#  Última Roma by León Arsenal (6th century)
#  Sombras de mariposa by Guillermo Galván (Liuvigild, Visigothic Kingdom)
#  Astur by Isabel San Sebastián (8th century Spain)
#  La última visigoda by Isabel San Sebastián (8th century Spain)
#  El reino imposible by Yeyo Balbás (8th century Spain)
#  Las cenizas de Hispania series by Ángel José Zoilo Hernández (Suebi, Alans, Vandals and Visigoths in Spain)
#  El alano
#  Niebla y acero
#  El dux del fin del mundo
#  Subsections (0):
#
#  Section: Medieval (2):
#  Tales of Count Lucanor by Don Juan Manuel, príncipe de Villena (14th century)
#  El mercenario de Granada by Juan Eslava Galán
#  El Doncel de don Enrique el Doliente by Mariano José de Larra (Enrique III de Castilla)
#  Sancho Saldaña o el castellano de Cuellar by José de Espronceda
#  Il cavaliere invisibile by Valerio Massimo Manfredi (14th century)
#  Tales of the Alhambra by Washington Irving (Emirato de Granada)
#  Los bandos de Castilla by Ramón López Soler (15th century)
#  Reinos de Sangre by Óscar Eimil (Fernando I)
#  Los bandos de Castilla by Ramón López Soler (15th century)
#  Los malos años by León Arsenal (14th century, Pedro I de Castilla and Blanca de Borbón)
#  1369 by Juan Rey (14th century, Pedro I de Castilla)
#  Corazón oscuro by León Arsenal (Battle of Teba, Alfonso XI of Castile, James Douglas death, Robert the Bruce heart in Spain.)
#  Tiempo de bastardos by Paula Cifuentes (14th century, Beatriz de Portugal)
#  La tierra de Alvar Fañez by Antonio Pérez Henares (11th century, Álvar Fáñez)
#  El Rey Pequeño by Antonio Pérez Henares (11th century, Alfonso VIII)
#  El reino de la espada by Álvaro Moreno Ancillo (13th century)
#  El peón del Rey by Pedro Jesús Fernández (Camino de Santiago, Alfonso X court)
#  Catalina de Lancaster by María Teresa Álvarez (14th century, Catalina de Lancaster)
#  El camino mozarabe by Jesús Sánchez Adalid (Embassies between Ramiro II of León and Abderramán III after Battle of Simancas)
#  Enrique de Castilla by Margarita Torres (13th century, Henry of Castile)
#  Doña Blanca de Navarra by Francisco Navarro Villoslada (15th century, Blanca de Navarra)
#  Las Compañías Blancas (Los Malandrines) by Tomás Salvador (14th century, Bertrand du Guesclin)
#  Alcazaba by Jesús Sánchez Adalid (Mérida uprising against Abderramán II)
#  Esperando al Rey by José María Pérez González (12th century, Alfonso VII of León and Castile and his children Sancho III of Castile and Ferdinand II of León)
#  Salvatierra by Miguel Martínez (13th century, Order of Calatrava, Salvatierra Castle)
#  El ejército de Dios by Sebastián Roa (Almohad Caliphate in Spain)
#  El Reino del norte by Jose Javier Esparza (9th century. Early Reconquista)
#  Recuerde el alma dormida by Rafael Álvarez Avello (Jorge Manrique)
#  María de Molina by Almudena de Arteaga
#  El olor de las especias by Alfonso Mateo-Sagasta
#  Die Rose von Asturien by Iny Lorentz
#  El Alma de la Ciudad by Jesús Sánchez Adalid
#  El señor de Bembibre by Enrique Gil y Carrasco (14th century)
#  La maldición de la reina Leonor by José María Pérez González
#  La reina sin reino by José María Pérez González
#  El Reino del norte by Jose Javier Esparza (9th century. Early Reconquista )
#  Guzmán el Bueno. El señor de la frontera by Juan Luis Pulido Begines (Alonso Pérez de Guzmán)
#  Tierra vieja by Antonio Pérez Henares
#  Cova Dónnica by Yeyo Balbás (Don Pelayo)
#  Las Navas by Juda Barber (Battle of Las Navas de Tolosa)
#  Subsections (0):
#
#  Section: Spanish Golden Age (2):
#  El ingenioso hidalgo Don Quijote de la Mancha by Miguel de Cervantes Saavedra (16th century)
#  The Ferdinand and Isabella Trilogy by Jean Plaidy (15th century)
#  Adventures of Captain Alatriste series by Arturo Pérez-Reverte
#  The Heretic: A Novel of the Inquisition by Miguel Delibes (16th century in Valladolid)
#  Martín Ojo de Plata series by Matilde Asensi (17th century)
#  That Lady by Kate O'Brien (Ana de Mendoza, Princesa of Éboli)
#  Jeromín by Luis Coloma (life of Juan de Austria)
#  Capa y espada by Fernando Fernán Gómez (court of Philip IV of Spain, murder of Count of Villamediana)
#  El comedido hidalgo by Juan Eslava Galán
#  El prisionero de Argel by Antonio Cavanillas de Blas (life of Miguel de Cervantes Saavedra)
#  La sombra de otro by Luis García Jambrina (life of Miguel de Cervantes Saavedra)
#  Misterioso asesinato en casa de Cervantes by Juan Eslava Galán (Miguel de Cervantes Saavedra in Valladolid, Ezpeleta process)
#  By Fire, By Water by Mitchell James Kaplan (15th century)
#  Sobra un rey by José García Abad (15th century)
#  La reina comunera by José García Abad (Juana I de Castilla, Revolt of the Comuneros)
#  El castellano de Flandes by Enrique Martínez Ruiz (16th century)
#  Hoy no se pondrá el sol by Rafael Rico Cabeza (Spanish Road, Duke of Alba)
#  Su peor enemigo by Alfonso Mateo-Sagasta  (Alonso Fernández de Avellaneda)
#  Isidoro de Montemayor series by Alfonso Mateo-Sagasta (17th century)
#  Ladrones de tinta
#  El gabinete de las maravillas
#  El reino de los hombres sin amor
#  Rojo amanecer en Lepanto by Luis Zueco (life of Alejandro Farnesio y Habsburgo and Juan de Austria, Battle of Lepanto)
#  The last crusader by Louis de Wohl (Juan de Austria)
#  Leonor de Habsburgo by Yolanda Scheuber (Leonor de Habsburgo)
#  Decidnos ¿Quién mató al conde? by Néstor Luján (court of Philip IV of Spain, murder of Count of Villamediana)
#  La cruz en la espada by Néstor Luján (court of Philip IV of Spain, last years of Francisco de Quevedo)
#  El caballero de Alcántara by Jesús Sánchez Adalid
#  Y de repente, Teresa by Jesús Sánchez Adalid (Teresa of Ávila)
#  The Queen's Vow: A Novel Of Isabella Of Castile by C. W. Gortner (Isabel de Castilla)
#  El abogado de Indias by Amós Milton (A lawyer in Sevilla at 16th century)
#  El comendador de Alcántara or El gobernador de Indias by José Miguel Carrillo de Albornoz (Nicolás de Ovando)
#  Ronin by Francisco Narla (Samurai in Spain, 17th century)
#  Capitán Alonso Cobos series by Juan Tazón (Espionage in the time of Felipe II)
#  Los caballeros de las sombras
#  Sabed que mi nombre se perdió
#  Crónica del rey pasmado by Gonzalo Torrente Ballester (Court of Felipe IV)
#  San Quintín. Memorias del maestre de campo de los tercios Julián Romero  by José Javier Esparza (Battle of St. Quentin (1557))
#  El náufrago de la Gran Armada by Fernando Martínez Laínez (La Grande y Felicísima Armada)
#  Lope: la furia del Fénix by Blas Malo (Life of Lope de Vega)
#  Lope de Vega: El desdén y la furia by Blas Malo (Life of Lope de Vega)
#  El Gran Capitán by José Calvo Poyato (Gonzalo Fernández de Córdoba)
#  La hora de Quevedo by Baltasar Magro (Francisco de Quevedo)
#  Juana, la reina traicionada by Álber Vázquez (Juana I de Castilla)
#  El sueño del gramático by Eva Díaz Pérez (Antonio de Nebrija)
#  Subsections (2):
#  Section: Picaresque novel (3):
#  Life and facts of Estebanillo González, man of good humour Anonymous (Thirty Years' War)
#  Lazarillo de Tormes Anonymous
#  La Celestina by Fernando de Rojas
#  El Buscón by Francisco de Quevedo
#  Subsections (0):
#
#  Section: Exploration and conquest (3):
#  The Heart of Jade (El Corazón de piedra verde) by Salvador de Madariaga
#  The Islands of Unwisdom by Robert Graves (Álvaro de Mendaña)
#  Captain From Castile by Samuel Shellabarger (Hernán Cortés Conquest of Mexico)
#  La aventura equinocial de Lope de Aguirre by Ramón José Sender Garcés (16th century, conqueror Lope de Aguirre)
#  Tlaloc Weeps for Mexico (Esőisten siratja Mexikót) by László Passuth (Hernán Cortés Conquest of Mexico)
#  Malinche by Laura Esquivel (La Malinche)
#  Centauros by Alberto Vázquez-Figueroa (Alonso de Ojeda)
#  Cristóbal Colón: Rumbo a Cipango by Edward Rosset
#  Los navegantes by Edward Rosset (Fernando de Magallanes, Juan Sebastián Elcano, Andrés de Urdaneta, Miguel López de Legazpi)
#  La ruta de las tormentas by Paula Cifuentes (Fourth voyage of Christopher Columbus, Ferdinand Columbus)
#  Las huellas del conquistador by José Luis Pérez Regueira (Hernando de Soto exploration of North America)
#  Hombres valientes, dioses crueles by Eugenio Chouciño
#  Conquistadores de lo imposible by José Ángel Mañas
#  Poniente by  Alber Vázquez (The first circumnavigation, Fernando de Magallanes, Juan Sebastián Elcano)
#  Victoria. La odisea de Magallanes y Elcano by Rafael Marín Trechera (The first circumnavigation, Fernando de Magallanes, Juan Sebastián Elcano)
#  La travesía final by José Calvo Poyato (Juan Sebastián Elcano, Loaísa expedition)
#  Lágrimas de oro by José Luis Gil Soto (Francisco Pizarro, Spanish conquest of the Inca Empire)
#  Pizarro y la conquista del Imperio Inca by Álber Vázquez (Francisco Pizarro, Spanish conquest of the Inca Empire)
#  El rey del Perú by Juan Pedro Cosano (Gonzalo Pizarro)
#  Subsections (0):
#
#  Section: 18th century (2):
#  Hombres buenos by Arturo Pérez-Reverte
#  El día que España derrotó a Inglaterra. De cómo Blas de Lezo, tuerto, manco y cojo, venció en Cartagena de Indias a la otra "Armada Invencible" by Pablo Victoria (Blas de Lezo, Battle of Cartagena de Indias)
#  Mediohombre by Alber Vázquez (Blas de Lezo, Battle of Cartagena de Indias)
#  El héroe del Caribe: La última batalla de Blas de Lezo by J. Pérez-Foncea (Blas de Lezo)
#  El paisano de Jamaica by Francisco Javier Romero Valentín (Blas de Lezo, Battle of Cartagena de Indias)
#  Das Ohr das Kapitäns by Gisbert Haefs (Battle of Cartagena de Indias)
#  Beltrán Ochoa, capitán de Dragones series by Octavio Sánchez-Machuca (Carlos III reign)
#  El asedio del Diablo
#  El alma en la batalla
#  Emboscada en Nápoles
#  La traición del rey by José Luis Gil Soto (Manuel de Godoy)
#  Conjura en Madrid by José Calvo Poyato (War of the Spanish Succession, Conspiration against Philip V)
#  Subsections (0):
#
#  Section: 19th century (2):
#  National Episodes by Benito Pérez Galdós (19th century)
#  La regenta by Leopoldo Alas "Clarín" (19th century)
#  Fortunata y Jacinta by Benito Pérez Galdós (19th century)
#  Un día de cólera by Arturo Pérez-Reverte (Dos de Mayo Uprising)
#  El húsar by Arturo Pérez-Reverte (Napoleonic age)
#  The siege (El asedio) by Arturo Pérez-Reverte (1811, Siege of Cádiz)
#  The Fencing Master by Arturo Pérez-Reverte (Isabella II age)
#  El secreto del rey cautivo by Antonio Gómez Rufo (Peninsular War)
#  Vientos de intriga by José Calvo Poyato (Mutiny of Aranjuez, Dos de Mayo Uprising)
#  Sangre en la calle del Turco by José Calvo Poyato (Prim murder)
#  El navío Príncipe de Asturias, Trafalgar by Luis Delgado Bañon (19th century) is the 9th book of Una saga marinera española
#  La artillera by Ángeles de Irisarri (Siege of Saragossa)
#  El león de ojos árabes by Antonio Cavanillas de Blas (Isabella II age)
#  Bandera negra by León Arsenal (Carlist Wars)
#  Subsections (0):
#
#  Section: 20th century (2):
#  Iberia by James A Michener (20th century)
#  Winter in Madrid by C. J. Sansom
#  Episodios nacionales contemporáneos series by Ricardo Fernández de la Reguera and Susana March
#  And in the distance a light...? also published as Beasts and Martyrs of Spain (A sangre y fuego. Héroes, bestias y mártires de España) by Manuel Chaves Nogales
#  Riña de gatos. Madrid 1936 by Eduardo Mendoza
#  El valle de las sombras by Jerónimo Tristante (Construction of the Valle de los Caídos)
#  The Communist's Daughter by Dennis Bock
#  The Forging of a Rebel trilogy by Arturo Barea
#  Línea de fuego by Arturo Pérez-Reverte
#  La sonata del silencio by Paloma Sánchez-Garnica
#  El arte de matar dragones by Ignacio del Valle
#  Subsections (0):,
#  Section: Sweden (1):
#  The Long Ships by Frans G. Bengtsson (Vikings, 10th century)
#  The Emigrants tetralogy by Vilhelm Moberg (middle of the 19th century)
#  Subsections (0):,
#  Section: Switzerland (1):
#  Anne of Geierstein by Sir Walter Scott (15th century)
#  Subsections (0):,
#  Section: Syria (1):
#  The End of a Brave Man by Hanna Mina (20th century)
#  Subsections (0):,
#  Section: Turkey (1):
#  The Prince of India; or, Why Constantinople Fell (1893) by Lew Wallace (15th century, Fall of Constantinople)
#  Subsections (0):,
#  Section: United Kingdom (1):
#
#  Subsections (8):
#  Section: Earliest history (2):
#  Stonehenge: A Novel of 2000 BC by Bernard Cornwell (Stonehenge)
#  Pillar of the Sky by Cecelia Holland (Stonehenge)
#  The Stronghold by Mollie Hunter (Orkney in the 1st century BC)
#  Subsections (0):
#
#  Section: Roman Britain (2):
#  Under the Eagle and others in the Cato series by Simon Scarrow (Roman invasion, AD 42)
#  The Silver Pigs, A Body in the Bath House and The Jupiter Myth by Lindsey Davis (crime in the reign of Vespasian, 1st century AD)
#  The Eagle of the Ninth by Rosemary Sutcliff (2nd century AD)
#  The Silver Branch by Rosemary Sutcliff (3rd century AD)
#  The Forest House, and others in the series by Marion Zimmer Bradley
#  The Eagle and the Raven, by Pauline Gedge (Caradoc, 1st century AD)
#  Subsections (0):
#
#  Section: Medieval (2):
#  Porius by John Cowper Powys (Arthurian, 5th century)
#  Sword at Sunset by Rosemary Sutcliff (Arthurian)
#  The Saxon Shore by Jack Whyte (Arthurian)
#  Grail Prince by Nancy McKenzie (Galahad)
#  Hild by Nicola Griffith (7th century)
#  The Saxon Stories by Bernard Cornwell (Alfred the Great, (9th century)
#  Avalon by Anya Seton (10th century)
#  The Conqueror by Georgette Heyer (William the Conqueror, 11th century)
#  Hereward the Wake by Charles Kingsley (Hereward the Wake, 11th century)
#  The Wake by Paul Kingsnorth (11th century)
#  Outlaw by Angus Donald, the first novel in the Outlaw Chronicles (12th century)
#  King's Man by Angus Donald, the third in the above series (12th century)
#  The Pillars of the Earth by Ken Follett (12th-century)
#  Ivanhoe by Sir Walter Scott (12th century)
#  Kay the Left-Handed by Leslie Barringer (12th century)
#  The Pillars of the Earth by Ken Follett (12th century)
#  Lady of the Forest by Jennifer Roberson (12th century)
#  Time and Chance by Sharon Kay Penman (12th century)
#  The Devil's Brood by Sharon Kay Penman (12th century)
#  Here Be Dragons by Sharon Kay Penman (Wales, 13th century)
#  The Reckoning by Sharon Kay Penman (13th century Wales)
#  The Heaven Tree Trilogy by Edith Pargeter (13th century Wales)
#  The Brothers of Gwynedd Quartet by Edith Pargeter (13th century Wales)
#  The Scottish Chiefs by Jane Porter (13th century Scotland, William Wallace)
#  The Fair Maid of Perth by Sir Walter Scott (14th-century Scotland)
#  The Grail Quest by Bernard Cornwell (14th century)
#  Katherine by Anya Seton (14th century)
#  Company of Liars by Karen Maitland (14th century)
#  World Without End by Ken Follett (14th century)
#  Owen Glendower by John Cowper Powys (15th century Wales)
#  Know Ye Not Agincourt? by Leslie Barringer (15th century)
#  The Sunne in Splendour by Sharon Kay Penman (15th century)
#  The Load of Unicorn by Cynthia Harnett (Caxton, 15th century London)
#  Subsections (0):
#
#  Section: Tudor and Stuart (2):
#  The House of Niccolò and Lymond Chronicles by Dorothy Dunnett (Scotland and beyond, 15th and 16th centuries)
#  The Fortunes of Perkin Warbeck by Mary Shelley (Henry VII and Perkin Warbeck)
#  Wolf Hall by Hilary Mantel (Thomas Cromwell's rise to power)
#  Bring up the Bodies by Hilary Mantel (Thomas Cromwell and Anne Boleyn)
#  The Other Boleyn Girl by Philippa Gregory (Mary Boleyn)
#  Amenable Women by Mavis Cheek (Anne of Cleves)
#  The Fifth Queen by Ford Madox Ford (Katharine Howard)
#  Young Bess, Elizabeth, Captive Princess and Elizabeth and the Prince of Spain by Margaret Irwin
#  Kenilworth by Sir Walter Scott (Elizabeth I and Amy Robsart)
#  Cue for Treason by Geoffrey Trease (English Renaissance theatre/Elizabethan Cumberland and London)
#  Come Rack! Come Rope! by Robert Hugh Benson (Elizabethan persecution of Catholics)
#  Woodstock by Sir Walter Scott (English Civil War)
#  Peveril of the Peak by Sir Walter Scott (English Civil War)
#  John Inglesant by Joseph Henry Shorthouse (Charles I, English Civil War, Catholic proselytism)
#  Lady of the Glen by Jennifer Roberson (Massacre of Glencoe)
#  A Tale of Old Mortality by Sir Walter Scott (17th-century Scottish rebellion)
#  A Journal of the Plague Year by Daniel Defoe (account of Great Plague of London, 1666)
#  Year of Wonders by Geraldine Brooks (Great Plague, 1666)
#  Forever Amber by Kathleen Winsor (17th century, Restoration period)
#  Royal Escape by Georgette Heyer (Cromwell and Charles II)
#  Micah Clarke by Sir Arthur Conan Doyle (17th century, Monmouth Rebellion)
#  Captain Blood by Rafael Sabatini (17th century, Monmouth Rebellion and aftermath)
#  The Baroque Cycle by Neal Stephenson (English Civil War, rule of Charles II, Glorious Revolution, early 18th century)
#  Hawksmoor by Peter Akroyd (Christopher Wren, Nicholas Hawksmoor and parallel modern story)
#  The History of Henry Esmond by William Makepeace Thackeray (reign of Queen Anne)
#  An Instance of the Fingerpost by Iain Pears (Restoration period)
#  Subsections (0):
#
#  Section: Hanoverian (2):
#  Rob Roy by Sir Walter Scott (1715 Jacobite rising)
#  The Heart of Mid-Lothian by Sir Walter Scott (1730s Scotland and England)
#  Waverley by Sir Walter Scott (1745 Jacobite rising)
#  The Luck of Barry Lyndon by William Makepeace Thackeray (18th-century England, Seven Years' War)
#  Redgauntlet by Sir Walter Scott (Jacobites in Dumfries, 1760s)
#  Barnaby Rudge: A Tale of the Riots of 'Eighty by Charles Dickens (Gordon riots, 1780)
#  A Tale of Two Cities by Charles Dickens (London and Paris during the French Revolution)
#  Richard Sharpe series by Bernard Cornwell (British Army in the Napoleonic Wars)
#  Horatio Hornblower series by C. S. Forester (British navy in the Napoleonic Wars)
#  Aubrey–Maturin series by Patrick O'Brian (British Navy in the Napoleonic Wars)
#  Ramage series by Dudley Pope (British Navy in the Napoleonic Wars)
#  Bolitho Novels by Alexander Kent (British Navy in the Napoleonic Wars)
#  Revolution series by Simon Scarrow (Wellington and Napoleon)
#  Judith by Brian Cleeve (Set around the start of the 19th century)
#  Thomas Kydd Series by Julian Stockwin, set during the French and Napoleonic Wars
#  Sacred Hunger by Barry Unsworth (18th century transatlantic slave trade)
#  Subsections (0):
#
#  Section: Victorian (2):
#  Fingersmith by Sarah Waters (1860s London and elsewhere)
#  The Flashman Papers by George MacDonald Fraser (Victorian era)
#  Laura Blundy by Julie Myerson (Victorian London)
#  Jamrach's Menagerie by Carol Birch (Victorian London and seafaring)
#  Lady's Maid by Margaret Forster (concerns Elizabeth Barrett Browning)
#  Subsections (0):
#
#  Section: 20th century (2):
#  The Wishing Game by Patrick Redmond (life in a strict and uncanny boarding school in rural Norfolk in the 1950s)
#  The Rotters' Club by Jonathan Coe (1970s)
#  Diary of an Ordinary Woman by Margaret Forster (a fictional diary of the period)
#  Subsections (0):
#
#  Section: Multiple time frames (2):
#  Sarum by Edward Rutherfurd – Tells the story of England through the eyes of six families in the Salisbury area, stretching from Prehistoric Britain through the 1980s
#  The Outlander series by Diana Gabaldon
#  Subsections (0):,
#  Section: United States (including areas that become part of the US) (1):
#
#  Subsections (4):
#  Section: Colonial (2):
#  Rachel Dyer: a North American Story by John Neal (Salem witch trials)
#  Logan, a Family History by John Neal (Aftermath of Lord Dunmore's War)
#  Seventy-Six by John Neal (American Revolution)
#  Brother Jonathan by John Neal (American Revolution)
#  Sergeant Lamb of the Ninth and Proceed, Sergeant Lamb by Robert Graves (American Revolution)
#  The Fort by Bernard Cornwell (the Penobscot Expedition of the American Revolution)
#  The Last of the Mohicans by James Fenimore Cooper (French and Indian War)
#  Richard Carvel by Winston Churchill (Maryland and the American Revolution)
#  Shadow Patriots, a Novel of the Revolution by Lucia St. Clair Robson (George Washington's Culper Spy Ring)
#  Johnny Tremain by Esther Forbes (Boston in the 1770s)
#  Mason & Dixon by Thomas Pynchon (18th century/American Revolution)
#  War Comes to Willy Freeman by James Lincoln Collier (American Revolution)
#  Las huellas del conquistador by José Luis Pérez Regueira (Hernando de Soto exploration of North America)
#  La fragata Princesa by Luis Delgado Bañón (Alta California, Discovering of Nootka Island)
#  Las batallas hispano-apaches en el salvaje norte de América series by Alber Vázquez (Spanish wars against Apaches)
#  Resiste Tucson
#  Largo camino hacia Zuni Pueblo
#  Guerras mescalero en Río Grande
#  Los acasos by Javier Pascual (Spanish wars against Apaches)
#  España contraataca: Relato sobre la derrota del imperio inglés en Norteamérica by Pablo Victoria (Bernardo de Gálvez)
#  Comanche by Jesús Maeso de la Torre
#  La rosa de California by Jesús Maeso de la Torre
#  Subsections (0):
#
#  Section: 19th century (2):
#  Burr by Gore Vidal (Aaron Burr)
#  My Theodosia by Anya Seton (The life of Theodosia Burr Alston, her father Aaron Burr's Vice Presidency and subsequent years)
#  The Confessions of Nat Turner by William Styron (1831 slave revolt)
#  Roots: The Saga of an American Family by Alex Haley (18th–19th century slavery)
#  Death Comes for the Archbishop by Willa Cather (mid-19th century New Mexico Territory
#  Cloudsplitter by Russell Banks (abolitionist John Brown, pre-Civil War)
#  The Emigrants series by Vilhelm Moberg (Swedish emigrants in Minnesota, 1850s)
#  The Known World by Edward P. Jones (antebellum Virginia)
#  The Travels of Jaimie McPheeters by Robert Lewis Taylor (mid-19th century Western wagon train)
#  Lincoln by Gore Vidal
#  Across Five Aprils by Irene Hunt (American Civil War)
#  Andersonville by MacKinlay Kantor (American Civil War)
#  Cold Mountain by Charles Frazier (American Civil War)
#  Gone with the Wind by Margaret Mitchell (American Civil War)
#  The Killer Angels by Michael Shaara (American Civil War)
#  The Red Badge of Courage by Stephen Crane (American Civil War)
#  Traveller by Richard Adams (American Civil War, told by Robert E. Lee's horse)
#  Andersonville by MacKinlay Kantor (Andersonville prison camp)
#  Shiloh by Shelby Foote
#  The March by E. L. Doctorow (Sherman's March to the Sea)
#  True Women by Janice Woods Windle (Texas Revolution, American Civil War, early 20th Century)
#  Lee and Grant at Appomattox by MacKinlay Kantor (American Civil War)
#  Oldest Living Confederate Widow Tells All by Allan Gurganus (American Civil War and late 19th century)
#  Beloved by Toni Morrison (post-Civil War)
#  Ride the Wind by Lucia St. Clair Robson (Cynthia Ann Parker's life with the Comanches)
#  The Turquoise by Anya Seton (The Santa Fe Trail and New York society)
#  Out of This Furnace by Thomas Bell (Immigrants and the steel mills of Pittsburgh, from 1880)
#  Martin Dressler: The Tale of an American Dreamer by Steven Millhauser (late 19th century New York City)
#  Shadow Country by Peter Matthiessen (Edgar "Bloody" Watson, late 19th century Florida)
#  The English Wife by Lauren Willig (New York Gilded Age)
#  The City Beautiful by Aden Polydoros (Chicago 1893, World's Columbian Exposition)
#  Subsections (0):
#
#  Section: 20th century (2):
#  Ragtime by E. L. Doctorow (beginning of the 20th century)
#  The Road to Wellville by T. C. Boyle (the story of Dr. John Harvey Kellogg in 1907)
#  Lanny Budd series by Upton Sinclair (1913–1949)
#  Cryptonomicon by Neal Stephenson (American soldiers in World War II)
#  Two Trains Running by Andrew Vachss (1960 presidential election)
#  Subsections (0):
#
#  Section: Multiple time frames (2):
#
#  Subsections (2):
#  Section: Novels by James A. Michener (3):
#  Alaska (Alaska)
#  Centennial (Colorado)
#  Chesapeake (Chesapeake Bay/Delmarva Peninsula)
#  Hawaii (Hawaiʻi)
#  Texas (Texas)
#  Subsections (0):
#
#  Section: Novels by other authors (3):
#  New York by Edward Rutherfurd (New York City)
#  A Council of Dolls by Mona Susan Power (Standing Rock Indian Reservation, South Dakota; Carlisle Indian Industrial School, Pennsylvania; Chicago, Illinois)
#  Subsections (0):,
#  Section: Vietnam (1):
#  The Sorrow of War by Bao Ninh (Vietnam War)
#  The Lotus Eaters by Tatjana Soli (Vietnam War)
#  Subsections (0):,
#  Section: See also (1):
#  Historical fiction
#  Historical novel
#  Novel
#  List of historical fiction by time period
#  List of historical video games
#  List of fiction set in ancient Rome
#  List of fiction set in ancient Greece
#  Subsections (0):,
#  Section: External links (1):
#  Database of German historical novels
#  Historical Fiction database, divided by time period.
#  A Guide to the Best Historical Novels and Tales by Jonathan Nield (1902). Project Gutenberg etext (accessed 05-2014)
#  A selection of historical novels set by epoch and author. (accessed 08-2010)
#  Annotated list of historical novels for children and teens Anchorage Public Library
#  History networking Authors, Publishers, Editors, Researchers. Suggest tools and sources, help with reading list, discussions challenges. Network, promote books or find work.
#  Subsections (0):]

# %% [markdown]
# ### Check Results
#
# Check results of extraction to see if db is of good quality
#
#
# find early way to display results?

# %%
db_dir = './../data/'

# %%
booklist  = os.listdir(db_dir)
booklist.sort()
booklist[1]
# Out:
# '10 Minutes 38 Seconds in This Strange World.json'

# %%
book = booklist[1]

# %%
booklist
# Out:
# ['.ipynb_checkpoints',
#  '10 Minutes 38 Seconds in This Strange World.json',
#  'A Bend in the River.json',
#  'A Brief History of Seven Killings.json',
#  'A Case of Exploding Mangoes.json',
#  'A Clubbable Woman.json',
#  'A Disaffection.json',
#  'A Fairly Honourable Defeat.json',
#  'A Fine Balance.json',
#  'A Fraction of the Whole.json',
#  'A Guilty Thing Surprised.json',
#  'A Little Life.json',
#  'A Long Long Way.json',
#  'A Passage North.json',
#  'A Place in England.json',
#  'A Short History of Tractors in Ukrainian.json',
#  'A Spell of Good Things.json',
#  'A Spool of Blue Thread.json',
#  'A Tale for the Time Being.json',
#  'According to Mark.json',
#  'According to Queeney.json',
#  'Alias Grace.json',
#  'All That Man Is.json',
#  'Amongst Women.json',
#  'An Artist of the Floating World.json',
#  'An Ice-Cream War.json',
#  'An Instant in the Wind.json',
#  'An Orchestra of Minorities.json',
#  "Animal's People.json",
#  'Anthills of the Savannah.json',
#  'Any Human Heart.json',
#  'Arthur & George.json',
#  'Astonishing Splashes of Colour.json',
#  'Beside the Ocean of Time.json',
#  'Bewilderment.json',
#  'Beyond Black.json',
#  'Bitter Fruit.json',
#  'Black Dogs.json',
#  'Black Swan Green.json',
#  'Breakfast on Pluto.json',
#  'Briefing for a Descent into Hell.json',
#  'Bring Up the Bodies.json',
#  "Bruno's Dream.json",
#  'Carry Me Down.json',
#  'Child 44.json',
#  'Clear Light of Day.json',
#  'Crossing the River.json',
#  'Darkmans.json',
#  'Did You Ever Have a Family.json',
#  'Dirt Music.json',
#  'Disgrace.json',
#  'Do Not Say We Have Nothing.json',
#  'Dorian, an Imitation.json',
#  'Down All the Days.json',
#  'Ducks, Newburyport.json',
#  'Earthly Powers.json',
#  'Elizabeth Costello.json',
#  'England, England.json',
#  'English Passengers.json',
#  'Exit West.json',
#  'Fasting, Feasting.json',
#  'Figures in a Landscape.json',
#  'Fire From Heaven.json',
#  'Five Star Billionaire.json',
#  "Flaubert's Parrot.json",
#  'Frankissstein.json',
#  'From A to X.json',
#  'From Scenes Like These.json',
#  'From a Low and Quiet Sea.json',
#  "Gabriel's Lament.json",
#  'Girl, Woman, Other.json',
#  'God on the Rocks.json',
#  'Goshawk Squadron.json',
#  'Gossip from the Forest.json',
#  'Grace Notes.json',
#  'Half-Blood Blues.json',
#  'Heat and Dust.json',
#  'His Bloody Project.json',
#  'History of Wolves.json',
#  'Hotel World.json',
#  'Hotel du Lac.json',
#  'How Much of These Hills Is Gold.json',
#  'How late it was, how late.json',
#  'How to Be Both.json',
#  'Hystopia.json',
#  "I'll Go to Bed at Noon.json",
#  "I'm the King of the Castle.json",
#  'If I Survive You.json',
#  'If Nobody Speaks of Remarkable Things.json',
#  'Illywhacker.json',
#  'In Ascension.json',
#  'In a Free State.json',
#  'In a Strange Room.json',
#  'In the Country of Men.json',
#  "Jake's Thing.json",
#  "Jamrach's Menagerie.json",
#  'Jonathan Strange & Mr Norrell.json',
#  'Klara and the Sun.json',
#  'Knowledge of Angels.json',
#  'Last Letters from Hav.json',
#  'Last Orders.json',
#  'Lies of Silence.json',
#  'Life & Times of Michael K.json',
#  'Life of Pi.json',
#  'Lincoln in the Bardo.json',
#  'Loitering with Intent.json',
#  'Lost Children Archive.json',
#  'Love and Summer.json',
#  'Maps for Lost Lovers.json',
#  'Master Georgie.json',
#  'Master and Commander.json',
#  "Midnight's Children.json",
#  'Mister Pip.json',
#  'Moon Tiger.json',
#  "Mrs Eckdorf in O'Neill's Hotel.json",
#  'My Name Is Lucy Barton.json',
#  'My Sister, the Serial Killer.json',
#  'Nice Work.json',
#  'Night Boat to Tangier.json',
#  'Nightcrawling.json',
#  'No One Is Talking About This.json',
#  'Normal People.json',
#  'Notes on a Scandal.json',
#  'Oh William!.json',
#  'On Beauty.json',
#  'On Chesil Beach.json',
#  'Oryx and Crake.json',
#  'Oscar and Lucinda.json',
#  'Out of the Shelter.json',
#  'Paddy Clarke Ha Ha Ha.json',
#  'Parrot and Olivier in America.json',
#  'Pigeon English.json',
#  'Possession: A Romance.json',
#  'Prophet Song.json',
#  'Purple Hibiscus.json',
#  'Quartet in Autumn.json',
#  'Reading in the Dark.json',
#  'Redhead by the Side of the Road.json',
#  'Remembering Babylon.json',
#  'Reservoir 13.json',
#  'Rumours of Rain.json',
#  'Sacred Hunger.json',
#  'Satin Island.json',
#  "Schindler's Ark.json",
#  'Sea of Poppies.json',
#  'Serious Sweet.json',
#  'Shalimar the Clown.json',
#  'Shuggie Bain.json',
#  'Sixty Lights.json',
#  'Skios.json',
#  'Skippy Dies.json',
#  'Sleeping on Jupiter.json',
#  'Slow Man.json',
#  'Small Things Like These.json',
#  'So Many Ways to Begin.json',
#  'Solar Bones.json',
#  'Solomon Gursky Was Here.json',
#  'Something Might Happen.json',
#  'Something to Answer For.json',
#  'Sour Sweet.json',
#  "St. Urbain's Horseman.json",
#  'Staying On.json',
#  'Study for Obedience.json',
#  'Such a Fun Age.json',
#  'Swimming Home.json',
#  'The Accidental.json',
#  'The Amber Spyglass.json',
#  'The Autograph Man.json',
#  'The Battle of Pollocks Crossing.json',
#  'The Bay of Noon.json',
#  'The Bee Sting.json',
#  'The Beginning of Spring.json',
#  'The Big Chapel.json',
#  'The Bird of Night.json',
#  'The Birds on the Trees.json',
#  'The Blackwater Lightship.json',
#  'The Blind Assassin.json',
#  'The Bone Clocks.json',
#  'The Bone People.json',
#  'The Book and the Brotherhood.json',
#  'The Book of Evidence.json',
#  'The Bookshop.json',
#  'The Bottle Factory Outing.json',
#  'The Chant of Jimmie Blacksmith.json',
#  'The Children of Dynmouth.json',
#  "The Children's Book.json",
#  'The Clothes on Their Backs.json',
#  'The Colour of Blood.json',
#  'The Comfort of Strangers.json',
#  'The Conservationist.json',
#  'The Curious Incident of the Dog in the Night-Time.json',
#  'The Death of Vishnu.json',
#  'The Elected Member.json',
#  'The Electric Michelangelo.json',
#  'The Element of Water.json',
#  'The Enchantress of Florence.json',
#  'The English Patient.json',
#  'The Essence of the Thing.json',
#  'The Famished Road.json',
#  'The Finkler Question.json',
#  'The Folding Star.json',
#  'The Fortune Men.json',
#  'The Garden of Evening Mists.json',
#  'The Gate of Angels.json',
#  'The Ghost Road.json',
#  'The Gift of Rain.json',
#  'The Glass Room.json',
#  'The God of Small Things.json',
#  'The Good Apprentice.json',
#  'The Good Terrorist.json',
#  "The Handmaid's Tale.json",
#  'The Harmony Silk Factory.json',
#  'The House of Doors.json',
#  'The Inheritance of Loss.json',
#  'The Keepers of Truth.json',
#  'The Line of Beauty.json',
#  'The Little Stranger.json',
#  'The Long Song.json',
#  'The Long Take.json',
#  'The Lost Dog.json',
#  'The Lowland.json',
#  'The Luminaries.json',
#  'The Mars Room.json',
#  'The Ministry of Utmost Happiness.json',
#  "The Moor's Last Sigh.json",
#  'The Mulberry Empire.json',
#  'The Nice and the Good.json',
#  'The Northern Clemency.json',
#  'The Old Devils.json',
#  'The Orchard on Fire.json',
#  'The Other Side of the Bridge.json',
#  'The Overstory.json',
#  'The Pickup.json',
#  'The Public Image.json',
#  'The Quickening Maze.json',
#  'The Redundancy of Courage.json',
#  'The Reluctant Fundamentalist.json',
#  'The Remains of the Day.json',
#  'The Restraint of Beasts.json',
#  'The Riders.json',
#  'The Road to Lichfield.json',
#  'The Schooldays of Jesus.json',
#  'The Sea, the Sea.json',
#  'The Secret River.json',
#  'The Secret Scripture.json',
#  'The Sense of an Ending.json',
#  'The Seven Moons of Maali Almeida.json',
#  'The Siege of Krishnapur.json',
#  'The Sirian Experiments.json',
#  'The Sisters Brothers.json',
#  'The Spinning Heart.json',
#  'The Stars in the Bright Sky.json',
#  'The Stone Carvers.json',
#  'The Stone Diaries.json',
#  'The Story of Lucy Gault.json',
#  'The Sweetness of Water.json',
#  'The Testament of Gideon Mack.json',
#  'The Testament of Mary.json',
#  'The Testaments.json',
#  'The Thousand Autumns of Jacob de Zoet.json',
#  'The Unlikely Pilgrimage of Harold Fry.json',
#  'The Vivisector.json',
#  'The White Hotel.json',
#  'The Year of the Runaways.json',
#  'Theft: A Love Story.json',
#  'This Mournable Body.json',
#  'This Thing of Darkness.json',
#  'To Rise Again at a Decent Hour.json',
#  'Translated Accounts.json',
#  'Treacle Walker.json',
#  'True History of the Kelly Gang.json',
#  'Under the Frog.json',
#  'Unless.json',
#  'Vernon God Little.json',
#  'Warlight.json',
#  'Washington Black.json',
#  'We Are All Completely Beside Ourselves.json',
#  'We Need New Names.json',
#  'Western Lane.json',
#  'What Was Lost.json',
#  "What's Bred in the Bone.json",
#  'When We Were Orphans.json',
#  'Wolf Hall.json',
#  'Work Like Any Other.json']

# %%
[book for book in booklist if book.split('.')[-1] == 'json']
# Out:
# ['10 Minutes 38 Seconds in This Strange World.json',
#  'A Bend in the River.json',
#  'A Brief History of Seven Killings.json',
#  'A Case of Exploding Mangoes.json',
#  'A Clubbable Woman.json',
#  'A Disaffection.json',
#  'A Fairly Honourable Defeat.json',
#  'A Fine Balance.json',
#  'A Fraction of the Whole.json',
#  'A Guilty Thing Surprised.json',
#  'A Little Life.json',
#  'A Long Long Way.json',
#  'A Passage North.json',
#  'A Place in England.json',
#  'A Short History of Tractors in Ukrainian.json',
#  'A Spell of Good Things.json',
#  'A Spool of Blue Thread.json',
#  'A Tale for the Time Being.json',
#  'According to Mark.json',
#  'According to Queeney.json',
#  'Alias Grace.json',
#  'All That Man Is.json',
#  'Amongst Women.json',
#  'An Artist of the Floating World.json',
#  'An Ice-Cream War.json',
#  'An Instant in the Wind.json',
#  'An Orchestra of Minorities.json',
#  "Animal's People.json",
#  'Anthills of the Savannah.json',
#  'Any Human Heart.json',
#  'Arthur & George.json',
#  'Astonishing Splashes of Colour.json',
#  'Beside the Ocean of Time.json',
#  'Bewilderment.json',
#  'Beyond Black.json',
#  'Bitter Fruit.json',
#  'Black Dogs.json',
#  'Black Swan Green.json',
#  'Breakfast on Pluto.json',
#  'Briefing for a Descent into Hell.json',
#  'Bring Up the Bodies.json',
#  "Bruno's Dream.json",
#  'Carry Me Down.json',
#  'Child 44.json',
#  'Clear Light of Day.json',
#  'Crossing the River.json',
#  'Darkmans.json',
#  'Did You Ever Have a Family.json',
#  'Dirt Music.json',
#  'Disgrace.json',
#  'Do Not Say We Have Nothing.json',
#  'Dorian, an Imitation.json',
#  'Down All the Days.json',
#  'Ducks, Newburyport.json',
#  'Earthly Powers.json',
#  'Elizabeth Costello.json',
#  'England, England.json',
#  'English Passengers.json',
#  'Exit West.json',
#  'Fasting, Feasting.json',
#  'Figures in a Landscape.json',
#  'Fire From Heaven.json',
#  'Five Star Billionaire.json',
#  "Flaubert's Parrot.json",
#  'Frankissstein.json',
#  'From A to X.json',
#  'From Scenes Like These.json',
#  'From a Low and Quiet Sea.json',
#  "Gabriel's Lament.json",
#  'Girl, Woman, Other.json',
#  'God on the Rocks.json',
#  'Goshawk Squadron.json',
#  'Gossip from the Forest.json',
#  'Grace Notes.json',
#  'Half-Blood Blues.json',
#  'Heat and Dust.json',
#  'His Bloody Project.json',
#  'History of Wolves.json',
#  'Hotel World.json',
#  'Hotel du Lac.json',
#  'How Much of These Hills Is Gold.json',
#  'How late it was, how late.json',
#  'How to Be Both.json',
#  'Hystopia.json',
#  "I'll Go to Bed at Noon.json",
#  "I'm the King of the Castle.json",
#  'If I Survive You.json',
#  'If Nobody Speaks of Remarkable Things.json',
#  'Illywhacker.json',
#  'In Ascension.json',
#  'In a Free State.json',
#  'In a Strange Room.json',
#  'In the Country of Men.json',
#  "Jake's Thing.json",
#  "Jamrach's Menagerie.json",
#  'Jonathan Strange & Mr Norrell.json',
#  'Klara and the Sun.json',
#  'Knowledge of Angels.json',
#  'Last Letters from Hav.json',
#  'Last Orders.json',
#  'Lies of Silence.json',
#  'Life & Times of Michael K.json',
#  'Life of Pi.json',
#  'Lincoln in the Bardo.json',
#  'Loitering with Intent.json',
#  'Lost Children Archive.json',
#  'Love and Summer.json',
#  'Maps for Lost Lovers.json',
#  'Master Georgie.json',
#  'Master and Commander.json',
#  "Midnight's Children.json",
#  'Mister Pip.json',
#  'Moon Tiger.json',
#  "Mrs Eckdorf in O'Neill's Hotel.json",
#  'My Name Is Lucy Barton.json',
#  'My Sister, the Serial Killer.json',
#  'Nice Work.json',
#  'Night Boat to Tangier.json',
#  'Nightcrawling.json',
#  'No One Is Talking About This.json',
#  'Normal People.json',
#  'Notes on a Scandal.json',
#  'Oh William!.json',
#  'On Beauty.json',
#  'On Chesil Beach.json',
#  'Oryx and Crake.json',
#  'Oscar and Lucinda.json',
#  'Out of the Shelter.json',
#  'Paddy Clarke Ha Ha Ha.json',
#  'Parrot and Olivier in America.json',
#  'Pigeon English.json',
#  'Possession: A Romance.json',
#  'Prophet Song.json',
#  'Purple Hibiscus.json',
#  'Quartet in Autumn.json',
#  'Reading in the Dark.json',
#  'Redhead by the Side of the Road.json',
#  'Remembering Babylon.json',
#  'Reservoir 13.json',
#  'Rumours of Rain.json',
#  'Sacred Hunger.json',
#  'Satin Island.json',
#  "Schindler's Ark.json",
#  'Sea of Poppies.json',
#  'Serious Sweet.json',
#  'Shalimar the Clown.json',
#  'Shuggie Bain.json',
#  'Sixty Lights.json',
#  'Skios.json',
#  'Skippy Dies.json',
#  'Sleeping on Jupiter.json',
#  'Slow Man.json',
#  'Small Things Like These.json',
#  'So Many Ways to Begin.json',
#  'Solar Bones.json',
#  'Solomon Gursky Was Here.json',
#  'Something Might Happen.json',
#  'Something to Answer For.json',
#  'Sour Sweet.json',
#  "St. Urbain's Horseman.json",
#  'Staying On.json',
#  'Study for Obedience.json',
#  'Such a Fun Age.json',
#  'Swimming Home.json',
#  'The Accidental.json',
#  'The Amber Spyglass.json',
#  'The Autograph Man.json',
#  'The Battle of Pollocks Crossing.json',
#  'The Bay of Noon.json',
#  'The Bee Sting.json',
#  'The Beginning of Spring.json',
#  'The Big Chapel.json',
#  'The Bird of Night.json',
#  'The Birds on the Trees.json',
#  'The Blackwater Lightship.json',
#  'The Blind Assassin.json',
#  'The Bone Clocks.json',
#  'The Bone People.json',
#  'The Book and the Brotherhood.json',
#  'The Book of Evidence.json',
#  'The Bookshop.json',
#  'The Bottle Factory Outing.json',
#  'The Chant of Jimmie Blacksmith.json',
#  'The Children of Dynmouth.json',
#  "The Children's Book.json",
#  'The Clothes on Their Backs.json',
#  'The Colour of Blood.json',
#  'The Comfort of Strangers.json',
#  'The Conservationist.json',
#  'The Curious Incident of the Dog in the Night-Time.json',
#  'The Death of Vishnu.json',
#  'The Elected Member.json',
#  'The Electric Michelangelo.json',
#  'The Element of Water.json',
#  'The Enchantress of Florence.json',
#  'The English Patient.json',
#  'The Essence of the Thing.json',
#  'The Famished Road.json',
#  'The Finkler Question.json',
#  'The Folding Star.json',
#  'The Fortune Men.json',
#  'The Garden of Evening Mists.json',
#  'The Gate of Angels.json',
#  'The Ghost Road.json',
#  'The Gift of Rain.json',
#  'The Glass Room.json',
#  'The God of Small Things.json',
#  'The Good Apprentice.json',
#  'The Good Terrorist.json',
#  "The Handmaid's Tale.json",
#  'The Harmony Silk Factory.json',
#  'The House of Doors.json',
#  'The Inheritance of Loss.json',
#  'The Keepers of Truth.json',
#  'The Line of Beauty.json',
#  'The Little Stranger.json',
#  'The Long Song.json',
#  'The Long Take.json',
#  'The Lost Dog.json',
#  'The Lowland.json',
#  'The Luminaries.json',
#  'The Mars Room.json',
#  'The Ministry of Utmost Happiness.json',
#  "The Moor's Last Sigh.json",
#  'The Mulberry Empire.json',
#  'The Nice and the Good.json',
#  'The Northern Clemency.json',
#  'The Old Devils.json',
#  'The Orchard on Fire.json',
#  'The Other Side of the Bridge.json',
#  'The Overstory.json',
#  'The Pickup.json',
#  'The Public Image.json',
#  'The Quickening Maze.json',
#  'The Redundancy of Courage.json',
#  'The Reluctant Fundamentalist.json',
#  'The Remains of the Day.json',
#  'The Restraint of Beasts.json',
#  'The Riders.json',
#  'The Road to Lichfield.json',
#  'The Schooldays of Jesus.json',
#  'The Sea, the Sea.json',
#  'The Secret River.json',
#  'The Secret Scripture.json',
#  'The Sense of an Ending.json',
#  'The Seven Moons of Maali Almeida.json',
#  'The Siege of Krishnapur.json',
#  'The Sirian Experiments.json',
#  'The Sisters Brothers.json',
#  'The Spinning Heart.json',
#  'The Stars in the Bright Sky.json',
#  'The Stone Carvers.json',
#  'The Stone Diaries.json',
#  'The Story of Lucy Gault.json',
#  'The Sweetness of Water.json',
#  'The Testament of Gideon Mack.json',
#  'The Testament of Mary.json',
#  'The Testaments.json',
#  'The Thousand Autumns of Jacob de Zoet.json',
#  'The Unlikely Pilgrimage of Harold Fry.json',
#  'The Vivisector.json',
#  'The White Hotel.json',
#  'The Year of the Runaways.json',
#  'Theft: A Love Story.json',
#  'This Mournable Body.json',
#  'This Thing of Darkness.json',
#  'To Rise Again at a Decent Hour.json',
#  'Translated Accounts.json',
#  'Treacle Walker.json',
#  'True History of the Kelly Gang.json',
#  'Under the Frog.json',
#  'Unless.json',
#  'Vernon God Little.json',
#  'Warlight.json',
#  'Washington Black.json',
#  'We Are All Completely Beside Ourselves.json',
#  'We Need New Names.json',
#  'Western Lane.json',
#  'What Was Lost.json',
#  "What's Bred in the Bone.json",
#  'When We Were Orphans.json',
#  'Wolf Hall.json',
#  'Work Like Any Other.json']

# %%
book
# Out:
# '10 Minutes 38 Seconds in This Strange World.json'

# %%
book_dir = db_dir+book

# %%
book_dir
# Out:
# './../data/10 Minutes 38 Seconds in This Strange World.json'

# %%
with open(book_dir, 'r') as f:
    data = json.load(f)
    print(data)
# Out:
# {'title': '10 Minutes and 38 Seconds in This Strange World', 'author': 'Elif Shafak', 'city': 'Istanbul', 'country': 'Turkey', 'page': '10 Minutes 38 Seconds in This Strange World'}

# %%
data['title']
# Out:
# '10 Minutes and 38 Seconds in This Strange World'

# %%
class CheckOutput:

    def __init__(self, db_dir = './../data/', book_schema = {'title':'', 'author':'', 'city':'', 'country':'', 'page':''}):
        self.db_dir = db_dir
        self.book_schema = book_schema

    def run(self):
        self.clean_db()
        
    def clean_db(self):
        booklist = os.listdir(self.db_dir)
        booklist.sort()


        self.book_dicts = {}
        self.failed_check = []
        self.failed_schema = {}

        # only allow json
        self.booklist = [book for book in booklist if book.split('.')[-1] == 'json'] # ensures book ends in .json

        for book in self.booklist:
            self.check_book(book)

        
        self.clean_db_df = pd.DataFrame(list(self.book_dicts.values()))
        
    def check_book(self, book):
        
        book_file = self.db_dir + book
        book_data = self.get_book_data(book_file)
        if isinstance(book_data, dict):
            self.book_dicts[book] = book_data
            """
            if book_data.keys() == self.book_schema.keys():
                self.book_dicts[book] = book_data
            else:
                self.failed_check.append(book)
                self.failed_schema[book] = book_data
            """
        else:
            self.failed_check.append(book)
    
        
    @staticmethod 
    def get_book_data(book_file):

        with open(book_file, 'r') as f:
            data = json.load(f)

        return data

# %%
co = CheckOutput()
co.clean_db()

# %%
co.clean_db_df[co.clean_db_df.city=='Kyoto']
# Out:
# Empty DataFrame
# Columns: [title, author, city, country, page]
# Index: []

# %%
co.clean_db_df.loc[co.clean_db_df.city.isna()]
# Out:
#                               title               author city country  \
# 4                 A Clubbable Woman        Reginald Hill  NaN     NaN
# 8           A Fraction of the Whole          Steve Toltz  NaN     NaN
# 29                  Any Human Heart         William Boyd  NaN     NaN
# 31   Astonishing Splashes of Colour        Clare Morrall  NaN     NaN
# 50       Do Not Say We Have Nothing                       NaN     NaN
# 56                 England, England        Julian Barnes  NaN     NaN
# 61                 Fire From Heaven         Mary Renault  NaN     NaN
# 63                Flaubert's Parrot        Julian Barnes  NaN     NaN
# 69               Girl, Woman, Other   Bernadine Evaristo  NaN     NaN
# 78                      Hotel World            Ali Smith  NaN     NaN
# 90                  In a Free State        V. S. Naipaul  NaN     NaN
# 98            Last Letters from Hav           Jan Morris  NaN     NaN
# 103            Lincoln in the Bardo      George Saunders  NaN     NaN
# 109            Master and Commander      Patrick O'Brian  NaN     NaN
# 123                       On Beauty          Zadie Smith  NaN     NaN
# 125                  Oryx and Crake      Margaret Atwood  NaN     NaN
# 131           Possession: A Romance           A.S. Byatt  NaN     NaN
# 134               Quartet in Autumn          Barbara Pym  NaN     NaN
# 136           If Morning Ever Comes           Anne Tyler  NaN     NaN
# 142                 Schindler's Ark      Thomas Keneally  NaN     NaN
# 153           So Many Ways to Begin         Jon McGregor  NaN     NaN
# 162                  Such a Fun Age  Renee Newman-Clarke  NaN     NaN
# 176                 The Bone Clocks       David Mitchell  NaN     NaN
# 191              The Elected Member       Bernice Rubens  NaN     NaN
# 194     The Enchantress of Florence       Salman Rushdie  NaN     NaN
# 202              The Gate of Angels  Penelope Fitzgerald  NaN     NaN
# 206         The God of Small Things        Arundhati Roy  NaN     NaN
# 233             The Quickening Maze          Adam Foulds  NaN     NaN
# 242                The Secret River       Kate Grenville  NaN     NaN
# 252               The Stone Diaries        Carol Shields  NaN     NaN
# 269  True History of the Kelly Gang          Peter Carey  NaN     NaN
# 273                        Warlight     Michael Ondaatje  NaN     NaN
#
#                                 page
# 4                  A Clubbable Woman
# 8            A Fraction of the Whole
# 29                   Any Human Heart
# 31    Astonishing Splashes of Colour
# 50        Do Not Say We Have Nothing
# 56                  England, England
# 61                  Fire From Heaven
# 63                 Flaubert's Parrot
# 69                Girl, Woman, Other
# 78                       Hotel World
# 90                   In a Free State
# 98             Last Letters from Hav
# 103             Lincoln in the Bardo
# 109             Master and Commander
# 123                        On Beauty
# 125                   Oryx and Crake
# 131            Possession: A Romance
# 134                Quartet in Autumn
# 136  Redhead by the Side of the Road
# 142                  Schindler's Ark
# 153            So Many Ways to Begin
# 162                   Such a Fun Age
# 176                  The Bone Clocks
# 191               The Elected Member
# 194      The Enchantress of Florence
# 202               The Gate of Angels
# 206          The God of Small Things
# 233              The Quickening Maze
# 242                 The Secret River
# 252                The Stone Diaries
# 269   True History of the Kelly Gang
# 273                         Warlight

# %%
co.book_dicts['10 Minutes 38 Seconds in This Strange World.json'].keys() == co.book_schema.keys()
# Out:
# True

# %%
pd.DataFrame(list(co.book_dicts.values()))
# Out:
#                                                title             author  \
# 0    10 Minutes and 38 Seconds in This Strange World        Elif Shafak
# 1                                A Bend in the River       V.S. Naipaul
# 2                  A Brief History of Seven Killings       Marlon James
# 3                           A Thousand Splendid Suns    Khaled Hosseini
# 4                                  A Clubbable Woman      Reginald Hill
# ..                                               ...                ...
# 278                                    What Was Lost  Catherine O'Flynn
# 279                          What's Bred in the Bone   Robertson Davies
# 280                             When We Were Orphans     Kazuo Ishiguro
# 281                                        Wolf Hall      Hilary Mantel
# 282                              Work Like Any Other    Virginia Reeves
#
#            city   country                                         page
# 0      Istanbul    Turkey  10 Minutes 38 Seconds in This Strange World
# 1     Kisangani     Zaire                          A Bend in the River
# 2            NA   Jamaica            A Brief History of Seven Killings
# 3        Lahore  Pakistan                  A Case of Exploding Mangoes
# 4           NaN       NaN                            A Clubbable Woman
# ..          ...       ...                                          ...
# 278  Birmingham   England                                What Was Lost
# 279          NA    Canada                      What's Bred in the Bone
# 280    Shanghai     China                         When We Were Orphans
# 281          NA   England                                    Wolf Hall
# 282          NA        NA                          Work Like Any Other
#
# [283 rows x 5 columns]

# %%
co.failed_schema
# Out:
# {'A Clubbable Woman.json': {'title': 'A Clubbable Woman',
#   'author': 'Reginald Hill',
#   'page': 'A Clubbable Woman'},
#  'A Fraction of the Whole.json': {'title': 'A Fraction of the Whole',
#   'author': 'Steve Toltz',
#   'page': 'A Fraction of the Whole'},
#  'Any Human Heart.json': {'title': 'Any Human Heart',
#   'author': 'William Boyd',
#   'page': 'Any Human Heart'},
#  'Astonishing Splashes of Colour.json': {'title': 'Astonishing Splashes of Colour',
#   'author': 'Clare Morrall',
#   'page': 'Astonishing Splashes of Colour'},
#  'Do Not Say We Have Nothing.json': {'title': 'Do Not Say We Have Nothing',
#   'author': '',
#   'page': 'Do Not Say We Have Nothing'},
#  'England, England.json': {'title': 'England, England',
#   'author': 'Julian Barnes',
#   'page': 'England, England'},
#  'Fire From Heaven.json': {'title': 'Fire From Heaven',
#   'author': 'Mary Renault',
#   'page': 'Fire From Heaven'},
#  "Flaubert's Parrot.json": {'title': "Flaubert's Parrot",
#   'author': 'Julian Barnes',
#   'page': "Flaubert's Parrot"},
#  'Girl, Woman, Other.json': {'title': 'Girl, Woman, Other',
#   'author': 'Bernadine Evaristo',
#   'page': 'Girl, Woman, Other'},
#  'Hotel World.json': {'title': 'Hotel World',
#   'author': 'Ali Smith',
#   'page': 'Hotel World'},
#  'In a Free State.json': {'title': 'In a Free State',
#   'author': 'V. S. Naipaul',
#   'page': 'In a Free State'},
#  'Last Letters from Hav.json': {'title': 'Last Letters from Hav',
#   'author': 'Jan Morris',
#   'page': 'Last Letters from Hav'},
#  'Lincoln in the Bardo.json': {'title': 'Lincoln in the Bardo',
#   'author': 'George Saunders',
#   'page': 'Lincoln in the Bardo'},
#  'Master and Commander.json': {'title': 'Master and Commander',
#   'author': "Patrick O'Brian",
#   'page': 'Master and Commander'},
#  'On Beauty.json': {'title': 'On Beauty',
#   'author': 'Zadie Smith',
#   'page': 'On Beauty'},
#  'Oryx and Crake.json': {'title': 'Oryx and Crake',
#   'author': 'Margaret Atwood',
#   'page': 'Oryx and Crake'},
#  'Possession: A Romance.json': {'title': 'Possession: A Romance',
#   'author': 'A.S. Byatt',
#   'page': 'Possession: A Romance'},
#  'Quartet in Autumn.json': {'title': 'Quartet in Autumn',
#   'author': 'Barbara Pym',
#   'page': 'Quartet in Autumn'},
#  'Redhead by the Side of the Road.json': {'title': 'If Morning Ever Comes',
#   'author': 'Anne Tyler',
#   'page': 'Redhead by the Side of the Road'},
#  "Schindler's Ark.json": {'title': "Schindler's Ark",
#   'author': 'Thomas Keneally',
#   'page': "Schindler's Ark"},
#  'So Many Ways to Begin.json': {'title': 'So Many Ways to Begin',
#   'author': 'Jon McGregor',
#   'page': 'So Many Ways to Begin'},
#  'Such a Fun Age.json': {'title': 'Such a Fun Age',
#   'author': 'Renee Newman-Clarke',
#   'page': 'Such a Fun Age'},
#  'The Bone Clocks.json': {'title': 'The Bone Clocks',
#   'author': 'David Mitchell',
#   'page': 'The Bone Clocks'},
#  'The Elected Member.json': {'title': 'The Elected Member',
#   'author': 'Bernice Rubens',
#   'page': 'The Elected Member'},
#  'The Enchantress of Florence.json': {'title': 'The Enchantress of Florence',
#   'author': 'Salman Rushdie',
#   'page': 'The Enchantress of Florence'},
#  'The Gate of Angels.json': {'title': 'The Gate of Angels',
#   'author': 'Penelope Fitzgerald',
#   'page': 'The Gate of Angels'},
#  'The God of Small Things.json': {'title': 'The God of Small Things',
#   'author': 'Arundhati Roy',
#   'page': 'The God of Small Things'},
#  'The Quickening Maze.json': {'title': 'The Quickening Maze',
#   'author': 'Adam Foulds',
#   'page': 'The Quickening Maze'},
#  'The Secret River.json': {'title': 'The Secret River',
#   'author': 'Kate Grenville',
#   'page': 'The Secret River'},
#  'The Stone Diaries.json': {'title': 'The Stone Diaries',
#   'author': 'Carol Shields',
#   'page': 'The Stone Diaries'},
#  'True History of the Kelly Gang.json': {'title': 'True History of the Kelly Gang',
#   'author': 'Peter Carey',
#   'page': 'True History of the Kelly Gang'},
#  'Warlight.json': {'title': 'Warlight',
#   'author': 'Michael Ondaatje',
#   'page': 'Warlight'}}

# %%
co.failed_check
# Out:
# []

# %%
co.book_dicts['A Brief History of Seven Killings.json'].keys() ==['title', 'author', 'city', 'country', 'page']
# Out:
# False

# %%
empty_list = []
for key, value in co.book_dicts.items():
    if value=={}:
        empty_list.append(key)

# %%
empty_list
# Out:
# []

# %%
co = CheckOutput
x = co.get_dict(book_dir)

# %%
x.is_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 x.is_dict()
#
# AttributeError: 'dict' object has no attribute 'is_dict'

# %%
x
# Out:
# {'title': '10 Minutes and 38 Seconds in This Strange World',
#  'author': 'Elif Shafak',
#  'city': 'Istanbul',
#  'country': 'Turkey',
#  'page': '10 Minutes 38 Seconds in This Strange World'}

# %%
if isinstance(x, dict):
    print('hai!')
# Out:
# hai!

# %%
# Out:
# /Users/shrey/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(

# %%
# Out:
# {'title': 'Musashi',
#  'author': 'Eiji Yoshikawa',
#  'city': 'NA',
#  'country': 'Japan'}

# %% [markdown]
# # using ollama
#
# ### PM Time:
#
# Currently we can pull a wikipedia page and have a seemingly reliable llm prompt that rips name, author, city, and country info from the book. Now we want to generate an eligible list of wikipedia page titles, starting with all booker prize books, and then scriptify so we can scrape their info correctly.

# %% [markdown]
# ### infra for whole notebook

# %%
llm = Ollama(model="llama3")
llm("The first man on the summit of Mount Everest, the highest peak on Earth, was ...")
# Out:
# /Users/shrey/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# "Tenzing Norgay, a Nepali Sherpa mountaineer, and Sir Edmund Hillary, a New Zealand mountaineer and explorer. They reached the summit of Mount Everest (then known as Chomolungma) on May 29, 1953. This achievement marked a major milestone in the history of mountain climbing and earned them international recognition.\n\nTenzing Norgay and Sir Edmund Hillary's successful ascent of Mount Everest was part of a British expedition led by John Hunt. The team spent several weeks acclimatizing to the high altitude and making their way up the mountain via the South Col route. After a long and challenging climb, Tenzing and Hillary reached the summit at around 11:30 am local time.\n\nTheir achievement marked the first time humans had reached the top of Mount Everest, which stands at an incredible 8,848 meters (29,029 feet) above sea level. Today, the summit is considered one of the most iconic and coveted destinations in the world for mountaineers and adventure seekers."

# %%
wiki_wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')
page_py = wiki_wiki.page('Python_(programming_language)')

# %% [markdown]
# ## Access the List of Valid Books
#
# booker prize books
#
# struggling to get table data with the wikipedia api so let's try more old school
#
# https://medium.com/analytics-vidhya/web-scraping-a-wikipedia-table-into-a-dataframe-c52617e1f451
#
# had success with beautiful soup!
#
# OK totally devious plan, most excellent--we take the scraped list of book titles from the beautiful soup made dataframe, and then we cross ref against the list of linked pages we get from the wikipedia api's .links call. from that intersection we'll get the set of all book pages that are booker winners AND have active wiki pages. From there we can run our llm.

# %%
class BookList:

    def __init__(self):
        self.wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')
        self.booker_page = 'List_of_winners_and_nominated_authors_of_the_Booker_Prize'
        self.booker_url = 'https://en.wikipedia.org/wiki/' + self.booker_page

    def run(self):

        self.get_booker_table()
        self.xref_booker_pages()
        
    def get_booker_table(self):
        wikiurl=self.booker_url
        table_class="wikitable sortable jquery-tablesorter"
        response=requests.get(wikiurl)
        print(response.status_code)
        
        self.soup = BeautifulSoup(response.text, 'html.parser')
        bookertable=self.soup.find('table',{'class':"wikitable"})
        df=pd.read_html(str(bookertable))
        self.booker_df=pd.DataFrame(df[0])

    def xref_booker_pages(self):
        self.booker_titles_list = self.booker_df.Title.dropna().tolist()
        self.booker = self.wiki.page(self.booker_page)
        self.booker_wiki_links = list(self.booker.links.keys())
        self.booker_eligible_pages = list(set(self.booker_wiki_links) & set(self.booker_titles_list))

# %%
bl = BookList()
bl.run()
# Out:
# 200
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_68741/3440289124.py:21: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_html(str(bookertable))

# %%
bl.booker_df.sort_values('Author')
# Out:
#          Year      Award         Author                        Title  \
# 387  2011[17]  Shortlist     A D Miller                    Snowdrops
# 7        1970  Shortlist   A. L. Barker            John Brown's Body
# 342  2007[13]   Longlist   A. N. Wilson                Winnie & Wolf
# 357  2009[15]  Shortlist    A. S. Byatt          The Children's Book
# 140      1990     Winner    A. S. Byatt        Possession: A Romance
# ..        ...        ...            ...                          ...
# 470      2017   Longlist    Zadie Smith                   Swing Time
# 247   2002[8]   Longlist    Zadie Smith            The Autograph Man
# 253   2003[9]  Shortlist     Zoë Heller           Notes on a Scandal
# 220   2001[7]   Longlist  Zvi Jagendorf  Wolfy and the Strudelbakers
# 550      2023        NaN            NaN                          NaN
#
#              Publisher                                             Judges
# 387     Atlantic Books  Dame Stella Rimington (chair) Matthew d'Ancona...
# 7              Hogarth  Antonia Fraser Ross Higgins Richard Hoggart Da...
# 342         Hutchinson  Howard Davies (chair) Wendy Cope Giles Foden R...
# 357  Chatto and Windus  James Naughtie (chair) Lucasta Miller John Mul...
# 140    Chatto & Windus  Sir Denis Forman (chair) Susannah Clapp A. Wal...
# ..                 ...                                                ...
# 470    Hamish Hamilton  Baroness Lola Young (chair) Lila Azam Zanganeh...
# 247    Hamish Hamilton  Lisa Jardine (chair) David Baddiel Russell Cel...
# 253             Viking  John Carey (Chair) A. C. Grayling Francine Sto...
# 220         Dewi Lewis  Kenneth Baker (chair) Philip Hensher Michèle R...
# 550                NaN                                                NaN
#
# [551 rows x 6 columns]

# %%
bl.booker_df
# Out:
#      Year         Award                 Author                       Title  \
# 0    1969        Winner            P. H. Newby     Something to Answer For
# 1    1969     Shortlist          Barry England      Figures in a Landscape
# 2    1969     Shortlist        Nicholas Mosley           Impossible Object
# 3    1969     Shortlist           Iris Murdoch       The Nice and the Good
# 4    1969     Shortlist           Muriel Spark            The Public Image
# ..    ...           ...                    ...                         ...
# 546  2023  Longlist[38]            Siân Hughes                       Pearl
# 547  2023  Longlist[38]  Viktoria Lloyd-Barlow  All the Little Bird-Hearts
# 548  2023  Longlist[38]        Martin MacInnes                In Ascension
# 549  2023  Longlist[38]           Tan Twan Eng          The House of Doors
# 550  2023           NaN                    NaN                         NaN
#
#               Publisher                                             Judges
# 0         Faber & Faber  David Farrer Frank Kermode Stephen Spender Dam...
# 1         Jonathan Cape  David Farrer Frank Kermode Stephen Spender Dam...
# 2    Hodder & Stoughton  David Farrer Frank Kermode Stephen Spender Dam...
# 3       Chatto & Windus  David Farrer Frank Kermode Stephen Spender Dam...
# 4             Macmillan  David Farrer Frank Kermode Stephen Spender Dam...
# ..                  ...                                                ...
# 546        Indigo Press  Esi Edugyan (chair) Adjoa Andoh Mary Jean Chan...
# 547        Tinder Press  Esi Edugyan (chair) Adjoa Andoh Mary Jean Chan...
# 548      Atlantic Books  Esi Edugyan (chair) Adjoa Andoh Mary Jean Chan...
# 549           Canongate  Esi Edugyan (chair) Adjoa Andoh Mary Jean Chan...
# 550                 NaN                                                NaN
#
# [551 rows x 6 columns]

# %%
bl.booker_eligible_pages # also can get author and prize type (winner, shortlist, etc) from the table
# Out:
# ['Satin Island',
#  'Translated Accounts',
#  'Arthur & George',
#  'Last Letters from Hav',
#  'Rumours of Rain',
#  'According to Queeney',
#  'Elizabeth Costello',
#  'The Nice and the Good',
#  'Sacred Hunger',
#  'The Mulberry Empire',
#  'Figures in a Landscape',
#  'Girl, Woman, Other',
#  'A Fine Balance',
#  'An Insular Possession',
#  'Rhine Journey',
#  'The Folding Star',
#  'Slow Man',
#  'Such a Fun Age',
#  'The 27th Kingdom',
#  'Night Boat to Tangier',
#  'Nice Work',
#  'The Hand Reared Boy',
#  'An Artist of the Floating World',
#  'Dorian, an Imitation',
#  'The Long Take',
#  'No One Is Talking About This',
#  "Flaubert's Parrot",
#  'Beyond Black',
#  'The Vivisector',
#  'Briefing for a Descent into Hell',
#  'Sour Sweet',
#  'The Bee Sting',
#  'Grace Notes',
#  'Possession: A Romance',
#  'The Testament of Mary',
#  'Bring Up the Bodies',
#  'The Amber Spyglass',
#  'The Blackwater Lightship',
#  'The Bird of Night',
#  'The Stars in the Bright Sky',
#  'The Big Chapel',
#  'A Clubbable Woman',
#  'Love and Summer',
#  'The Stone Carvers',
#  'A Brief History of Seven Killings',
#  'A Tale for the Time Being',
#  'The Stone Diaries',
#  'The God of Small Things',
#  'Oh William!',
#  'A Fraction of the Whole',
#  'My Name Is Lucy Barton',
#  'Warlight',
#  'The Schooldays of Jesus',
#  'The Reluctant Fundamentalist',
#  'Pigeon English',
#  'The Testaments',
#  'The Clothes on Their Backs',
#  'Beside the Ocean of Time',
#  'A Green Equinox',
#  'Remembering Babylon',
#  'We Are All Completely Beside Ourselves',
#  'An Ice-Cream War',
#  'Skippy Dies',
#  'Half-Blood Blues',
#  'Life & Times of Michael K',
#  'Under the Frog',
#  'To Rise Again at a Decent Hour',
#  'Treacle Walker',
#  'The Autograph Man',
#  'Do Not Say We Have Nothing',
#  'In Ascension',
#  'Oryx and Crake',
#  'The Famished Road',
#  'The Good Apprentice',
#  'Illywhacker',
#  'English Passengers',
#  'The Keepers of Truth',
#  'Ending Up',
#  'Hystopia',
#  'Notes on a Scandal',
#  'A Long Long Way',
#  'The Northern Clemency',
#  'Dirt Music',
#  'This Thing of Darkness',
#  'A Spell of Good Things',
#  'Hotel du Lac',
#  'Gossip from the Forest',
#  'Nightcrawling',
#  'Purple Hibiscus',
#  "I'm the King of the Castle",
#  'Sixty Lights',
#  'Staying On',
#  'The White Hotel',
#  'Disgrace',
#  'In Every Face I Meet',
#  'Crossing the River',
#  'Rates of Exchange',
#  'Lost Children Archive',
#  'Flying to Nowhere',
#  'Shadows on our Skin',
#  'The Book of Evidence',
#  'The Conservationist',
#  'The Gift of Rain',
#  "Mrs Eckdorf in O'Neill's Hotel",
#  'Who They Was',
#  'If Nobody Speaks of Remarkable Things',
#  'A Fairly Honourable Defeat',
#  'The Good Terrorist',
#  'The Beginning of Spring',
#  'Reading in the Dark',
#  'The Road to Lichfield',
#  'The Bone Clocks',
#  'Master Georgie',
#  'The Fortune Men',
#  'The Ghost Road',
#  'Loitering with Intent',
#  'Five Star Billionaire',
#  'A Bend in the River',
#  'The Colour of Blood',
#  'Darkmans',
#  'Last Orders',
#  'King Fisher Lives',
#  'An Instant in the Wind',
#  'The Line of Beauty',
#  'Quartet in Autumn',
#  'The Lowland',
#  'The Year of the Runaways',
#  'How late it was, how late',
#  'Breakfast on Pluto',
#  'A Little Life',
#  'The Redundancy of Courage',
#  'The Quickening Maze',
#  'Something to Answer For',
#  'The Secret River',
#  'Normal People',
#  'The Birds on the Trees',
#  'In a Free State',
#  'The Overstory',
#  'The Finkler Question',
#  'Jonathan Strange & Mr Norrell',
#  'Prophet Song',
#  '10 Minutes 38 Seconds in This Strange World',
#  'Frankissstein',
#  'History of Wolves',
#  'The Electric Michelangelo',
#  'How Much of These Hills Is Gold',
#  'The Testament of Gideon Mack',
#  'Fasting, Feasting',
#  'Clear Light of Day',
#  'The Bone People',
#  'Unless',
#  'A Short History of Tractors in Ukrainian',
#  'On Chesil Beach',
#  'The Bottle Factory Outing',
#  'Anthills of the Savannah',
#  'Reservoir 13',
#  'Bitter Fruit',
#  'In Their Wisdom',
#  "The Children's Book",
#  'The Accidental',
#  'So Many Ways to Begin',
#  'The Sea, the Sea',
#  'The Deposition of Father McGreevy',
#  'Vernon God Little',
#  'The Sisters Brothers',
#  'Silence Among the Weapons',
#  "Jake's Thing",
#  'The Death of Vishnu',
#  'The Harmony Silk Factory',
#  'The Book and the Brotherhood',
#  'Lincoln in the Bardo',
#  'The Public Image',
#  'Earthly Powers',
#  'Amongst Women',
#  "Gabriel's Lament",
#  'The Seven Moons of Maali Almeida',
#  'Fire From Heaven',
#  'The Riders',
#  'The Secret Scripture',
#  'From A to X',
#  'The Spinning Heart',
#  'Shalimar the Clown',
#  'Black Dogs',
#  'Child 44',
#  "The Moor's Last Sigh",
#  'Serious Sweet',
#  'Klara and the Sun',
#  'The Old Devils',
#  "Jamrach's Menagerie",
#  'A Guilty Thing Surprised',
#  'What Was Lost',
#  'The Long Song',
#  'Daughters of the House',
#  'Redhead by the Side of the Road',
#  'The Children of Dynmouth',
#  'The Unlikely Pilgrimage of Harold Fry',
#  'Life of Pi',
#  'A Passage North',
#  'True History of the Kelly Gang',
#  'Parrot and Olivier in America',
#  "Peter Smart's Confessions",
#  'The Mars Room',
#  'Bewilderment',
#  "I'll Go to Bed at Noon",
#  'Hotel World',
#  'The Comfort of Strangers',
#  'A Disaffection',
#  'The Sense of an Ending',
#  'Washington Black',
#  'Master and Commander',
#  'Sea of Poppies',
#  'The Lost Dog',
#  'A Five-Year Sentence',
#  'This Mournable Body',
#  'A Little Of What You Fancy?',
#  'A Place in England',
#  'Exit West',
#  'The English Patient',
#  'On Beauty',
#  'Sleeping on Jupiter',
#  'The Restraint of Beasts',
#  'The Little Stranger',
#  "Schindler's Ark",
#  'The Gate of Angels',
#  'The Sirian Experiments',
#  'Did You Ever Have a Family',
#  'The Blue Tango',
#  'How to Be Both',
#  'The Thousand Autumns of Jacob de Zoet',
#  'The Remains of the Day',
#  'In a Strange Room',
#  'The House of Doors',
#  'Work Like Any Other',
#  'The Element of Water',
#  'If I Survive You',
#  "Animal's People",
#  'Astonishing Splashes of Colour',
#  'Great Granny Webster',
#  'Swimming Home',
#  'All That Man Is',
#  'A Spool of Blue Thread',
#  'Moon Tiger',
#  'The Blind Assassin',
#  'His Bloody Project',
#  'Wolfy and the Strudelbakers',
#  'Solomon Gursky Was Here',
#  'Something Might Happen',
#  'The Bay of Noon',
#  'Serenity House',
#  'The Industry of Souls',
#  'Mister Pip',
#  'Heat and Dust',
#  'Knowledge of Angels',
#  'The Curious Incident of the Dog in the Night-Time',
#  "Bruno's Dream",
#  'My Sister, the Serial Killer',
#  'The Pickup',
#  'From Scenes Like These',
#  'The Enchantress of Florence',
#  'Maps for Lost Lovers',
#  'The Sweetness of Water',
#  'The Battle of Pollocks Crossing',
#  'From a Low and Quiet Sea',
#  'We Need New Names',
#  'Skios',
#  'The Elected Member',
#  'Solar Bones',
#  'God on the Rocks',
#  'Carry Me Down',
#  'Goshawk Squadron',
#  'The Luminaries',
#  'The Bookshop',
#  'The Glass Room',
#  'According to Mark',
#  'The Ministry of Utmost Happiness',
#  "What's Bred in the Bone",
#  'Ducks, Newburyport',
#  'Alias Grace',
#  'England, England',
#  'A Case of Exploding Mangoes',
#  'Shuggie Bain',
#  'Out of the Shelter',
#  'Western Lane',
#  'The Garden of Evening Mists',
#  'Love and Other Thought Experiments',
#  "Midnight's Children",
#  'The Siege of Krishnapur',
#  'In the Country of Men',
#  'Paddy Clarke Ha Ha Ha',
#  'The Conjunction',
#  'The Essence of the Thing',
#  'The Chant of Jimmie Blacksmith',
#  'Any Human Heart',
#  'Theft: A Love Story',
#  'The Story of Lucy Gault',
#  'Study for Obedience',
#  'The Other Side of the Bridge',
#  "St. Urbain's Horseman",
#  'The Orchard on Fire',
#  'Wolf Hall',
#  'The Map of Love',
#  'Black Swan Green',
#  'An Orchestra of Minorities',
#  "The Handmaid's Tale",
#  'When We Were Orphans',
#  'Lies of Silence',
#  'Down All the Days',
#  'The Inheritance of Loss',
#  'Oscar and Lucinda',
#  'Small Things Like These']

# %%
bl.booker_eligible_pages.sort()

# %%
bl.booker_eligible_pages
# Out:
# ['10 Minutes 38 Seconds in This Strange World',
#  'A Bend in the River',
#  'A Brief History of Seven Killings',
#  'A Case of Exploding Mangoes',
#  'A Clubbable Woman',
#  'A Disaffection',
#  'A Fairly Honourable Defeat',
#  'A Fine Balance',
#  'A Five-Year Sentence',
#  'A Fraction of the Whole',
#  'A Green Equinox',
#  'A Guilty Thing Surprised',
#  'A Little Life',
#  'A Little Of What You Fancy?',
#  'A Long Long Way',
#  'A Passage North',
#  'A Place in England',
#  'A Short History of Tractors in Ukrainian',
#  'A Spell of Good Things',
#  'A Spool of Blue Thread',
#  'A Tale for the Time Being',
#  'According to Mark',
#  'According to Queeney',
#  'Alias Grace',
#  'All That Man Is',
#  'Amongst Women',
#  'An Artist of the Floating World',
#  'An Ice-Cream War',
#  'An Instant in the Wind',
#  'An Insular Possession',
#  'An Orchestra of Minorities',
#  "Animal's People",
#  'Anthills of the Savannah',
#  'Any Human Heart',
#  'Arthur & George',
#  'Astonishing Splashes of Colour',
#  'Beside the Ocean of Time',
#  'Bewilderment',
#  'Beyond Black',
#  'Bitter Fruit',
#  'Black Dogs',
#  'Black Swan Green',
#  'Breakfast on Pluto',
#  'Briefing for a Descent into Hell',
#  'Bring Up the Bodies',
#  "Bruno's Dream",
#  'Carry Me Down',
#  'Child 44',
#  'Clear Light of Day',
#  'Crossing the River',
#  'Darkmans',
#  'Daughters of the House',
#  'Did You Ever Have a Family',
#  'Dirt Music',
#  'Disgrace',
#  'Do Not Say We Have Nothing',
#  'Dorian, an Imitation',
#  'Down All the Days',
#  'Ducks, Newburyport',
#  'Earthly Powers',
#  'Elizabeth Costello',
#  'Ending Up',
#  'England, England',
#  'English Passengers',
#  'Exit West',
#  'Fasting, Feasting',
#  'Figures in a Landscape',
#  'Fire From Heaven',
#  'Five Star Billionaire',
#  "Flaubert's Parrot",
#  'Flying to Nowhere',
#  'Frankissstein',
#  'From A to X',
#  'From Scenes Like These',
#  'From a Low and Quiet Sea',
#  "Gabriel's Lament",
#  'Girl, Woman, Other',
#  'God on the Rocks',
#  'Goshawk Squadron',
#  'Gossip from the Forest',
#  'Grace Notes',
#  'Great Granny Webster',
#  'Half-Blood Blues',
#  'Heat and Dust',
#  'His Bloody Project',
#  'History of Wolves',
#  'Hotel World',
#  'Hotel du Lac',
#  'How Much of These Hills Is Gold',
#  'How late it was, how late',
#  'How to Be Both',
#  'Hystopia',
#  "I'll Go to Bed at Noon",
#  "I'm the King of the Castle",
#  'If I Survive You',
#  'If Nobody Speaks of Remarkable Things',
#  'Illywhacker',
#  'In Ascension',
#  'In Every Face I Meet',
#  'In Their Wisdom',
#  'In a Free State',
#  'In a Strange Room',
#  'In the Country of Men',
#  "Jake's Thing",
#  "Jamrach's Menagerie",
#  'Jonathan Strange & Mr Norrell',
#  'King Fisher Lives',
#  'Klara and the Sun',
#  'Knowledge of Angels',
#  'Last Letters from Hav',
#  'Last Orders',
#  'Lies of Silence',
#  'Life & Times of Michael K',
#  'Life of Pi',
#  'Lincoln in the Bardo',
#  'Loitering with Intent',
#  'Lost Children Archive',
#  'Love and Other Thought Experiments',
#  'Love and Summer',
#  'Maps for Lost Lovers',
#  'Master Georgie',
#  'Master and Commander',
#  "Midnight's Children",
#  'Mister Pip',
#  'Moon Tiger',
#  "Mrs Eckdorf in O'Neill's Hotel",
#  'My Name Is Lucy Barton',
#  'My Sister, the Serial Killer',
#  'Nice Work',
#  'Night Boat to Tangier',
#  'Nightcrawling',
#  'No One Is Talking About This',
#  'Normal People',
#  'Notes on a Scandal',
#  'Oh William!',
#  'On Beauty',
#  'On Chesil Beach',
#  'Oryx and Crake',
#  'Oscar and Lucinda',
#  'Out of the Shelter',
#  'Paddy Clarke Ha Ha Ha',
#  'Parrot and Olivier in America',
#  "Peter Smart's Confessions",
#  'Pigeon English',
#  'Possession: A Romance',
#  'Prophet Song',
#  'Purple Hibiscus',
#  'Quartet in Autumn',
#  'Rates of Exchange',
#  'Reading in the Dark',
#  'Redhead by the Side of the Road',
#  'Remembering Babylon',
#  'Reservoir 13',
#  'Rhine Journey',
#  'Rumours of Rain',
#  'Sacred Hunger',
#  'Satin Island',
#  "Schindler's Ark",
#  'Sea of Poppies',
#  'Serenity House',
#  'Serious Sweet',
#  'Shadows on our Skin',
#  'Shalimar the Clown',
#  'Shuggie Bain',
#  'Silence Among the Weapons',
#  'Sixty Lights',
#  'Skios',
#  'Skippy Dies',
#  'Sleeping on Jupiter',
#  'Slow Man',
#  'Small Things Like These',
#  'So Many Ways to Begin',
#  'Solar Bones',
#  'Solomon Gursky Was Here',
#  'Something Might Happen',
#  'Something to Answer For',
#  'Sour Sweet',
#  "St. Urbain's Horseman",
#  'Staying On',
#  'Study for Obedience',
#  'Such a Fun Age',
#  'Swimming Home',
#  'The 27th Kingdom',
#  'The Accidental',
#  'The Amber Spyglass',
#  'The Autograph Man',
#  'The Battle of Pollocks Crossing',
#  'The Bay of Noon',
#  'The Bee Sting',
#  'The Beginning of Spring',
#  'The Big Chapel',
#  'The Bird of Night',
#  'The Birds on the Trees',
#  'The Blackwater Lightship',
#  'The Blind Assassin',
#  'The Blue Tango',
#  'The Bone Clocks',
#  'The Bone People',
#  'The Book and the Brotherhood',
#  'The Book of Evidence',
#  'The Bookshop',
#  'The Bottle Factory Outing',
#  'The Chant of Jimmie Blacksmith',
#  'The Children of Dynmouth',
#  "The Children's Book",
#  'The Clothes on Their Backs',
#  'The Colour of Blood',
#  'The Comfort of Strangers',
#  'The Conjunction',
#  'The Conservationist',
#  'The Curious Incident of the Dog in the Night-Time',
#  'The Death of Vishnu',
#  'The Deposition of Father McGreevy',
#  'The Elected Member',
#  'The Electric Michelangelo',
#  'The Element of Water',
#  'The Enchantress of Florence',
#  'The English Patient',
#  'The Essence of the Thing',
#  'The Famished Road',
#  'The Finkler Question',
#  'The Folding Star',
#  'The Fortune Men',
#  'The Garden of Evening Mists',
#  'The Gate of Angels',
#  'The Ghost Road',
#  'The Gift of Rain',
#  'The Glass Room',
#  'The God of Small Things',
#  'The Good Apprentice',
#  'The Good Terrorist',
#  'The Hand Reared Boy',
#  "The Handmaid's Tale",
#  'The Harmony Silk Factory',
#  'The House of Doors',
#  'The Industry of Souls',
#  'The Inheritance of Loss',
#  'The Keepers of Truth',
#  'The Line of Beauty',
#  'The Little Stranger',
#  'The Long Song',
#  'The Long Take',
#  'The Lost Dog',
#  'The Lowland',
#  'The Luminaries',
#  'The Map of Love',
#  'The Mars Room',
#  'The Ministry of Utmost Happiness',
#  "The Moor's Last Sigh",
#  'The Mulberry Empire',
#  'The Nice and the Good',
#  'The Northern Clemency',
#  'The Old Devils',
#  'The Orchard on Fire',
#  'The Other Side of the Bridge',
#  'The Overstory',
#  'The Pickup',
#  'The Public Image',
#  'The Quickening Maze',
#  'The Redundancy of Courage',
#  'The Reluctant Fundamentalist',
#  'The Remains of the Day',
#  'The Restraint of Beasts',
#  'The Riders',
#  'The Road to Lichfield',
#  'The Schooldays of Jesus',
#  'The Sea, the Sea',
#  'The Secret River',
#  'The Secret Scripture',
#  'The Sense of an Ending',
#  'The Seven Moons of Maali Almeida',
#  'The Siege of Krishnapur',
#  'The Sirian Experiments',
#  'The Sisters Brothers',
#  'The Spinning Heart',
#  'The Stars in the Bright Sky',
#  'The Stone Carvers',
#  'The Stone Diaries',
#  'The Story of Lucy Gault',
#  'The Sweetness of Water',
#  'The Testament of Gideon Mack',
#  'The Testament of Mary',
#  'The Testaments',
#  'The Thousand Autumns of Jacob de Zoet',
#  'The Unlikely Pilgrimage of Harold Fry',
#  'The Vivisector',
#  'The White Hotel',
#  'The Year of the Runaways',
#  'Theft: A Love Story',
#  'This Mournable Body',
#  'This Thing of Darkness',
#  'To Rise Again at a Decent Hour',
#  'Translated Accounts',
#  'Treacle Walker',
#  'True History of the Kelly Gang',
#  'Under the Frog',
#  'Unless',
#  'Vernon God Little',
#  'Warlight',
#  'Washington Black',
#  'We Are All Completely Beside Ourselves',
#  'We Need New Names',
#  'Western Lane',
#  'What Was Lost',
#  "What's Bred in the Bone",
#  'When We Were Orphans',
#  'Who They Was',
#  'Wolf Hall',
#  'Wolfy and the Strudelbakers',
#  'Work Like Any Other']

# %%
bl.get_booker_table()

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_winners_and_nominated_authors_of_the_Booker_Prize"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')
bookertable=soup.find('table',{'class':"wikitable"})

# %%
df=pd.read_html(str(bookertable))
# convert list to dataframe
df=pd.DataFrame(df[0])
# Out:
# /var/folders/0v/k0bzhvd900gd2q39m4qbtlkw0000gn/T/ipykernel_8105/1108399091.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_html(str(bookertable))

# %%
df.Title.dropna().tolist()
# Out:
# ['Something to Answer For',
#  'Figures in a Landscape',
#  'Impossible Object',
#  'The Nice and the Good',
#  'The Public Image',
#  'From Scenes Like These',
#  'The Elected Member',
#  "John Brown's Body",
#  'Eva Trout',
#  "Bruno's Dream",
#  "Mrs Eckdorf in O'Neill's Hotel",
#  'The Conjunction',
#  'Troubles',
#  'The Birds on the Trees',
#  'The Bay of Noon',
#  'Fire From Heaven',
#  "The Driver's Seat",
#  'The Vivisector',
#  'The Hand Reared Boy',
#  'A Little Of What You Fancy?',
#  'A Place in England',
#  'Down All the Days',
#  'Bomber',
#  'The Circle',
#  'A Clubbable Woman',
#  "I'm the King of the Castle",
#  'A Domestic Animal',
#  'The Fire Dwellers',
#  'Out of the Shelter',
#  'A Fairly Honourable Defeat',
#  'Fireflies',
#  'Master and Commander',
#  'Head To Toe',
#  'A Guilty Thing Surprised',
#  'In a Free State',
#  'The Big Chapel',
#  'Briefing for a Descent into Hell',
#  "St. Urbain's Horseman",
#  'Goshawk Squadron',
#  'Mrs. Palfrey at the Claremont',
#  'G.',
#  'The Bird of Night',
#  'The Chant of Jimmie Blacksmith',
#  'Pasmore',
#  'The Siege of Krishnapur',
#  'The Dressmaker',
#  'A Green Equinox',
#  'The Black Prince',
#  'The Conservationist',
#  'Holiday',
#  'Ending Up',
#  'The Bottle Factory Outing',
#  'In Their Wisdom',
#  'Heat and Dust',
#  'Gossip from the Forest',
#  'Saville',
#  'An Instant in the Wind',
#  'Rising',
#  "The Doctor's Wife",
#  'King Fisher Lives',
#  'The Children of Dynmouth',
#  'Staying On',
#  "Peter Smart's Confessions",
#  'Great Granny Webster',
#  'Shadows on our Skin',
#  'The Road to Lichfield',
#  'Quartet in Autumn',
#  'The Sea, the Sea',
#  "Jake's Thing",
#  'Rumours of Rain',
#  'The Bookshop',
#  'God on the Rocks',
#  'A Five-Year Sentence',
#  'Offshore',
#  'Confederates',
#  'A Bend in the River',
#  'Joseph',
#  'Praxis',
#  'Rites of Passage',
#  'Earthly Powers',
#  'A Month in the Country',
#  'Clear Light of Day',
#  'The Beggar Maid',
#  'No Country for Young Men',
#  "Pascali's Island",
#  "Midnight's Children",
#  'Good Behaviour',
#  'The Sirian Experiments',
#  'The Comfort of Strangers',
#  'Rhine Journey',
#  'Loitering with Intent',
#  'The White Hotel',
#  "Schindler's Ark",
#  'Silence Among the Weapons',
#  'An Ice-Cream War',
#  'Constance or Solitary Practices',
#  'The 27th Kingdom',
#  'Sour Sweet',
#  'Life & Times of Michael K',
#  'Rates of Exchange',
#  'Flying to Nowhere',
#  'The Illusionist',
#  'Shame',
#  'Waterland',
#  'Hotel du Lac',
#  'Empire of the Sun',
#  "Flaubert's Parrot",
#  'In Custody',
#  'According to Mark',
#  'Small World',
#  'The Bone People',
#  'Illywhacker',
#  'The Battle of Pollocks Crossing',
#  'The Good Terrorist',
#  'Last Letters from Hav',
#  'The Good Apprentice',
#  'The Old Devils',
#  "The Handmaid's Tale",
#  "Gabriel's Lament",
#  "What's Bred in the Bone",
#  'An Artist of the Floating World',
#  'An Insular Possession',
#  'Moon Tiger',
#  'Anthills of the Savannah',
#  'Chatterton',
#  'Circles of Deceit',
#  'The Colour of Blood',
#  'The Book and the Brotherhood',
#  'Oscar and Lucinda',
#  'Utz',
#  'The Beginning of Spring',
#  'Nice Work',
#  'The Satanic Verses',
#  'The Lost Father',
#  'The Remains of the Day',
#  "Cat's Eye",
#  'The Book of Evidence',
#  'Jigsaw',
#  'A Disaffection',
#  'Restoration',
#  'Possession: A Romance',
#  'An Awfully Big Adventure',
#  'The Gate of Angels',
#  'Amongst Women',
#  'Lies of Silence',
#  'Solomon Gursky Was Here',
#  'The Famished Road',
#  "Time's Arrow",
#  'The Van',
#  'Such a Long Journey',
#  'The Redundancy of Courage',
#  'Reading Turgenev[5]',
#  'The English Patient',
#  'Sacred Hunger',
#  'Serenity House',
#  'The Butcher Boy',
#  'Black Dogs',
#  'Daughters of the House',
#  'Paddy Clarke Ha Ha Ha',
#  'Under the Frog',
#  'Scar Tissue',
#  'Remembering Babylon',
#  'Crossing the River',
#  'The Stone Diaries',
#  'How late it was, how late',
#  'Reef',
#  'Paradise',
#  'The Folding Star',
#  'Beside the Ocean of Time',
#  'Knowledge of Angels',
#  'The Ghost Road',
#  'In Every Face I Meet',
#  "The Moor's Last Sigh",
#  'Morality Play',
#  'The Riders',
#  'Last Orders',
#  'Alias Grace',
#  'Every Man for Himself',
#  'Reading in the Dark',
#  'The Orchard on Fire',
#  'A Fine Balance',
#  'The God of Small Things',
#  'Quarantine',
#  'The Underground Man',
#  'Grace Notes',
#  'Europa',
#  'The Essence of the Thing',
#  'Amsterdam',
#  'Master Georgie',
#  'England, England',
#  'The Industry of Souls',
#  'Breakfast on Pluto',
#  'The Restraint of Beasts',
#  'Disgrace',
#  'Fasting, Feasting',
#  'Headlong',
#  'Our Fathers',
#  'The Map of Love',
#  'The Blackwater Lightship',
#  'The Blind Assassin',
#  'The Hiding Place',
#  'The Keepers of Truth',
#  'When We Were Orphans',
#  'English Passengers',
#  'The Deposition of Father McGreevy',
#  'True History of the Kelly Gang',
#  'Atonement',
#  'Oxygen',
#  'number9dream',
#  'The Dark Room',
#  'Hotel World',
#  'According to Queeney',
#  'If The Invader Comes',
#  'A Son of War',
#  'Shamrock Tea',
#  'The Element of Water',
#  'The Pickup',
#  'Dogside Story',
#  'By The Sea',
#  'How To Be Good',
#  'Wolfy and the Strudelbakers',
#  'Translated Accounts',
#  'The Blue Tango',
#  'Fairness',
#  'Half a Life',
#  'The Amber Spyglass',
#  'The Death of Vishnu',
#  'The Stone Carvers',
#  'The Leto Bundle',
#  'Life of Pi',
#  'Family Matters',
#  'Unless',
#  'The Story of Lucy Gault',
#  'Fingersmith',
#  'Dirt Music',
#  'The Strange Case of Dr Simmonds and Dr Glass',
#  'Shroud',
#  'Critical Injuries',
#  'Any Human Heart',
#  'The Next Big Thing',
#  'Peacetime',
#  'Spies',
#  'Still Here',
#  'The Mulberry Empire',
#  'Who’s Sorry Now?',
#  'If Nobody Speaks of Remarkable Things',
#  'Dorian, an Imitation',
#  'The Autograph Man',
#  'To The Last City',
#  'Vernon God Little',
#  'Brick Lane',
#  'Oryx and Crake',
#  'The Good Doctor',
#  'Notes on a Scandal',
#  'Astonishing Splashes of Colour',
#  'Yellow Dog',
#  'Turn Again Home',
#  'Crossing the Lines',
#  'Elizabeth Costello',
#  'The Taxi Driver’s Daughter',
#  'Schopenhauer’s Telescope',
#  'The Romantic',
#  'The Curious Incident of the Dog in the Night-Time',
#  'The Nick of Time',
#  'Heligoland',
#  'Jazz etc.',
#  'Something Might Happen',
#  'Judge Savage',
#  'A Distant Shore',
#  'Waxwings',
#  'The Light of Day',
#  'Frankie & Stankie',
#  'The Line of Beauty',
#  'Bitter Fruit',
#  'The Electric Michelangelo',
#  'Cloud Atlas',
#  'The Master',
#  "I'll Go to Bed at Noon",
#  'Purple Hibiscus',
#  'Maps for Lost Lovers',
#  'Clear: A Transparent Novel',
#  'The Island Walkers',
#  'Havoc, in its Third Year',
#  'Jonathan Strange & Mr Norrell',
#  'Always the Sun',
#  'Becoming Strangers',
#  'A Blade of Grass',
#  'Cooking with Fernet Branca',
#  'The Honeymoon',
#  'The Great Fire',
#  'Sixty Lights',
#  'The Unnumbered',
#  'Snowleg',
#  'Cherry',
#  'The Sea',
#  'Arthur & George',
#  'A Long Long Way',
#  'Never Let Me Go',
#  'The Accidental',
#  'On Beauty',
#  'The Harmony Silk Factory',
#  'Slow Man',
#  'In the Fold',
#  'All For Love',
#  'A Short History of Tractors in Ukrainian',
#  'Beyond Black',
#  'Saturday',
#  'The People’s Act of Love',
#  'Shalimar the Clown',
#  'This Thing of Darkness',
#  'This Is The Country',
#  'The Inheritance of Loss',
#  'The Secret River',
#  'Carry Me Down',
#  'In the Country of Men',
#  "Mother's Milk",
#  'The Night Watch',
#  'Theft: A Love Story',
#  'Gathering the Water',
#  'Get A Life',
#  'Kalooki Nights',
#  'Seven Lies',
#  'The Other Side of the Bridge',
#  'So Many Ways to Begin',
#  'The Emperor’s Children',
#  'Black Swan Green',
#  'The Perfect Man',
#  'Be Near Me',
#  'The Testament of Gideon Mack',
#  'The Ruby In Her Navel',
#  'The Gathering',
#  'Darkmans',
#  'The Reluctant Fundamentalist',
#  'Mister Pip',
#  'On Chesil Beach',
#  "Animal's People",
#  'Self Help',
#  'The Welsh Girl',
#  'Gifted',
#  'What Was Lost',
#  'Consolation',
#  'The Gift of Rain',
#  'Winnie & Wolf',
#  'The White Tiger',
#  'The Secret Scripture',
#  'Sea of Poppies',
#  'The Clothes on Their Backs',
#  'The Northern Clemency',
#  'A Fraction of the Whole',
#  'Girl in a Blue Dress',
#  'From A to X',
#  'The Lost Dog',
#  'A Case of Exploding Mangoes',
#  'Netherland',
#  'The Enchantress of Florence',
#  'Child 44',
#  'Wolf Hall',
#  "The Children's Book",
#  'Summertime',
#  'The Quickening Maze',
#  'The Glass Room',
#  'The Little Stranger',
#  'How to Paint a Dead Man',
#  'The Wilderness',
#  'Me Cheeta',
#  'Not Untrue & Not Unkind',
#  'Heliopolis',
#  'Brooklyn',
#  'Love and Summer',
#  'The Finkler Question',
#  'Parrot and Olivier in America',
#  'Room',
#  'In a Strange Room',
#  'The Long Song',
#  'C',
#  'The Betrayal',
#  'The Thousand Autumns of Jacob de Zoet',
#  'February',
#  'Skippy Dies',
#  'Trespass',
#  'The Slap',
#  'The Stars in the Bright Sky',
#  'The Sense of an Ending',
#  "Jamrach's Menagerie",
#  'The Sisters Brothers',
#  'Half-Blood Blues',
#  'Pigeon English',
#  'Snowdrops',
#  'On Canaan’s Side',
#  'A Cupboard Full of Coats',
#  'The Stranger’s Child',
#  'The Last Hundred Days',
#  'Far to Go',
#  'The Testament of Jessie Lamb',
#  'Derby Day',
#  'Bring Up the Bodies',
#  'Swimming Home',
#  'The Lighthouse',
#  'Umbrella',
#  'The Garden of Evening Mists',
#  'Narcopolis',
#  'The Yips',
#  'The Teleportation Accident',
#  'Philida',
#  'Skios',
#  'The Unlikely Pilgrimage of Harold Fry',
#  'Communion Town',
#  'The Luminaries',
#  'We Need New Names',
#  'Harvest',
#  'The Lowland',
#  'A Tale for the Time Being',
#  'The Testament of Mary',
#  'Five Star Billionaire',
#  'The Marrying of Chani Kaufman',
#  'The Kills',
#  'Unexploded',
#  'TransAtlantic',
#  'Almost English',
#  'The Spinning Heart',
#  'The Narrow Road to the Deep North',
#  'To Rise Again at a Decent Hour',
#  'We Are All Completely Beside Ourselves',
#  'J',
#  'The Lives of Others',
#  'How to Be Both',
#  'The Blazing World',
#  'The Wake',
#  'The Bone Clocks',
#  'Us',
#  'The Dog',
#  'Orfeo',
#  'History of the Rain',
#  'A Brief History of Seven Killings',
#  'Satin Island',
#  'The Fishermen',
#  'The Year of the Runaways',
#  'A Spool of Blue Thread',
#  'A Little Life',
#  'Did You Ever Have a Family',
#  'The Green Road',
#  'The Moor’s Account',
#  'The Illuminations',
#  'Lila',
#  'Sleeping on Jupiter',
#  'The Chimes',
#  'The Sellout',
#  'Hot Milk',
#  'His Bloody Project',
#  'Eileen',
#  'All That Man Is',
#  'Do Not Say We Have Nothing',
#  'The Schooldays of Jesus',
#  'Serious Sweet',
#  'The North Water',
#  'Hystopia',
#  'The Many',
#  'Work Like Any Other',
#  'My Name Is Lucy Barton',
#  'Lincoln in the Bardo',
#  '4 3 2 1',
#  'History of Wolves',
#  'Exit West',
#  'Elmet',
#  'Autumn',
#  'Days Without End',
#  'Solar Bones',
#  'Reservoir 13',
#  'The Ministry of Utmost Happiness',
#  'Home Fire',
#  'Swing Time',
#  'The Underground Railroad',
#  'Milkman',
#  'Washington Black',
#  'Everything Under',
#  'The Mars Room',
#  'The Overstory',
#  'The Long Take',
#  'Snap',
#  'Sabrina',
#  'In Our Mad And Furious City',
#  'The Water Cure',
#  'Warlight',
#  'Normal People',
#  'From a Low and Quiet Sea',
#  'The Testaments',
#  'Girl, Woman, Other',
#  'Ducks, Newburyport',
#  'An Orchestra of Minorities',
#  'Quichotte',
#  '10 Minutes 38 Seconds in This Strange World',
#  'Night Boat to Tangier',
#  'My Sister, the Serial Killer',
#  'The Wall',
#  'The Man Who Saw Everything',
#  'Lost Children Archive',
#  'Lanny',
#  'Frankissstein',
#  'Shuggie Bain',
#  'The New Wilderness',
#  'This Mournable Body',
#  'Burnt Sugar',
#  'The Shadow King',
#  'Real Life',
#  'Who They Was',
#  'The Mirror and the Light[30]',
#  'Apeirogon',
#  'Such a Fun Age',
#  'Redhead by the Side of the Road',
#  'Love and Other Thought Experiments',
#  'How Much of These Hills Is Gold',
#  'The Promise',
#  'A Passage North',
#  'No One Is Talking About This',
#  'The Fortune Men',
#  'Bewilderment',
#  'Great Circle',
#  'Second Place',
#  'The Sweetness of Water',
#  'Klara and the Sun',
#  'An Island',
#  'A Town Called Solace',
#  'China Room',
#  'Light Perpetual',
#  'The Seven Moons of Maali Almeida',
#  'Glory',
#  'The Trees',
#  'Treacle Walker',
#  'Small Things Like These',
#  'Oh William!',
#  'Case Study',
#  'Trust',
#  'Booth',
#  'The Colony',
#  'Maps of our Spectacular Bodies',
#  'Nightcrawling',
#  'After Sappho',
#  'Prophet Song',
#  'Study for Obedience',
#  'If I Survive You',
#  'This Other Eden',
#  'The Bee Sting',
#  'Western Lane',
#  'A Spell of Good Things',
#  "Old God's Time",
#  'How to Build a Boat',
#  'Pearl',
#  'All the Little Bird-Hearts',
#  'In Ascension',
#  'The House of Doors']

# %%
booker = wiki_wiki.page('List_of_winners_and_nominated_authors_of_the_Booker_Prize')

# %%
list(booker.links.keys())
# Out:
# ['10 Minutes 38 Seconds in This Strange World',
#  '2006 Man Booker Prize',
#  '2007 Man Booker Prize',
#  '2008 Man Booker Prize',
#  '2009 Man Booker Prize',
#  '2010 Man Booker Prize',
#  '2011 Man Booker Prize',
#  '2012 Man Booker Prize',
#  '2013 Man Booker Prize',
#  '2014 Man Booker Prize',
#  '2015 Man Booker Prize',
#  '2016 Man Booker Prize',
#  '2017 Man Booker Prize',
#  '2018 Man Booker Prize',
#  '2019 Booker Prize',
#  '2020 Booker Prize',
#  '2021 Booker Prize',
#  '2022 Booker Prize',
#  '2023 Booker Prize',
#  '4 3 2 1 (novel)',
#  '4th Estate',
#  '4th Estate (imprint)',
#  'A. C. Grayling',
#  'A. L. Barker',
#  'A. L. Kennedy',
#  'A. N. Wilson',
#  'A. S. Byatt',
#  'A. Walton Litz',
#  'A Bend in the River',
#  'A Brief History of Seven Killings',
#  'A Case of Exploding Mangoes',
#  'A Clubbable Woman',
#  'A Disaffection',
#  'A Distant Shore (novel)',
#  'A Fairly Honourable Defeat',
#  'A Fine Balance',
#  'A Five-Year Sentence',
#  'A Fraction of the Whole',
#  'A Green Equinox',
#  'A Guilty Thing Surprised',
#  'A Little Life',
#  'A Little Of What You Fancy?',
#  'A Long Long Way',
#  'A Month in the Country (novel)',
#  'A Passage North',
#  'A Place in England',
#  'A Short History of Tractors in Ukrainian',
#  'A Spell of Good Things',
#  'A Spool of Blue Thread',
#  'A Tale for the Time Being',
#  'Abdulrazak Gurnah',
#  'According to Mark',
#  'According to Queeney',
#  'Achmat Dangor',
#  'Adam Foulds',
#  'Adam Mars-Jones',
#  'Adjoa Andoh',
#  'Afua Hirsch',
#  'Ahdaf Soueif',
#  'Alain Mabanckou',
#  'Alan Garner',
#  'Alan Hollinghurst',
#  'Alan Warner',
#  'Alastair Niven',
#  'Alex Clark (journalist)',
#  'Ali Smith',
#  'Alias Grace',
#  'Alice Munro',
#  'Alice Thomas Ellis',
#  'Alison MacLeod',
#  'Alison Moore (writer)',
#  'Alison Pick',
#  'All That Man Is',
#  'Allan Massie',
#  'Allen & Unwin',
#  'Amanda Foreman (biographer)',
#  'Amanda Foreman (historian)',
#  'Amitav Ghosh',
#  'Amongst Women',
#  'Amsterdam (novel)',
#  'An Artist of the Floating World',
#  'An Awfully Big Adventure (novel)',
#  'An Ice-Cream War',
#  'An Instant in the Wind',
#  'An Insular Possession',
#  'An Orchestra of Minorities',
#  'Andre Brink',
#  'Andrea Levy',
#  'Andrew Miller (novelist)',
#  'Andrew Miller (writer)',
#  'Andrew Motion',
#  "Andrew O'Hagan",
#  'André Brink',
#  'André Deutsch',
#  'Angela Carter',
#  'Angela Huth',
#  'Angus & Robertson',
#  'Angus Wilson',
#  "Animal's People",
#  'Anita Brookner',
#  'Anita Desai',
#  'Anita Mason',
#  'Ann Schlee',
#  'Anna Burns',
#  'Anna Smaill',
#  'Anne Chisholm',
#  'Anne Enright',
#  'Anne Tyler',
#  'Anthills of the Savannah',
#  'Anthony Burgess',
#  'Anthony Curtis (journalist)',
#  'Anthony Thwaite',
#  'Antonia Fraser',
#  'Antony Quinn',
#  'Anuk Arudpragasam',
#  'Anuradha Roy (novelist)',
#  'Any Human Heart',
#  'Apeirogon (novel)',
#  'Aravind Adiga',
#  'Arthur & George',
#  'Arundhati Roy',
#  'Asa Briggs',
#  'Astonishing Splashes of Colour',
#  'Atlantic Books',
#  'Atonement (novel)',
#  'Audrey Magee',
#  'Autumn (Smith novel)',
#  'Avni Doshi',
#  'Ayobami Adebayo',
#  'BBC',
#  'BBC News',
#  'Bantam Press',
#  'Barbara Gowdy',
#  'Barbara Pym',
#  'Barbara Trapido',
#  'Barry England',
#  'Barry Unsworth',
#  'Belinda Bauer (author)',
#  'Ben Okri',
#  'Benny Green (saxophonist)',
#  'Bernard MacLaverty',
#  'Bernardine Evaristo',
#  'Bernice Rubens',
#  'Beryl Bainbridge',
#  'Beside the Ocean of Time',
#  'Bewilderment',
#  'Beyond Black',
#  'Bill Clegg',
#  'Bitter Fruit',
#  'Black Dogs',
#  'Black Swan (imprint)',
#  'Black Swan Green',
#  'Blake Morrison',
#  'Bloomsbury Publishing',
#  'Bodley Head',
#  'Bomber (novel)',
#  'Booker Prize',
#  'Booker Prize for Fiction',
#  'Booker of Bookers',
#  'Boyd Tonkin',
#  'Brandon Taylor (writer)',
#  'Breakfast on Pluto',
#  'Brendan Gill',
#  'Brian Aldiss',
#  'Brian Moore (novelist)',
#  "Brian O'Doherty",
#  'Brian Wenham',
#  'Brick Lane (book)',
#  'Briefing for a Descent into Hell',
#  'Bring Up the Bodies',
#  'Brooklyn (novel)',
#  'Bruce Chatwin',
#  "Bruno's Dream",
#  'By the Sea (novel)',
#  'C. P. Snow',
#  'C (novel)',
#  'C Pam Zhang',
#  'Candia McWilliam',
#  'Canongate Books',
#  'Carmen Callil',
#  'Carol Birch',
#  'Carol Shields',
#  'Caroline Blackwood',
#  'Caroline Gascoigne',
#  'Carry Me Down',
#  'Caryl Phillips',
#  "Cat's Eye (novel)",
#  "Catherine O'Flynn",
#  'Charlotte Mendelson',
#  'Chatterton (novel)',
#  'Chatto & Windus',
#  'Chetna Maroo',
#  'Chigozie Obioma',
#  'Child 44',
#  'Chimamanda Ngozi Adichie',
#  'Chinua Achebe',
#  'Chris Mullin (politician)',
#  'Chris Smith, Baron Smith of Finsbury',
#  'Christopher Hope (novelist)',
#  'Christos Tsiolkas',
#  'Christy Brown',
#  'Ciaran Carson',
#  'Circles of Deceit (novel)',
#  'Claire Keegan',
#  'Claire Messud',
#  'Claire Tomalin',
#  'Clare Boylan',
#  'Clare Morrall',
#  'Clear Light of Day',
#  'Cloud Atlas (novel)',
#  'Colin Thubron',
#  'Colm Toibin',
#  'Colm Tóibín',
#  'Colson Whitehead',
#  'Colum McCann',
#  'Commonwealth of Nations',
#  'Confederates (novel)',
#  'Constance (novel)',
#  'Corsair (imprint)',
#  'Crossing the River',
#  'Cyril Connolly',
#  'D. J. Taylor (writer)',
#  'D. M. Thomas',
#  'DBC Pierre',
#  'Daisy Johnson (writer)',
#  'Dame Rebecca West',
#  'Damon Galgut',
#  'Dan Jacobson',
#  'Dan Stevens',
#  'Daniel Glaser',
#  'Dannie Abse',
#  'Darkmans',
#  'Daughters of the House',
#  'David Baddiel',
#  'David Daiches',
#  'David Farrer',
#  'David Harsent',
#  'David Hughes (novelist)',
#  'David Lodge (author)',
#  'David Malouf',
#  'David Means',
#  'David Mitchell (author)',
#  'David Nicholls (writer)',
#  'David Profumo',
#  'David R. Holloway',
#  'David Sexton',
#  'David Storey',
#  'David Szalay',
#  'Days Without End (novel)',
#  'Deborah Bull',
#  'Deborah Levy',
#  'Denis Forman',
#  'Derek Beaven',
#  'Derek Robinson (novelist)',
#  'Derwent May',
#  'Diane Cook',
#  'Did You Ever Have a Family',
#  'Dinah Birch',
#  'Dirt Music',
#  'Disgrace',
#  'Disgrace (novel)',
#  'Do Not Say We Have Nothing',
#  'Donal Ryan',
#  'Dorian, an Imitation',
#  'Doris Lessing',
#  'Doubleday (publisher)',
#  'Douglas Hurd',
#  'Douglas Stuart (writer)',
#  'Down All the Days',
#  'Ducks, Newburyport',
#  'Duckworth Books',
#  'Earthly Powers',
#  "Ed O'Loughlin",
#  'Edinburgh International Book Festival',
#  'Edmund White',
#  'Edna Healey',
#  "Edna O'Brien",
#  'Edward Docx',
#  'Edward St Aubyn',
#  'Eileen (novel)',
#  'Elaine Feeney',
#  'Elaine Feinstein',
#  'Eleanor Catton',
#  'Elif Shafak',
#  'Elizabeth Bowen',
#  'Elizabeth Costello',
#  'Elizabeth Jane Howard',
#  'Elizabeth Mavor',
#  'Elizabeth Strout',
#  'Elizabeth Taylor (novelist)',
#  'Ellah Wakatama Allfrey',
#  'Elmet (Mozley novel)',
#  'Emily Fridlund',
#  'Emily Wilson (classicist)',
#  'Emma Donoghue',
#  'Empire of the Sun (novel)',
#  'Ending Up',
#  'England, England',
#  'English Passengers',
#  'Eoin McNamee',
#  'Erica Wagner',
#  'Esi Edugyan',
#  'Europa (novel)',
#  'Eva Trout (novel)',
#  'Every Man for Himself (novel)',
#  'Exit West',
#  'Eyre & Spottiswoode',
#  'Faber & Faber',
#  'Faber and Faber',
#  'Family Matters (novel)',
#  'Fasting, Feasting',
#  'Fay Weldon',
#  'Ferdinand Mount',
#  'Fiammetta Rocco',
#  'Figures in a Landscape',
#  'Fingersmith (novel)',
#  'Fiona Mozley',
#  'Fiona Shaw',
#  'Fire From Heaven',
#  'Fireflies (novel)',
#  'Five Star Billionaire',
#  'Flamingo (imprint)',
#  "Flaubert's Parrot",
#  'Fleet Publishing',
#  'Flying to Nowhere',
#  'Frances Osborne',
#  'Frances Wilson (writer)',
#  'Francine Stock',
#  'Francis King',
#  'Francis Spufford',
#  'Frank Delaney',
#  'Frank Kermode',
#  'Frankissstein',
#  'From A to X',
#  'From Scenes Like These',
#  'From a Low and Quiet Sea',
#  'G. (novel)',
#  "Gabriel's Lament",
#  'Gabriel Krauze',
#  'Gaby Wood',
#  'Gail Jones (writer)',
#  'Galley Beggar',
#  'Gaynor Arnold',
#  'George Mackay Brown',
#  'George Saunders',
#  'George Steiner',
#  'George Walden',
#  'Gerald Kaufman',
#  'Gerard Donovan',
#  'Gerard Woodward',
#  'Get a Life (novel)',
#  'Gifted (novel)',
#  'Giles Foden',
#  'Gillian Beer',
#  'Gillian Reynolds',
#  'Girl, Woman, Other',
#  'Girl in White Cotton',
#  'Glory (Bulawayo novel)',
#  'God on the Rocks',
#  'Good Behaviour (Keane novel)',
#  'Gordon Williams (writer)',
#  'Goshawk Squadron',
#  'Gossip from the Forest',
#  'Grace Notes',
#  'Graeme Macrae Burnet',
#  'Graham Swift',
#  'Granta',
#  'Granta Books',
#  'Great Circle (novel)',
#  'Great Granny Webster',
#  'Grey Gowrie',
#  'Guy Gunaratne',
#  'H. E. Bates',
#  'Hachette (publisher)',
#  'Half-Blood Blues',
#  'Half a Life (novel)',
#  'Hamish Hamilton',
#  'Hanya Yanagihara',
#  'Hardeep Singh Kohli',
#  'HarperCollins',
#  'Harriet Harvey Wood',
#  'Harry Thompson',
#  'Harvest (Jim Crace novel)',
#  'Harvill Secker',
#  'Headlong (Frayn novel)',
#  'Heat and Dust',
#  'Heinemann (publisher)',
#  'Helen Castor',
#  'Helen Dunmore',
#  'Helen McNeil',
#  'Heligoland (novel)',
#  'Heliopolis (Scudamore novel)',
#  'Hermione Lee',
#  'Hernan Diaz (writer)',
#  'Hilary Mantel',
#  'Hilary Spurling',
#  'His Bloody Project',
#  'Hisham Matar',
#  'History of Wolves',
#  'Hodder & Stoughton',
#  'Hodder and Stoughton',
#  'Hogarth Press',
#  'Holiday (novel)',
#  'Holland House Books',
#  'Home Fire (novel)',
#  'Hot Milk (novel)',
#  'Hotel World',
#  'Hotel du Lac',
#  'How Late It Was, How Late',
#  'How Much of These Hills Is Gold',
#  'How late it was, how late',
#  'How to Be Both',
#  'How to Be Good',
#  'Howard Davies (economist)',
#  'Howard Jacobson',
#  'Hutchinson (publisher)',
#  'Hystopia',
#  "I'll Go to Bed at Noon",
#  "I'm the King of the Castle",
#  'Ian Jack',
#  'Ian McEwan',
#  'Ian McGuire',
#  'If I Survive You',
#  'If Nobody Speaks of Remarkable Things',
#  'Illywhacker',
#  'Imogen Stubbs',
#  'Impossible Object (novel)',
#  'In Ascension',
#  'In Custody (novel)',
#  'In Every Face I Meet',
#  'In Their Wisdom',
#  'In a Free State',
#  'In a Strange Room',
#  'In the Country of Men',
#  'Indra Sinha',
#  'Influx Press',
#  'International Booker Prize',
#  'Ion Trewin',
#  'Iris Murdoch',
#  'Isabel Quigley',
#  'J. G. Ballard',
#  'J. G. Farrell',
#  'J. L. Carr',
#  'J. M. Coetzee',
#  'J. W. Lambert',
#  'J (novel)',
#  'Jacqueline Rose',
#  "Jake's Thing",
#  'James Hamilton-Paterson',
#  'James Heneage',
#  'James Kelman',
#  'James Lasdun',
#  'James Meek (author)',
#  'James Naughtie',
#  'James Robertson (novelist)',
#  'James S. Shapiro',
#  'James Scudamore (author)',
#  'James Wood (critic)',
#  "Jamrach's Menagerie",
#  'Jan Dalley',
#  'Jan Morris',
#  'Jane Gardam',
#  'Jane Rogers (novelist)',
#  'Jane Urquhart',
#  'Jason Cowley (journalist)',
#  'Jeanette Winterson',
#  'Jeet Thayil',
#  'Jennifer Johnston (novelist)',
#  'Jeremy Treglown',
#  'Jhumpa Lahiri',
#  'Jigsaw (novel)',
#  'Jill Paton Walsh',
#  'Jim Crace',
#  'Joan Bakewell',
#  'Joan Barfoot',
#  'Joanna Lumley',
#  'Joanna MacGregor',
#  'Joe Orton',
#  'John Arden',
#  'John B. Thompson (novelist)',
#  'John Banville',
#  'John Bayley (writer)',
#  'John Bemrose',
#  'John Berger',
#  "John Brown's Body (novel)",
#  'John Burnside (writer)',
#  'John Carey (critic)',
#  'John Fowles',
#  'John Fuller (poet)',
#  'John Gross',
#  'John Lanchester',
#  'John McGahern',
#  'John Mullan (academic)',
#  'John Murray (publishing house)',
#  'John Sutherland (author)',
#  'Jon McGregor',
#  'Jonathan Bate',
#  'Jonathan Cape',
#  'Jonathan Coe',
#  'Jonathan Escoffery',
#  'Jonathan Keates',
#  'Jonathan Raban',
#  'Jonathan Strange & Mr Norrell',
#  'Joseph (novel)',
#  "Joseph O'Neill (writer, born 1964)",
#  'Josephine Hart',
#  'Joshua Ferris',
#  'Julia Darling',
#  'Julia Neuberger',
#  "Julia O'Faolain",
#  'Julian Barnes',
#  'Julian Rathbone',
#  'Julie Myerson',
#  'Justin Cartwright',
#  'Justin Haythe',
#  'Kamila Shamsie',
#  'Karen Jennings (author)',
#  'Karen Joy Fowler',
#  'Karl Miller',
#  'Kate Grenville',
#  'Kate Kellaway',
#  'Kate Saunders',
#  'Kate Summerscale',
#  'Katie Derham',
#  'Kazuo Ishiguro',
#  'Kenneth Baker, Baron Baker of Dorking',
#  'Keri Hulme',
#  'Kevin Barry (author)',
#  'Kiley Reid',
#  'King Fisher Lives',
#  'Kingsley Amis',
#  'Kiran Desai',
#  'Kirkus Reviews',
#  'Klara and the Sun',
#  'Knowledge of Angels',
#  'Kwame Anthony Appiah',
#  'Lady Antonia Fraser',
#  'Laila Lalami',
#  'Last Letters from Hav',
#  'Last Orders',
#  'Lawrence Durrell',
#  'Leanne Shapton',
#  'Lee Child',
#  'Leila Mottley',
#  'Lemn Sissay',
#  'Len Deighton',
#  'Libby Purves',
#  'Lies of Silence',
#  'Life & Times of Michael K',
#  'Life of Pi',
#  'Lila (Robinson novel)',
#  'Lila Azam Zanganeh',
#  'Lincoln in the Bardo',
#  'Linda Grant',
#  'Linda Grant (novelist)',
#  'Lindsay Duguid',
#  'Lisa Jardine',
#  'Lisa Moore (writer)',
#  'Little, Brown',
#  'Liz Calder',
#  'Lloyd Jones (New Zealand author)',
#  'Loitering with Intent',
#  'Lola Young, Baroness Young of Hornsey',
#  'Longman',
#  'Lorna Sage',
#  'Lost Children Archive',
#  'Lost Man Booker Prize',
#  'Louise Dean (author)',
#  'Louise Doughty',
#  'Love and Other Thought Experiments',
#  'Love and Summer',
#  'Lucasta Miller',
#  'Lucy Ellmann',
#  'M. J. Hyland',
#  'M. John Harrison',
#  'Maaza Mengiste',
#  'Maclehose Press',
#  'Macmillan Publishers',
#  'Maddie Mortimer',
#  'Madeleine St John',
#  'Madeleine Thien',
#  'Maggie Gee (novelist)',
#  'Maggie Shipstead',
#  'Magnus Mills',
#  'Malcolm Bradbury',
#  'Man Booker Prize',
#  'Manil Suri',
#  'Maps for Lost Lovers',
#  'Margaret Atwood',
#  'Margaret Busby',
#  'Margaret Forster',
#  'Margaret Laurence',
#  'Mariella Frostrup',
#  'Marilynne Robinson',
#  'Marina Lewycka',
#  'Marina Warner',
#  'Mark Haddon',
#  'Mark Lawson',
#  'Marlon James (novelist)',
#  'Martha Kearney',
#  'Martin Amis',
#  'Martin Booth',
#  'Martin MacInnes',
#  'Mary Jean Chan',
#  'Mary Lawson (novelist)',
#  'Mary McCarthy (author)',
#  'Mary Renault',
#  'Mary Wilson, Baroness Wilson of Rievaulx',
#  'Master Georgie',
#  'Master and Commander',
#  'Matt Thorne',
#  'Matthew Kneale',
#  "Matthew d'Ancona",
#  'Max Porter (writer)',
#  'Maya Jasanoff',
#  'Melvyn Bragg',
#  'Methuen Publishing',
#  'Michael Collins (Irish author)',
#  'Michael Foot',
#  'Michael Frayn',
#  'Michael Ignatieff',
#  'Michael Joseph (publisher)',
#  'Michael Ondaatje',
#  'Michael Portillo',
#  'Michael Prodger',
#  'Michael Ratcliffe',
#  'Michael Redhill',
#  'Michael Wood (academic)',
#  'Michelle de Kretser',
#  'Michèle Roberts',
#  'Mick Jackson (author)',
#  "Midnight's Children",
#  'Mike McCormack (writer)',
#  'Milkman (novel)',
#  'Miriam Gross',
#  'Mister Pip',
#  'Mohammed Hanif',
#  'Mohsin Hamid',
#  'Molly Keane',
#  'Monica Ali',
#  'Moon Tiger',
#  'Morality Play (novel)',
#  'Mordecai Richler',
#  "Mother's Milk (novel)",
#  'Mrs. Palfrey at the Claremont (novel)',
#  "Mrs Eckdorf in O'Neill's Hotel",
#  'Muriel Spark',
#  'My Name Is Lucy Barton',
#  'My Sister, the Serial Killer',
#  'Myrmidon Books',
#  'Nadeem Aslam',
#  'Nadifa Mohamed',
#  'Nadine Gordimer',
#  'Naeem Murr',
#  'Narcopolis (book)',
#  'Natalie Haynes',
#  'Natascha McElhone',
#  'Natasha Walter',
#  'Nathan Harris (novelist)',
#  'Ned Beauman',
#  'Neel Mukherjee (writer)',
#  'Neil Cross',
#  'Neil MacGregor',
#  'Netherland (novel)',
#  'Never Let Me Go (novel)',
#  'Niall Williams (writer)',
#  'Nice Work',
#  'Nicholas Clee',
#  'Nicholas Mosley',
#  'Nicholas Shakespeare',
#  'Nick Drnaso',
#  'Nick Hornby',
#  'Nicola Barker',
#  'Nigella Lawson',
#  'Night Boat to Tangier',
#  'Nightcrawling',
#  'Nikita Lalwani',
#  'Nina Bawden',
#  'NoViolet Bulawayo',
#  'No One Is Talking About This',
#  'Normal People',
#  'Norman St John-Stevas',
#  'Notes on a Scandal',
#  'Number9dream',
#  'Offshore (novel)',
#  'Oh William!',
#  'Olivier Todd',
#  'On Beauty',
#  "On Canaan's Side",
#  'On Chesil Beach',
#  'Oneworld Publications',
#  'Orfeo (novel)',
#  'Oryx and Crake',
#  'Oscar and Lucinda',
#  'Ottessa Moshfegh',
#  'Our Fathers (novel)',
#  'Out of the Shelter',
#  'Oxygen (Miller novel)',
#  'Oyinkan Braithwaite',
#  'P. D. James',
#  'P. H. Newby',
#  'Paddy Clarke Ha Ha Ha',
#  'Paradise (Gurnah novel)',
#  'Parrot and Olivier in America',
#  "Pascali's Island (novel)",
#  'Pasmore (novel)',
#  'Pat Barker',
#  'Patricia Grace',
#  'Patricia Lockwood',
#  'Patrick McCabe (novelist)',
#  'Patrick McGuinness',
#  "Patrick O'Brian",
#  'Patrick White',
#  'Patrick deWitt',
#  'Paul Auster',
#  'Paul Bailey (British writer)',
#  'Paul Beatty',
#  'Paul Harding (author)',
#  'Paul Kingsnorth',
#  'Paul Lynch (writer)',
#  'Paul Mark Scott',
#  'Paul Murray (author)',
#  'Paul Scott (novelist)',
#  'Paul Theroux',
#  'Penelope Fitzgerald',
#  'Penelope Lively',
#  'Penguin Books',
#  'Penguin Random House',
#  'Percival Everett',
#  'Peter Ackroyd',
#  'Peter Carey (novelist)',
#  'Peter Florence',
#  'Peter Ho Davies',
#  'Peter Kemp (writer)',
#  'Peter Porter (poet)',
#  "Peter Smart's Confessions",
#  'Peter Stothard',
#  'Philip French',
#  'Philip Hensher',
#  'Philip Larkin',
#  'Philip Pullman',
#  'Philip Toynbee',
#  'Picador',
#  'Picador (imprint)',
#  'Pigeon English',
#  'Polly Devlin',
#  'Possession: A Romance',
#  'Possession (Byatt novel)',
#  'Praxis (novel)',
#  'Prophet Song',
#  'Purple Hibiscus',
#  'Quarantine (Jim Crace novel)',
#  'Quartet in Autumn',
#  'Quichotte (novel)',
#  'R. C. Hutchinson',
#  'R. F. Foster (historian)',
#  'Rachel Billington',
#  'Rachel Cooke',
#  'Rachel Cusk',
#  'Rachel Joyce (writer)',
#  'Rachel Kushner',
#  'Rachel Seiffert',
#  'Rates of Exchange',
#  'Reading in the Dark',
#  'Real Life (novel)',
#  'Rebecca Stephens (climber)',
#  'Redhead by the Side of the Road',
#  'Reef (novel)',
#  'Reginald Hill',
#  'Remembering Babylon',
#  'Republic of Ireland',
#  'Reservoir 13',
#  'Restoration (Tremain novel)',
#  'Rhine Journey',
#  'Richard Cobb',
#  'Richard Flanagan',
#  'Richard Hoggart',
#  'Richard House',
#  'Richard Powers',
#  'Rick Gekoski',
#  'Rising (novel)',
#  'Robert Douglas-Fairhurst',
#  'Robert Edric',
#  'Robert Macfarlane (travel writer)',
#  'Robert Webb',
#  'Robertson Davies',
#  'Robin Ray',
#  'Robin Robertson',
#  'Roddy Doyle',
#  'Roderick Watson',
#  'Rohinton Mistry',
#  'Romesh Gunesekera',
#  'Ronald Blythe',
#  'Ronan Bennett',
#  'Room (novel)',
#  'Rose Tremain',
#  'Rosie Blau',
#  'Ross Higgins',
#  'Rowan Pelling',
#  'Rowan Williams',
#  'Roy Fuller',
#  'Rumours of Rain',
#  'Russell Celyn Jones',
#  'Ruth Ozeki',
#  'Ruth Prawer Jhabvala',
#  'Ruth Rendell',
#  'Ruth Scurr',
#  'Sabrina (comics)',
#  'Sacred Hunger',
#  'Salley Vickers',
#  'Sally Rooney',
#  'Salman Rushdie',
#  'Salt Publishing',
#  'Sam Leith',
#  'Sam Thompson (writer)',
#  'Samantha Harvey (author)',
#  'Sameer Rahim',
#  'Samuel Hynes',
#  'Saraband (publisher)',
#  'Sarah Bernstein (author)',
#  'Sarah Churchwell',
#  'Sarah Hall (writer)',
#  'Sarah Waters',
#  'Satin Island',
#  'Saturday (novel)',
#  'Saul Bellow',
#  'Saville (novel)',
#  'Scar Tissue (novel)',
#  'Sceptre',
#  'Sceptre (imprint)',
#  'Sceptre Press',
#  "Schindler's Ark",
#  "Schopenhauer's Telescope",
#  'Sea of Poppies',
#  'Seamus Deane',
#  'Sebastian Barry',
#  'Sebastian Faulks',
#  'Secker & Warburg',
#  'Second Place (novel)',
#  'Selby Wynn Schwartz',
#  'Self Help (novel)',
#  'Selina Hastings (writer)',
#  'Seren Books',
#  'Serenity House',
#  'Serious Sweet',
#  "Serpent's Tail",
#  'Shadows on our Skin',
#  'Shahidha Bari',
#  'Shalimar the Clown',
#  'Shame (Rushdie novel)',
#  'Shehan Karunatilaka',
#  'Shelf Awareness',
#  'Shena Mackay',
#  'Shirley Hazzard',
#  'Shiva Naipaul',
#  'Shroud (novel)',
#  'Shuggie Bain',
#  'Silence Among the Weapons',
#  'Simon & Schuster',
#  'Simon Armitage',
#  'Simon Jenkins',
#  'Simon Mawer',
#  'Sir Alfred Ayer',
#  'Siri Hustvedt',
#  'Sixty Lights',
#  'Siân Hughes',
#  'Skios',
#  'Skippy Dies',
#  'Sleeping on Jupiter',
#  'Slow Man',
#  'Small Things Like These',
#  'Small World: An Academic Romance',
#  'Snowdrops (novel)',
#  'So Many Ways to Begin',
#  'Solar Bones',
#  'Solomon Gursky Was Here',
#  'Something Might Happen',
#  'Something to Answer For',
#  'Sophie Mackintosh',
#  'Sophie Ward',
#  'Sort of Books',
#  'Sour Sweet',
#  'Spies (novel)',
#  "St. Urbain's Horseman",
#  'Stanley Middleton',
#  'Staying On',
#  'Stella Rimington',
#  'Stephen Kelman',
#  'Stephen Spender',
#  'Steve Toltz',
#  'Stevie Davies',
#  'Stuart Kelly (literary critic)',
#  'Study for Obedience',
#  'Such a Fun Age',
#  'Such a Long Journey (novel)',
#  'Sue Perkins',
#  'Summertime (novel)',
#  'Sunjeev Sahota',
#  'Susan Hill',
#  'Susanna Clarke',
#  'Susannah Clapp',
#  'Swimming Home',
#  'Swing Time (novel)',
#  'Sybille Bedford',
#  'Tan Twan Eng',
#  'Tash Aw',
#  'Ted Rowlands',
#  'Terence Kilmartin',
#  'Terence Wheeler',
#  'The 27th Kingdom',
#  'The Accidental',
#  'The Amber Spyglass',
#  'The Autograph Man',
#  'The Battle of Pollocks Crossing',
#  'The Bay of Noon',
#  'The Bee Sting',
#  'The Beginning of Spring',
#  'The Best of the Booker',
#  'The Betrayal (Dunmore novel)',
#  'The Big Chapel',
#  'The Bird of Night',
#  'The Birds on the Trees',
#  'The Black Prince (novel)',
#  'The Blackwater Lightship',
#  'The Blind Assassin',
#  'The Blue Tango',
#  'The Bone Clocks',
#  'The Bone People',
#  'The Book and the Brotherhood',
#  'The Book of Evidence',
#  'The Bookshop',
#  'The Bottle Factory Outing',
#  'The Butcher Boy (novel)',
#  'The Chant of Jimmie Blacksmith',
#  "The Children's Book",
#  'The Children of Dynmouth',
#  'The Clothes on Their Backs',
#  'The Colour of Blood',
#  'The Comfort of Strangers',
#  'The Conjunction',
#  'The Conservationist',
#  'The Curious Incident of the Dog in the Night-Time',
#  'The Dark Room (Seiffert novel)',
#  'The Death of Vishnu',
#  'The Deposition of Father McGreevy',
#  "The Doctor's Wife (Brian Moore novel)",
#  'The Dressmaker (1973 novel)',
#  "The Driver's Seat (novel)",
#  'The Elected Member',
#  'The Electric Michelangelo',
#  'The Element of Water',
#  "The Emperor's Children",
#  'The Enchantress of Florence',
#  'The English Patient',
#  'The Essence of the Thing',
#  'The Famished Road',
#  'The Finkler Question',
#  'The Fishermen (Chigozie Obioma novel)',
#  'The Folding Star',
#  'The Fortune Men',
#  'The Garden of Evening Mists',
#  'The Gate of Angels',
#  'The Gathering (Enright novel)',
#  'The Ghost Road',
#  'The Gift of Rain',
#  'The Glass Room',
#  'The God of Small Things',
#  'The Golden Man Booker',
#  'The Good Apprentice',
#  'The Good Doctor (novel)',
#  'The Good Terrorist',
#  'The Great Fire (Hazzard novel)',
#  'The Green Road (Enright novel)',
#  'The Guardian',
#  'The Hand Reared Boy',
#  "The Handmaid's Tale",
#  'The Harmony Silk Factory',
#  'The Hiding Place (Azzopardi novel)',
#  'The House of Doors',
#  'The Industry of Souls',
#  'The Inheritance of Loss',
#  'The Keepers of Truth',
#  'The Kills (novel)',
#  'The Light of Day (Graham Swift novel)',
#  'The Lighthouse (2012 novel)',
#  'The Line of Beauty',
#  'The Little Stranger',
#  'The Lives of Others (novel)',
#  'The Long Song',
#  'The Long Take',
#  'The Lost Dog',
#  'The Lowland',
#  'The Luminaries',
#  'The Many (novel)',
#  'The Map of Love',
#  'The Mars Room',
#  'The Master (novel)',
#  'The Ministry of Utmost Happiness',
#  'The Mirror and the Light',
#  "The Moor's Account",
#  ...]

# %%
p_wiki = wiki_wiki.page("The House of Doors")

# %%
p_wiki.text
# Out:
# 'The House of Doors is a 2023 historical novel by Tan Twan Eng, published by Bloomsbury Publishing. The novel, set in the 1920s British colony of the Federated Malay States, tells the stories of the local residents and visitors, including a fictionalized version of William Somerset Maugham.\nThe novel was longlisted for the 2023 Booker Prize and listed among notable fiction works in 2023 by The Washington Post and The Financial Times.\n\nNarrative\nThe book tells of a fictionalized account of William Somerset Maugham\'s travels through the Federated Malay States in the 1920s. While in Penang, Maugham and Gerald Haxton, who is ostensibly his travelling secretary but is actually his lover, stay with Maugham\'s friend Robert Hamlyn. Robert and his wife Lesley are British expatriots living in the Federated Malay States. While staying with the Hamlyns, Maughan develops a friendship with Lesley.\nThis eventually leads Lesley to confide in Maugham, revealing many personal secrets which would eventually become subjects of Maugham\'s literary works. This includes Lesley\'s dissatisfaction with her marriage with Robert. Robert Hamlyn, suffering from the disabling effects of chemical warfare from the First World War, is pressuring his wife, much to her dismay, to move to South Africa where he believes the less humid climate will allow his wounds to heal. Lesley also finds out about her husband\'s infidelity. Earlier, Lesley told Maugham about her affair with Arthur, a member of Sun Yat-sen\'s Chinese revolutionary party, when he was in Malaysia to raise funds for the campaign. Lesley felt justified in engaging in the invigorating affair with her true love after learning of her own husband\'s infidelity. And Lesley also tells Maugham of her friend Ethel Proudlock, who was tried for murder in 1911 after killing a man who she claimed had tried to rape her.\n\nReception\nWriting for The Guardian in a mixed review, critic Xan Brooks stated: "Sun, in his way, is as much a storyteller as Maugham. But his revolutionary adventure feels undercooked and imported. We view it via Lesley, the white colonial wife, and her vision of events is partial and obscured." Brooks also stated that the eclectic storylines in the novel sometimes reduce the overall quality, stating "The sheer weight of its interests sometimes slows it down".\nWriting for NPR, Heller McAlpin described the work as "a paean to the art of transforming life experiences into literature". With McAlpin further commending Tan\'s ambitious creativity in interpreting Maugham\'s works in a new literary piece. Writing for The Financial Times, Michael Arditti describes the novel as "expertly constructed, tightly plotted and richly atmospheric."\nThe novel was named one of the "50 notable works of fiction" for 2023 by The Washington Post and among the "best books of 2023" in fiction by the The Financial Times. It was longlisted for the 2023 Booker Prize, whose listing describes the novel as a "masterful novel of public morality and private truth" which "examines love and betrayal under the shadow of Empire."\n\n\n== References =='

# %%
llm("Tell me which city this novel takes place in, if it takes place in a city, based on its wikipedia summary which is as follows:" + p_wiki.text)
# Out:
# 'According to the Wikipedia summary, the novel "The House of Doors" by Tan Twan Eng takes place in Penang, which is part of the Federated Malay States (now Malaysia). Therefore, the city where this novel takes place is Penang.'

# %%
prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. if multiple cities are mentioned in a novel but the novel is mostly set in one place, then return that place (city and country). \
if a novel is set in many places and not focused on one place, then return NA as your response for city and country. \
if a novel is not set in a real place on earth, for example Duke being set in Arrakis, then return NA as your response for city and country.\
return the name, author, city, and country information as a dictionary with name, author, city, and country as four dictionary keys.\
\Finally, it is possible that the wikipedia article provided is not the wikipedia article for a book. \
Add a fifth dictionary key called is_book and if the text provided seems like the wikipedia article for a book, return True as the value. \
If the wikipedia article is not that of a book, return False as the value for is_book. In this case, return NA for all other values.\
Do not return any text other than the dictionary in your response. Do not make a human readable sentence. \
Here is the text of the wikipedia article for which you will return a dictionary: "

# %%
p_wiki = wiki_wiki.page("The House of Doors")

# %%
llm(prompt + p_wiki.text)
# Out:
# "{'name': 'The House of Doors', 'author': 'Tan Twan Eng', 'city': 'Penang', 'country': 'Malaysia', 'is_book': True}"

# %%
test_wiki = wiki_wiki.page("In_Ascension")

# %%
prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. if multiple cities are mentioned in a novel but the novel is mostly set in one place, then return that place (city and country). \
if a novel is set in many places and not focused on one place, then return NA as your response for city and country. \
if a novel is not set in a real place on earth, for example Duke being set in Arrakis, then return NA as your response for city and country.\
return the name, author, city, and country information as a dictionary with name, author, city, and country as four dictionary keys.\
\Finally, it is possible that the wikipedia article provided is not the wikipedia article for a book. \
Add a fifth dictionary key called is_book and if the text provided seems like the wikipedia article for a book, return True as the value. \
If the wikipedia article is not that of a book, return False as the value for is_book. In this case, return NA for all other values.\
Do not return any text other than the dictionary in your response. Do not make a human readable sentence. \
Here is the text of the wikipedia article for which you will return a dictionary: "

reminder_text = " Remember, your task is to return a python dictionary with keys name, author, city, country, and is_book. \
Do not return any text other than the dictionary. An example of legitimate output is: \
{'name': 'The House of Doors', 'author': 'Tan Twan Eng', 'city': 'Penang', 'country': 'Malaysia', 'is_Book': True} \
DO NOT RETURN ANY TEXT OTHER THAN THE DICTIONARY"

llm(prompt + test_wiki.text)

#fails on our test case Dune. doesn't on House of Doors though.
# Out:
# "{'name': 'In Ascension', 'author': 'Martin MacInnes', 'city': 'Rotterdam', 'country': 'Netherlands', 'is_Book': True}"

# %%
prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
Do not output anything other than the JSON.\
First, find the book's title and add it to the JSON with the key 'title'.\
Next, find the book's author and add it to the JSON with the key 'author'.\
Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
with the key 'country'. Finally, surround your JSON output with <result></result> tags. \
Here is the text from the wikipedia article for this book: "



end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
Do not output anything other than the JSON.\
First, find the book's title and add it to the JSON with the key 'title'.\
Next, find the book's author and add it to the JSON with the key 'author'.\
Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
with the key 'country'. Finally, surround your JSON output with <result></result> tags."

reminder_text = "Return a valid JSON with keys 'title','author', 'city', and 'country' describing this book according to the instructions given previously. "

llm_response = llm(prompt + wiki_wiki.page("Shuggie_Bain").text + end_prompt)

# %%
import json

json_string = llm_response.split('<result>')[1].split('</result>')[0]
parsed_json = json.loads(json_string.strip())

parsed_json
# Out:
# {'title': 'Shuggie Bain',
#  'author': 'Douglas Stuart',
#  'city': 'Glasgow',
#  'country': 'Scotland'}

# %%
prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
Do not output anything other than the JSON.\
First, find the book's title and add it to the JSON with the key 'title'.\
Next, find the book's author and add it to the JSON with the key 'author'.\
Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
with the key 'country'. Finally, surround your JSON output with <result></result> tags. \
Here is the text from the wikipedia article for this book: "



end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
Do not output anything other than the JSON.\
First, find the book's title and add it to the JSON with the key 'title'.\
Next, find the book's author and add it to the JSON with the key 'author'.\
Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
with the key 'country'. Finally, surround your JSON output with <result></result> tags."

reminder_text = "Return a valid JSON with keys 'title','author', 'city', and 'country' describing this book according to the instructions given previously. "

llm_response = llm(prompt + wiki_wiki.page("Dune_(novel)").text + end_prompt)

# %%
json_string = llm_response.split('<result>')[1].split('</result>')[0]
parsed_json = json.loads(json_string.strip())

parsed_json
# Out:
# {'title': 'Dune', 'author': 'Frank Herbert'}

# %%
llm_response
# Out:
# '<result>\n{\n"title": "Dune",\n"author": "Frank Herbert"\n}\n</result>'

# %%
class SaveWork:

    def __init__(self):
        self.llm = Ollama(model="llama3")
        self.wiki = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')

        return 

    def pull_book(self):

        prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, find the book's title and add it to the JSON with the key 'title'.\
        Next, find the book's author and add it to the JSON with the key 'author'.\
        Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
        you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
        Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
        If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
        with the key 'country'. Finally, surround your JSON output with <result></result> tags. \
        Here is the text from the wikipedia article for this book: "
        
        
        
        end_prompt = "Based on the book's wikipedia article provided above, create a JSON describing this book. Your output must be in valid JSON. \
        Do not output anything other than the JSON.\
        First, find the book's title and add it to the JSON with the key 'title'.\
        Next, find the book's author and add it to the JSON with the key 'author'.\
        Next, find the city that the book is set in and add it to the JSON with the key 'city'. If the book is not set in a real city on earth or\
        you cannot determine what city it is set in, add 'NA' to the JSON with the key 'city'.\
        Next, find the country that the book is set in and add it to the JSON with the key 'country'. \
        If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the JSON\
        with the key 'country'. Finally, surround your JSON output with <result></result> tags."
                
        self.llm_response = self.llm(prompt + self.wiki.page("Dune_(novel)").text + end_prompt)

    def parse_response(self):

        json_string = self.llm_response.split('<result>')[1].split('</result>')[0]
        self.parsed_json = json.loads(json_string.strip())

# %%
prompt = "You are a bot that reads wikipedia articles about books and returns information about them. Your output must be a python dictionary. \
Do not output anything other than the python dictionary.\
First, find the book's title and add it to the dictionary with the key 'title'.\
Next, find the book's author and add it to the dictionary with the key 'author'.\
Next, find the city that the book is set in and add it to the dictionary with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the dictionary with the key 'city'.\
Next, find the country that the book is set in and add it to the dictionary with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the dictionary\
with the key 'country'. Finally, surround your dictinary output with <result></result> tags. \
Here is the text from the wikipedia article for this book: "



end_prompt = "Based on the book's wikipedia article provided above, create a python dictionary describing this book. Your output must be a python dictionary. \
Do not output anything other than the python dictionary.\
First, find the book's title and add it to the dictionary with the key 'title'.\
Next, find the book's author and add it to the dictionary with the key 'author'.\
Next, find the city that the book is set in and add it to the dictionary with the key 'city'. If the book is not set in a real city on earth or\
you cannot determine what city it is set in, add 'NA' to the dictionary with the key 'city'.\
Next, find the country that the book is set in and add it to the dictionary with the key 'country'. \
If the book is not set in a real country on earth or you cannot determine what country it is set in, add 'NA' to the dictionary\
with the key 'country'. Finally, surround your dictinary output with <result></result> tags. \
Here is the text from the wikipedia article for this book: "

llm(prompt + wiki_wiki.page("Shuggie_Bain").text + end_prompt)
# Out:
# "<result>\n{\n'title': 'Shuggie Bain',\n'author': 'Douglas Stuart',\n'city': 'Glasgow',\n'country': 'Scotland'\n}\n</result>"

# %%
bookers = wiki_wiki.page('List_of_winners_and_nominated_authors_of_the_Booker_Prize')

# %%
bookers.links
# Out:
# {'10 Minutes 38 Seconds in This Strange World': 10 Minutes 38 Seconds in This Strange World (id: ??, ns: 0),
#  '2006 Man Booker Prize': 2006 Man Booker Prize (id: ??, ns: 0),
#  '2007 Man Booker Prize': 2007 Man Booker Prize (id: ??, ns: 0),
#  '2008 Man Booker Prize': 2008 Man Booker Prize (id: ??, ns: 0),
#  '2009 Man Booker Prize': 2009 Man Booker Prize (id: ??, ns: 0),
#  '2010 Man Booker Prize': 2010 Man Booker Prize (id: ??, ns: 0),
#  '2011 Man Booker Prize': 2011 Man Booker Prize (id: ??, ns: 0),
#  '2012 Man Booker Prize': 2012 Man Booker Prize (id: ??, ns: 0),
#  '2013 Man Booker Prize': 2013 Man Booker Prize (id: ??, ns: 0),
#  '2014 Man Booker Prize': 2014 Man Booker Prize (id: ??, ns: 0),
#  '2015 Man Booker Prize': 2015 Man Booker Prize (id: ??, ns: 0),
#  '2016 Man Booker Prize': 2016 Man Booker Prize (id: ??, ns: 0),
#  '2017 Man Booker Prize': 2017 Man Booker Prize (id: ??, ns: 0),
#  '2018 Man Booker Prize': 2018 Man Booker Prize (id: ??, ns: 0),
#  '2019 Booker Prize': 2019 Booker Prize (id: ??, ns: 0),
#  '2020 Booker Prize': 2020 Booker Prize (id: ??, ns: 0),
#  '2021 Booker Prize': 2021 Booker Prize (id: ??, ns: 0),
#  '2022 Booker Prize': 2022 Booker Prize (id: ??, ns: 0),
#  '2023 Booker Prize': 2023 Booker Prize (id: ??, ns: 0),
#  '4 3 2 1 (novel)': 4 3 2 1 (novel) (id: ??, ns: 0),
#  '4th Estate': 4th Estate (id: ??, ns: 0),
#  '4th Estate (imprint)': 4th Estate (imprint) (id: ??, ns: 0),
#  'A. C. Grayling': A. C. Grayling (id: ??, ns: 0),
#  'A. L. Barker': A. L. Barker (id: ??, ns: 0),
#  'A. L. Kennedy': A. L. Kennedy (id: ??, ns: 0),
#  'A. N. Wilson': A. N. Wilson (id: ??, ns: 0),
#  'A. S. Byatt': A. S. Byatt (id: ??, ns: 0),
#  'A. Walton Litz': A. Walton Litz (id: ??, ns: 0),
#  'A Bend in the River': A Bend in the River (id: ??, ns: 0),
#  'A Brief History of Seven Killings': A Brief History of Seven Killings (id: ??, ns: 0),
#  'A Case of Exploding Mangoes': A Case of Exploding Mangoes (id: ??, ns: 0),
#  'A Clubbable Woman': A Clubbable Woman (id: ??, ns: 0),
#  'A Disaffection': A Disaffection (id: ??, ns: 0),
#  'A Distant Shore (novel)': A Distant Shore (novel) (id: ??, ns: 0),
#  'A Fairly Honourable Defeat': A Fairly Honourable Defeat (id: ??, ns: 0),
#  'A Fine Balance': A Fine Balance (id: ??, ns: 0),
#  'A Five-Year Sentence': A Five-Year Sentence (id: ??, ns: 0),
#  'A Fraction of the Whole': A Fraction of the Whole (id: ??, ns: 0),
#  'A Green Equinox': A Green Equinox (id: ??, ns: 0),
#  'A Guilty Thing Surprised': A Guilty Thing Surprised (id: ??, ns: 0),
#  'A Little Life': A Little Life (id: ??, ns: 0),
#  'A Little Of What You Fancy?': A Little Of What You Fancy? (id: ??, ns: 0),
#  'A Long Long Way': A Long Long Way (id: ??, ns: 0),
#  'A Month in the Country (novel)': A Month in the Country (novel) (id: ??, ns: 0),
#  'A Passage North': A Passage North (id: ??, ns: 0),
#  'A Place in England': A Place in England (id: ??, ns: 0),
#  'A Short History of Tractors in Ukrainian': A Short History of Tractors in Ukrainian (id: ??, ns: 0),
#  'A Spell of Good Things': A Spell of Good Things (id: ??, ns: 0),
#  'A Spool of Blue Thread': A Spool of Blue Thread (id: ??, ns: 0),
#  'A Tale for the Time Being': A Tale for the Time Being (id: ??, ns: 0),
#  'Abdulrazak Gurnah': Abdulrazak Gurnah (id: ??, ns: 0),
#  'According to Mark': According to Mark (id: ??, ns: 0),
#  'According to Queeney': According to Queeney (id: ??, ns: 0),
#  'Achmat Dangor': Achmat Dangor (id: ??, ns: 0),
#  'Adam Foulds': Adam Foulds (id: ??, ns: 0),
#  'Adam Mars-Jones': Adam Mars-Jones (id: ??, ns: 0),
#  'Adjoa Andoh': Adjoa Andoh (id: ??, ns: 0),
#  'Afua Hirsch': Afua Hirsch (id: ??, ns: 0),
#  'Ahdaf Soueif': Ahdaf Soueif (id: ??, ns: 0),
#  'Alain Mabanckou': Alain Mabanckou (id: ??, ns: 0),
#  'Alan Garner': Alan Garner (id: ??, ns: 0),
#  'Alan Hollinghurst': Alan Hollinghurst (id: ??, ns: 0),
#  'Alan Warner': Alan Warner (id: ??, ns: 0),
#  'Alastair Niven': Alastair Niven (id: ??, ns: 0),
#  'Alex Clark (journalist)': Alex Clark (journalist) (id: ??, ns: 0),
#  'Ali Smith': Ali Smith (id: ??, ns: 0),
#  'Alias Grace': Alias Grace (id: ??, ns: 0),
#  'Alice Munro': Alice Munro (id: ??, ns: 0),
#  'Alice Thomas Ellis': Alice Thomas Ellis (id: ??, ns: 0),
#  'Alison MacLeod': Alison MacLeod (id: ??, ns: 0),
#  'Alison Moore (writer)': Alison Moore (writer) (id: ??, ns: 0),
#  'Alison Pick': Alison Pick (id: ??, ns: 0),
#  'All That Man Is': All That Man Is (id: ??, ns: 0),
#  'Allan Massie': Allan Massie (id: ??, ns: 0),
#  'Allen & Unwin': Allen & Unwin (id: ??, ns: 0),
#  'Amanda Foreman (biographer)': Amanda Foreman (biographer) (id: ??, ns: 0),
#  'Amanda Foreman (historian)': Amanda Foreman (historian) (id: ??, ns: 0),
#  'Amitav Ghosh': Amitav Ghosh (id: ??, ns: 0),
#  'Amongst Women': Amongst Women (id: ??, ns: 0),
#  'Amsterdam (novel)': Amsterdam (novel) (id: ??, ns: 0),
#  'An Artist of the Floating World': An Artist of the Floating World (id: ??, ns: 0),
#  'An Awfully Big Adventure (novel)': An Awfully Big Adventure (novel) (id: ??, ns: 0),
#  'An Ice-Cream War': An Ice-Cream War (id: ??, ns: 0),
#  'An Instant in the Wind': An Instant in the Wind (id: ??, ns: 0),
#  'An Insular Possession': An Insular Possession (id: ??, ns: 0),
#  'An Orchestra of Minorities': An Orchestra of Minorities (id: ??, ns: 0),
#  'Andre Brink': Andre Brink (id: ??, ns: 0),
#  'Andrea Levy': Andrea Levy (id: ??, ns: 0),
#  'Andrew Miller (novelist)': Andrew Miller (novelist) (id: ??, ns: 0),
#  'Andrew Miller (writer)': Andrew Miller (writer) (id: ??, ns: 0),
#  'Andrew Motion': Andrew Motion (id: ??, ns: 0),
#  "Andrew O'Hagan": Andrew O'Hagan (id: ??, ns: 0),
#  'André Brink': André Brink (id: ??, ns: 0),
#  'André Deutsch': André Deutsch (id: ??, ns: 0),
#  'Angela Carter': Angela Carter (id: ??, ns: 0),
#  'Angela Huth': Angela Huth (id: ??, ns: 0),
#  'Angus & Robertson': Angus & Robertson (id: ??, ns: 0),
#  'Angus Wilson': Angus Wilson (id: ??, ns: 0),
#  "Animal's People": Animal's People (id: ??, ns: 0),
#  'Anita Brookner': Anita Brookner (id: ??, ns: 0),
#  'Anita Desai': Anita Desai (id: ??, ns: 0),
#  'Anita Mason': Anita Mason (id: ??, ns: 0),
#  'Ann Schlee': Ann Schlee (id: ??, ns: 0),
#  'Anna Burns': Anna Burns (id: ??, ns: 0),
#  'Anna Smaill': Anna Smaill (id: ??, ns: 0),
#  'Anne Chisholm': Anne Chisholm (id: ??, ns: 0),
#  'Anne Enright': Anne Enright (id: ??, ns: 0),
#  'Anne Tyler': Anne Tyler (id: ??, ns: 0),
#  'Anthills of the Savannah': Anthills of the Savannah (id: ??, ns: 0),
#  'Anthony Burgess': Anthony Burgess (id: ??, ns: 0),
#  'Anthony Curtis (journalist)': Anthony Curtis (journalist) (id: ??, ns: 0),
#  'Anthony Thwaite': Anthony Thwaite (id: ??, ns: 0),
#  'Antonia Fraser': Antonia Fraser (id: ??, ns: 0),
#  'Antony Quinn': Antony Quinn (id: ??, ns: 0),
#  'Anuk Arudpragasam': Anuk Arudpragasam (id: ??, ns: 0),
#  'Anuradha Roy (novelist)': Anuradha Roy (novelist) (id: ??, ns: 0),
#  'Any Human Heart': Any Human Heart (id: ??, ns: 0),
#  'Apeirogon (novel)': Apeirogon (novel) (id: ??, ns: 0),
#  'Aravind Adiga': Aravind Adiga (id: ??, ns: 0),
#  'Arthur & George': Arthur & George (id: ??, ns: 0),
#  'Arundhati Roy': Arundhati Roy (id: ??, ns: 0),
#  'Asa Briggs': Asa Briggs (id: ??, ns: 0),
#  'Astonishing Splashes of Colour': Astonishing Splashes of Colour (id: ??, ns: 0),
#  'Atlantic Books': Atlantic Books (id: ??, ns: 0),
#  'Atonement (novel)': Atonement (novel) (id: ??, ns: 0),
#  'Audrey Magee': Audrey Magee (id: ??, ns: 0),
#  'Autumn (Smith novel)': Autumn (Smith novel) (id: ??, ns: 0),
#  'Avni Doshi': Avni Doshi (id: ??, ns: 0),
#  'Ayobami Adebayo': Ayobami Adebayo (id: ??, ns: 0),
#  'BBC': BBC (id: ??, ns: 0),
#  'BBC News': BBC News (id: ??, ns: 0),
#  'Bantam Press': Bantam Press (id: ??, ns: 0),
#  'Barbara Gowdy': Barbara Gowdy (id: ??, ns: 0),
#  'Barbara Pym': Barbara Pym (id: ??, ns: 0),
#  'Barbara Trapido': Barbara Trapido (id: ??, ns: 0),
#  'Barry England': Barry England (id: ??, ns: 0),
#  'Barry Unsworth': Barry Unsworth (id: ??, ns: 0),
#  'Belinda Bauer (author)': Belinda Bauer (author) (id: ??, ns: 0),
#  'Ben Okri': Ben Okri (id: ??, ns: 0),
#  'Benny Green (saxophonist)': Benny Green (saxophonist) (id: ??, ns: 0),
#  'Bernard MacLaverty': Bernard MacLaverty (id: ??, ns: 0),
#  'Bernardine Evaristo': Bernardine Evaristo (id: ??, ns: 0),
#  'Bernice Rubens': Bernice Rubens (id: ??, ns: 0),
#  'Beryl Bainbridge': Beryl Bainbridge (id: ??, ns: 0),
#  'Beside the Ocean of Time': Beside the Ocean of Time (id: ??, ns: 0),
#  'Bewilderment': Bewilderment (id: ??, ns: 0),
#  'Beyond Black': Beyond Black (id: ??, ns: 0),
#  'Bill Clegg': Bill Clegg (id: ??, ns: 0),
#  'Bitter Fruit': Bitter Fruit (id: ??, ns: 0),
#  'Black Dogs': Black Dogs (id: ??, ns: 0),
#  'Black Swan (imprint)': Black Swan (imprint) (id: ??, ns: 0),
#  'Black Swan Green': Black Swan Green (id: ??, ns: 0),
#  'Blake Morrison': Blake Morrison (id: ??, ns: 0),
#  'Bloomsbury Publishing': Bloomsbury Publishing (id: ??, ns: 0),
#  'Bodley Head': Bodley Head (id: ??, ns: 0),
#  'Bomber (novel)': Bomber (novel) (id: ??, ns: 0),
#  'Booker Prize': Booker Prize (id: ??, ns: 0),
#  'Booker Prize for Fiction': Booker Prize for Fiction (id: ??, ns: 0),
#  'Booker of Bookers': Booker of Bookers (id: ??, ns: 0),
#  'Boyd Tonkin': Boyd Tonkin (id: ??, ns: 0),
#  'Brandon Taylor (writer)': Brandon Taylor (writer) (id: ??, ns: 0),
#  'Breakfast on Pluto': Breakfast on Pluto (id: ??, ns: 0),
#  'Brendan Gill': Brendan Gill (id: ??, ns: 0),
#  'Brian Aldiss': Brian Aldiss (id: ??, ns: 0),
#  'Brian Moore (novelist)': Brian Moore (novelist) (id: ??, ns: 0),
#  "Brian O'Doherty": Brian O'Doherty (id: ??, ns: 0),
#  'Brian Wenham': Brian Wenham (id: ??, ns: 0),
#  'Brick Lane (book)': Brick Lane (book) (id: ??, ns: 0),
#  'Briefing for a Descent into Hell': Briefing for a Descent into Hell (id: ??, ns: 0),
#  'Bring Up the Bodies': Bring Up the Bodies (id: ??, ns: 0),
#  'Brooklyn (novel)': Brooklyn (novel) (id: ??, ns: 0),
#  'Bruce Chatwin': Bruce Chatwin (id: ??, ns: 0),
#  "Bruno's Dream": Bruno's Dream (id: ??, ns: 0),
#  'By the Sea (novel)': By the Sea (novel) (id: ??, ns: 0),
#  'C. P. Snow': C. P. Snow (id: ??, ns: 0),
#  'C (novel)': C (novel) (id: ??, ns: 0),
#  'C Pam Zhang': C Pam Zhang (id: ??, ns: 0),
#  'Candia McWilliam': Candia McWilliam (id: ??, ns: 0),
#  'Canongate Books': Canongate Books (id: ??, ns: 0),
#  'Carmen Callil': Carmen Callil (id: ??, ns: 0),
#  'Carol Birch': Carol Birch (id: ??, ns: 0),
#  'Carol Shields': Carol Shields (id: ??, ns: 0),
#  'Caroline Blackwood': Caroline Blackwood (id: ??, ns: 0),
#  'Caroline Gascoigne': Caroline Gascoigne (id: ??, ns: 0),
#  'Carry Me Down': Carry Me Down (id: ??, ns: 0),
#  'Caryl Phillips': Caryl Phillips (id: ??, ns: 0),
#  "Cat's Eye (novel)": Cat's Eye (novel) (id: ??, ns: 0),
#  "Catherine O'Flynn": Catherine O'Flynn (id: ??, ns: 0),
#  'Charlotte Mendelson': Charlotte Mendelson (id: ??, ns: 0),
#  'Chatterton (novel)': Chatterton (novel) (id: ??, ns: 0),
#  'Chatto & Windus': Chatto & Windus (id: ??, ns: 0),
#  'Chetna Maroo': Chetna Maroo (id: ??, ns: 0),
#  'Chigozie Obioma': Chigozie Obioma (id: ??, ns: 0),
#  'Child 44': Child 44 (id: ??, ns: 0),
#  'Chimamanda Ngozi Adichie': Chimamanda Ngozi Adichie (id: ??, ns: 0),
#  'Chinua Achebe': Chinua Achebe (id: ??, ns: 0),
#  'Chris Mullin (politician)': Chris Mullin (politician) (id: ??, ns: 0),
#  'Chris Smith, Baron Smith of Finsbury': Chris Smith, Baron Smith of Finsbury (id: ??, ns: 0),
#  'Christopher Hope (novelist)': Christopher Hope (novelist) (id: ??, ns: 0),
#  'Christos Tsiolkas': Christos Tsiolkas (id: ??, ns: 0),
#  'Christy Brown': Christy Brown (id: ??, ns: 0),
#  'Ciaran Carson': Ciaran Carson (id: ??, ns: 0),
#  'Circles of Deceit (novel)': Circles of Deceit (novel) (id: ??, ns: 0),
#  'Claire Keegan': Claire Keegan (id: ??, ns: 0),
#  'Claire Messud': Claire Messud (id: ??, ns: 0),
#  'Claire Tomalin': Claire Tomalin (id: ??, ns: 0),
#  'Clare Boylan': Clare Boylan (id: ??, ns: 0),
#  'Clare Morrall': Clare Morrall (id: ??, ns: 0),
#  'Clear Light of Day': Clear Light of Day (id: ??, ns: 0),
#  'Cloud Atlas (novel)': Cloud Atlas (novel) (id: ??, ns: 0),
#  'Colin Thubron': Colin Thubron (id: ??, ns: 0),
#  'Colm Toibin': Colm Toibin (id: ??, ns: 0),
#  'Colm Tóibín': Colm Tóibín (id: ??, ns: 0),
#  'Colson Whitehead': Colson Whitehead (id: ??, ns: 0),
#  'Colum McCann': Colum McCann (id: ??, ns: 0),
#  'Commonwealth of Nations': Commonwealth of Nations (id: ??, ns: 0),
#  'Confederates (novel)': Confederates (novel) (id: ??, ns: 0),
#  'Constance (novel)': Constance (novel) (id: ??, ns: 0),
#  'Corsair (imprint)': Corsair (imprint) (id: ??, ns: 0),
#  'Crossing the River': Crossing the River (id: ??, ns: 0),
#  'Cyril Connolly': Cyril Connolly (id: ??, ns: 0),
#  'D. J. Taylor (writer)': D. J. Taylor (writer) (id: ??, ns: 0),
#  'D. M. Thomas': D. M. Thomas (id: ??, ns: 0),
#  'DBC Pierre': DBC Pierre (id: ??, ns: 0),
#  'Daisy Johnson (writer)': Daisy Johnson (writer) (id: ??, ns: 0),
#  'Dame Rebecca West': Dame Rebecca West (id: ??, ns: 0),
#  'Damon Galgut': Damon Galgut (id: ??, ns: 0),
#  'Dan Jacobson': Dan Jacobson (id: ??, ns: 0),
#  'Dan Stevens': Dan Stevens (id: ??, ns: 0),
#  'Daniel Glaser': Daniel Glaser (id: ??, ns: 0),
#  'Dannie Abse': Dannie Abse (id: ??, ns: 0),
#  'Darkmans': Darkmans (id: ??, ns: 0),
#  'Daughters of the House': Daughters of the House (id: ??, ns: 0),
#  'David Baddiel': David Baddiel (id: ??, ns: 0),
#  'David Daiches': David Daiches (id: ??, ns: 0),
#  'David Farrer': David Farrer (id: ??, ns: 0),
#  'David Harsent': David Harsent (id: ??, ns: 0),
#  'David Hughes (novelist)': David Hughes (novelist) (id: ??, ns: 0),
#  'David Lodge (author)': David Lodge (author) (id: ??, ns: 0),
#  'David Malouf': David Malouf (id: ??, ns: 0),
#  'David Means': David Means (id: ??, ns: 0),
#  'David Mitchell (author)': David Mitchell (author) (id: ??, ns: 0),
#  'David Nicholls (writer)': David Nicholls (writer) (id: ??, ns: 0),
#  'David Profumo': David Profumo (id: ??, ns: 0),
#  'David R. Holloway': David R. Holloway (id: ??, ns: 0),
#  'David Sexton': David Sexton (id: ??, ns: 0),
#  'David Storey': David Storey (id: ??, ns: 0),
#  'David Szalay': David Szalay (id: ??, ns: 0),
#  'Days Without End (novel)': Days Without End (novel) (id: ??, ns: 0),
#  'Deborah Bull': Deborah Bull (id: ??, ns: 0),
#  'Deborah Levy': Deborah Levy (id: ??, ns: 0),
#  'Denis Forman': Denis Forman (id: ??, ns: 0),
#  'Derek Beaven': Derek Beaven (id: ??, ns: 0),
#  'Derek Robinson (novelist)': Derek Robinson (novelist) (id: ??, ns: 0),
#  'Derwent May': Derwent May (id: ??, ns: 0),
#  'Diane Cook': Diane Cook (id: ??, ns: 0),
#  'Did You Ever Have a Family': Did You Ever Have a Family (id: ??, ns: 0),
#  'Dinah Birch': Dinah Birch (id: ??, ns: 0),
#  'Dirt Music': Dirt Music (id: ??, ns: 0),
#  'Disgrace': Disgrace (id: ??, ns: 0),
#  'Disgrace (novel)': Disgrace (novel) (id: ??, ns: 0),
#  'Do Not Say We Have Nothing': Do Not Say We Have Nothing (id: ??, ns: 0),
#  'Donal Ryan': Donal Ryan (id: ??, ns: 0),
#  'Dorian, an Imitation': Dorian, an Imitation (id: ??, ns: 0),
#  'Doris Lessing': Doris Lessing (id: ??, ns: 0),
#  'Doubleday (publisher)': Doubleday (publisher) (id: ??, ns: 0),
#  'Douglas Hurd': Douglas Hurd (id: ??, ns: 0),
#  'Douglas Stuart (writer)': Douglas Stuart (writer) (id: ??, ns: 0),
#  'Down All the Days': Down All the Days (id: ??, ns: 0),
#  'Ducks, Newburyport': Ducks, Newburyport (id: ??, ns: 0),
#  'Duckworth Books': Duckworth Books (id: ??, ns: 0),
#  'Earthly Powers': Earthly Powers (id: ??, ns: 0),
#  "Ed O'Loughlin": Ed O'Loughlin (id: ??, ns: 0),
#  'Edinburgh International Book Festival': Edinburgh International Book Festival (id: ??, ns: 0),
#  'Edmund White': Edmund White (id: ??, ns: 0),
#  'Edna Healey': Edna Healey (id: ??, ns: 0),
#  "Edna O'Brien": Edna O'Brien (id: ??, ns: 0),
#  'Edward Docx': Edward Docx (id: ??, ns: 0),
#  'Edward St Aubyn': Edward St Aubyn (id: ??, ns: 0),
#  'Eileen (novel)': Eileen (novel) (id: ??, ns: 0),
#  'Elaine Feeney': Elaine Feeney (id: ??, ns: 0),
#  'Elaine Feinstein': Elaine Feinstein (id: ??, ns: 0),
#  'Eleanor Catton': Eleanor Catton (id: ??, ns: 0),
#  'Elif Shafak': Elif Shafak (id: ??, ns: 0),
#  'Elizabeth Bowen': Elizabeth Bowen (id: ??, ns: 0),
#  'Elizabeth Costello': Elizabeth Costello (id: ??, ns: 0),
#  'Elizabeth Jane Howard': Elizabeth Jane Howard (id: ??, ns: 0),
#  'Elizabeth Mavor': Elizabeth Mavor (id: ??, ns: 0),
#  'Elizabeth Strout': Elizabeth Strout (id: ??, ns: 0),
#  'Elizabeth Taylor (novelist)': Elizabeth Taylor (novelist) (id: ??, ns: 0),
#  'Ellah Wakatama Allfrey': Ellah Wakatama Allfrey (id: ??, ns: 0),
#  'Elmet (Mozley novel)': Elmet (Mozley novel) (id: ??, ns: 0),
#  'Emily Fridlund': Emily Fridlund (id: ??, ns: 0),
#  'Emily Wilson (classicist)': Emily Wilson (classicist) (id: ??, ns: 0),
#  'Emma Donoghue': Emma Donoghue (id: ??, ns: 0),
#  'Empire of the Sun (novel)': Empire of the Sun (novel) (id: ??, ns: 0),
#  'Ending Up': Ending Up (id: ??, ns: 0),
#  'England, England': England, England (id: ??, ns: 0),
#  'English Passengers': English Passengers (id: ??, ns: 0),
#  'Eoin McNamee': Eoin McNamee (id: ??, ns: 0),
#  'Erica Wagner': Erica Wagner (id: ??, ns: 0),
#  'Esi Edugyan': Esi Edugyan (id: ??, ns: 0),
#  'Europa (novel)': Europa (novel) (id: ??, ns: 0),
#  'Eva Trout (novel)': Eva Trout (novel) (id: ??, ns: 0),
#  'Every Man for Himself (novel)': Every Man for Himself (novel) (id: ??, ns: 0),
#  'Exit West': Exit West (id: ??, ns: 0),
#  'Eyre & Spottiswoode': Eyre & Spottiswoode (id: ??, ns: 0),
#  'Faber & Faber': Faber & Faber (id: ??, ns: 0),
#  'Faber and Faber': Faber and Faber (id: ??, ns: 0),
#  'Family Matters (novel)': Family Matters (novel) (id: ??, ns: 0),
#  'Fasting, Feasting': Fasting, Feasting (id: ??, ns: 0),
#  'Fay Weldon': Fay Weldon (id: ??, ns: 0),
#  'Ferdinand Mount': Ferdinand Mount (id: ??, ns: 0),
#  'Fiammetta Rocco': Fiammetta Rocco (id: ??, ns: 0),
#  'Figures in a Landscape': Figures in a Landscape (id: ??, ns: 0),
#  'Fingersmith (novel)': Fingersmith (novel) (id: ??, ns: 0),
#  'Fiona Mozley': Fiona Mozley (id: ??, ns: 0),
#  'Fiona Shaw': Fiona Shaw (id: ??, ns: 0),
#  'Fire From Heaven': Fire From Heaven (id: ??, ns: 0),
#  'Fireflies (novel)': Fireflies (novel) (id: ??, ns: 0),
#  'Five Star Billionaire': Five Star Billionaire (id: ??, ns: 0),
#  'Flamingo (imprint)': Flamingo (imprint) (id: ??, ns: 0),
#  "Flaubert's Parrot": Flaubert's Parrot (id: ??, ns: 0),
#  'Fleet Publishing': Fleet Publishing (id: ??, ns: 0),
#  'Flying to Nowhere': Flying to Nowhere (id: ??, ns: 0),
#  'Frances Osborne': Frances Osborne (id: ??, ns: 0),
#  'Frances Wilson (writer)': Frances Wilson (writer) (id: ??, ns: 0),
#  'Francine Stock': Francine Stock (id: ??, ns: 0),
#  'Francis King': Francis King (id: ??, ns: 0),
#  'Francis Spufford': Francis Spufford (id: ??, ns: 0),
#  'Frank Delaney': Frank Delaney (id: ??, ns: 0),
#  'Frank Kermode': Frank Kermode (id: ??, ns: 0),
#  'Frankissstein': Frankissstein (id: ??, ns: 0),
#  'From A to X': From A to X (id: ??, ns: 0),
#  'From Scenes Like These': From Scenes Like These (id: ??, ns: 0),
#  'From a Low and Quiet Sea': From a Low and Quiet Sea (id: ??, ns: 0),
#  'G. (novel)': G. (novel) (id: ??, ns: 0),
#  "Gabriel's Lament": Gabriel's Lament (id: ??, ns: 0),
#  'Gabriel Krauze': Gabriel Krauze (id: ??, ns: 0),
#  'Gaby Wood': Gaby Wood (id: ??, ns: 0),
#  'Gail Jones (writer)': Gail Jones (writer) (id: ??, ns: 0),
#  'Galley Beggar': Galley Beggar (id: ??, ns: 0),
#  'Gaynor Arnold': Gaynor Arnold (id: ??, ns: 0),
#  'George Mackay Brown': George Mackay Brown (id: ??, ns: 0),
#  'George Saunders': George Saunders (id: ??, ns: 0),
#  'George Steiner': George Steiner (id: ??, ns: 0),
#  'George Walden': George Walden (id: ??, ns: 0),
#  'Gerald Kaufman': Gerald Kaufman (id: ??, ns: 0),
#  'Gerard Donovan': Gerard Donovan (id: ??, ns: 0),
#  'Gerard Woodward': Gerard Woodward (id: ??, ns: 0),
#  'Get a Life (novel)': Get a Life (novel) (id: ??, ns: 0),
#  'Gifted (novel)': Gifted (novel) (id: ??, ns: 0),
#  'Giles Foden': Giles Foden (id: ??, ns: 0),
#  'Gillian Beer': Gillian Beer (id: ??, ns: 0),
#  'Gillian Reynolds': Gillian Reynolds (id: ??, ns: 0),
#  'Girl, Woman, Other': Girl, Woman, Other (id: ??, ns: 0),
#  'Girl in White Cotton': Girl in White Cotton (id: ??, ns: 0),
#  'Glory (Bulawayo novel)': Glory (Bulawayo novel) (id: ??, ns: 0),
#  'God on the Rocks': God on the Rocks (id: ??, ns: 0),
#  'Good Behaviour (Keane novel)': Good Behaviour (Keane novel) (id: ??, ns: 0),
#  'Gordon Williams (writer)': Gordon Williams (writer) (id: ??, ns: 0),
#  'Goshawk Squadron': Goshawk Squadron (id: ??, ns: 0),
#  'Gossip from the Forest': Gossip from the Forest (id: ??, ns: 0),
#  'Grace Notes': Grace Notes (id: ??, ns: 0),
#  'Graeme Macrae Burnet': Graeme Macrae Burnet (id: ??, ns: 0),
#  'Graham Swift': Graham Swift (id: ??, ns: 0),
#  'Granta': Granta (id: ??, ns: 0),
#  'Granta Books': Granta Books (id: ??, ns: 0),
#  'Great Circle (novel)': Great Circle (novel) (id: ??, ns: 0),
#  'Great Granny Webster': Great Granny Webster (id: ??, ns: 0),
#  'Grey Gowrie': Grey Gowrie (id: ??, ns: 0),
#  'Guy Gunaratne': Guy Gunaratne (id: ??, ns: 0),
#  'H. E. Bates': H. E. Bates (id: ??, ns: 0),
#  'Hachette (publisher)': Hachette (publisher) (id: ??, ns: 0),
#  'Half-Blood Blues': Half-Blood Blues (id: ??, ns: 0),
#  'Half a Life (novel)': Half a Life (novel) (id: ??, ns: 0),
#  'Hamish Hamilton': Hamish Hamilton (id: ??, ns: 0),
#  'Hanya Yanagihara': Hanya Yanagihara (id: ??, ns: 0),
#  'Hardeep Singh Kohli': Hardeep Singh Kohli (id: ??, ns: 0),
#  'HarperCollins': HarperCollins (id: ??, ns: 0),
#  'Harriet Harvey Wood': Harriet Harvey Wood (id: ??, ns: 0),
#  'Harry Thompson': Harry Thompson (id: ??, ns: 0),
#  'Harvest (Jim Crace novel)': Harvest (Jim Crace novel) (id: ??, ns: 0),
#  'Harvill Secker': Harvill Secker (id: ??, ns: 0),
#  'Headlong (Frayn novel)': Headlong (Frayn novel) (id: ??, ns: 0),
#  'Heat and Dust': Heat and Dust (id: ??, ns: 0),
#  'Heinemann (publisher)': Heinemann (publisher) (id: ??, ns: 0),
#  'Helen Castor': Helen Castor (id: ??, ns: 0),
#  'Helen Dunmore': Helen Dunmore (id: ??, ns: 0),
#  'Helen McNeil': Helen McNeil (id: ??, ns: 0),
#  'Heligoland (novel)': Heligoland (novel) (id: ??, ns: 0),
#  'Heliopolis (Scudamore novel)': Heliopolis (Scudamore novel) (id: ??, ns: 0),
#  'Hermione Lee': Hermione Lee (id: ??, ns: 0),
#  'Hernan Diaz (writer)': Hernan Diaz (writer) (id: ??, ns: 0),
#  'Hilary Mantel': Hilary Mantel (id: ??, ns: 0),
#  'Hilary Spurling': Hilary Spurling (id: ??, ns: 0),
#  'His Bloody Project': His Bloody Project (id: ??, ns: 0),
#  'Hisham Matar': Hisham Matar (id: ??, ns: 0),
#  'History of Wolves': History of Wolves (id: ??, ns: 0),
#  'Hodder & Stoughton': Hodder & Stoughton (id: ??, ns: 0),
#  'Hodder and Stoughton': Hodder and Stoughton (id: ??, ns: 0),
#  'Hogarth Press': Hogarth Press (id: ??, ns: 0),
#  'Holiday (novel)': Holiday (novel) (id: ??, ns: 0),
#  'Holland House Books': Holland House Books (id: ??, ns: 0),
#  'Home Fire (novel)': Home Fire (novel) (id: ??, ns: 0),
#  'Hot Milk (novel)': Hot Milk (novel) (id: ??, ns: 0),
#  'Hotel World': Hotel World (id: ??, ns: 0),
#  'Hotel du Lac': Hotel du Lac (id: ??, ns: 0),
#  'How Late It Was, How Late': How Late It Was, How Late (id: ??, ns: 0),
#  'How Much of These Hills Is Gold': How Much of These Hills Is Gold (id: ??, ns: 0),
#  'How late it was, how late': How late it was, how late (id: ??, ns: 0),
#  'How to Be Both': How to Be Both (id: ??, ns: 0),
#  'How to Be Good': How to Be Good (id: ??, ns: 0),
#  'Howard Davies (economist)': Howard Davies (economist) (id: ??, ns: 0),
#  'Howard Jacobson': Howard Jacobson (id: ??, ns: 0),
#  'Hutchinson (publisher)': Hutchinson (publisher) (id: ??, ns: 0),
#  'Hystopia': Hystopia (id: ??, ns: 0),
#  "I'll Go to Bed at Noon": I'll Go to Bed at Noon (id: ??, ns: 0),
#  "I'm the King of the Castle": I'm the King of the Castle (id: ??, ns: 0),
#  'Ian Jack': Ian Jack (id: ??, ns: 0),
#  'Ian McEwan': Ian McEwan (id: ??, ns: 0),
#  'Ian McGuire': Ian McGuire (id: ??, ns: 0),
#  'If I Survive You': If I Survive You (id: ??, ns: 0),
#  'If Nobody Speaks of Remarkable Things': If Nobody Speaks of Remarkable Things (id: ??, ns: 0),
#  'Illywhacker': Illywhacker (id: ??, ns: 0),
#  'Imogen Stubbs': Imogen Stubbs (id: ??, ns: 0),
#  'Impossible Object (novel)': Impossible Object (novel) (id: ??, ns: 0),
#  'In Ascension': In Ascension (id: ??, ns: 0),
#  'In Custody (novel)': In Custody (novel) (id: ??, ns: 0),
#  'In Every Face I Meet': In Every Face I Meet (id: ??, ns: 0),
#  'In Their Wisdom': In Their Wisdom (id: ??, ns: 0),
#  'In a Free State': In a Free State (id: ??, ns: 0),
#  'In a Strange Room': In a Strange Room (id: ??, ns: 0),
#  'In the Country of Men': In the Country of Men (id: ??, ns: 0),
#  'Indra Sinha': Indra Sinha (id: ??, ns: 0),
#  'Influx Press': Influx Press (id: ??, ns: 0),
#  'International Booker Prize': International Booker Prize (id: ??, ns: 0),
#  'Ion Trewin': Ion Trewin (id: ??, ns: 0),
#  'Iris Murdoch': Iris Murdoch (id: ??, ns: 0),
#  'Isabel Quigley': Isabel Quigley (id: ??, ns: 0),
#  'J. G. Ballard': J. G. Ballard (id: ??, ns: 0),
#  'J. G. Farrell': J. G. Farrell (id: ??, ns: 0),
#  'J. L. Carr': J. L. Carr (id: ??, ns: 0),
#  'J. M. Coetzee': J. M. Coetzee (id: ??, ns: 0),
#  'J. W. Lambert': J. W. Lambert (id: ??, ns: 0),
#  'J (novel)': J (novel) (id: ??, ns: 0),
#  'Jacqueline Rose': Jacqueline Rose (id: ??, ns: 0),
#  "Jake's Thing": Jake's Thing (id: ??, ns: 0),
#  'James Hamilton-Paterson': James Hamilton-Paterson (id: ??, ns: 0),
#  'James Heneage': James Heneage (id: ??, ns: 0),
#  'James Kelman': James Kelman (id: ??, ns: 0),
#  'James Lasdun': James Lasdun (id: ??, ns: 0),
#  'James Meek (author)': James Meek (author) (id: ??, ns: 0),
#  'James Naughtie': James Naughtie (id: ??, ns: 0),
#  'James Robertson (novelist)': James Robertson (novelist) (id: ??, ns: 0),
#  'James S. Shapiro': James S. Shapiro (id: ??, ns: 0),
#  'James Scudamore (author)': James Scudamore (author) (id: ??, ns: 0),
#  'James Wood (critic)': James Wood (critic) (id: ??, ns: 0),
#  "Jamrach's Menagerie": Jamrach's Menagerie (id: ??, ns: 0),
#  'Jan Dalley': Jan Dalley (id: ??, ns: 0),
#  'Jan Morris': Jan Morris (id: ??, ns: 0),
#  'Jane Gardam': Jane Gardam (id: ??, ns: 0),
#  'Jane Rogers (novelist)': Jane Rogers (novelist) (id: ??, ns: 0),
#  'Jane Urquhart': Jane Urquhart (id: ??, ns: 0),
#  'Jason Cowley (journalist)': Jason Cowley (journalist) (id: ??, ns: 0),
#  'Jeanette Winterson': Jeanette Winterson (id: ??, ns: 0),
#  'Jeet Thayil': Jeet Thayil (id: ??, ns: 0),
#  'Jennifer Johnston (novelist)': Jennifer Johnston (novelist) (id: ??, ns: 0),
#  'Jeremy Treglown': Jeremy Treglown (id: ??, ns: 0),
#  'Jhumpa Lahiri': Jhumpa Lahiri (id: ??, ns: 0),
#  'Jigsaw (novel)': Jigsaw (novel) (id: ??, ns: 0),
#  'Jill Paton Walsh': Jill Paton Walsh (id: ??, ns: 0),
#  'Jim Crace': Jim Crace (id: ??, ns: 0),
#  'Joan Bakewell': Joan Bakewell (id: ??, ns: 0),
#  'Joan Barfoot': Joan Barfoot (id: ??, ns: 0),
#  'Joanna Lumley': Joanna Lumley (id: ??, ns: 0),
#  'Joanna MacGregor': Joanna MacGregor (id: ??, ns: 0),
#  'Joe Orton': Joe Orton (id: ??, ns: 0),
#  'John Arden': John Arden (id: ??, ns: 0),
#  'John B. Thompson (novelist)': John B. Thompson (novelist) (id: ??, ns: 0),
#  'John Banville': John Banville (id: ??, ns: 0),
#  'John Bayley (writer)': John Bayley (writer) (id: ??, ns: 0),
#  'John Bemrose': John Bemrose (id: ??, ns: 0),
#  'John Berger': John Berger (id: ??, ns: 0),
#  "John Brown's Body (novel)": John Brown's Body (novel) (id: ??, ns: 0),
#  'John Burnside (writer)': John Burnside (writer) (id: ??, ns: 0),
#  'John Carey (critic)': John Carey (critic) (id: ??, ns: 0),
#  'John Fowles': John Fowles (id: ??, ns: 0),
#  'John Fuller (poet)': John Fuller (poet) (id: ??, ns: 0),
#  'John Gross': John Gross (id: ??, ns: 0),
#  'John Lanchester': John Lanchester (id: ??, ns: 0),
#  'John McGahern': John McGahern (id: ??, ns: 0),
#  'John Mullan (academic)': John Mullan (academic) (id: ??, ns: 0),
#  'John Murray (publishing house)': John Murray (publishing house) (id: ??, ns: 0),
#  'John Sutherland (author)': John Sutherland (author) (id: ??, ns: 0),
#  'Jon McGregor': Jon McGregor (id: ??, ns: 0),
#  'Jonathan Bate': Jonathan Bate (id: ??, ns: 0),
#  'Jonathan Cape': Jonathan Cape (id: ??, ns: 0),
#  'Jonathan Coe': Jonathan Coe (id: ??, ns: 0),
#  'Jonathan Escoffery': Jonathan Escoffery (id: ??, ns: 0),
#  'Jonathan Keates': Jonathan Keates (id: ??, ns: 0),
#  'Jonathan Raban': Jonathan Raban (id: ??, ns: 0),
#  'Jonathan Strange & Mr Norrell': Jonathan Strange & Mr Norrell (id: ??, ns: 0),
#  'Joseph (novel)': Joseph (novel) (id: ??, ns: 0),
#  "Joseph O'Neill (writer, born 1964)": Joseph O'Neill (writer, born 1964) (id: ??, ns: 0),
#  'Josephine Hart': Josephine Hart (id: ??, ns: 0),
#  'Joshua Ferris': Joshua Ferris (id: ??, ns: 0),
#  'Julia Darling': Julia Darling (id: ??, ns: 0),
#  'Julia Neuberger': Julia Neuberger (id: ??, ns: 0),
#  "Julia O'Faolain": Julia O'Faolain (id: ??, ns: 0),
#  'Julian Barnes': Julian Barnes (id: ??, ns: 0),
#  'Julian Rathbone': Julian Rathbone (id: ??, ns: 0),
#  'Julie Myerson': Julie Myerson (id: ??, ns: 0),
#  'Justin Cartwright': Justin Cartwright (id: ??, ns: 0),
#  'Justin Haythe': Justin Haythe (id: ??, ns: 0),
#  'Kamila Shamsie': Kamila Shamsie (id: ??, ns: 0),
#  'Karen Jennings (author)': Karen Jennings (author) (id: ??, ns: 0),
#  'Karen Joy Fowler': Karen Joy Fowler (id: ??, ns: 0),
#  'Karl Miller': Karl Miller (id: ??, ns: 0),
#  'Kate Grenville': Kate Grenville (id: ??, ns: 0),
#  'Kate Kellaway': Kate Kellaway (id: ??, ns: 0),
#  'Kate Saunders': Kate Saunders (id: ??, ns: 0),
#  'Kate Summerscale': Kate Summerscale (id: ??, ns: 0),
#  'Katie Derham': Katie Derham (id: ??, ns: 0),
#  'Kazuo Ishiguro': Kazuo Ishiguro (id: ??, ns: 0),
#  'Kenneth Baker, Baron Baker of Dorking': Kenneth Baker, Baron Baker of Dorking (id: ??, ns: 0),
#  'Keri Hulme': Keri Hulme (id: ??, ns: 0),
#  'Kevin Barry (author)': Kevin Barry (author) (id: ??, ns: 0),
#  'Kiley Reid': Kiley Reid (id: ??, ns: 0),
#  'King Fisher Lives': King Fisher Lives (id: ??, ns: 0),
#  'Kingsley Amis': Kingsley Amis (id: ??, ns: 0),
#  'Kiran Desai': Kiran Desai (id: ??, ns: 0),
#  'Kirkus Reviews': Kirkus Reviews (id: ??, ns: 0),
#  'Klara and the Sun': Klara and the Sun (id: ??, ns: 0),
#  'Knowledge of Angels': Knowledge of Angels (id: ??, ns: 0),
#  'Kwame Anthony Appiah': Kwame Anthony Appiah (id: ??, ns: 0),
#  'Lady Antonia Fraser': Lady Antonia Fraser (id: ??, ns: 0),
#  'Laila Lalami': Laila Lalami (id: ??, ns: 0),
#  'Last Letters from Hav': Last Letters from Hav (id: ??, ns: 0),
#  'Last Orders': Last Orders (id: ??, ns: 0),
#  'Lawrence Durrell': Lawrence Durrell (id: ??, ns: 0),
#  'Leanne Shapton': Leanne Shapton (id: ??, ns: 0),
#  'Lee Child': Lee Child (id: ??, ns: 0),
#  'Leila Mottley': Leila Mottley (id: ??, ns: 0),
#  'Lemn Sissay': Lemn Sissay (id: ??, ns: 0),
#  'Len Deighton': Len Deighton (id: ??, ns: 0),
#  'Libby Purves': Libby Purves (id: ??, ns: 0),
#  'Lies of Silence': Lies of Silence (id: ??, ns: 0),
#  'Life & Times of Michael K': Life & Times of Michael K (id: ??, ns: 0),
#  'Life of Pi': Life of Pi (id: ??, ns: 0),
#  'Lila (Robinson novel)': Lila (Robinson novel) (id: ??, ns: 0),
#  'Lila Azam Zanganeh': Lila Azam Zanganeh (id: ??, ns: 0),
#  'Lincoln in the Bardo': Lincoln in the Bardo (id: ??, ns: 0),
#  'Linda Grant': Linda Grant (id: ??, ns: 0),
#  'Linda Grant (novelist)': Linda Grant (novelist) (id: ??, ns: 0),
#  'Lindsay Duguid': Lindsay Duguid (id: ??, ns: 0),
#  'Lisa Jardine': Lisa Jardine (id: ??, ns: 0),
#  'Lisa Moore (writer)': Lisa Moore (writer) (id: ??, ns: 0),
#  'Little, Brown': Little, Brown (id: ??, ns: 0),
#  'Liz Calder': Liz Calder (id: ??, ns: 0),
#  'Lloyd Jones (New Zealand author)': Lloyd Jones (New Zealand author) (id: ??, ns: 0),
#  'Loitering with Intent': Loitering with Intent (id: ??, ns: 0),
#  'Lola Young, Baroness Young of Hornsey': Lola Young, Baroness Young of Hornsey (id: ??, ns: 0),
#  'Longman': Longman (id: ??, ns: 0),
#  'Lorna Sage': Lorna Sage (id: ??, ns: 0),
#  'Lost Children Archive': Lost Children Archive (id: ??, ns: 0),
#  'Lost Man Booker Prize': Lost Man Booker Prize (id: ??, ns: 0),
#  'Louise Dean (author)': Louise Dean (author) (id: ??, ns: 0),
#  'Louise Doughty': Louise Doughty (id: ??, ns: 0),
#  'Love and Other Thought Experiments': Love and Other Thought Experiments (id: ??, ns: 0),
#  'Love and Summer': Love and Summer (id: ??, ns: 0),
#  'Lucasta Miller': Lucasta Miller (id: ??, ns: 0),
#  'Lucy Ellmann': Lucy Ellmann (id: ??, ns: 0),
#  'M. J. Hyland': M. J. Hyland (id: ??, ns: 0),
#  'M. John Harrison': M. John Harrison (id: ??, ns: 0),
#  'Maaza Mengiste': Maaza Mengiste (id: ??, ns: 0),
#  'Maclehose Press': Maclehose Press (id: ??, ns: 0),
#  'Macmillan Publishers': Macmillan Publishers (id: ??, ns: 0),
#  'Maddie Mortimer': Maddie Mortimer (id: ??, ns: 0),
#  'Madeleine St John': Madeleine St John (id: ??, ns: 0),
#  'Madeleine Thien': Madeleine Thien (id: ??, ns: 0),
#  'Maggie Gee (novelist)': Maggie Gee (novelist) (id: ??, ns: 0),
#  'Maggie Shipstead': Maggie Shipstead (id: ??, ns: 0),
#  'Magnus Mills': Magnus Mills (id: ??, ns: 0),
#  'Malcolm Bradbury': Malcolm Bradbury (id: ??, ns: 0),
#  'Man Booker Prize': Man Booker Prize (id: ??, ns: 0),
#  'Manil Suri': Manil Suri (id: ??, ns: 0),
#  'Maps for Lost Lovers': Maps for Lost Lovers (id: ??, ns: 0),
#  'Margaret Atwood': Margaret Atwood (id: ??, ns: 0),
#  'Margaret Busby': Margaret Busby (id: ??, ns: 0),
#  'Margaret Forster': Margaret Forster (id: ??, ns: 0),
#  'Margaret Laurence': Margaret Laurence (id: ??, ns: 0),
#  'Mariella Frostrup': Mariella Frostrup (id: ??, ns: 0),
#  'Marilynne Robinson': Marilynne Robinson (id: ??, ns: 0),
#  'Marina Lewycka': Marina Lewycka (id: ??, ns: 0),
#  'Marina Warner': Marina Warner (id: ??, ns: 0),
#  'Mark Haddon': Mark Haddon (id: ??, ns: 0),
#  'Mark Lawson': Mark Lawson (id: ??, ns: 0),
#  'Marlon James (novelist)': Marlon James (novelist) (id: ??, ns: 0),
#  'Martha Kearney': Martha Kearney (id: ??, ns: 0),
#  'Martin Amis': Martin Amis (id: ??, ns: 0),
#  'Martin Booth': Martin Booth (id: ??, ns: 0),
#  'Martin MacInnes': Martin MacInnes (id: ??, ns: 0),
#  'Mary Jean Chan': Mary Jean Chan (id: ??, ns: 0),
#  'Mary Lawson (novelist)': Mary Lawson (novelist) (id: ??, ns: 0),
#  'Mary McCarthy (author)': Mary McCarthy (author) (id: ??, ns: 0),
#  'Mary Renault': Mary Renault (id: ??, ns: 0),
#  'Mary Wilson, Baroness Wilson of Rievaulx': Mary Wilson, Baroness Wilson of Rievaulx (id: ??, ns: 0),
#  'Master Georgie': Master Georgie (id: ??, ns: 0),
#  'Master and Commander': Master and Commander (id: ??, ns: 0),
#  'Matt Thorne': Matt Thorne (id: ??, ns: 0),
#  'Matthew Kneale': Matthew Kneale (id: ??, ns: 0),
#  "Matthew d'Ancona": Matthew d'Ancona (id: ??, ns: 0),
#  'Max Porter (writer)': Max Porter (writer) (id: ??, ns: 0),
#  'Maya Jasanoff': Maya Jasanoff (id: ??, ns: 0),
#  'Melvyn Bragg': Melvyn Bragg (id: ??, ns: 0),
#  'Methuen Publishing': Methuen Publishing (id: ??, ns: 0),
#  'Michael Collins (Irish author)': Michael Collins (Irish author) (id: ??, ns: 0),
#  'Michael Foot': Michael Foot (id: ??, ns: 0),
#  'Michael Frayn': Michael Frayn (id: ??, ns: 0),
#  'Michael Ignatieff': Michael Ignatieff (id: ??, ns: 0),
#  'Michael Joseph (publisher)': Michael Joseph (publisher) (id: ??, ns: 0),
#  'Michael Ondaatje': Michael Ondaatje (id: ??, ns: 0),
#  'Michael Portillo': Michael Portillo (id: ??, ns: 0),
#  'Michael Prodger': Michael Prodger (id: ??, ns: 0),
#  'Michael Ratcliffe': Michael Ratcliffe (id: ??, ns: 0),
#  'Michael Redhill': Michael Redhill (id: ??, ns: 0),
#  'Michael Wood (academic)': Michael Wood (academic) (id: ??, ns: 0),
#  'Michelle de Kretser': Michelle de Kretser (id: ??, ns: 0),
#  'Michèle Roberts': Michèle Roberts (id: ??, ns: 0),
#  'Mick Jackson (author)': Mick Jackson (author) (id: ??, ns: 0),
#  "Midnight's Children": Midnight's Children (id: ??, ns: 0),
#  'Mike McCormack (writer)': Mike McCormack (writer) (id: ??, ns: 0),
#  'Milkman (novel)': Milkman (novel) (id: ??, ns: 0),
#  'Miriam Gross': Miriam Gross (id: ??, ns: 0),
#  'Mister Pip': Mister Pip (id: ??, ns: 0),
#  'Mohammed Hanif': Mohammed Hanif (id: ??, ns: 0),
#  'Mohsin Hamid': Mohsin Hamid (id: ??, ns: 0),
#  'Molly Keane': Molly Keane (id: ??, ns: 0),
#  'Monica Ali': Monica Ali (id: ??, ns: 0),
#  'Moon Tiger': Moon Tiger (id: ??, ns: 0),
#  'Morality Play (novel)': Morality Play (novel) (id: ??, ns: 0),
#  'Mordecai Richler': Mordecai Richler (id: ??, ns: 0),
#  "Mother's Milk (novel)": Mother's Milk (novel) (id: ??, ns: 0),
#  'Mrs. Palfrey at the Claremont (novel)': Mrs. Palfrey at the Claremont (novel) (id: ??, ns: 0),
#  "Mrs Eckdorf in O'Neill's Hotel": Mrs Eckdorf in O'Neill's Hotel (id: ??, ns: 0),
#  'Muriel Spark': Muriel Spark (id: ??, ns: 0),
#  'My Name Is Lucy Barton': My Name Is Lucy Barton (id: ??, ns: 0),
#  'My Sister, the Serial Killer': My Sister, the Serial Killer (id: ??, ns: 0),
#  'Myrmidon Books': Myrmidon Books (id: ??, ns: 0),
#  'Nadeem Aslam': Nadeem Aslam (id: ??, ns: 0),
#  'Nadifa Mohamed': Nadifa Mohamed (id: ??, ns: 0),
#  'Nadine Gordimer': Nadine Gordimer (id: ??, ns: 0),
#  'Naeem Murr': Naeem Murr (id: ??, ns: 0),
#  'Narcopolis (book)': Narcopolis (book) (id: ??, ns: 0),
#  'Natalie Haynes': Natalie Haynes (id: ??, ns: 0),
#  'Natascha McElhone': Natascha McElhone (id: ??, ns: 0),
#  'Natasha Walter': Natasha Walter (id: ??, ns: 0),
#  'Nathan Harris (novelist)': Nathan Harris (novelist) (id: ??, ns: 0),
#  'Ned Beauman': Ned Beauman (id: ??, ns: 0),
#  'Neel Mukherjee (writer)': Neel Mukherjee (writer) (id: ??, ns: 0),
#  'Neil Cross': Neil Cross (id: ??, ns: 0),
#  'Neil MacGregor': Neil MacGregor (id: ??, ns: 0),
#  'Netherland (novel)': Netherland (novel) (id: ??, ns: 0),
#  'Never Let Me Go (novel)': Never Let Me Go (novel) (id: ??, ns: 0),
#  'Niall Williams (writer)': Niall Williams (writer) (id: ??, ns: 0),
#  'Nice Work': Nice Work (id: ??, ns: 0),
#  'Nicholas Clee': Nicholas Clee (id: ??, ns: 0),
#  'Nicholas Mosley': Nicholas Mosley (id: ??, ns: 0),
#  'Nicholas Shakespeare': Nicholas Shakespeare (id: ??, ns: 0),
#  'Nick Drnaso': Nick Drnaso (id: ??, ns: 0),
#  'Nick Hornby': Nick Hornby (id: ??, ns: 0),
#  'Nicola Barker': Nicola Barker (id: ??, ns: 0),
#  'Nigella Lawson': Nigella Lawson (id: ??, ns: 0),
#  'Night Boat to Tangier': Night Boat to Tangier (id: ??, ns: 0),
#  'Nightcrawling': Nightcrawling (id: ??, ns: 0),
#  'Nikita Lalwani': Nikita Lalwani (id: ??, ns: 0),
#  'Nina Bawden': Nina Bawden (id: ??, ns: 0),
#  'NoViolet Bulawayo': NoViolet Bulawayo (id: ??, ns: 0),
#  'No One Is Talking About This': No One Is Talking About This (id: ??, ns: 0),
#  'Normal People': Normal People (id: ??, ns: 0),
#  'Norman St John-Stevas': Norman St John-Stevas (id: ??, ns: 0),
#  'Notes on a Scandal': Notes on a Scandal (id: ??, ns: 0),
#  'Number9dream': Number9dream (id: ??, ns: 0),
#  'Offshore (novel)': Offshore (novel) (id: ??, ns: 0),
#  'Oh William!': Oh William! (id: ??, ns: 0),
#  'Olivier Todd': Olivier Todd (id: ??, ns: 0),
#  'On Beauty': On Beauty (id: ??, ns: 0),
#  "On Canaan's Side": On Canaan's Side (id: ??, ns: 0),
#  'On Chesil Beach': On Chesil Beach (id: ??, ns: 0),
#  'Oneworld Publications': Oneworld Publications (id: ??, ns: 0),
#  'Orfeo (novel)': Orfeo (novel) (id: ??, ns: 0),
#  'Oryx and Crake': Oryx and Crake (id: ??, ns: 0),
#  'Oscar and Lucinda': Oscar and Lucinda (id: ??, ns: 0),
#  'Ottessa Moshfegh': Ottessa Moshfegh (id: ??, ns: 0),
#  'Our Fathers (novel)': Our Fathers (novel) (id: ??, ns: 0),
#  'Out of the Shelter': Out of the Shelter (id: ??, ns: 0),
#  'Oxygen (Miller novel)': Oxygen (Miller novel) (id: ??, ns: 0),
#  'Oyinkan Braithwaite': Oyinkan Braithwaite (id: ??, ns: 0),
#  'P. D. James': P. D. James (id: ??, ns: 0),
#  'P. H. Newby': P. H. Newby (id: ??, ns: 0),
#  'Paddy Clarke Ha Ha Ha': Paddy Clarke Ha Ha Ha (id: ??, ns: 0),
#  'Paradise (Gurnah novel)': Paradise (Gurnah novel) (id: ??, ns: 0),
#  'Parrot and Olivier in America': Parrot and Olivier in America (id: ??, ns: 0),
#  "Pascali's Island (novel)": Pascali's Island (novel) (id: ??, ns: 0),
#  'Pasmore (novel)': Pasmore (novel) (id: ??, ns: 0),
#  'Pat Barker': Pat Barker (id: ??, ns: 0),
#  'Patricia Grace': Patricia Grace (id: ??, ns: 0),
#  'Patricia Lockwood': Patricia Lockwood (id: ??, ns: 0),
#  'Patrick McCabe (novelist)': Patrick McCabe (novelist) (id: ??, ns: 0),
#  'Patrick McGuinness': Patrick McGuinness (id: ??, ns: 0),
#  "Patrick O'Brian": Patrick O'Brian (id: ??, ns: 0),
#  'Patrick White': Patrick White (id: ??, ns: 0),
#  'Patrick deWitt': Patrick deWitt (id: ??, ns: 0),
#  'Paul Auster': Paul Auster (id: ??, ns: 0),
#  'Paul Bailey (British writer)': Paul Bailey (British writer) (id: ??, ns: 0),
#  'Paul Beatty': Paul Beatty (id: ??, ns: 0),
#  'Paul Harding (author)': Paul Harding (author) (id: ??, ns: 0),
#  'Paul Kingsnorth': Paul Kingsnorth (id: ??, ns: 0),
#  'Paul Lynch (writer)': Paul Lynch (writer) (id: ??, ns: 0),
#  'Paul Mark Scott': Paul Mark Scott (id: ??, ns: 0),
#  'Paul Murray (author)': Paul Murray (author) (id: ??, ns: 0),
#  'Paul Scott (novelist)': Paul Scott (novelist) (id: ??, ns: 0),
#  'Paul Theroux': Paul Theroux (id: ??, ns: 0),
#  'Penelope Fitzgerald': Penelope Fitzgerald (id: ??, ns: 0),
#  'Penelope Lively': Penelope Lively (id: ??, ns: 0),
#  'Penguin Books': Penguin Books (id: ??, ns: 0),
#  'Penguin Random House': Penguin Random House (id: ??, ns: 0),
#  'Percival Everett': Percival Everett (id: ??, ns: 0),
#  'Peter Ackroyd': Peter Ackroyd (id: ??, ns: 0),
#  'Peter Carey (novelist)': Peter Carey (novelist) (id: ??, ns: 0),
#  'Peter Florence': Peter Florence (id: ??, ns: 0),
#  'Peter Ho Davies': Peter Ho Davies (id: ??, ns: 0),
#  'Peter Kemp (writer)': Peter Kemp (writer) (id: ??, ns: 0),
#  'Peter Porter (poet)': Peter Porter (poet) (id: ??, ns: 0),
#  "Peter Smart's Confessions": Peter Smart's Confessions (id: ??, ns: 0),
#  'Peter Stothard': Peter Stothard (id: ??, ns: 0),
#  'Philip French': Philip French (id: ??, ns: 0),
#  'Philip Hensher': Philip Hensher (id: ??, ns: 0),
#  'Philip Larkin': Philip Larkin (id: ??, ns: 0),
#  'Philip Pullman': Philip Pullman (id: ??, ns: 0),
#  'Philip Toynbee': Philip Toynbee (id: ??, ns: 0),
#  'Picador': Picador (id: ??, ns: 0),
#  'Picador (imprint)': Picador (imprint) (id: ??, ns: 0),
#  'Pigeon English': Pigeon English (id: ??, ns: 0),
#  'Polly Devlin': Polly Devlin (id: ??, ns: 0),
#  'Possession: A Romance': Possession: A Romance (id: ??, ns: 0),
#  'Possession (Byatt novel)': Possession (Byatt novel) (id: ??, ns: 0),
#  'Praxis (novel)': Praxis (novel) (id: ??, ns: 0),
#  'Prophet Song': Prophet Song (id: ??, ns: 0),
#  'Purple Hibiscus': Purple Hibiscus (id: ??, ns: 0),
#  'Quarantine (Jim Crace novel)': Quarantine (Jim Crace novel) (id: ??, ns: 0),
#  'Quartet in Autumn': Quartet in Autumn (id: ??, ns: 0),
#  'Quichotte (novel)': Quichotte (novel) (id: ??, ns: 0),
#  'R. C. Hutchinson': R. C. Hutchinson (id: ??, ns: 0),
#  'R. F. Foster (historian)': R. F. Foster (historian) (id: ??, ns: 0),
#  'Rachel Billington': Rachel Billington (id: ??, ns: 0),
#  'Rachel Cooke': Rachel Cooke (id: ??, ns: 0),
#  'Rachel Cusk': Rachel Cusk (id: ??, ns: 0),
#  'Rachel Joyce (writer)': Rachel Joyce (writer) (id: ??, ns: 0),
#  'Rachel Kushner': Rachel Kushner (id: ??, ns: 0),
#  'Rachel Seiffert': Rachel Seiffert (id: ??, ns: 0),
#  'Rates of Exchange': Rates of Exchange (id: ??, ns: 0),
#  'Reading in the Dark': Reading in the Dark (id: ??, ns: 0),
#  'Real Life (novel)': Real Life (novel) (id: ??, ns: 0),
#  'Rebecca Stephens (climber)': Rebecca Stephens (climber) (id: ??, ns: 0),
#  'Redhead by the Side of the Road': Redhead by the Side of the Road (id: ??, ns: 0),
#  'Reef (novel)': Reef (novel) (id: ??, ns: 0),
#  'Reginald Hill': Reginald Hill (id: ??, ns: 0),
#  'Remembering Babylon': Remembering Babylon (id: ??, ns: 0),
#  'Republic of Ireland': Republic of Ireland (id: ??, ns: 0),
#  'Reservoir 13': Reservoir 13 (id: ??, ns: 0),
#  'Restoration (Tremain novel)': Restoration (Tremain novel) (id: ??, ns: 0),
#  'Rhine Journey': Rhine Journey (id: ??, ns: 0),
#  'Richard Cobb': Richard Cobb (id: ??, ns: 0),
#  'Richard Flanagan': Richard Flanagan (id: ??, ns: 0),
#  'Richard Hoggart': Richard Hoggart (id: ??, ns: 0),
#  'Richard House': Richard House (id: ??, ns: 0),
#  'Richard Powers': Richard Powers (id: ??, ns: 0),
#  'Rick Gekoski': Rick Gekoski (id: ??, ns: 0),
#  'Rising (novel)': Rising (novel) (id: ??, ns: 0),
#  'Robert Douglas-Fairhurst': Robert Douglas-Fairhurst (id: ??, ns: 0),
#  'Robert Edric': Robert Edric (id: ??, ns: 0),
#  'Robert Macfarlane (travel writer)': Robert Macfarlane (travel writer) (id: ??, ns: 0),
#  'Robert Webb': Robert Webb (id: ??, ns: 0),
#  'Robertson Davies': Robertson Davies (id: ??, ns: 0),
#  'Robin Ray': Robin Ray (id: ??, ns: 0),
#  'Robin Robertson': Robin Robertson (id: ??, ns: 0),
#  'Roddy Doyle': Roddy Doyle (id: ??, ns: 0),
#  'Roderick Watson': Roderick Watson (id: ??, ns: 0),
#  'Rohinton Mistry': Rohinton Mistry (id: ??, ns: 0),
#  'Romesh Gunesekera': Romesh Gunesekera (id: ??, ns: 0),
#  'Ronald Blythe': Ronald Blythe (id: ??, ns: 0),
#  'Ronan Bennett': Ronan Bennett (id: ??, ns: 0),
#  'Room (novel)': Room (novel) (id: ??, ns: 0),
#  'Rose Tremain': Rose Tremain (id: ??, ns: 0),
#  'Rosie Blau': Rosie Blau (id: ??, ns: 0),
#  'Ross Higgins': Ross Higgins (id: ??, ns: 0),
#  'Rowan Pelling': Rowan Pelling (id: ??, ns: 0),
#  'Rowan Williams': Rowan Williams (id: ??, ns: 0),
#  'Roy Fuller': Roy Fuller (id: ??, ns: 0),
#  'Rumours of Rain': Rumours of Rain (id: ??, ns: 0),
#  'Russell Celyn Jones': Russell Celyn Jones (id: ??, ns: 0),
#  'Ruth Ozeki': Ruth Ozeki (id: ??, ns: 0),
#  'Ruth Prawer Jhabvala': Ruth Prawer Jhabvala (id: ??, ns: 0),
#  'Ruth Rendell': Ruth Rendell (id: ??, ns: 0),
#  'Ruth Scurr': Ruth Scurr (id: ??, ns: 0),
#  'Sabrina (comics)': Sabrina (comics) (id: ??, ns: 0),
#  'Sacred Hunger': Sacred Hunger (id: ??, ns: 0),
#  'Salley Vickers': Salley Vickers (id: ??, ns: 0),
#  'Sally Rooney': Sally Rooney (id: ??, ns: 0),
#  'Salman Rushdie': Salman Rushdie (id: ??, ns: 0),
#  'Salt Publishing': Salt Publishing (id: ??, ns: 0),
#  'Sam Leith': Sam Leith (id: ??, ns: 0),
#  'Sam Thompson (writer)': Sam Thompson (writer) (id: ??, ns: 0),
#  'Samantha Harvey (author)': Samantha Harvey (author) (id: ??, ns: 0),
#  'Sameer Rahim': Sameer Rahim (id: ??, ns: 0),
#  'Samuel Hynes': Samuel Hynes (id: ??, ns: 0),
#  'Saraband (publisher)': Saraband (publisher) (id: ??, ns: 0),
#  'Sarah Bernstein (author)': Sarah Bernstein (author) (id: ??, ns: 0),
#  'Sarah Churchwell': Sarah Churchwell (id: ??, ns: 0),
#  'Sarah Hall (writer)': Sarah Hall (writer) (id: ??, ns: 0),
#  'Sarah Waters': Sarah Waters (id: ??, ns: 0),
#  'Satin Island': Satin Island (id: ??, ns: 0),
#  'Saturday (novel)': Saturday (novel) (id: ??, ns: 0),
#  'Saul Bellow': Saul Bellow (id: ??, ns: 0),
#  'Saville (novel)': Saville (novel) (id: ??, ns: 0),
#  'Scar Tissue (novel)': Scar Tissue (novel) (id: ??, ns: 0),
#  'Sceptre': Sceptre (id: ??, ns: 0),
#  'Sceptre (imprint)': Sceptre (imprint) (id: ??, ns: 0),
#  'Sceptre Press': Sceptre Press (id: ??, ns: 0),
#  "Schindler's Ark": Schindler's Ark (id: ??, ns: 0),
#  "Schopenhauer's Telescope": Schopenhauer's Telescope (id: ??, ns: 0),
#  'Sea of Poppies': Sea of Poppies (id: ??, ns: 0),
#  'Seamus Deane': Seamus Deane (id: ??, ns: 0),
#  'Sebastian Barry': Sebastian Barry (id: ??, ns: 0),
#  'Sebastian Faulks': Sebastian Faulks (id: ??, ns: 0),
#  'Secker & Warburg': Secker & Warburg (id: ??, ns: 0),
#  'Second Place (novel)': Second Place (novel) (id: ??, ns: 0),
#  'Selby Wynn Schwartz': Selby Wynn Schwartz (id: ??, ns: 0),
#  'Self Help (novel)': Self Help (novel) (id: ??, ns: 0),
#  'Selina Hastings (writer)': Selina Hastings (writer) (id: ??, ns: 0),
#  'Seren Books': Seren Books (id: ??, ns: 0),
#  'Serenity House': Serenity House (id: ??, ns: 0),
#  'Serious Sweet': Serious Sweet (id: ??, ns: 0),
#  "Serpent's Tail": Serpent's Tail (id: ??, ns: 0),
#  'Shadows on our Skin': Shadows on our Skin (id: ??, ns: 0),
#  'Shahidha Bari': Shahidha Bari (id: ??, ns: 0),
#  'Shalimar the Clown': Shalimar the Clown (id: ??, ns: 0),
#  'Shame (Rushdie novel)': Shame (Rushdie novel) (id: ??, ns: 0),
#  'Shehan Karunatilaka': Shehan Karunatilaka (id: ??, ns: 0),
#  'Shelf Awareness': Shelf Awareness (id: ??, ns: 0),
#  'Shena Mackay': Shena Mackay (id: ??, ns: 0),
#  'Shirley Hazzard': Shirley Hazzard (id: ??, ns: 0),
#  'Shiva Naipaul': Shiva Naipaul (id: ??, ns: 0),
#  'Shroud (novel)': Shroud (novel) (id: ??, ns: 0),
#  'Shuggie Bain': Shuggie Bain (id: ??, ns: 0),
#  'Silence Among the Weapons': Silence Among the Weapons (id: ??, ns: 0),
#  'Simon & Schuster': Simon & Schuster (id: ??, ns: 0),
#  'Simon Armitage': Simon Armitage (id: ??, ns: 0),
#  'Simon Jenkins': Simon Jenkins (id: ??, ns: 0),
#  'Simon Mawer': Simon Mawer (id: ??, ns: 0),
#  'Sir Alfred Ayer': Sir Alfred Ayer (id: ??, ns: 0),
#  'Siri Hustvedt': Siri Hustvedt (id: ??, ns: 0),
#  'Sixty Lights': Sixty Lights (id: ??, ns: 0),
#  'Siân Hughes': Siân Hughes (id: ??, ns: 0),
#  'Skios': Skios (id: ??, ns: 0),
#  'Skippy Dies': Skippy Dies (id: ??, ns: 0),
#  'Sleeping on Jupiter': Sleeping on Jupiter (id: ??, ns: 0),
#  'Slow Man': Slow Man (id: ??, ns: 0),
#  'Small Things Like These': Small Things Like These (id: ??, ns: 0),
#  'Small World: An Academic Romance': Small World: An Academic Romance (id: ??, ns: 0),
#  'Snowdrops (novel)': Snowdrops (novel) (id: ??, ns: 0),
#  'So Many Ways to Begin': So Many Ways to Begin (id: ??, ns: 0),
#  'Solar Bones': Solar Bones (id: ??, ns: 0),
#  'Solomon Gursky Was Here': Solomon Gursky Was Here (id: ??, ns: 0),
#  'Something Might Happen': Something Might Happen (id: ??, ns: 0),
#  'Something to Answer For': Something to Answer For (id: ??, ns: 0),
#  'Sophie Mackintosh': Sophie Mackintosh (id: ??, ns: 0),
#  'Sophie Ward': Sophie Ward (id: ??, ns: 0),
#  'Sort of Books': Sort of Books (id: ??, ns: 0),
#  'Sour Sweet': Sour Sweet (id: ??, ns: 0),
#  'Spies (novel)': Spies (novel) (id: ??, ns: 0),
#  "St. Urbain's Horseman": St. Urbain's Horseman (id: ??, ns: 0),
#  'Stanley Middleton': Stanley Middleton (id: ??, ns: 0),
#  'Staying On': Staying On (id: ??, ns: 0),
#  'Stella Rimington': Stella Rimington (id: ??, ns: 0),
#  'Stephen Kelman': Stephen Kelman (id: ??, ns: 0),
#  'Stephen Spender': Stephen Spender (id: ??, ns: 0),
#  'Steve Toltz': Steve Toltz (id: ??, ns: 0),
#  'Stevie Davies': Stevie Davies (id: ??, ns: 0),
#  'Stuart Kelly (literary critic)': Stuart Kelly (literary critic) (id: ??, ns: 0),
#  'Study for Obedience': Study for Obedience (id: ??, ns: 0),
#  'Such a Fun Age': Such a Fun Age (id: ??, ns: 0),
#  'Such a Long Journey (novel)': Such a Long Journey (novel) (id: ??, ns: 0),
#  'Sue Perkins': Sue Perkins (id: ??, ns: 0),
#  'Summertime (novel)': Summertime (novel) (id: ??, ns: 0),
#  'Sunjeev Sahota': Sunjeev Sahota (id: ??, ns: 0),
#  'Susan Hill': Susan Hill (id: ??, ns: 0),
#  'Susanna Clarke': Susanna Clarke (id: ??, ns: 0),
#  'Susannah Clapp': Susannah Clapp (id: ??, ns: 0),
#  'Swimming Home': Swimming Home (id: ??, ns: 0),
#  'Swing Time (novel)': Swing Time (novel) (id: ??, ns: 0),
#  'Sybille Bedford': Sybille Bedford (id: ??, ns: 0),
#  'Tan Twan Eng': Tan Twan Eng (id: ??, ns: 0),
#  'Tash Aw': Tash Aw (id: ??, ns: 0),
#  'Ted Rowlands': Ted Rowlands (id: ??, ns: 0),
#  'Terence Kilmartin': Terence Kilmartin (id: ??, ns: 0),
#  'Terence Wheeler': Terence Wheeler (id: ??, ns: 0),
#  'The 27th Kingdom': The 27th Kingdom (id: ??, ns: 0),
#  'The Accidental': The Accidental (id: ??, ns: 0),
#  'The Amber Spyglass': The Amber Spyglass (id: ??, ns: 0),
#  'The Autograph Man': The Autograph Man (id: ??, ns: 0),
#  'The Battle of Pollocks Crossing': The Battle of Pollocks Crossing (id: ??, ns: 0),
#  'The Bay of Noon': The Bay of Noon (id: ??, ns: 0),
#  'The Bee Sting': The Bee Sting (id: ??, ns: 0),
#  'The Beginning of Spring': The Beginning of Spring (id: ??, ns: 0),
#  'The Best of the Booker': The Best of the Booker (id: ??, ns: 0),
#  'The Betrayal (Dunmore novel)': The Betrayal (Dunmore novel) (id: ??, ns: 0),
#  'The Big Chapel': The Big Chapel (id: ??, ns: 0),
#  'The Bird of Night': The Bird of Night (id: ??, ns: 0),
#  'The Birds on the Trees': The Birds on the Trees (id: ??, ns: 0),
#  'The Black Prince (novel)': The Black Prince (novel) (id: ??, ns: 0),
#  'The Blackwater Lightship': The Blackwater Lightship (id: ??, ns: 0),
#  'The Blind Assassin': The Blind Assassin (id: ??, ns: 0),
#  'The Blue Tango': The Blue Tango (id: ??, ns: 0),
#  'The Bone Clocks': The Bone Clocks (id: ??, ns: 0),
#  'The Bone People': The Bone People (id: ??, ns: 0),
#  'The Book and the Brotherhood': The Book and the Brotherhood (id: ??, ns: 0),
#  'The Book of Evidence': The Book of Evidence (id: ??, ns: 0),
#  'The Bookshop': The Bookshop (id: ??, ns: 0),
#  'The Bottle Factory Outing': The Bottle Factory Outing (id: ??, ns: 0),
#  'The Butcher Boy (novel)': The Butcher Boy (novel) (id: ??, ns: 0),
#  'The Chant of Jimmie Blacksmith': The Chant of Jimmie Blacksmith (id: ??, ns: 0),
#  "The Children's Book": The Children's Book (id: ??, ns: 0),
#  'The Children of Dynmouth': The Children of Dynmouth (id: ??, ns: 0),
#  'The Clothes on Their Backs': The Clothes on Their Backs (id: ??, ns: 0),
#  'The Colour of Blood': The Colour of Blood (id: ??, ns: 0),
#  'The Comfort of Strangers': The Comfort of Strangers (id: ??, ns: 0),
#  'The Conjunction': The Conjunction (id: ??, ns: 0),
#  'The Conservationist': The Conservationist (id: ??, ns: 0),
#  'The Curious Incident of the Dog in the Night-Time': The Curious Incident of the Dog in the Night-Time (id: ??, ns: 0),
#  'The Dark Room (Seiffert novel)': The Dark Room (Seiffert novel) (id: ??, ns: 0),
#  'The Death of Vishnu': The Death of Vishnu (id: ??, ns: 0),
#  'The Deposition of Father McGreevy': The Deposition of Father McGreevy (id: ??, ns: 0),
#  "The Doctor's Wife (Brian Moore novel)": The Doctor's Wife (Brian Moore novel) (id: ??, ns: 0),
#  'The Dressmaker (1973 novel)': The Dressmaker (1973 novel) (id: ??, ns: 0),
#  "The Driver's Seat (novel)": The Driver's Seat (novel) (id: ??, ns: 0),
#  'The Elected Member': The Elected Member (id: ??, ns: 0),
#  'The Electric Michelangelo': The Electric Michelangelo (id: ??, ns: 0),
#  'The Element of Water': The Element of Water (id: ??, ns: 0),
#  "The Emperor's Children": The Emperor's Children (id: ??, ns: 0),
#  'The Enchantress of Florence': The Enchantress of Florence (id: ??, ns: 0),
#  'The English Patient': The English Patient (id: ??, ns: 0),
#  'The Essence of the Thing': The Essence of the Thing (id: ??, ns: 0),
#  'The Famished Road': The Famished Road (id: ??, ns: 0),
#  'The Finkler Question': The Finkler Question (id: ??, ns: 0),
#  'The Fishermen (Chigozie Obioma novel)': The Fishermen (Chigozie Obioma novel) (id: ??, ns: 0),
#  'The Folding Star': The Folding Star (id: ??, ns: 0),
#  'The Fortune Men': The Fortune Men (id: ??, ns: 0),
#  'The Garden of Evening Mists': The Garden of Evening Mists (id: ??, ns: 0),
#  'The Gate of Angels': The Gate of Angels (id: ??, ns: 0),
#  'The Gathering (Enright novel)': The Gathering (Enright novel) (id: ??, ns: 0),
#  'The Ghost Road': The Ghost Road (id: ??, ns: 0),
#  'The Gift of Rain': The Gift of Rain (id: ??, ns: 0),
#  'The Glass Room': The Glass Room (id: ??, ns: 0),
#  'The God of Small Things': The God of Small Things (id: ??, ns: 0),
#  'The Golden Man Booker': The Golden Man Booker (id: ??, ns: 0),
#  'The Good Apprentice': The Good Apprentice (id: ??, ns: 0),
#  'The Good Doctor (novel)': The Good Doctor (novel) (id: ??, ns: 0),
#  'The Good Terrorist': The Good Terrorist (id: ??, ns: 0),
#  'The Great Fire (Hazzard novel)': The Great Fire (Hazzard novel) (id: ??, ns: 0),
#  'The Green Road (Enright novel)': The Green Road (Enright novel) (id: ??, ns: 0),
#  'The Guardian': The Guardian (id: ??, ns: 0),
#  'The Hand Reared Boy': The Hand Reared Boy (id: ??, ns: 0),
#  "The Handmaid's Tale": The Handmaid's Tale (id: ??, ns: 0),
#  'The Harmony Silk Factory': The Harmony Silk Factory (id: ??, ns: 0),
#  'The Hiding Place (Azzopardi novel)': The Hiding Place (Azzopardi novel) (id: ??, ns: 0),
#  'The House of Doors': The House of Doors (id: ??, ns: 0),
#  'The Industry of Souls': The Industry of Souls (id: ??, ns: 0),
#  'The Inheritance of Loss': The Inheritance of Loss (id: ??, ns: 0),
#  'The Keepers of Truth': The Keepers of Truth (id: ??, ns: 0),
#  'The Kills (novel)': The Kills (novel) (id: ??, ns: 0),
#  'The Light of Day (Graham Swift novel)': The Light of Day (Graham Swift novel) (id: ??, ns: 0),
#  'The Lighthouse (2012 novel)': The Lighthouse (2012 novel) (id: ??, ns: 0),
#  'The Line of Beauty': The Line of Beauty (id: ??, ns: 0),
#  'The Little Stranger': The Little Stranger (id: ??, ns: 0),
#  'The Lives of Others (novel)': The Lives of Others (novel) (id: ??, ns: 0),
#  'The Long Song': The Long Song (id: ??, ns: 0),
#  'The Long Take': The Long Take (id: ??, ns: 0),
#  'The Lost Dog': The Lost Dog (id: ??, ns: 0),
#  'The Lowland': The Lowland (id: ??, ns: 0),
#  'The Luminaries': The Luminaries (id: ??, ns: 0),
#  'The Many (novel)': The Many (novel) (id: ??, ns: 0),
#  'The Map of Love': The Map of Love (id: ??, ns: 0),
#  'The Mars Room': The Mars Room (id: ??, ns: 0),
#  'The Master (novel)': The Master (novel) (id: ??, ns: 0),
#  'The Ministry of Utmost Happiness': The Ministry of Utmost Happiness (id: ??, ns: 0),
#  'The Mirror and the Light': The Mirror and the Light (id: ??, ns: 0),
#  "The Moor's Account": The Moor's Account (id: ??, ns: 0),
#  ...}

# %%
prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. if multiple cities are mentioned in a novel but the novel is mostly set in one place, then return that place (city and country). \
if a novel is set in many places and not focused on one place, then return NA as your response for city and country. \
if a novel is not set in a real place on earth, for example Duke being set in Arrakis, then return NA as your response for city and country.\
return the name, author, city, and country information as a dictionary with name, author, city, and country as four dictionary keys.\
\Finally, it is possible that the wikipedia article provided is not the wikipedia article for a book. \
Add a fifth dictionary key called is_book and if the text provided seems like the wikipedia article for a book, return True as the value. \
If the wikipedia article is not that of a book, return False as the value for is_book. In this case, return NA for all other values.\
Do not return any text other than the dictionary in your response. Do not make a human readable sentence. \
Here is the text of the wikipedia article for which you will return a dictionary: "

reminder_text = " Remember, your task is to return a python dictionary with keys name, author, city, country, and is_book. \
Do not return any text other than the dictionary. An example of legitimate output is: \
{'name': 'The House of Doors', 'author': 'Tan Twan Eng', 'city': 'Penang', 'country': 'Malaysia', 'is_Book': True} \
DO NOT RETURN ANY TEXT OTHER THAN THE DICTIONARY"

llm(prompt + wiki_wiki.page("Shuggie_Bain").text)
# Out:
# 'Based on the information provided, here are some awards and nominations for "Shuggie Bain":\n\n* Longlisted for the 2021 Andrew Carnegie Medal for Excellence in Fiction\n* Shortlisted for the 2020 Center for Fiction First Novel Prize\n* Finalist for the 2020 Kirkus Prize\n* Finalist for the 2020 National Book Award for Fiction\n* Winner of the 2020 Booker Prize\n\nAdditionally, "Shuggie Bain" was included on several lists of best books of 2020, including:\n\n* The Telegraph\'s list of 50 best books of 2020\n* The Times\' list of best novels of 2020\n* Kirkus Reviews\' list of best books of 2020\n* Vogue and Elle\'s lists of best books of 2020\n\nIt was also named as one of the best books of the year by several other publications, including The New York Times, The Washington Post, Time, and the BBC.'

# %% [markdown]
# ### pre-parse book status?
#
# tried using

# %%
# ok the check book part fails when we include it in the summarization. maybe doing a two step filter is better
# step one check if it's a book 

check_book_prompt = "based on the text of the wikipedia article provided, tell me if the wikipedia article is a book or not. \
return your response as a python dictionary with key is_book, and value True or False. \
Do not return any text other than the dictionary in your response. Do not make a human readable sentence. \
Here is the text of the wikipedia article for which you will return a dictionary: "

# %%
llm(check_book_prompt + test_wiki.text)

# it's not working...let's parse the output like this
# https://www.gettingstarted.ai/how-to-langchain-output-parsers-convert-text-to-objects/
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~/.pyenv/versions/3.9.5/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:953, in getaddrinfo(host, port, family, type, proto, flags)
#     952 addrlist = []
# --> 953 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connection.py:210, in HTTPConnection._new_conn(self)
#     209 except socket.gaierror as e:
# --> 210     raise NameResolutionError(self.host, self, e) from e
#     211 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x112c644c0>: Failed to resolve 'en.wikipedia.org' ([Errno 8] nodename nor servname provided, or not known)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?action=query&prop=extracts&titles=Dune&explaintext=1&exsectionformat=wiki&format=json&redirects=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x112c644c0>: Failed to resolve 'en.wikipedia.org' ([Errno 8] nodename nor servname provided, or not known)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 llm(check_book_prompt + test_wiki.text)
#       3 # it's not working...let's parse the output like this
#       4 # https://www.gettingstarted.ai/how-to-langchain-output-parsers-convert-text-to-objects/
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/wikipediaapi/__init__.py:975, in WikipediaPage.text(self)
#     968 @property
#     969 def text(self) -> str:
#     970     """
#     971     Returns text of the current page.
#     972
#     973     :return: text of the current page
#     974     """
# --> 975     txt = self.summary
#     976     if len(txt) > 0:
#     977         txt += "\n\n"
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/wikipediaapi/__init__.py:920, in WikipediaPage.summary(self)
#     914 """
#     915 Returns summary of the current page.
#     916
#     917 :return: summary
#     918 """
#     919 if not self._called["extracts"]:
# --> 920     self._fetch("extracts")
#     921 return self._summary
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/wikipediaapi/__init__.py:1064, in WikipediaPage._fetch(self, call)
#    1062 def _fetch(self, call) -> "WikipediaPage":
#    1063     """Fetches some data?."""
# -> 1064     getattr(self.wiki, call)(self)
#    1065     self._called[call] = True
#    1066     return self
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/wikipediaapi/__init__.py:297, in Wikipedia.extracts(self, page, **kwargs)
#     294 used_params = kwargs
#     295 used_params.update(params)
# --> 297 raw = self._query(page, used_params)
#     298 self._common_attributes(raw["query"], page)
#     299 pages = raw["query"]["pages"]
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/wikipediaapi/__init__.py:528, in Wikipedia._query(self, page, params)
#     526 params["format"] = "json"
#     527 params["redirects"] = 1
# --> 528 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     529 return r.json()
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?action=query&prop=extracts&titles=Dune&explaintext=1&exsectionformat=wiki&format=json&redirects=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x112c644c0>: Failed to resolve 'en.wikipedia.org' ([Errno 8] nodename nor servname provided, or not known)"))

# %% [markdown]
# ### just figuring out how to return as json

# %%
from typing import List

from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field, validator

# %%
# Define your desired data structure.
class Joke(BaseModel):
    setup: str = Field(description="question to set up a joke")
    punchline: str = Field(description="answer to resolve the joke")

    # You can add custom validation logic easily with Pydantic.
    @validator("setup")
    def question_ends_with_question_mark(cls, field):
        if field[-1] != "?":
            raise ValueError("Badly formed question!")
        return field


# And a query intented to prompt a language model to populate the data structure.
joke_query = "Tell me a joke."

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=Joke)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser

chain.invoke({"query": joke_query})
# Out:
# Joke(setup="Why don't scientists trust atoms?", punchline='Because they make up everything!')

# %%
class Book(BaseModel):
    name: str = Field(description="name of the novel")
    author: str = Field(description="name of the author")
    city: str = Field(description="the city it is most focused on or set in")
    country: str = Field(description="the country it is most focused on or set in")



# And a query intented to prompt a language model to populate the data structure.

writing_prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. \
Here is the text of the wikipedia article: "

book_query = writing_prompt + p_wiki.text

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=Book)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser

chain.invoke({"query": book_query})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:35, in PydanticOutputParser._parse_obj(self, obj)
#      34 elif issubclass(self.pydantic_object, pydantic.v1.BaseModel):
# ---> 35     return self.pydantic_object.parse_obj(obj)
#      36 else:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:526, in BaseModel.parse_obj(cls, obj)
#     525         raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526 return cls(**obj)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#
# ValidationError: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[58], line 29
#      21 prompt = PromptTemplate(
#      22     template="Answer the user query.\n{format_instructions}\n{query}\n",
#      23     input_variables=["query"],
#      24     partial_variables={"format_instructions": parser.get_format_instructions()},
#      25 )
#      27 chain = prompt | llm | parser
# ---> 29 chain.invoke({"query": book_query})
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:2499, in invoke(self, input, config)
#    2494 try:
#    2495     if return_exceptions:
#    2496         # Track which inputs (by index) failed so far
#    2497         # If an input has failed it will be present in this map,
#    2498         # and the value will be the exception that was raised.
# -> 2499         failed_inputs_map: Dict[int, Exception] = {}
#    2500         for stepidx, step in enumerate(self.steps):
#    2501             # Assemble the original indexes of the remaining inputs
#    2502             # (i.e. the ones that haven't failed yet)
#    2503             remaining_idxs = [
#    2504                 i for i in range(len(configs)) if i not in failed_inputs_map
#    2505             ]
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:178, in BaseOutputParser.invoke(self, input, config)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:1626, in _call_with_config(self, func, input, config, run_type, **kwargs)
#    1624 else:
#    1625     first_exception: Optional[Exception] = None
# -> 1626     for run_manager, out in zip(run_managers, output):
#    1627         if isinstance(out, Exception):
#    1628             first_exception = first_exception or out
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     330 def call_func_with_variable_args(
#     331     func: Union[
#     332         Callable[[Input], Output],
#    (...)
#     340     **kwargs: Any,
#     341 ) -> Output:
#     342     """Call function that may optionally accept a run_manager and/or config.
#     343
#     344     Args:
#     345         func (Union[Callable[[Input], Output],
#     346           Callable[[Input, CallbackManagerForChainRun], Output],
# --> 347           Callable[[Input, CallbackManagerForChainRun, RunnableConfig], Output]]):
#     348            The function to call.
#     349         input (Input): The input to the function.
#     350         run_manager (CallbackManagerForChainRun): The run manager to
#     351           pass to the function.
#     352         config (RunnableConfig): The config to pass to the function.
#     353         **kwargs (Any): The keyword arguments to pass to the function.
#     354
#     355     Returns:
#     356         Output: The output of the function.
#     357     """
#     358     if accepts_config(func):
#     359         if run_manager is not None:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:61, in PydanticOutputParser.parse_result(self, result, partial)
#      57 def parse_result(
#      58     self, result: List[Generation], *, partial: bool = False
#      59 ) -> TBaseModel:
#      60     json_object = super().parse_result(result)
# ---> 61     return self._parse_obj(json_object)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:42, in PydanticOutputParser._parse_obj(self, obj)
#      37             raise OutputParserException(
#      38                 f"Unsupported model version for PydanticOutputParser: \
#      39                     {self.pydantic_object.__class__}"
#      40             )
#      41     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 42         raise self._parser_exception(e, obj)
#      43 else:  # pydantic v1
#      44     try:
#
# OutputParserException: Failed to parse Book from completion {"properties": {"name": {"title": "Name", "description": "name of the novel", "type": "string"}, "author": {"title": "Author", "description": "name of the author", "type": "string"}, "city": {"title": "City", "description": "the city it is most focused on or set in", "type": "string"}, "country": {"title": "Country", "description": "the country it is most focused on or set in", "type": "string"}}, "required": ["name", "author", "city", "country"]}. Got: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)

# %%
class Book(BaseModel):
    name: str = Field(description="name of the novel")
    author: str = Field(description="name of the author")
    city: str = Field(description="the city it is most focused on or set in")
    country: str = Field(description="the country it is most focused on or set in")



# And a query intented to prompt a language model to populate the data structure.

writing_prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. \
Here is the text of the wikipedia article: "

book_query = writing_prompt + p_wiki.text

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=Book)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser

chain.invoke({"query": book_query})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:35, in PydanticOutputParser._parse_obj(self, obj)
#      34 elif issubclass(self.pydantic_object, pydantic.v1.BaseModel):
# ---> 35     return self.pydantic_object.parse_obj(obj)
#      36 else:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:526, in BaseModel.parse_obj(cls, obj)
#     525         raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526 return cls(**obj)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#
# ValidationError: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[56], line 29
#      21 prompt = PromptTemplate(
#      22     template="Answer the user query.\n{format_instructions}\n{query}\n",
#      23     input_variables=["query"],
#      24     partial_variables={"format_instructions": parser.get_format_instructions()},
#      25 )
#      27 chain = prompt | llm | parser
# ---> 29 chain.invoke({"query": book_query})
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:2499, in invoke(self, input, config)
#    2494 try:
#    2495     if return_exceptions:
#    2496         # Track which inputs (by index) failed so far
#    2497         # If an input has failed it will be present in this map,
#    2498         # and the value will be the exception that was raised.
# -> 2499         failed_inputs_map: Dict[int, Exception] = {}
#    2500         for stepidx, step in enumerate(self.steps):
#    2501             # Assemble the original indexes of the remaining inputs
#    2502             # (i.e. the ones that haven't failed yet)
#    2503             remaining_idxs = [
#    2504                 i for i in range(len(configs)) if i not in failed_inputs_map
#    2505             ]
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:178, in BaseOutputParser.invoke(self, input, config)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:1626, in _call_with_config(self, func, input, config, run_type, **kwargs)
#    1624 else:
#    1625     first_exception: Optional[Exception] = None
# -> 1626     for run_manager, out in zip(run_managers, output):
#    1627         if isinstance(out, Exception):
#    1628             first_exception = first_exception or out
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     330 def call_func_with_variable_args(
#     331     func: Union[
#     332         Callable[[Input], Output],
#    (...)
#     340     **kwargs: Any,
#     341 ) -> Output:
#     342     """Call function that may optionally accept a run_manager and/or config.
#     343
#     344     Args:
#     345         func (Union[Callable[[Input], Output],
#     346           Callable[[Input, CallbackManagerForChainRun], Output],
# --> 347           Callable[[Input, CallbackManagerForChainRun, RunnableConfig], Output]]):
#     348            The function to call.
#     349         input (Input): The input to the function.
#     350         run_manager (CallbackManagerForChainRun): The run manager to
#     351           pass to the function.
#     352         config (RunnableConfig): The config to pass to the function.
#     353         **kwargs (Any): The keyword arguments to pass to the function.
#     354
#     355     Returns:
#     356         Output: The output of the function.
#     357     """
#     358     if accepts_config(func):
#     359         if run_manager is not None:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:61, in PydanticOutputParser.parse_result(self, result, partial)
#      57 def parse_result(
#      58     self, result: List[Generation], *, partial: bool = False
#      59 ) -> TBaseModel:
#      60     json_object = super().parse_result(result)
# ---> 61     return self._parse_obj(json_object)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:42, in PydanticOutputParser._parse_obj(self, obj)
#      37             raise OutputParserException(
#      38                 f"Unsupported model version for PydanticOutputParser: \
#      39                     {self.pydantic_object.__class__}"
#      40             )
#      41     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 42         raise self._parser_exception(e, obj)
#      43 else:  # pydantic v1
#      44     try:
#
# OutputParserException: Failed to parse Book from completion {"properties": {"name": {"title": "Name", "description": "name of the novel", "type": "string"}, "author": {"title": "Author", "description": "name of the author", "type": "string"}, "city": {"title": "City", "description": "the city it is most focused on or set in", "type": "string"}, "country": {"title": "Country", "description": "the country it is most focused on or set in", "type": "string"}}, "required": ["name", "author", "city", "country"]}. Got: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)

# %%
class Book(BaseModel):
    name: str = Field(description="name of the novel")
    author: str = Field(description="name of the author")
    city: str = Field(description="the city it is most focused on or set in")
    country: str = Field(description="the country it is most focused on or set in")



# And a query intented to prompt a language model to populate the data structure.

writing_prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. If the article is not for a book, or the book is not set on a real city or country on Earth, you can use NaN as a response. \
Here is the text of the wikipedia article: "

book_query = writing_prompt + test_wiki.text

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=Book)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser

chain.invoke({"query": book_query})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:35, in PydanticOutputParser._parse_obj(self, obj)
#      34 elif issubclass(self.pydantic_object, pydantic.v1.BaseModel):
# ---> 35     return self.pydantic_object.parse_obj(obj)
#      36 else:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:526, in BaseModel.parse_obj(cls, obj)
#     525         raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526 return cls(**obj)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#
# ValidationError: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[53], line 29
#      21 prompt = PromptTemplate(
#      22     template="Answer the user query.\n{format_instructions}\n{query}\n",
#      23     input_variables=["query"],
#      24     partial_variables={"format_instructions": parser.get_format_instructions()},
#      25 )
#      27 chain = prompt | llm | parser
# ---> 29 chain.invoke({"query": book_query})
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:2499, in invoke(self, input, config)
#    2494 try:
#    2495     if return_exceptions:
#    2496         # Track which inputs (by index) failed so far
#    2497         # If an input has failed it will be present in this map,
#    2498         # and the value will be the exception that was raised.
# -> 2499         failed_inputs_map: Dict[int, Exception] = {}
#    2500         for stepidx, step in enumerate(self.steps):
#    2501             # Assemble the original indexes of the remaining inputs
#    2502             # (i.e. the ones that haven't failed yet)
#    2503             remaining_idxs = [
#    2504                 i for i in range(len(configs)) if i not in failed_inputs_map
#    2505             ]
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:178, in BaseOutputParser.invoke(self, input, config)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:1626, in _call_with_config(self, func, input, config, run_type, **kwargs)
#    1624 else:
#    1625     first_exception: Optional[Exception] = None
# -> 1626     for run_manager, out in zip(run_managers, output):
#    1627         if isinstance(out, Exception):
#    1628             first_exception = first_exception or out
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     330 def call_func_with_variable_args(
#     331     func: Union[
#     332         Callable[[Input], Output],
#    (...)
#     340     **kwargs: Any,
#     341 ) -> Output:
#     342     """Call function that may optionally accept a run_manager and/or config.
#     343
#     344     Args:
#     345         func (Union[Callable[[Input], Output],
#     346           Callable[[Input, CallbackManagerForChainRun], Output],
# --> 347           Callable[[Input, CallbackManagerForChainRun, RunnableConfig], Output]]):
#     348            The function to call.
#     349         input (Input): The input to the function.
#     350         run_manager (CallbackManagerForChainRun): The run manager to
#     351           pass to the function.
#     352         config (RunnableConfig): The config to pass to the function.
#     353         **kwargs (Any): The keyword arguments to pass to the function.
#     354
#     355     Returns:
#     356         Output: The output of the function.
#     357     """
#     358     if accepts_config(func):
#     359         if run_manager is not None:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:61, in PydanticOutputParser.parse_result(self, result, partial)
#      57 def parse_result(
#      58     self, result: List[Generation], *, partial: bool = False
#      59 ) -> TBaseModel:
#      60     json_object = super().parse_result(result)
# ---> 61     return self._parse_obj(json_object)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:42, in PydanticOutputParser._parse_obj(self, obj)
#      37             raise OutputParserException(
#      38                 f"Unsupported model version for PydanticOutputParser: \
#      39                     {self.pydantic_object.__class__}"
#      40             )
#      41     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 42         raise self._parser_exception(e, obj)
#      43 else:  # pydantic v1
#      44     try:
#
# OutputParserException: Failed to parse Book from completion {"answer": [{"title": "Tales from the Twilight World", "inspiration_source": "Paul Atreides' visions of future and past"}, {"title": "Fear is The Mindkiller", "inspiration_source": "litany against fear"}, {"title": "Near Fantastica", "inspiration_source": "Frank Herbert's Dune series"}, {"title": "Dune and Philosophy", "edits": [{"name": "Kevin S. Decker"}, {"name": "Dominic J. Nardi"}]}, {"title": "The Wisdom of the Sand: Philosophy and Frank Herbert's Dune", "author": "Kevin C. Williams"}], "related": [{"url": "https://www.litweb.net"}, {"url": "https://www.tor.com"}, {"url": "https://www.nautilus.org"}]}. Got: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)

# %%
class Book(BaseModel):
    name: str = Field(description="name of the novel")
    author: str = Field(description="name of the author")
    city: str = Field(description="the city it is most focused on or set in")
    country: str = Field(description="the country it is most focused on or set in")



# And a query intented to prompt a language model to populate the data structure.

writing_prompt = "I am building a database of novels set in different cities and countries on Earth. Based on the wikipedia article for this novel \
tell me the name of the novel, the name of the author, the city it is most focused on or set in, and the country it is most focused on or \
set in. If the article is not for a book, or the book is not set on a real city or country on Earth, you can use NaN as a response. \
Here is the text of the wikipedia article: "

book_query = writing_prompt + p_wiki.text

# Set up a parser + inject instructions into the prompt template.
parser = PydanticOutputParser(pydantic_object=Book)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser

chain.invoke({"query": book_query})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:35, in PydanticOutputParser._parse_obj(self, obj)
#      34 elif issubclass(self.pydantic_object, pydantic.v1.BaseModel):
# ---> 35     return self.pydantic_object.parse_obj(obj)
#      36 else:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:526, in BaseModel.parse_obj(cls, obj)
#     525         raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526 return cls(**obj)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#
# ValidationError: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[55], line 29
#      21 prompt = PromptTemplate(
#      22     template="Answer the user query.\n{format_instructions}\n{query}\n",
#      23     input_variables=["query"],
#      24     partial_variables={"format_instructions": parser.get_format_instructions()},
#      25 )
#      27 chain = prompt | llm | parser
# ---> 29 chain.invoke({"query": book_query})
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:2499, in invoke(self, input, config)
#    2494 try:
#    2495     if return_exceptions:
#    2496         # Track which inputs (by index) failed so far
#    2497         # If an input has failed it will be present in this map,
#    2498         # and the value will be the exception that was raised.
# -> 2499         failed_inputs_map: Dict[int, Exception] = {}
#    2500         for stepidx, step in enumerate(self.steps):
#    2501             # Assemble the original indexes of the remaining inputs
#    2502             # (i.e. the ones that haven't failed yet)
#    2503             remaining_idxs = [
#    2504                 i for i in range(len(configs)) if i not in failed_inputs_map
#    2505             ]
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:178, in BaseOutputParser.invoke(self, input, config)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/base.py:1626, in _call_with_config(self, func, input, config, run_type, **kwargs)
#    1624 else:
#    1625     first_exception: Optional[Exception] = None
# -> 1626     for run_manager, out in zip(run_managers, output):
#    1627         if isinstance(out, Exception):
#    1628             first_exception = first_exception or out
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     330 def call_func_with_variable_args(
#     331     func: Union[
#     332         Callable[[Input], Output],
#    (...)
#     340     **kwargs: Any,
#     341 ) -> Output:
#     342     """Call function that may optionally accept a run_manager and/or config.
#     343
#     344     Args:
#     345         func (Union[Callable[[Input], Output],
#     346           Callable[[Input, CallbackManagerForChainRun], Output],
# --> 347           Callable[[Input, CallbackManagerForChainRun, RunnableConfig], Output]]):
#     348            The function to call.
#     349         input (Input): The input to the function.
#     350         run_manager (CallbackManagerForChainRun): The run manager to
#     351           pass to the function.
#     352         config (RunnableConfig): The config to pass to the function.
#     353         **kwargs (Any): The keyword arguments to pass to the function.
#     354
#     355     Returns:
#     356         Output: The output of the function.
#     357     """
#     358     if accepts_config(func):
#     359         if run_manager is not None:
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:61, in PydanticOutputParser.parse_result(self, result, partial)
#      57 def parse_result(
#      58     self, result: List[Generation], *, partial: bool = False
#      59 ) -> TBaseModel:
#      60     json_object = super().parse_result(result)
# ---> 61     return self._parse_obj(json_object)
#
# File ~/.pyenv/versions/3.9.5/envs/workshop/lib/python3.9/site-packages/langchain_core/output_parsers/pydantic.py:42, in PydanticOutputParser._parse_obj(self, obj)
#      37             raise OutputParserException(
#      38                 f"Unsupported model version for PydanticOutputParser: \
#      39                     {self.pydantic_object.__class__}"
#      40             )
#      41     except (pydantic.ValidationError, pydantic.v1.ValidationError) as e:
# ---> 42         raise self._parser_exception(e, obj)
#      43 else:  # pydantic v1
#      44     try:
#
# OutputParserException: Failed to parse Book from completion {"properties": {"name": {"title": "Name", "description": "name of the novel", "type": "string"}, "author": {"title": "Author", "description": "name of the author", "type": "string"}, "city": {"title": "City", "description": "the city it is most focused on or set in", "type": "string"}, "country": {"title": "Country", "description": "the country it is most focused on or set in", "type": "string"}}, "required": ["name", "author", "city", "country"]}. Got: 4 validation errors for Book
# name
#   field required (type=value_error.missing)
# author
#   field required (type=value_error.missing)
# city
#   field required (type=value_error.missing)
# country
#   field required (type=value_error.missing)

# %%
from pydantic import BaseModel, Field

# %%
parser = PydanticOutputParser(pydantic_object=Book)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 parser = PydanticOutputParser(pydantic_object=Book)
#
# NameError: name 'PydanticOutputParser' is not defined

# %%
prompt = PromptTemplate(
    template=reservation_template,
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# %% [markdown]
# ### wiki stuff

# %%
p_wiki.categories
# Out:
# {'Category:2023 novels': Category:2023 novels (id: ??, ns: 14),
#  'Category:Articles with short description': Category:Articles with short description (id: ??, ns: 14),
#  'Category:Historical novels': Category:Historical novels (id: ??, ns: 14),
#  'Category:Malaysian novels': Category:Malaysian novels (id: ??, ns: 14),
#  'Category:Novels about writers': Category:Novels about writers (id: ??, ns: 14),
#  'Category:Novels set in Malaysia': Category:Novels set in Malaysia (id: ??, ns: 14),
#  'Category:Novels set in the 1920s': Category:Novels set in the 1920s (id: ??, ns: 14),
#  'Category:Short description matches Wikidata': Category:Short description matches Wikidata (id: ??, ns: 14),
#  'Category:Use mdy dates from November 2023': Category:Use mdy dates from November 2023 (id: ??, ns: 14)}

# %%
list(p_wiki.links.keys())
# Out:
# ['2023 Booker Prize',
#  'Bloomsbury Publishing',
#  'Booker Prize',
#  'Ethel Proudlock case',
#  'Federated Malay States',
#  'First World War',
#  'Gerald Haxton',
#  'ISBN (identifier)',
#  'NPR',
#  'Penang',
#  'Sun Yat-sen',
#  'Tan Twan Eng',
#  'The Financial Times',
#  'The Guardian',
#  'The Washington Post',
#  'William Somerset Maugham',
#  'Category:Use mdy dates from November 2023']

# %%
test_wiki = wiki_wiki.page(list(p_wiki.links.keys())[-1])

# %%
test_wiki.text
# Out:
# 'Wikipedia articles (tagged in this month) that use mm dd yyyy date formats, whether by application of the first main contributor rule or by virtue of close national ties to the subject belong in this category. Use {{Use mdy dates}} to add an article to this category. See MOS:DATE.\nThis system of tagging or categorisation is used as a status monitor of all articles that use mm dd yyyy date formats, and not as a clean up.'

# %% [markdown]
# ### next data scraping steps
#
# ok let's start by acquiring our lists of books. we then need to actually check that these are books

# %%
# ok one downstream task is to acquire the author of a book and then acquire the nationality of that author. 
# could use the llm to first generate the list of authors
